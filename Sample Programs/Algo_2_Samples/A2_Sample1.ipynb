# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import time
import os
import json

class NSEStockIndexAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_index_analysis'
        self.results_dir = os.path.join(self.base_dir, 'index_results')
        os.makedirs(self.results_dir, exist_ok=True)
        
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'
        }
        self.session = requests.Session()
        self.session.get("http://nseindia.com", headers=self.headers)
        
        # List of indices to analyze
        self.equity_market_categories = [
            'NIFTY 50', 'NIFTY ENERGY', 'NIFTY MIDCAP 50', 'NIFTY SMALLCAP 50', 'NIFTY AUTO', 'NIFTY BANK', 'NIFTY FINANCIAL SERVICES', 'NIFTY FMCG', 'NIFTY IT', 'NIFTY MEDIA', 'NIFTY METAL', 'NIFTY PHARMA', 'NIFTY PSU BANK', 'NIFTY REALTY', 'NIFTY PRIVATE BANK', 'NIFTY INFRASTRUCTURE', 'NIFTY MNC', 'NIFTY PSE'," NIFTY CONSUMER DURABLES"]

    def equity_market_data(self, category, symbol_list=False):
        """
        Retrieve stock data for a specific index using NSE API
        
        Args:
            category (str): Index name
            symbol_list (bool): If True, return only list of symbols
        
        Returns:
            list or DataFrame: Stocks in the specified index
        """
        try:
            category = category.upper().replace(' ', '%20').replace('&', '%26')
            response = self.session.get(
                f"https://www.nseindia.com/api/equity-stockIndices?index={category}", 
                headers=self.headers
            )
            
            if response.status_code != 200:
                print(f"Error fetching data for {category}: HTTP {response.status_code}")
                return []
            
            data = response.json()["data"]
            df = pd.DataFrame(data)
            df = df.drop(["meta"], axis=1)
            df = df.set_index("symbol", drop=True)
            
            if symbol_list:
                return list(df.index)
            else:
                return df
        
        except Exception as e:
            print(f"Error retrieving stocks for {category}: {e}")
            return []

    def calculate_rsi(self, prices_tuple, periods=14):
        """RSI calculation method"""
        try:
            prices = pd.Series(prices_tuple)
            
            if len(prices) < periods + 1:
                return None
                
            # Calculate price changes
            delta = prices.diff()
            
            # Split gains and losses
            gains = delta.copy()
            losses = delta.copy()
            
            gains[gains < 0] = 0
            losses[losses > 0] = 0
            losses = abs(losses)
            
            # Calculate initial averages
            first_avg_gain = gains[:periods+1].mean()
            first_avg_loss = losses[:periods+1].mean()
            
            avg_gains = [first_avg_gain]
            avg_losses = [first_avg_loss]
            
            # Calculate subsequent values
            for i in range(periods+1, len(gains)):
                avg_gain = (avg_gains[-1] * (periods-1) + gains[i]) / periods
                avg_loss = (avg_losses[-1] * (periods-1) + losses[i]) / periods
                avg_gains.append(avg_gain)
                avg_losses.append(avg_loss)
            
            # Calculate final RSI
            if avg_losses[-1] == 0:
                rsi = 100.0
            else:
                rs = avg_gains[-1] / avg_losses[-1]
                rsi = 100 - (100 / (1 + rs))
            
            return float(rsi)
            
        except Exception as e:
            print(f"Error calculating RSI: {e}")
            return None

    def get_stock_data(self, symbol):
        """Fetch detailed stock data"""
        try:
            time.sleep(1)  # Rate limiting
            ticker = yf.Ticker(f"{symbol}.NS")
            
            # Get stock info
            info = ticker.info
            
            # Get historical data
            hist_data = ticker.history(period="1y", interval="1d")

            if hist_data.empty:
                return None

            # Calculate basic metrics
            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            
            latest_rsi = self.calculate_rsi(prices_tuple)
            
            # Prepare stock information dictionary
            stock_info = {
                'Symbol': symbol,
                'Latest_Price': round(latest_price, 2),
                'RSI': round(latest_rsi, 2) if latest_rsi is not None else 'N/A',
                'Market_Cap': info.get('marketCap', 'N/A'),
                'Sector': info.get('sector', 'N/A'),
                'Industry': info.get('industry', 'N/A'),
                'PE_Ratio': round(info.get('trailingPE', 'N/A'), 2) if isinstance(info.get('trailingPE'), (int, float)) else 'N/A',
                '52W_High': round(info.get('fiftyTwoWeekHigh', 'N/A'), 2) if isinstance(info.get('fiftyTwoWeekHigh'), (int, float)) else 'N/A',
                '52W_Low': round(info.get('fiftyTwoWeekLow', 'N/A'), 2) if isinstance(info.get('fiftyTwoWeekLow'), (int, float)) else 'N/A',
                'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 'N/A'
            }
            
            return stock_info

        except Exception as e:
            print(f"Error processing {symbol}: {e}")
            return None

    def analyze_indices_stocks(self):
        """Analyze stocks for each index and generate Excel report"""
        # Timestamp for unique filename
        current_date = datetime.now().strftime('%Y%m%d_%H%M%S')
        excel_file = os.path.join(self.results_dir, f'index_stocks_analysis_{current_date}.xlsx')
        
        # Prepare Excel writer
        with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
            for index_category in self.equity_market_categories:
                try:
                    # Get stocks for this index
                    stocks = self.equity_market_data(index_category, symbol_list=True)
                    
                    # Process stocks for this index
                    results = []
                    for symbol in stocks:
                        stock_data = self.get_stock_data(symbol)
                        if stock_data:
                            results.append(stock_data)
                    
                    # Convert to DataFrame
                    if results:
                        df = pd.DataFrame(results)
                        
                        # Write to Excel sheet named after the index
                        sheet_name = index_category[:31]  # Excel sheet names limited to 31 chars
                        df.to_excel(writer, sheet_name=sheet_name, index=False)
                        
                        print(f"Processed {len(results)} stocks for {index_category}")
                
                except Exception as e:
                    print(f"Error processing {index_category}: {e}")
        
        print(f"\nAnalysis complete. Results saved to {excel_file}")

if __name__ == "__main__":
    analyzer = NSEStockIndexAnalyzer()
    analyzer.analyze_indices_stocks()

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import time
import os
import json

class NSEStockIndexAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_index_analysis'
        self.results_dir = os.path.join(self.base_dir, 'index_results')
        os.makedirs(self.results_dir, exist_ok=True)
        
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'
        }
        self.session = requests.Session()
        self.session.get("http://nseindia.com", headers=self.headers)
        
        # List of indices to analyze
        self.equity_market_categories = [
            'NIFTY 50', 'NIFTY ENERGY', 'NIFTY MIDCAP 50', 'NIFTY SMALLCAP 50', 'NIFTY AUTO', 'NIFTY BANK', 'NIFTY FINANCIAL SERVICES', 'NIFTY FMCG', 'NIFTY IT', 'NIFTY MEDIA', 'NIFTY METAL', 'NIFTY PHARMA', 'NIFTY PSU BANK', 'NIFTY REALTY', 'NIFTY PRIVATE BANK', 'NIFTY INFRASTRUCTURE', 'NIFTY MNC', 'NIFTY PSE', 'NIFTY CONSUMER DURABLES']

    def equity_market_data(self, category, symbol_list=False):
        """
        Retrieve stock data for a specific index using NSE API
        
        Args:
            category (str): Index name
            symbol_list (bool): If True, return only list of symbols
        
        Returns:
            list or DataFrame: Stocks in the specified index
        """
        try:
            category = category.upper().replace(' ', '%20').replace('&', '%26')
            response = self.session.get(
                f"https://www.nseindia.com/api/equity-stockIndices?index={category}", 
                headers=self.headers
            )
            
            if response.status_code != 200:
                print(f"Error fetching data for {category}: HTTP {response.status_code}")
                return []
            
            data = response.json()["data"]
            df = pd.DataFrame(data)
            df = df.drop(["meta"], axis=1)
            df = df.drop(df.index[0])
            df = df.set_index("symbol", drop=True)
            
            if symbol_list:
                return list(df.index)
            else:
                return df
        
        except Exception as e:
            print(f"Error retrieving stocks for {category}: {e}")
            return []

    def calculate_rsi(self, prices_tuple, periods=14):
        """RSI calculation method"""
        try:
            prices = pd.Series(prices_tuple)
            
            if len(prices) < periods + 1:
                return None
                
            # Calculate price changes
            delta = prices.diff()
            
            # Split gains and losses
            gains = delta.copy()
            losses = delta.copy()
            
            gains[gains < 0] = 0
            losses[losses > 0] = 0
            losses = abs(losses)
            
            # Calculate initial averages
            first_avg_gain = gains[:periods+1].mean()
            first_avg_loss = losses[:periods+1].mean()
            
            avg_gains = [first_avg_gain]
            avg_losses = [first_avg_loss]
            
            # Calculate subsequent values
            for i in range(periods+1, len(gains)):
                avg_gain = (avg_gains[-1] * (periods-1) + gains[i]) / periods
                avg_loss = (avg_losses[-1] * (periods-1) + losses[i]) / periods
                avg_gains.append(avg_gain)
                avg_losses.append(avg_loss)
            
            # Calculate final RSI
            if avg_losses[-1] == 0:
                rsi = 100.0
            else:
                rs = avg_gains[-1] / avg_losses[-1]
                rsi = 100 - (100 / (1 + rs))
            
            return float(rsi)
            
        except Exception as e:
            print(f"Error calculating RSI: {e}")
            return None

    def calculate_tema(self, prices, period=50):
        """
        Calculate Triple Exponential Moving Average (TEMA)
        
        Args:
            prices (pd.Series): Price series
            period (int): Period for TEMA calculation
        
        Returns:
            float: TEMA value
        """
        try:
            if len(prices) < period:
                return None
            
            # Calculate EMAs
            ema1 = prices.ewm(span=period, adjust=False).mean()
            ema2 = ema1.ewm(span=period, adjust=False).mean()
            ema3 = ema2.ewm(span=period, adjust=False).mean()
            
            # TEMA Formula: TEMA = 3 * EMA1 - 3 * EMA2 + EMA3
            tema = 3 * ema1.iloc[-1] - 3 * ema2.iloc[-1] + ema3.iloc[-1]
            
            return float(tema)
        
        except Exception as e:
            print(f"Error calculating TEMA: {e}")
            return None

    def get_stock_data(self, symbol):
        """Fetch detailed stock data"""
        try:
            time.sleep(1)  # Rate limiting
            ticker = yf.Ticker(f"{symbol}.NS")
            
            # Get stock info
            info = ticker.info
            
            # Get historical data for 1 year
            hist_data = ticker.history(period="1y", interval="1d")

            # Check if 1 year data is available, else get maximum available data
            if hist_data.empty:
                hist_data = ticker.history(period="max", interval="1d")
                if hist_data.empty:
                    return None

            # Calculate basic metrics
            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            
            # Calculate indicators
            latest_rsi = self.calculate_rsi(prices_tuple)
            
            # Calculate EMA-50 and TEMA-50
            prices_series = hist_data['Close']
            ema_50 = prices_series.ewm(span=50, adjust=False).mean().iloc[-1]
            tema_50 = self.calculate_tema(prices_series)
            
            # Prepare stock information dictionary
            stock_info = {
                'Symbol': symbol,
                'Latest_Price': round(latest_price, 2),
                'RSI': round(latest_rsi, 2) if latest_rsi is not None else 'N/A',
                'EMA_50': round(ema_50, 2) if ema_50 is not None else 'N/A',
                'TEMA_50': round(tema_50, 2) if tema_50 is not None else 'N/A',
                'TEMA_50-EMA_50': round(tema_50 - ema_50, 2) if tema_50 is not None and ema_50 is not None else 'N/A',
                'Market_Cap': info.get('marketCap', 'N/A'),
                'Sector': info.get('sector', 'N/A'),
                'Industry': info.get('industry', 'N/A'),
                'PE_Ratio': round(info.get('trailingPE', 'N/A'), 2) if isinstance(info.get('trailingPE'), (int, float)) else 'N/A',
                '52W_High': round(info.get('fiftyTwoWeekHigh', 'N/A'), 2) if isinstance(info.get('fiftyTwoWeekHigh'), (int, float)) else 'N/A',
                '52W_Low': round(info.get('fiftyTwoWeekLow', 'N/A'), 2) if isinstance(info.get('fiftyTwoWeekLow'), (int, float)) else 'N/A',
                'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 'N/A'
            }
            
            return stock_info

        except Exception as e:
            print(f"Error processing {symbol}: {e}")
            return None

    def analyze_indices_stocks(self):
        """Analyze stocks for each index and generate Excel report"""
        # Timestamp for unique filename
        current_date = datetime.now().strftime('%Y%m%d_%H%M%S')
        excel_file = os.path.join(self.results_dir, f'index_stocks_analysis_{current_date}.xlsx')
        
        # Prepare Excel writer
        with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
            for index_category in self.equity_market_categories:
                try:
                    # Get stocks for this index
                    stocks = self.equity_market_data(index_category, symbol_list=True)
                    
                    # Process stocks for this index
                    results = []
                    for symbol in stocks:
                        stock_data = self.get_stock_data(symbol)
                        if stock_data:
                            results.append(stock_data)
                    
                    # Convert to DataFrame
                    if results:
                        df = pd.DataFrame(results)
                        
                        # Write to Excel sheet named after the index
                        sheet_name = index_category[:31]  # Excel sheet names limited to 31 chars
                        df.to_excel(writer, sheet_name=sheet_name, index=False)
                        
                        print(f"Processed {len(results)} stocks for {index_category}")
                
                except Exception as e:
                    print(f"Error processing {index_category}: {e}")
        
        print(f"\nAnalysis complete. Results saved to {excel_file}")

if __name__ == "__main__":
    analyzer = NSEStockIndexAnalyzer()
    analyzer.analyze_indices_stocks()
# Out:
# Processed 50 stocks for NIFTY 50
# Processed 40 stocks for NIFTY ENERGY
# Processed 50 stocks for NIFTY MIDCAP 50
# Processed 50 stocks for NIFTY SMALLCAP 50
# Processed 15 stocks for NIFTY AUTO
# Processed 12 stocks for NIFTY BANK
# Processed 20 stocks for NIFTY FINANCIAL SERVICES
# Processed 15 stocks for NIFTY FMCG
# Processed 10 stocks for NIFTY IT
# Processed 10 stocks for NIFTY MEDIA
# Processed 15 stocks for NIFTY METAL
# Processed 20 stocks for NIFTY PHARMA
# Processed 12 stocks for NIFTY PSU BANK
# Processed 10 stocks for NIFTY REALTY
# Processed 10 stocks for NIFTY PRIVATE BANK
# Processed 30 stocks for NIFTY INFRASTRUCTURE
# Processed 30 stocks for NIFTY MNC
# Processed 20 stocks for NIFTY PSE
# Processed 15 stocks for NIFTY CONSUMER DURABLES
#
# Analysis complete. Results saved to stock_index_analysis\index_results\index_stocks_analysis_20250127_161014.xlsx

# %%
print(NSEStockIndexAnalyzer().equity_market_data('NIFTY 50')[1::])
# Out:
#             priority     identifier      open   dayHigh    dayLow  lastPrice  \
# symbol
# HINDUNILVR         0  HINDUNILVREQN   2332.85   2380.80   2323.00    2380.10
# BRITANNIA          0   BRITANNIAEQN   5037.70   5108.00   5013.15    5100.00
# EICHERMOT          0   EICHERMOTEQN   5134.00   5224.50   5115.05    5190.25
# GRASIM             0      GRASIMEQN   2466.35   2514.05   2453.45    2495.00
# ICICIBANK          0   ICICIBANKEQN   1203.10   1218.00   1202.00    1213.70
# TATACONSUM         0  TATACONSUMEQN    988.75   1004.00    986.40     992.80
# WIPRO              0       WIPROEQN    319.00    322.50    316.60     319.95
# TECHM              0       TECHMEQN   1719.00   1736.40   1705.35    1724.00
# POWERGRID          0   POWERGRIDEQN    295.30    302.50    294.35     296.00
# INFY               0        INFYEQN   1865.50   1894.90   1864.25    1875.00
# NESTLEIND          0   NESTLEINDEQN   2202.00   2222.75   2190.10    2209.90
# BHARTIARTL         0  BHARTIARTLEQN   1634.05   1661.90   1634.05    1641.45
# ITC                0         ITCEQN    439.40    445.00    439.05     441.40
# JSWSTEEL           0    JSWSTEELEQN    930.00    953.00    925.15     931.95
# TCS                0         TCSEQN   4104.00   4178.00   4104.00    4153.10
# NTPC               0        NTPCEQN    324.80    329.90    322.10     324.00
# BAJAJ-AUTO         0  BAJAJ-AUTOEQN   8414.40   8489.95   8360.00    8409.00
# TATASTEEL          0   TATASTEELEQN    130.50    133.20    129.31     130.50
# HDFCLIFE           0    HDFCLIFEEQN    620.55    625.00    613.30     621.30
# TITAN              0       TITANEQN   3407.00   3447.65   3380.45    3398.00
# HINDALCO           0    HINDALCOEQN    608.70    615.35    599.90     607.60
# BAJFINANCE         0  BAJFINANCEEQN   7443.25   7505.00   7338.30    7430.00
# SBIN               0        SBINEQN    749.90    753.70    739.00     744.50
# AXISBANK           0    AXISBANKEQN    948.00    961.80    946.10     948.55
# COALINDIA          0   COALINDIAEQN    386.05    392.25    381.70     384.00
# ASIANPAINT         0  ASIANPAINTEQN   2283.00   2296.55   2255.05    2263.50
# KOTAKBANK          0   KOTAKBANKEQN   1891.00   1918.50   1873.05    1883.40
# HCLTECH            0     HCLTECHEQN   1800.00   1829.40   1791.10    1796.00
# MARUTI             0      MARUTIEQN  11930.00  12093.00  11914.10   11949.35
# SUNPHARMA          0   SUNPHARMAEQN   1829.00   1843.10   1808.20    1818.00
# BAJAJFINSV         0  BAJAJFINSVEQN   1751.00   1754.90   1725.00    1729.55
# ADANIPORTS         0  ADANIPORTSEQN   1104.15   1115.00   1088.25    1093.50
# SHRIRAMFIN         0  SHRIRAMFINEQN    531.95    541.80    509.15     524.65
# SBILIFE            0     SBILIFEEQN   1451.30   1455.60   1418.15    1435.00
# ULTRACEMCO         0  ULTRACEMCOEQN  11251.00  11609.70  11222.40   11300.00
# HDFCBANK           0    HDFCBANKEQN   1660.00   1670.30   1644.50    1645.00
# HEROMOTOCO         0  HEROMOTOCOEQN   4105.05   4125.00   4041.10    4049.90
# LT                 0          LTEQN   3514.50   3521.10   3446.05    3459.80
# BEL                0         BELEQN    273.95    276.70    268.80     270.30
# RELIANCE           0    RELIANCEEQN   1266.00   1273.00   1243.50    1244.45
# ONGC               0        ONGCEQN    262.99    265.64    255.75     258.25
# INDUSINDBK         0  INDUSINDBKEQN    970.85    973.00    948.25     950.00
# CIPLA              0       CIPLAEQN   1445.25   1451.00   1408.00    1415.00
# TATAMOTORS         0  TATAMOTORSEQN    750.05    754.15    732.20     733.40
# APOLLOHOSP         0  APOLLOHOSPEQN   6915.25   6915.25   6728.45    6742.00
# BPCL               0        BPCLEQN    274.00    279.40    263.00     263.25
# ADANIENT           0    ADANIENTEQN   2387.75   2406.00   2299.40    2314.05
# M&M                0         M&MEQN   2875.00   2896.00   2790.00    2799.00
# TRENT              0       TRENTEQN   5720.00   5755.05   5466.45    5499.00
# DRREDDY            0     DRREDDYEQN   1229.95   1252.65   1203.50    1226.20
#
#             previousClose  change  pChange          ffmc  ...    nearWKH  \
# symbol                                                    ...
# HINDUNILVR        2321.70   58.40     2.52  2.110207e+12  ...  21.578254
# BRITANNIA         5012.60   87.40     1.74  6.002580e+11  ...  21.173434
# EICHERMOT         5116.20   74.05     1.45  7.132249e+11  ...   3.629055
# GRASIM            2461.15   33.85     1.38  9.258957e+11  ...  13.300321
# ICICIBANK         1201.75   11.95     0.99  8.555937e+12  ...  10.911293
# TATACONSUM         983.90    8.90     0.90  6.449390e+11  ...  20.983095
# WIPRO              317.70    2.25     0.71  9.049925e+11  ...   1.432532
# TECHM             1713.40   10.60     0.62  1.093069e+12  ...   4.630193
# POWERGRID          294.35    1.65     0.56  1.339098e+12  ...  19.180887
# INFY              1865.45    9.55     0.51  6.745260e+12  ...   6.551372
# NESTLEIND         2198.95   10.95     0.50  7.904224e+11  ...  20.449964
# BHARTIARTL        1636.00    5.45     0.33  4.397064e+12  ...   7.731872
# ITC                440.20    1.20     0.27  4.098571e+12  ...  16.480605
# JSWSTEEL           929.90    2.05     0.22  8.931880e+11  ...  12.328316
# TCS               4145.45    7.65     0.18  4.238838e+12  ...   9.562850
# NTPC               323.65    0.35     0.11  1.532179e+12  ...  27.751143
# BAJAJ-AUTO        8399.95    9.05     0.11  9.319490e+11  ...  34.170972
# TATASTEEL          130.37    0.13     0.10  1.079947e+12  ...  29.306609
# HDFCLIFE           621.00    0.30     0.05  6.632201e+11  ...  18.378875
# TITAN             3398.55   -0.55    -0.02  1.404046e+12  ...  12.579272
# HINDALCO           608.25   -0.65    -0.11  8.821044e+11  ...  21.361548
# BAJFINANCE        7443.25  -13.25    -0.18  2.076941e+12  ...   5.035787
# SBIN               745.90   -1.40    -0.19  2.861389e+12  ...  18.366228
# AXISBANK           951.05   -2.50    -0.26  2.702282e+12  ...  29.194193
# COALINDIA          385.80   -1.80    -0.47  8.698333e+11  ...  29.353325
# ASIANPAINT        2276.35  -12.85    -0.56  1.022396e+12  ...  33.326460
# KOTAKBANK         1894.85  -11.45    -0.60  2.762026e+12  ...   3.017508
# HCLTECH           1807.00  -11.00    -0.61  1.898761e+12  ...  10.744459
# MARUTI           12045.75  -96.40    -0.80  1.570406e+12  ...  12.650950
# SUNPHARMA         1833.60  -15.60    -0.85  1.959877e+12  ...   7.261458
# BAJAJFINSV        1746.15  -16.60    -0.95  9.446729e+11  ...  14.796295
# ADANIPORTS        1104.00  -10.50    -0.95  8.049345e+11  ...  32.558283
# SHRIRAMFIN         529.80   -5.15    -0.97  7.323156e+11  ...  28.174413
# SBILIFE           1449.85  -14.85    -1.02  6.413599e+11  ...  25.878099
# ULTRACEMCO       11420.90 -120.90    -1.06  1.287083e+12  ...   6.960277
# HDFCBANK          1664.90  -19.90    -1.20  1.249389e+13  ...  12.500000
# HEROMOTOCO        4100.35  -50.45    -1.23  5.243118e+11  ...  35.162698
# LT                3503.25  -43.45    -1.24  4.067704e+12  ...  12.708465
# BEL                273.95   -3.65    -1.33  9.654494e+11  ...  20.616740
# RELIANCE          1263.65  -19.20    -1.52  8.437038e+12  ...  22.647315
# ONGC               263.05   -4.80    -1.82  1.000398e+12  ...  25.144928
# INDUSINDBK         970.95  -20.95    -2.16  6.266611e+11  ...  39.734196
# CIPLA             1451.15  -36.15    -2.49  7.767994e+11  ...  16.864957
# TATAMOTORS         752.50  -19.10    -2.54  1.535346e+12  ...  37.794741
# APOLLOHOSP        6920.85 -178.85    -2.58  6.816600e+11  ...  10.646955
# BPCL               271.25   -8.00    -2.95  5.088507e+11  ...  29.986702
# ADANIENT          2385.00  -70.95    -2.97  5.753827e+11  ...  38.191458
# M&M               2886.45  -87.45    -3.03  2.474865e+12  ...  13.532383
# TRENT             5733.60 -234.60    -4.09  1.219494e+12  ...  34.104254
# DRREDDY           1289.40  -63.20    -4.90  7.469043e+11  ...  13.738401
#
#               nearWKL  perChange365d  date365dAgo  \
# symbol
# HINDUNILVR  -9.578509          -2.48  25-Jan-2024
# BRITANNIA   -9.890110          -0.78  25-Jan-2024
# EICHERMOT  -45.693273          43.96  25-Jan-2024
# GRASIM     -23.726166          19.95  25-Jan-2024
# ICICIBANK  -23.187008          19.73  25-Jan-2024
# TATACONSUM -12.447616         -12.70  25-Jan-2024
# WIPRO      -53.453237         -31.89  25-Jan-2024
# TECHM      -48.243691          30.33  25-Jan-2024
# POWERGRID  -25.957447          20.51  25-Jan-2024
# INFY       -38.035116          12.36  25-Jan-2024
# NESTLEIND   -3.006432         -11.05  25-Jan-2024
# BHARTIARTL -49.542204          41.73  25-Jan-2024
# ITC        -10.529611          -3.08  25-Jan-2024
# JSWSTEEL   -22.343288          14.31  25-Jan-2024
# TCS        -15.636921           8.98  25-Jan-2024
# NTPC        -9.146033           2.83  25-Jan-2024
# BAJAJ-AUTO -19.646567          10.58  25-Jan-2024
# TATASTEEL   -6.426358          -3.00  25-Jan-2024
# HDFCLIFE   -21.490027           7.27  25-Jan-2024
# TITAN      -11.203836          -9.76  25-Jan-2024
# HINDALCO   -22.413619           7.00  25-Jan-2024
# BAJFINANCE -20.074986           4.98  25-Jan-2024
# SBIN       -23.445531          21.44  25-Jan-2024
# AXISBANK    -0.258958          -8.99  25-Jan-2024
# COALINDIA   -6.297578          -1.63  25-Jan-2024
# ASIANPAINT  -2.522873         -23.29  25-Jan-2024
# KOTAKBANK  -21.993717           6.66  25-Jan-2024
# HCLTECH    -45.425101          15.65  25-Jan-2024
# MARUTI     -22.494618          21.12  25-Jan-2024
# SUNPHARMA  -34.816463          33.17  25-Jan-2024
# BAJAJFINSV -21.880836           6.05  25-Jan-2024
# ADANIPORTS  -9.827751          -4.55  25-Jan-2024
# SHRIRAMFIN -19.619243         -77.14  25-Jan-2024
# SBILIFE     -9.734649           4.31  25-Jan-2024
# ULTRACEMCO -22.162162          13.21  25-Jan-2024
# HDFCBANK   -20.640974          14.98  25-Jan-2024
# HEROMOTOCO  -1.310819          -8.79  25-Jan-2024
# LT          -8.968363          -3.76  25-Jan-2024
# BEL        -57.379913          42.41  25-Jan-2024
# RELIANCE    -3.574698         -53.95  25-Jan-2024
# ONGC       -15.807175           9.60  25-Jan-2024
# INDUSINDBK  -2.541961         -37.12  25-Jan-2024
# CIPLA       -7.850610           3.05  25-Jan-2024
# TATAMOTORS  -2.187544          -9.58  25-Jan-2024
# APOLLOHOSP -18.421977           9.34  25-Jan-2024
# BPCL       -13.641269         -44.39  25-Jan-2024
# ADANIENT   -14.274074         -19.99  25-Jan-2024
# M&M        -77.714286          71.29  25-Jan-2024
# TRENT      -86.091371          69.89  25-Jan-2024
# DRREDDY     -9.482143         -79.09  25-Jan-2024
#
#                                                 chart365dPath   date30dAgo  \
# symbol
# HINDUNILVR  https://nsearchives.nseindia.com/365d/HINDUNIL...  24-Dec-2024
# BRITANNIA   https://nsearchives.nseindia.com/365d/BRITANNI...  24-Dec-2024
# EICHERMOT   https://nsearchives.nseindia.com/365d/EICHERMO...  24-Dec-2024
# GRASIM      https://nsearchives.nseindia.com/365d/GRASIM-E...  24-Dec-2024
# ICICIBANK   https://nsearchives.nseindia.com/365d/ICICIBAN...  24-Dec-2024
# TATACONSUM  https://nsearchives.nseindia.com/365d/TATACONS...  24-Dec-2024
# WIPRO       https://nsearchives.nseindia.com/365d/WIPRO-EQ...  24-Dec-2024
# TECHM       https://nsearchives.nseindia.com/365d/TECHM-EQ...  24-Dec-2024
# POWERGRID   https://nsearchives.nseindia.com/365d/POWERGRI...  24-Dec-2024
# INFY        https://nsearchives.nseindia.com/365d/INFY-EQ.svg  24-Dec-2024
# NESTLEIND   https://nsearchives.nseindia.com/365d/NESTLEIN...  24-Dec-2024
# BHARTIARTL  https://nsearchives.nseindia.com/365d/BHARTIAR...  24-Dec-2024
# ITC          https://nsearchives.nseindia.com/365d/ITC-EQ.svg  24-Dec-2024
# JSWSTEEL    https://nsearchives.nseindia.com/365d/JSWSTEEL...  24-Dec-2024
# TCS          https://nsearchives.nseindia.com/365d/TCS-EQ.svg  24-Dec-2024
# NTPC        https://nsearchives.nseindia.com/365d/NTPC-EQ.svg  24-Dec-2024
# BAJAJ-AUTO  https://nsearchives.nseindia.com/365d/BAJAJ-AU...  24-Dec-2024
# TATASTEEL   https://nsearchives.nseindia.com/365d/TATASTEE...  24-Dec-2024
# HDFCLIFE    https://nsearchives.nseindia.com/365d/HDFCLIFE...  24-Dec-2024
# TITAN       https://nsearchives.nseindia.com/365d/TITAN-EQ...  24-Dec-2024
# HINDALCO    https://nsearchives.nseindia.com/365d/HINDALCO...  24-Dec-2024
# BAJFINANCE  https://nsearchives.nseindia.com/365d/BAJFINAN...  24-Dec-2024
# SBIN        https://nsearchives.nseindia.com/365d/SBIN-EQ.svg  24-Dec-2024
# AXISBANK    https://nsearchives.nseindia.com/365d/AXISBANK...  24-Dec-2024
# COALINDIA   https://nsearchives.nseindia.com/365d/COALINDI...  24-Dec-2024
# ASIANPAINT  https://nsearchives.nseindia.com/365d/ASIANPAI...  24-Dec-2024
# KOTAKBANK   https://nsearchives.nseindia.com/365d/KOTAKBAN...  24-Dec-2024
# HCLTECH     https://nsearchives.nseindia.com/365d/HCLTECH-...  24-Dec-2024
# MARUTI      https://nsearchives.nseindia.com/365d/MARUTI-E...  24-Dec-2024
# SUNPHARMA   https://nsearchives.nseindia.com/365d/SUNPHARM...  24-Dec-2024
# BAJAJFINSV  https://nsearchives.nseindia.com/365d/BAJAJFIN...  24-Dec-2024
# ADANIPORTS  https://nsearchives.nseindia.com/365d/ADANIPOR...  24-Dec-2024
# SHRIRAMFIN  https://nsearchives.nseindia.com/365d/SHRIRAMF...  24-Dec-2024
# SBILIFE     https://nsearchives.nseindia.com/365d/SBILIFE-...  24-Dec-2024
# ULTRACEMCO  https://nsearchives.nseindia.com/365d/ULTRACEM...  24-Dec-2024
# HDFCBANK    https://nsearchives.nseindia.com/365d/HDFCBANK...  24-Dec-2024
# HEROMOTOCO  https://nsearchives.nseindia.com/365d/HEROMOTO...  24-Dec-2024
# LT            https://nsearchives.nseindia.com/365d/LT-EQ.svg  24-Dec-2024
# BEL          https://nsearchives.nseindia.com/365d/BEL-EQ.svg  24-Dec-2024
# RELIANCE    https://nsearchives.nseindia.com/365d/RELIANCE...  24-Dec-2024
# ONGC        https://nsearchives.nseindia.com/365d/ONGC-EQ.svg  24-Dec-2024
# INDUSINDBK  https://nsearchives.nseindia.com/365d/INDUSIND...  24-Dec-2024
# CIPLA       https://nsearchives.nseindia.com/365d/CIPLA-EQ...  24-Dec-2024
# TATAMOTORS  https://nsearchives.nseindia.com/365d/TATAMOTO...  24-Dec-2024
# APOLLOHOSP  https://nsearchives.nseindia.com/365d/APOLLOHO...  24-Dec-2024
# BPCL        https://nsearchives.nseindia.com/365d/BPCL-EQ.svg  24-Dec-2024
# ADANIENT    https://nsearchives.nseindia.com/365d/ADANIENT...  24-Dec-2024
# M&M          https://nsearchives.nseindia.com/365d/M&M-EQ.svg  24-Dec-2024
# TRENT       https://nsearchives.nseindia.com/365d/TRENT-EQ...  24-Dec-2024
# DRREDDY     https://nsearchives.nseindia.com/365d/DRREDDY-...  24-Dec-2024
#
#             perChange30d                                       chart30dPath  \
# symbol
# HINDUNILVR          1.39  https://nsearchives.nseindia.com/30d/HINDUNILV...
# BRITANNIA           7.53  https://nsearchives.nseindia.com/30d/BRITANNIA...
# EICHERMOT           8.63  https://nsearchives.nseindia.com/30d/EICHERMOT...
# GRASIM             -0.44  https://nsearchives.nseindia.com/30d/GRASIM-EQ...
# ICICIBANK          -6.79  https://nsearchives.nseindia.com/30d/ICICIBANK...
# TATACONSUM          9.37  https://nsearchives.nseindia.com/30d/TATACONSU...
# WIPRO               4.85  https://nsearchives.nseindia.com/30d/WIPRO-EQ.svg
# TECHM               1.06  https://nsearchives.nseindia.com/30d/TECHM-EQ.svg
# POWERGRID          -4.60  https://nsearchives.nseindia.com/30d/POWERGRID...
# INFY               -1.76   https://nsearchives.nseindia.com/30d/INFY-EQ.svg
# NESTLEIND           1.90  https://nsearchives.nseindia.com/30d/NESTLEIND...
# BHARTIARTL          3.84  https://nsearchives.nseindia.com/30d/BHARTIART...
# ITC                -7.70    https://nsearchives.nseindia.com/30d/ITC-EQ.svg
# JSWSTEEL            1.15  https://nsearchives.nseindia.com/30d/JSWSTEEL-...
# TCS                -0.65    https://nsearchives.nseindia.com/30d/TCS-EQ.svg
# NTPC               -3.47   https://nsearchives.nseindia.com/30d/NTPC-EQ.svg
# BAJAJ-AUTO         -4.29  https://nsearchives.nseindia.com/30d/BAJAJ-AUT...
# TATASTEEL          -7.58  https://nsearchives.nseindia.com/30d/TATASTEEL...
# HDFCLIFE           -0.22  https://nsearchives.nseindia.com/30d/HDFCLIFE-...
# TITAN               1.45  https://nsearchives.nseindia.com/30d/TITAN-EQ.svg
# HINDALCO           -3.28  https://nsearchives.nseindia.com/30d/HINDALCO-...
# BAJFINANCE          9.26  https://nsearchives.nseindia.com/30d/BAJFINANC...
# SBIN               -8.36   https://nsearchives.nseindia.com/30d/SBIN-EQ.svg
# AXISBANK          -12.09  https://nsearchives.nseindia.com/30d/AXISBANK-...
# COALINDIA          -0.38  https://nsearchives.nseindia.com/30d/COALINDIA...
# ASIANPAINT         -0.95  https://nsearchives.nseindia.com/30d/ASIANPAIN...
# KOTAKBANK           7.84  https://nsearchives.nseindia.com/30d/KOTAKBANK...
# HCLTECH            -5.49  https://nsearchives.nseindia.com/30d/HCLTECH-E...
# MARUTI             11.47  https://nsearchives.nseindia.com/30d/MARUTI-EQ...
# SUNPHARMA           0.18  https://nsearchives.nseindia.com/30d/SUNPHARMA...
# BAJAJFINSV         10.49  https://nsearchives.nseindia.com/30d/BAJAJFINS...
# ADANIPORTS         -7.45  https://nsearchives.nseindia.com/30d/ADANIPORT...
# SHRIRAMFIN        -81.70  https://nsearchives.nseindia.com/30d/SHRIRAMFI...
# SBILIFE             3.85  https://nsearchives.nseindia.com/30d/SBILIFE-E...
# ULTRACEMCO         -0.92  https://nsearchives.nseindia.com/30d/ULTRACEMC...
# HDFCBANK           -8.25  https://nsearchives.nseindia.com/30d/HDFCBANK-...
# HEROMOTOCO         -4.86  https://nsearchives.nseindia.com/30d/HEROMOTOC...
# LT                 -4.99     https://nsearchives.nseindia.com/30d/LT-EQ.svg
# BEL                -7.63    https://nsearchives.nseindia.com/30d/BEL-EQ.svg
# RELIANCE            1.93  https://nsearchives.nseindia.com/30d/RELIANCE-...
# ONGC                7.35   https://nsearchives.nseindia.com/30d/ONGC-EQ.svg
# INDUSINDBK          1.66  https://nsearchives.nseindia.com/30d/INDUSINDB...
# CIPLA              -4.36  https://nsearchives.nseindia.com/30d/CIPLA-EQ.svg
# TATAMOTORS         -0.27  https://nsearchives.nseindia.com/30d/TATAMOTOR...
# APOLLOHOSP         -6.84  https://nsearchives.nseindia.com/30d/APOLLOHOS...
# BPCL               -9.66   https://nsearchives.nseindia.com/30d/BPCL-EQ.svg
# ADANIENT           -2.42  https://nsearchives.nseindia.com/30d/ADANIENT-...
# M&M                -4.35    https://nsearchives.nseindia.com/30d/M&M-EQ.svg
# TRENT             -21.65  https://nsearchives.nseindia.com/30d/TRENT-EQ.svg
# DRREDDY            -9.36  https://nsearchives.nseindia.com/30d/DRREDDY-E...
#
#                                                chartTodayPath series
# symbol
# HINDUNILVR  https://nsearchives.nseindia.com/today/HINDUNI...     EQ
# BRITANNIA   https://nsearchives.nseindia.com/today/BRITANN...     EQ
# EICHERMOT   https://nsearchives.nseindia.com/today/EICHERM...     EQ
# GRASIM      https://nsearchives.nseindia.com/today/GRASIME...     EQ
# ICICIBANK   https://nsearchives.nseindia.com/today/ICICIBA...     EQ
# TATACONSUM  https://nsearchives.nseindia.com/today/TATACON...     EQ
# WIPRO       https://nsearchives.nseindia.com/today/WIPROEQ...     EQ
# TECHM       https://nsearchives.nseindia.com/today/TECHMEQ...     EQ
# POWERGRID   https://nsearchives.nseindia.com/today/POWERGR...     EQ
# INFY        https://nsearchives.nseindia.com/today/INFYEQN...     EQ
# NESTLEIND   https://nsearchives.nseindia.com/today/NESTLEI...     EQ
# BHARTIARTL  https://nsearchives.nseindia.com/today/BHARTIA...     EQ
# ITC         https://nsearchives.nseindia.com/today/ITCEQN.svg     EQ
# JSWSTEEL    https://nsearchives.nseindia.com/today/JSWSTEE...     EQ
# TCS         https://nsearchives.nseindia.com/today/TCSEQN.svg     EQ
# NTPC        https://nsearchives.nseindia.com/today/NTPCEQN...     EQ
# BAJAJ-AUTO  https://nsearchives.nseindia.com/today/BAJAJ-A...     EQ
# TATASTEEL   https://nsearchives.nseindia.com/today/TATASTE...     EQ
# HDFCLIFE    https://nsearchives.nseindia.com/today/HDFCLIF...     EQ
# TITAN       https://nsearchives.nseindia.com/today/TITANEQ...     EQ
# HINDALCO    https://nsearchives.nseindia.com/today/HINDALC...     EQ
# BAJFINANCE  https://nsearchives.nseindia.com/today/BAJFINA...     EQ
# SBIN        https://nsearchives.nseindia.com/today/SBINEQN...     EQ
# AXISBANK    https://nsearchives.nseindia.com/today/AXISBAN...     EQ
# COALINDIA   https://nsearchives.nseindia.com/today/COALIND...     EQ
# ASIANPAINT  https://nsearchives.nseindia.com/today/ASIANPA...     EQ
# KOTAKBANK   https://nsearchives.nseindia.com/today/KOTAKBA...     EQ
# HCLTECH     https://nsearchives.nseindia.com/today/HCLTECH...     EQ
# MARUTI      https://nsearchives.nseindia.com/today/MARUTIE...     EQ
# SUNPHARMA   https://nsearchives.nseindia.com/today/SUNPHAR...     EQ
# BAJAJFINSV  https://nsearchives.nseindia.com/today/BAJAJFI...     EQ
# ADANIPORTS  https://nsearchives.nseindia.com/today/ADANIPO...     EQ
# SHRIRAMFIN  https://nsearchives.nseindia.com/today/SHRIRAM...     EQ
# SBILIFE     https://nsearchives.nseindia.com/today/SBILIFE...     EQ
# ULTRACEMCO  https://nsearchives.nseindia.com/today/ULTRACE...     EQ
# HDFCBANK    https://nsearchives.nseindia.com/today/HDFCBAN...     EQ
# HEROMOTOCO  https://nsearchives.nseindia.com/today/HEROMOT...     EQ
# LT           https://nsearchives.nseindia.com/today/LTEQN.svg     EQ
# BEL         https://nsearchives.nseindia.com/today/BELEQN.svg     EQ
# RELIANCE    https://nsearchives.nseindia.com/today/RELIANC...     EQ
# ONGC        https://nsearchives.nseindia.com/today/ONGCEQN...     EQ
# INDUSINDBK  https://nsearchives.nseindia.com/today/INDUSIN...     EQ
# CIPLA       https://nsearchives.nseindia.com/today/CIPLAEQ...     EQ
# TATAMOTORS  https://nsearchives.nseindia.com/today/TATAMOT...     EQ
# APOLLOHOSP  https://nsearchives.nseindia.com/today/APOLLOH...     EQ
# BPCL        https://nsearchives.nseindia.com/today/BPCLEQN...     EQ
# ADANIENT    https://nsearchives.nseindia.com/today/ADANIEN...     EQ
# M&M         https://nsearchives.nseindia.com/today/M&MEQN.svg     EQ
# TRENT       https://nsearchives.nseindia.com/today/TRENTEQ...     EQ
# DRREDDY     https://nsearchives.nseindia.com/today/DRREDDY...     EQ
#
# [50 rows x 26 columns]

# %%
import requests

def fetch_hdfc_option_chain():
    symbol = "HDFC"
    base_url = "https://www.nseindia.com"
    option_chain_url = f"{base_url}/api/option-chain-equities?symbol={symbol}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
    }

    session = requests.Session()
    session.get(base_url, headers=headers)
    response = session.get(option_chain_url, headers=headers)

    if response.status_code == 200:
        try:
            # Parse JSON response
            data = response.json()
            print("Raw JSON response:\n", data)  # Debugging
            
            # Extracting options if available
            records = data.get("records", {})
            options = records.get("data", [])
            
            if options:
                print(f"Option chain data for {symbol}:\n")
                for entry in options[:5]:  # Limit to 5 entries for brevity
                    ce = entry.get("CE", {})
                    pe = entry.get("PE", {})
                    print(
                        f"Strike Price: {ce.get('strikePrice')} | "
                        f"Call OI: {ce.get('openInterest')} | "
                        f"Put OI: {pe.get('openInterest')}"
                    )
            else:
                print("No options data found.")
        except Exception as e:
            print(f"Error processing data: {e}")
    else:
        print(f"Failed to fetch data. HTTP Status Code: {response.status_code}")


fetch_hdfc_option_chain()
# Out:
# Raw JSON response:
#  {}
# No options data found.
