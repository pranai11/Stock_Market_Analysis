# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def calculate_ema(self, data, length, source='Close', offset=0, smoothing_length=9):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            smoothing_length (int): Length of initial SMA smoothing
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=smoothing_length).mean()
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=200):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            time.sleep(1)  # Add a delay of 1 second between requests
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty:
                return None, None, None, None

            # Check if there are required entries
            if len(hist_data) < 9:
                hist_data['EMA_9'] = float('nan')
            else:
                hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0, smoothing_length=9)
            if len(hist_data) < 21:
                hist_data['EMA_21'] = float('nan')
            else:
                hist_data['EMA_21'] = self.calculate_ema(hist_data, length=21, source='Close', offset=0, smoothing_length=9)
            if len(hist_data) < 50:
                hist_data['EMA_50'] = float('nan')
            else:
                hist_data['EMA_50'] = self.calculate_ema(hist_data, length=50, source='Close', offset=0, smoothing_length=9)
            
            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'EMA_21': hist_data['EMA_21'].iloc[-1] if 'EMA_21' in hist_data else 'N/A',
                            'EMA_50': hist_data['EMA_50'].iloc[-1] if 'EMA_50' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2062 NSE and 3026 BSE stocks
#
# NSE analysis complete. Results saved to stock_analysis\daily_results\nse_analysis_20250110.xlsx
#
# NSE Stocks with RSI >= 40:
# ATLASCYCLE (Atlas Cycles (Haryana) Limited): RSI = 100.00, Price = ₹112.81
# BGRENERGY (BGR Energy Systems Limited): RSI = 100.00, Price = ₹119.00
# AARVEEDEN (Aarvee Denims and Exports Ltd.): RSI = 100.00, Price = ₹131.58
# SVLL (Shree Vasu Logistics Limited): RSI = 100.00, Price = ₹394.65
# VISASTEEL (VISA Steel Limited): RSI = 100.00, Price = ₹45.48
# BLUECOAST (Blue Coast Hotels Limited): RSI = 100.00, Price = ₹22.27
# GVT&D (GE Vernova T&D India Ltd): RSI = 100.00, Price = ₹1931.00
# FSC (Future Supply Chain Solutions Limited): RSI = 96.77, Price = ₹2.49
# INDOTHAI (Indo Thai Securities Limited): RSI = 96.13, Price = ₹1731.35
# TATACONSUM (Tata Consumer Products Limited): RSI = 89.84, Price = ₹974.10
# AXISCADES (AXISCADES Technologies Limited): RSI = 88.92, Price = ₹798.60
# PTCIL (PTC Industries Limited): RSI = 86.50, Price = ₹16792.60
# CAPITALSFB (Capital Small Finance Bank Limited): RSI = 85.93, Price = ₹308.80
# ZOTA (Zota Health Care Limited): RSI = 84.42, Price = ₹1019.50
# LLOYDSME (Lloyds Metals and Energy Limited): RSI = 84.17, Price = ₹1474.95
# SUNCLAY (Sundaram-Clayton Limited): RSI = 83.93, Price = ₹2834.95
# INDIACEM (The India Cements Limited): RSI = 83.11, Price = ₹376.60
# GODREJCP (Godrej Consumer Products Limited): RSI = 82.73, Price = ₹1173.45
# SHAKTIPUMP (Shakti Pumps (India) Limited): RSI = 81.60, Price = ₹1321.00
# BAJAJFINSV (Bajaj Finserv Ltd.): RSI = 79.72, Price = ₹1709.65
# BRITANNIA (Britannia Industries Limited): RSI = 79.23, Price = ₹4941.55
# VIJAYA (Vijaya Diagnostic Centre Limited): RSI = 79.03, Price = ₹1229.90
# ESCORTS (Escorts Kubota Limited): RSI = 79.00, Price = ₹3417.70
# CALSOFT (California Software Company Limited): RSI = 77.94, Price = ₹20.76
# AVONMORE (Avonmore Capital & Management Services Limited): RSI = 77.50, Price = ₹25.87
# PROZONER (Prozone Realty Limited): RSI = 77.08, Price = ₹36.75
# KIMS (Krishna Institute of Medical Sciences Limited): RSI = 76.67, Price = ₹652.45
# AVROIND (Avro India Limited): RSI = 76.10, Price = ₹217.92
# COFFEEDAY (Coffee Day Enterprises Limited): RSI = 75.69, Price = ₹30.28
# SEYAIND (Seya Industries Limited): RSI = 75.66, Price = ₹29.55
# LLOYDSENT (Lloyds Enterprises Limited): RSI = 75.30, Price = ₹57.91
# UPL (UPL Limited): RSI = 75.19, Price = ₹551.20
# HINDUNILVR (Hindustan Unilever Limited): RSI = 75.18, Price = ₹2450.80
# SRF (SRF Limited): RSI = 75.16, Price = ₹2599.80
# UNIVASTU (Univastu India Limited): RSI = 75.15, Price = ₹283.15
# LFIC (Lakshmi Finance & Industrial Corporation Limited): RSI = 74.93, Price = ₹246.12
# MEDICO (Medico Remedies Limited): RSI = 74.38, Price = ₹61.89
# V2RETAIL (V2 Retail Limited): RSI = 74.07, Price = ₹1725.00
# ATALREAL (Atal Realtech Limited): RSI = 74.01, Price = ₹14.15
# DNAMEDIA (Diligent Media Corporation Limited): RSI = 73.86, Price = ₹6.99
# JSWHL (JSW Holdings Limited): RSI = 73.79, Price = ₹17761.85
# JUBLFOOD (Jubilant FoodWorks Limited): RSI = 73.69, Price = ₹733.65
# ARIHANTSUP (Arihant Superstructures Limited): RSI = 73.42, Price = ₹508.95
# MAZDA (Mazda Limited): RSI = 73.10, Price = ₹1925.95
# INDOTECH (Indo Tech Transformers Limited): RSI = 73.04, Price = ₹3565.00
# BROOKS (Brooks Laboratories Limited): RSI = 73.04, Price = ₹182.06
# INDORAMA (Indo Rama Synthetics (India) Limited): RSI = 72.33, Price = ₹44.70
# HMT (HMT Limited): RSI = 72.25, Price = ₹73.84
# BAJFINANCE (Bajaj Finance Limited): RSI = 72.21, Price = ₹7294.25
# MARICO (Marico Limited): RSI = 72.16, Price = ₹674.45
# AARTIPHARM (Aarti Pharmalabs Limited): RSI = 72.13, Price = ₹671.40
# AMBER (Amber Enterprises India Limited): RSI = 72.02, Price = ₹7848.15
# MANCREDIT (Mangal Credit and Fincorp Limited): RSI = 71.92, Price = ₹164.54
# INDGN (N/A): RSI = 71.75, Price = ₹623.50
# RKFORGE (Ramkrishna Forgings Limited): RSI = 71.53, Price = ₹993.15
# MVGJL (Manoj Vaibhav Gems 'N' Jewellers Limited): RSI = 70.81, Price = ₹286.95
# BTML (Bodhi Tree Multimedia Limited): RSI = 70.66, Price = ₹12.40
# SMSLIFE (SMS Lifesciences India Limited): RSI = 70.27, Price = ₹1298.40
# KALYANIFRG (Kalyani Forge Limited): RSI = 70.25, Price = ₹771.00
# ASTERDM (Aster DM Healthcare Limited): RSI = 69.58, Price = ₹512.15
# FMNL (Future Market Networks Limited): RSI = 69.56, Price = ₹25.96
# SBILIFE (SBI Life Insurance Company Limited): RSI = 69.42, Price = ₹1482.65
# MEGASTAR (Megastar Foods Limited): RSI = 69.25, Price = ₹275.00
# WORTH (Worth Peripherals Limited): RSI = 69.24, Price = ₹165.11
# GLFL (Gujarat Lease Financing Limited): RSI = 69.03, Price = ₹8.03
# AURUM (Aurum PropTech Limited): RSI = 69.01, Price = ₹253.70
# MEGASOFT (Megasoft Limited): RSI = 68.72, Price = ₹101.90
# EICHERMOT (Eicher Motors Limited): RSI = 68.54, Price = ₹5076.00
# BATAINDIA (Bata India Limited): RSI = 68.51, Price = ₹1438.10
# COROMANDEL (Coromandel International Limited): RSI = 68.11, Price = ₹1925.00
# ASMS (Bartronics India Limited): RSI = 68.10, Price = ₹21.62
# EPACK (EPACK Durable Limited): RSI = 68.00, Price = ₹568.45
# JTLIND (JTL Industries Limited): RSI = 67.74, Price = ₹105.60
# SBICARD (SBI Cards and Payment Services Limited): RSI = 67.68, Price = ₹730.00
# APOLLO (Apollo Micro Systems Limited): RSI = 67.61, Price = ₹121.60
# CREDITACC (CreditAccess Grameen Limited): RSI = 67.51, Price = ₹959.90
# EQUITASBNK (Equitas Small Finance Bank Limited): RSI = 67.49, Price = ₹68.51
# NACLIND (NACL Industries Limited): RSI = 67.48, Price = ₹66.29
# MARUTI (Maruti Suzuki India Limited): RSI = 67.31, Price = ₹11642.00
# M&M (Mahindra & Mahindra Limited): RSI = 67.24, Price = ₹3108.80
# USK (Udayshivakumar Infra Limited): RSI = 67.09, Price = ₹54.00
# BHARTIARTL (Bharti Airtel Limited): RSI = 66.87, Price = ₹1616.00
# MGL (Mahanagar Gas Limited): RSI = 66.87, Price = ₹1297.15
# DELTACORP (Delta Corp Limited): RSI = 66.81, Price = ₹120.20
# AUBANK (AU Small Finance Bank Limited): RSI = 66.78, Price = ₹578.70
# MBAPL (Madhya Bharat Agro Products Limited): RSI = 66.76, Price = ₹241.07
# ALLDIGI (Alldigi Tech Limited): RSI = 66.49, Price = ₹1033.20
# ABDL (N/A): RSI = 66.46, Price = ₹416.50
# DCXINDIA (DCX Systems Limited): RSI = 66.30, Price = ₹362.85
# BLUECHIP (Blue Chip India Limited): RSI = 66.23, Price = ₹8.75
# BERGEPAINT (Berger Paints India Limited): RSI = 66.21, Price = ₹463.90
# LTIM (LTIMindtree Limited): RSI = 66.05, Price = ₹6134.35
# DMART (Avenue Supermarts Limited): RSI = 65.99, Price = ₹3727.25
# ASIANHOTNR (Asian Hotels (North) Limited): RSI = 65.83, Price = ₹282.00
# ASHAPURMIN (Ashapura Minechem Limited): RSI = 65.63, Price = ₹462.80
# CANTABIL (Cantabil Retail India Limited): RSI = 65.61, Price = ₹298.25
# ALPA (Alpa Laboratories Limited): RSI = 65.47, Price = ₹126.20
# AIIL (Authum Investment & Infrastructure Limited): RSI = 65.33, Price = ₹1867.90
# MGEL (Mangalam Global Enterprise Limited): RSI = 65.32, Price = ₹28.86
# TECILCHEM (Tecil Chemicals and Hydro Power Ltd.): RSI = 65.29, Price = ₹26.80
# VASWANI (Vaswani Industries Limited): RSI = 65.27, Price = ₹53.89
# GOLDIAM (Goldiam International Limited): RSI = 65.18, Price = ₹475.15
# SPANDANA (Spandana Sphoorty Financial Limited): RSI = 64.92, Price = ₹412.50
# ITI (ITI Limited): RSI = 64.54, Price = ₹445.15
# KILITCH (Kilitch Drugs (India) Limited): RSI = 64.52, Price = ₹340.80
# DECCANCE (Deccan Cements Limited): RSI = 64.50, Price = ₹701.00
# JUSTDIAL (Just Dial Limited): RSI = 64.33, Price = ₹1052.25
# M&MFIN (Mahindra & Mahindra Financial Services Limited): RSI = 64.05, Price = ₹276.60
# GENESYS (Genesys International Corporation Limited): RSI = 63.77, Price = ₹1003.30
# E2E (E2E Networks Limited): RSI = 63.74, Price = ₹4250.00
# GMRP&UI (GMR Power And Urban Infra Limited): RSI = 63.71, Price = ₹116.15
# DIAMONDYD (Prataap Snacks Limited): RSI = 63.62, Price = ₹1144.10
# ASALCBR (Associated Alcohols & Breweries Limited): RSI = 63.51, Price = ₹1164.50
# EMBDL (N/A): RSI = 63.46, Price = ₹137.19
# MANGCHEFER (Mangalore Chemicals & Fertilizers Limited): RSI = 63.40, Price = ₹166.38
# ZEEMEDIA (Zee Media Corporation Limited): RSI = 62.97, Price = ₹20.66
# RELIANCE (Reliance Industries Limited): RSI = 62.96, Price = ₹1250.55
# JYOTHYLAB (Jyothy Labs Limited): RSI = 62.89, Price = ₹402.10
# LORDSCHLO (Lords Chloro Alkali Limited): RSI = 62.71, Price = ₹194.40
# AKUMS (N/A): RSI = 62.62, Price = ₹625.55
# INNOVACAP (Innova Captab Limited): RSI = 62.50, Price = ₹1090.05
# CONCORDBIO (Concord Biotech Limited): RSI = 62.15, Price = ₹2262.95
# VLEGOV (VL E-Governance & IT Solutions Limited): RSI = 62.14, Price = ₹171.40
# ATFL (Agro Tech Foods Limited): RSI = 62.12, Price = ₹932.05
# JISLJALEQS (Jain Irrigation Systems Limited): RSI = 61.78, Price = ₹74.65
# TCLCONS (Tantia Constructions Limited): RSI = 61.78, Price = ₹46.09
# ROML (Raj Oil Mills Limited): RSI = 61.75, Price = ₹55.23
# DEVIT (Dev Information Technology Limited): RSI = 61.67, Price = ₹170.29
# DABUR (Dabur India Limited): RSI = 61.63, Price = ₹519.50
# RAMAPHO (Rama Phosphates Limited): RSI = 61.61, Price = ₹217.81
# SHAILY (Shaily Engineering Plastics Limited): RSI = 61.60, Price = ₹1583.00
# LUPIN (Lupin Limited): RSI = 61.19, Price = ₹2252.85
# FSL (Firstsource Solutions Limited): RSI = 61.18, Price = ₹380.50
# ANANTRAJ (Anant Raj Limited): RSI = 61.17, Price = ₹898.30
# REPL (Rudrabhishek Enterprises Limited): RSI = 61.14, Price = ₹319.00
# ITDCEM (ITD Cementation India Limited): RSI = 61.12, Price = ₹524.00
# MATRIMONY (Matrimony.com Limited): RSI = 61.08, Price = ₹659.45
# LAURUSLABS (Laurus Labs Limited): RSI = 60.94, Price = ₹584.80
# MONARCH (Monarch Networth Capital Limited): RSI = 60.91, Price = ₹442.35
# MANGLMCEM (Mangalam Cement Limited): RSI = 60.90, Price = ₹973.40
# IGL (Indraprastha Gas Limited): RSI = 60.89, Price = ₹418.45
# IDEA (Vodafone Idea Limited): RSI = 60.85, Price = ₹7.81
# CHOLAFIN (Cholamandalam Investment and Finance Company Limited): RSI = 60.83, Price = ₹1257.25
# TATAMOTORS (Tata Motors Limited): RSI = 60.51, Price = ₹780.10
# SAPPHIRE (Sapphire Foods India Limited): RSI = 60.49, Price = ₹331.80
# TCPLPACK (TCPL Packaging Limited): RSI = 60.43, Price = ₹3251.15
# LLOYDSENGG (Lloyds Engineering Works Limited): RSI = 60.37, Price = ₹84.68
# HOMEFIRST (Home First Finance Company India Limited): RSI = 60.37, Price = ₹1038.75
# GUFICBIO (Gufic Biosciences Limited): RSI = 60.32, Price = ₹453.85
# GANESHHOUC (Ganesh Housing Corporation Limited): RSI = 60.30, Price = ₹1270.80
# BIOCON (Biocon Limited): RSI = 60.27, Price = ₹359.90
# SYNGENE (Syngene International Limited): RSI = 60.26, Price = ₹866.05
# TBOTEK (N/A): RSI = 59.91, Price = ₹1746.80
# APARINDS (APAR Industries Limited): RSI = 59.90, Price = ₹10667.80
# INFY (Infosys Limited): RSI = 59.73, Price = ₹1968.80
# WELENT (Welspun Enterprises Limited): RSI = 59.73, Price = ₹617.45
# CHOLAHLDNG (Cholamandalam Financial Holdings Limited): RSI = 59.62, Price = ₹1514.00
# MTEDUCARE (MT Educare Limited): RSI = 59.60, Price = ₹2.72
# HSCL (Himadri Speciality Chemical Limited): RSI = 59.47, Price = ₹567.00
# SHRADHA (Shradha Infraprojects Limited): RSI = 59.42, Price = ₹88.96
# KAUSHALYA (Kaushalya Infrastructure Development Corporation Limited): RSI = 59.42, Price = ₹1040.00
# DHANI (Dhani Services Limited): RSI = 59.39, Price = ₹96.50
# GARUDA (N/A): RSI = 59.34, Price = ₹131.75
# DCI (DC Infotech and Communication Limited): RSI = 59.31, Price = ₹363.00
# MANAKCOAT (Manaksia Coated Metals & Industries Limited): RSI = 59.31, Price = ₹110.50
# SASKEN (Sasken Technologies Limited): RSI = 59.31, Price = ₹2150.00
# PRUDMOULI (Prudential Sugar Corporation Ltd.): RSI = 59.30, Price = ₹68.95
# AMNPLST (Amines & Plasticizers Limited): RSI = 59.26, Price = ₹296.40
# ASTRAZEN (AstraZeneca Pharma India Limited): RSI = 59.11, Price = ₹6901.05
# SAREGAMA (Saregama India Limited): RSI = 59.09, Price = ₹534.50
# AKZOINDIA (Akzo Nobel India Limited): RSI = 59.08, Price = ₹3749.85
# KHAITANLTD (Khaitan (India) Limited): RSI = 58.99, Price = ₹86.29
# VARDMNPOLY (Vardhman Polytex Limited): RSI = 58.82, Price = ₹14.40
# GUJAPOLLO (Gujarat Apollo Industries Limited): RSI = 58.76, Price = ₹350.40
# VINCOFE (Vintage Coffee and Beverages Limited): RSI = 58.72, Price = ₹121.39
# LTTS (L&T Technology Services Limited): RSI = 58.71, Price = ₹4945.00
# JINDWORLD (Jindal Worldwide Limited): RSI = 58.70, Price = ₹425.20
# SILVERTUC (Silver Touch Technologies Limited): RSI = 58.58, Price = ₹692.95
# SUNDARMFIN (Sundaram Finance Limited): RSI = 58.49, Price = ₹4596.05
# AADHARHFC (N/A): RSI = 58.45, Price = ₹435.35
# SIGNPOST (Signpost India Limited): RSI = 58.40, Price = ₹382.65
# UNIVCABLES (Universal Cables Limited): RSI = 58.36, Price = ₹782.00
# INDIAMART (IndiaMART InterMESH Limited): RSI = 58.35, Price = ₹2319.90
# UNOMINDA (Uno Minda Limited): RSI = 58.26, Price = ₹1079.85
# ZYDUSLIFE (Zydus Lifesciences Limited): RSI = 58.25, Price = ₹1006.65
# CEATLTD (CEAT Limited): RSI = 58.19, Price = ₹3100.00
# SUVIDHAA (Suvidhaa Infoserve Limited): RSI = 58.08, Price = ₹6.59
# KIOCL (KIOCL Limited): RSI = 58.00, Price = ₹392.95
# BANARBEADS (Banaras Beads Limited): RSI = 57.85, Price = ₹129.99
# JCHAC (Johnson Controls-Hitachi Air Conditioning India Limited): RSI = 57.83, Price = ₹1839.55
# TITAN (Titan Company Limited): RSI = 57.81, Price = ₹3436.15
# ASHIANA (Ashiana Housing Limited): RSI = 57.71, Price = ₹362.45
# FLEXITUFF (Flexituff Ventures International Limited): RSI = 57.71, Price = ₹64.69
# FUSION (Fusion Finance Limited): RSI = 57.70, Price = ₹181.51
# SUNDRMBRAK (Sundaram Brake Linings Limited): RSI = 57.64, Price = ₹1166.95
# GHCL (GHCL Limited): RSI = 57.60, Price = ₹688.55
# IPCALAB (Ipca Laboratories Limited): RSI = 57.37, Price = ₹1630.00
# MARATHON (Marathon Nextgen Realty Limited): RSI = 57.36, Price = ₹648.65
# AJOONI (Ajooni Biotech Limited): RSI = 57.28, Price = ₹7.68
# DEVYANI (Devyani International Limited): RSI = 57.28, Price = ₹181.43
# COLPAL (Colgate-Palmolive (India) Limited): RSI = 57.25, Price = ₹2835.00
# MUKTAARTS (Mukta Arts Limited): RSI = 57.22, Price = ₹91.77
# ASIANPAINT (Asian Paints Limited): RSI = 57.20, Price = ₹2326.55
# SBFC (SBFC Finance Limited): RSI = 57.17, Price = ₹87.60
# JSFB (Jana Small Finance Bank Limited): RSI = 57.13, Price = ₹395.15
# SUBROS (Subros Limited): RSI = 56.96, Price = ₹642.60
# CREATIVE (Creative Newtech Limited): RSI = 56.95, Price = ₹940.00
# GREAVESCOT (Greaves Cotton Limited): RSI = 56.90, Price = ₹255.60
# MUTHOOTFIN (Muthoot Finance Limited): RSI = 56.90, Price = ₹2135.10
# IFBIND (IFB Industries Limited): RSI = 56.76, Price = ₹1877.00
# ANANDRATHI (Anand Rathi Wealth Limited): RSI = 56.72, Price = ₹4174.90
# MAHESHWARI (Maheshwari Logistics Limited): RSI = 56.68, Price = ₹62.72
# IIFL (IIFL Finance Limited): RSI = 56.55, Price = ₹420.95
# GUJRAFFIA (Gujarat Raffia Industries Limited): RSI = 56.47, Price = ₹88.23
# TAJGVK (TAJGVK Hotels & Resorts Limited): RSI = 56.40, Price = ₹393.95
# MOIL (MOIL Limited): RSI = 56.37, Price = ₹357.20
# PVP (PVP Ventures Limited): RSI = 56.13, Price = ₹30.46
# INTELLECT (Intellect Design Arena Limited): RSI = 56.08, Price = ₹903.00
# SHANTI (Shanti Overseas (India) Limited): RSI = 56.06, Price = ₹17.01
# WEWIN (We Win Limited): RSI = 56.06, Price = ₹87.41
# SHALPAINTS (Shalimar Paints Limited): RSI = 56.05, Price = ₹128.94
# KOTAKBANK (Kotak Mahindra Bank Limited): RSI = 56.02, Price = ₹1772.75
# BAFNAPH (Bafna Pharmaceuticals Limited): RSI = 55.99, Price = ₹84.06
# VISAKAIND (Visaka Industries Limited): RSI = 55.97, Price = ₹96.34
# MANINDS (Man Industries (India) Limited): RSI = 55.91, Price = ₹336.05
# JINDALSTEL (Jindal Steel & Power Limited): RSI = 55.88, Price = ₹924.35
# SUPERSPIN (Super Spinning Mills Limited): RSI = 55.77, Price = ₹14.33
# MINDACORP (Minda Corporation Limited): RSI = 55.73, Price = ₹520.50
# SWSOLAR (Sterling and Wilson Renewable Energy Limited): RSI = 55.73, Price = ₹457.00
# GALAPREC (N/A): RSI = 55.72, Price = ₹1184.70
# VAKRANGEE (Vakrangee Limited): RSI = 55.67, Price = ₹34.90
# SUNFLAG (Sunflag Iron and Steel Company Limited): RSI = 55.64, Price = ₹295.00
# KELLTONTEC (Kellton Tech Solutions Limited): RSI = 55.63, Price = ₹161.55
# SFL (Sheela Foam Limited): RSI = 55.59, Price = ₹979.10
# ALPHAGEO (Alphageo (India) Limited): RSI = 55.34, Price = ₹451.60
# KINGFA (Kingfa Science & Technology (India) Limited): RSI = 55.33, Price = ₹3571.25
# HYUNDAI (N/A): RSI = 55.32, Price = ₹1788.90
# CAPLIPOINT (Caplin Point Laboratories Limited): RSI = 55.23, Price = ₹2477.50
# GRPLTD (GRP Limited): RSI = 55.22, Price = ₹3282.95
# SINDHUTRAD (Sindhu Trade Links Limited): RSI = 55.17, Price = ₹23.00
# SANOFICONR (N/A): RSI = 55.17, Price = ₹4854.75
# YUKEN (Yuken India Limited): RSI = 55.13, Price = ₹1092.60
# RKEC (RKEC Projects Limited): RSI = 55.11, Price = ₹96.65
# KSCL (Kaveri Seed Company Limited): RSI = 55.02, Price = ₹910.00
# CAMLINFINE (Camlin Fine Sciences Limited): RSI = 55.01, Price = ₹131.13
# DOLPHIN (Dolphin Offshore Enterprises (India) Limited): RSI = 54.97, Price = ₹563.90
# RAJRATAN (Rajratan Global Wire Limited): RSI = 54.95, Price = ₹498.00
# SOUTHBANK (The South Indian Bank Limited): RSI = 54.91, Price = ₹25.50
# DRREDDY (Dr. Reddy's Laboratories Limited): RSI = 54.82, Price = ₹1358.95
# GLOBE (Globe Textiles (India) Limited): RSI = 54.80, Price = ₹4.99
# BALAJEE (N/A): RSI = 54.74, Price = ₹72.28
# CENTURYPLY (Century Plyboards (India) Limited): RSI = 54.71, Price = ₹802.60
# LGHL (N/A): RSI = 54.68, Price = ₹511.10
# ABBOTINDIA (Abbott India Limited): RSI = 54.62, Price = ₹29025.00
# RAMKY (Ramky Infrastructure Limited): RSI = 54.57, Price = ₹616.00
# GANGAFORGE (Ganga Forging Limited): RSI = 54.55, Price = ₹7.05
# INDUSINDBK (IndusInd Bank Limited): RSI = 54.54, Price = ₹980.90
# BLUEJET (Blue Jet Healthcare Limited): RSI = 54.54, Price = ₹577.50
# SANGINITA (Sanginita Chemicals Limited): RSI = 54.42, Price = ₹15.60
# SAGCEM (Sagar Cements Limited): RSI = 54.35, Price = ₹220.00
# ZEEL (Zee Entertainment Enterprises Limited): RSI = 54.35, Price = ₹127.76
# ADANIENT (Adani Enterprises Limited): RSI = 54.21, Price = ₹2402.15
# DATAMATICS (Datamatics Global Services Limited): RSI = 54.08, Price = ₹657.00
# VAIBHAVGBL (Vaibhav Global Limited): RSI = 54.05, Price = ₹296.80
# SCHAEFFLER (Schaeffler India Limited): RSI = 54.04, Price = ₹3347.00
# INFOBEAN (InfoBeans Technologies Limited): RSI = 54.03, Price = ₹428.10
# HAPPSTMNDS (Happiest Minds Technologies Limited): RSI = 53.98, Price = ₹712.20
# TARSONS (Tarsons Products Limited): RSI = 53.93, Price = ₹407.25
# SHEKHAWATI (Shekhawati Industries Limited): RSI = 53.91, Price = ₹31.35
# BAJAJHCARE (Bajaj HealthCare Limited): RSI = 53.88, Price = ₹561.55
# JKCEMENT (J.K. Cement Limited): RSI = 53.85, Price = ₹4576.00
# RELINFRA (Reliance Infrastructure Limited): RSI = 53.81, Price = ₹298.30
# AJMERA (Ajmera Realty & Infra India Limited): RSI = 53.78, Price = ₹1091.20
# SARDAEN (Sarda Energy & Minerals Limited): RSI = 53.77, Price = ₹476.45
# AARTECH (Aartech Solonics Limited): RSI = 53.76, Price = ₹86.06
# SEQUENT (Sequent Scientific Limited): RSI = 53.75, Price = ₹182.01
# HINDMOTORS (Hindustan Motors Limited): RSI = 53.71, Price = ₹26.23
# SHRIPISTON (Shriram Pistons & Rings Limited): RSI = 53.70, Price = ₹2089.05
# RICOAUTO (Rico Auto Industries Limited): RSI = 53.68, Price = ₹88.07
# STARTECK (Starteck Finance Limited): RSI = 53.65, Price = ₹305.00
# ASIANENE (Asian Energy Services Limited): RSI = 53.64, Price = ₹388.65
# AARON (Aaron Industries Limited): RSI = 53.62, Price = ₹359.20
# ITDC (India Tourism Development Corporation Limited): RSI = 53.55, Price = ₹635.55
# TATACOMM (Tata Communications Limited): RSI = 53.55, Price = ₹1725.10
# GILLETTE (Gillette India Limited): RSI = 53.54, Price = ₹9604.45
# TECHM (Tech Mahindra Limited): RSI = 53.54, Price = ₹1706.60
# CHENNPETRO (Chennai Petroleum Corporation Limited): RSI = 53.50, Price = ₹604.75
# SPENCERS (Spencer's Retail Limited): RSI = 53.49, Price = ₹84.90
# SIGMA (Sigma Solve Limited): RSI = 53.35, Price = ₹344.30
# BALKRISHNA (Balkrishna Paper Mills Limited): RSI = 53.35, Price = ₹24.07
# HEUBACHIND (Heubach Colorants India Limited): RSI = 53.35, Price = ₹544.10
# HILTON (Hilton Metal Forging Limited): RSI = 53.29, Price = ₹100.69
# CONTROLPR (Control Print Limited): RSI = 53.28, Price = ₹723.10
# LTF (L&T Finance Limited): RSI = 53.27, Price = ₹138.46
# ARKADE (N/A): RSI = 53.24, Price = ₹166.62
# RITCO (Ritco Logistics Limited): RSI = 53.23, Price = ₹391.05
# RBLBANK (RBL Bank Limited): RSI = 53.23, Price = ₹155.30
# ZENSARTECH (Zensar Technologies Limited): RSI = 53.23, Price = ₹779.90
# LUMAXTECH (Lumax Auto Technologies Limited): RSI = 53.20, Price = ₹628.00
# IL&FSENGG (IL&FS Engineering and Construction Company Limited): RSI = 53.14, Price = ₹42.52
# SAURASHCEM (Saurashtra Cement Limited): RSI = 53.12, Price = ₹109.00
# RBZJEWEL (RBZ Jewellers Limited): RSI = 53.04, Price = ₹212.12
# TATVA (Tatva Chintan Pharma Chem Limited): RSI = 53.03, Price = ₹862.10
# FORTIS (Fortis Healthcare Limited): RSI = 52.95, Price = ₹688.80
# ASTRON (Astron Paper & Board Mill Limited): RSI = 52.84, Price = ₹20.00
# ABMINTLLTD (ABM International Limited): RSI = 52.83, Price = ₹66.80
# JISLDVREQS (Jain Irrigation Systems Limited): RSI = 52.80, Price = ₹36.38
# SHYAMMETL (Shyam Metalics and Energy Limited): RSI = 52.80, Price = ₹779.50
# KEI (KEI Industries Limited): RSI = 52.79, Price = ₹4207.90
# VINEETLAB (Vineet Laboratories Limited): RSI = 52.74, Price = ₹57.80
# DSSL (Dynacons Systems & Solutions Limited): RSI = 52.72, Price = ₹1427.10
# SOMICONVEY (Somi Conveyor Beltings Limited): RSI = 52.69, Price = ₹203.12
# LUMAXIND (Lumax Industries Limited): RSI = 52.67, Price = ₹2445.65
# ARMANFIN (Arman Financial Services Limited): RSI = 52.66, Price = ₹1282.35
# HEIDELBERG (HeidelbergCement India Limited): RSI = 52.64, Price = ₹210.62
# CCCL (Consolidated Construction Consortium Limited): RSI = 52.56, Price = ₹17.28
# INDRAMEDCO (Indraprastha Medical Corporation Limited): RSI = 52.54, Price = ₹501.95
# TARIL (N/A): RSI = 52.51, Price = ₹1119.85
# MANAPPURAM (Manappuram Finance Limited): RSI = 52.51, Price = ₹182.98
# AARTIDRUGS (Aarti Drugs Limited): RSI = 52.49, Price = ₹435.10
# BAJAJHLDNG (Bajaj Holdings & Investment Limited): RSI = 52.46, Price = ₹10960.00
# AZAD (N/A): RSI = 52.38, Price = ₹1691.00
# JAIPURKURT (Nandani Creation Limited): RSI = 52.37, Price = ₹35.54
# ASPINWALL (Aspinwall and Company Limited): RSI = 52.31, Price = ₹306.35
# APLLTD (Alembic Pharmaceuticals Limited): RSI = 52.19, Price = ₹1054.75
# XCHANGING (Xchanging Solutions Limited): RSI = 52.17, Price = ₹110.85
# HONAUT (Honeywell Automation India Limited): RSI = 52.15, Price = ₹41450.00
# KARMAENG (Karma Energy Limited): RSI = 52.12, Price = ₹69.97
# ROHLTD (Royal Orchid Hotels Limited): RSI = 52.12, Price = ₹347.75
# TANLA (Tanla Platforms Limited): RSI = 52.11, Price = ₹676.55
# RELIABLE (Reliable Data Services Limited): RSI = 52.09, Price = ₹70.05
# SALONA (Salona Cotspin Limited): RSI = 52.02, Price = ₹296.95
# MANINFRA (Man Infraconstruction Limited): RSI = 52.01, Price = ₹235.73
# KOHINOOR (Kohinoor Foods Limited): RSI = 52.01, Price = ₹40.75
# WEL (Wonder Electricals Limited): RSI = 51.98, Price = ₹160.55
# AEGISLOG (N/A): RSI = 51.94, Price = ₹839.90
# DANGEE (Dangee Dums Limited): RSI = 51.92, Price = ₹7.02
# GLENMARK (Glenmark Pharmaceuticals Limited): RSI = 51.92, Price = ₹1551.30
# AIROLAM (Airo Lam Limited): RSI = 51.89, Price = ₹128.23
# MHRIL (Mahindra Holidays & Resorts India Limited): RSI = 51.87, Price = ₹363.75
# SDBL (Som Distilleries & Breweries Limited): RSI = 51.85, Price = ₹111.25
# AWL (Adani Wilmar Limited): RSI = 51.84, Price = ₹295.50
# KRN (N/A): RSI = 51.82, Price = ₹715.00
# GLAND (Gland Pharma Limited): RSI = 51.81, Price = ₹1784.95
# ARTEMISMED (Artemis Medicare Services Limited): RSI = 51.77, Price = ₹326.40
# MANAKALUCO (Manaksia Aluminium Company Limited): RSI = 51.74, Price = ₹29.75
# GOCOLORS (Go Fashion (India) Limited): RSI = 51.74, Price = ₹985.35
# GMMPFAUDLR (GMM Pfaudler Limited): RSI = 51.71, Price = ₹1226.70
# GRANULES (Granules India Limited): RSI = 51.63, Price = ₹595.30
# KAMDHENU (Kamdhenu Limited): RSI = 51.63, Price = ₹48.15
# STEELCAS (Steelcast Limited): RSI = 51.51, Price = ₹872.20
# RESPONIND (Responsive Industries Limited): RSI = 51.50, Price = ₹253.80
# GOCLCORP (GOCL Corporation Limited): RSI = 51.50, Price = ₹370.00
# CIPLA (Cipla Limited): RSI = 51.48, Price = ₹1476.20
# GPTHEALTH (GPT Healthcare Limited): RSI = 51.48, Price = ₹178.96
# STARCEMENT (Star Cement Limited): RSI = 51.47, Price = ₹215.08
# ASTEC (Astec LifeSciences Limited): RSI = 51.40, Price = ₹1096.55
# BEDMUTHA (Bedmutha Industries Limited): RSI = 51.40, Price = ₹203.22
# KHANDSE (Khandwala Securities Limited): RSI = 51.38, Price = ₹28.39
# ZYDUSWELL (Zydus Wellness Limited): RSI = 51.32, Price = ₹1918.90
# DEEPAKFERT (Deepak Fertilisers And Petrochemicals Corporation Limited): RSI = 51.28, Price = ₹1154.00
# UNITEDTEA (The United Nilgiri Tea Estates Company Limited): RSI = 51.28, Price = ₹525.80
# BLUESTARCO (Blue Star Limited): RSI = 51.27, Price = ₹1996.50
# SAMMAANCAP (Sammaan Capital Limited): RSI = 51.26, Price = ₹152.88
# BHAGERIA (Bhageria Industries Limited): RSI = 51.22, Price = ₹200.00
# SREEL (Sreeleathers Limited): RSI = 51.18, Price = ₹263.65
# AIAENG (AIA Engineering Limited): RSI = 51.15, Price = ₹3373.70
# COFORGE (Coforge Limited): RSI = 51.14, Price = ₹9401.10
# JSWINFRA (JSW Infrastructure Limited): RSI = 51.13, Price = ₹310.40
# WEBELSOLAR (Websol Energy System Limited): RSI = 51.12, Price = ₹1742.55
# SAH (Sah Polymers Limited): RSI = 51.09, Price = ₹90.00
# LINDEINDIA (Linde India Limited): RSI = 51.07, Price = ₹6395.40
# DCMSHRIRAM (DCM Shriram Limited): RSI = 51.07, Price = ₹1072.15
# TGBHOTELS (TGB Banquets and Hotels Limited): RSI = 51.04, Price = ₹14.04
# SATIN (Satin Creditcare Network Limited): RSI = 51.00, Price = ₹150.10
# CRISIL (CRISIL Limited): RSI = 51.00, Price = ₹5801.00
# RPSGVENT (RPSG Ventures Limited): RSI = 50.92, Price = ₹1055.05
# MITTAL (Mittal Life Style Limited): RSI = 50.91, Price = ₹2.22
# SILLYMONKS (Silly Monks Entertainment Limited): RSI = 50.85, Price = ₹24.50
# IDEAFORGE (ideaForge Technology Limited): RSI = 50.83, Price = ₹589.95
# DBSTOCKBRO (DB (International) Stock Brokers Limited): RSI = 50.82, Price = ₹44.45
# ATGL (Adani Total Gas Limited): RSI = 50.79, Price = ₹677.25
# KABRAEXTRU (Kabra Extrusiontechnik Limited): RSI = 50.74, Price = ₹512.90
# AUTOAXLES (Automotive Axles Limited): RSI = 50.73, Price = ₹1784.85
# IRCTC (Indian Railway Catering & Tourism Corporation Limited): RSI = 50.73, Price = ₹785.95
# GLS (Alivus Life Sciences Limited): RSI = 50.72, Price = ₹1017.00
# CRAFTSMAN (Craftsman Automation Limited): RSI = 50.69, Price = ₹5201.40
# LYKALABS (Lyka Labs Limited): RSI = 50.69, Price = ₹150.30
# BLISSGVS (Bliss GVS Pharma Limited): RSI = 50.69, Price = ₹162.06
# UJJIVANSFB (Ujjivan Small Finance Bank Limited): RSI = 50.66, Price = ₹34.25
# RHL (Robust Hotels Limited): RSI = 50.56, Price = ₹263.00
# EMCURE (N/A): RSI = 50.49, Price = ₹1375.80
# XTGLOBAL (XTGlobal Infotech Limited): RSI = 50.49, Price = ₹42.36
# BAJAJ-AUTO (Bajaj Auto Limited): RSI = 50.45, Price = ₹8800.00
# BLKASHYAP (B.L. Kashyap and Sons Limited): RSI = 50.44, Price = ₹76.30
# TVTODAY (T.V. Today Network Limited): RSI = 50.37, Price = ₹206.72
# ARROWGREEN (Arrow Greentech Limited): RSI = 50.37, Price = ₹824.35
# SETCO (Setco Automotive Limited): RSI = 50.36, Price = ₹20.20
# TRIGYN (Trigyn Technologies Limited): RSI = 50.33, Price = ₹110.00
# ELGIRUBCO (Elgi Rubber Company Limited): RSI = 50.31, Price = ₹121.41
# JAYNECOIND (Jayaswal Neco Industries Limited): RSI = 50.30, Price = ₹39.83
# RVTH (Revathi Equipment India Limited): RSI = 50.29, Price = ₹2051.30
# SHALBY (Shalby Limited): RSI = 50.28, Price = ₹225.97
# EMAMILTD (Emami Limited): RSI = 50.17, Price = ₹591.35
# BCONCEPTS (Brand Concepts Limited): RSI = 50.17, Price = ₹477.00
# MRPL (Mangalore Refinery and Petrochemicals Limited): RSI = 50.07, Price = ₹142.27
# GOKULAGRO (Gokul Agro Resources Limited): RSI = 50.00, Price = ₹350.15
# SUPREMEENG (Supreme Engineering Limited): RSI = 50.00, Price = ₹2.91
# GREENLAM (Greenlam Industries Limited): RSI = 49.97, Price = ₹550.20
# MBECL (McNally Bharat Engineering Company Limited): RSI = 49.95, Price = ₹4.19
# ENTERO (Entero Healthcare Solutions Limited): RSI = 49.93, Price = ₹1423.05
# AWFIS (N/A): RSI = 49.87, Price = ₹714.10
# RATEGAIN (RateGain Travel Technologies Limited): RSI = 49.80, Price = ₹696.90
# MMP (MMP Industries Limited): RSI = 49.80, Price = ₹336.75
# KNRCON (KNR Constructions Limited): RSI = 49.79, Price = ₹324.85
# ZEELEARN (Zee Learn Limited): RSI = 49.66, Price = ₹8.30
# IREDA (Indian Renewable Energy Development Agency Limited): RSI = 49.61, Price = ₹205.61
# DEEPINDS (Deep Industries Limited): RSI = 49.57, Price = ₹578.70
# INDOWIND (Indowind Energy Limited): RSI = 49.56, Price = ₹23.99
# STCINDIA (The State Trading Corporation of India Limited): RSI = 49.55, Price = ₹152.80
# MAXHEALTH (Max Healthcare Institute Limited): RSI = 49.55, Price = ₹1162.30
# SIGNATURE (Signatureglobal (India) Limited): RSI = 49.54, Price = ₹1253.50
# MADRASFERT (Madras Fertilizers Limited): RSI = 49.51, Price = ₹96.45
# ESTER (Ester Industries Limited): RSI = 49.39, Price = ₹160.41
# RACE (Race Eco Chain Limited): RSI = 49.36, Price = ₹338.10
# THEMISMED (Themis Medicare Limited): RSI = 49.34, Price = ₹267.65
# KAVVERITEL (Kavveri Defence & Wireless Technologies Limited): RSI = 49.33, Price = ₹57.21
# RSSOFTWARE (R S Software (India) Limited): RSI = 49.32, Price = ₹195.46
# THOMASCOTT (Thomas Scott (India) Limited): RSI = 49.29, Price = ₹451.50
# ACCELYA (Accelya Solutions India Limited): RSI = 49.28, Price = ₹1502.05
# TIPSFILMS (Tips Films Limited): RSI = 49.26, Price = ₹618.70
# DICIND (DIC India Limited): RSI = 49.25, Price = ₹675.00
# MEDIASSIST (N/A): RSI = 49.21, Price = ₹592.60
# UNITDSPR (N/A): RSI = 49.21, Price = ₹1540.20
# APEX (Apex Frozen Foods Limited): RSI = 49.20, Price = ₹245.25
# AMIORG (Ami Organics Limited): RSI = 49.17, Price = ₹2102.95
# EXXARO (Exxaro Tiles Limited): RSI = 49.16, Price = ₹8.75
# REDINGTON (Redington Limited): RSI = 49.11, Price = ₹204.61
# ASKAUTOLTD (N/A): RSI = 49.11, Price = ₹468.70
# SMSPHARMA (SMS Pharmaceuticals Limited): RSI = 48.96, Price = ₹229.57
# LINCOLN (Lincoln Pharmaceuticals Limited): RSI = 48.95, Price = ₹806.70
# HOVS (HOV Services Limited): RSI = 48.91, Price = ₹72.12
# VSTTILLERS (V.S.T. Tillers Tractors Limited): RSI = 48.88, Price = ₹4911.85
# UGROCAP (UGRO Capital Limited): RSI = 48.82, Price = ₹233.02
# JTEKTINDIA (JTEKT India Limited): RSI = 48.82, Price = ₹161.11
# JASH (Jash Engineering Limited): RSI = 48.80, Price = ₹591.85
# VINATIORGA (Vinati Organics Limited): RSI = 48.80, Price = ₹1700.20
# DELTAMAGNT (Delta Manufacturing Limited): RSI = 48.77, Price = ₹107.00
# UBL (United Breweries Limited): RSI = 48.74, Price = ₹2015.10
# AARTIIND (Aarti Industries Limited): RSI = 48.71, Price = ₹413.40
# TI (Tilaknagar Industries Ltd.): RSI = 48.66, Price = ₹407.95
# RCF (Rashtriya Chemicals and Fertilizers Limited): RSI = 48.65, Price = ₹168.36
# VOLTAS (Voltas Limited): RSI = 48.60, Price = ₹1727.90
# GENSOL (Gensol Engineering Limited): RSI = 48.59, Price = ₹749.00
# FACT (The Fertilisers and Chemicals Travancore Limited): RSI = 48.55, Price = ₹939.05
# CIEINDIA (CIE Automotive India Limited): RSI = 48.50, Price = ₹457.75
# RPEL (Raghav Productivity Enhancers Limited): RSI = 48.49, Price = ₹704.05
# ICICIGI (ICICI Lombard General Insurance Company Limited): RSI = 48.40, Price = ₹1891.55
# ABINFRA (N/A): RSI = 48.39, Price = ₹91.98
# ROSSARI (Rossari Biotech Limited): RSI = 48.38, Price = ₹787.45
# SANGAMIND (Sangam (India) Limited): RSI = 48.37, Price = ₹402.90
# TARAPUR (Tarapur Transformers Limited): RSI = 48.32, Price = ₹45.06
# CSBBANK (CSB Bank Limited): RSI = 48.28, Price = ₹310.15
# LOTUSEYE (Lotus Eye Hospital and Institute Limited): RSI = 48.26, Price = ₹67.35
# WEALTH (Wealth First Portfolio Managers Limited): RSI = 48.19, Price = ₹1539.00
# TFCILTD (Tourism Finance Corporation of India Limited): RSI = 48.16, Price = ₹160.33
# SHARDAMOTR (Sharda Motor Industries Limited): RSI = 48.15, Price = ₹1878.00
# AVANTIFEED (Avanti Feeds Limited): RSI = 48.14, Price = ₹611.35
# EIHOTEL (EIH Limited): RSI = 48.10, Price = ₹408.35
# ZAGGLE (Zaggle Prepaid Ocean Services Limited): RSI = 48.09, Price = ₹523.50
# LALPATHLAB (Dr. Lal PathLabs Limited): RSI = 48.08, Price = ₹2922.20
# EUREKAFORB (Eureka Forbes Limited): RSI = 48.05, Price = ₹567.50
# AAVAS (Aavas Financiers Limited): RSI = 48.03, Price = ₹1660.40
# SICALLOG (Sical Logistics Limited): RSI = 47.98, Price = ₹139.87
# HUBTOWN (Hubtown Limited): RSI = 47.97, Price = ₹271.60
# GNA (G N A Axles Limited): RSI = 47.96, Price = ₹404.75
# SRM (N/A): RSI = 47.95, Price = ₹366.00
# EXICOM (Exicom Tele-Systems Limited): RSI = 47.94, Price = ₹258.99
# CTE (Cambridge Technology Enterprises Limited): RSI = 47.92, Price = ₹103.33
# REFEX (Refex Industries Limited): RSI = 47.91, Price = ₹483.85
# MPHASIS (Mphasis Limited): RSI = 47.86, Price = ₹2928.80
# INDIAGLYCO (India Glycols Limited): RSI = 47.86, Price = ₹1312.20
# CROWN (Crown Lifters Limited): RSI = 47.82, Price = ₹203.80
# JAMNAAUTO (Jamna Auto Industries Limited): RSI = 47.82, Price = ₹95.74
# VIMTALABS (Vimta Labs Limited): RSI = 47.80, Price = ₹948.00
# RAINBOW (Rainbow Children's Medicare Limited): RSI = 47.74, Price = ₹1534.00
# DCAL (Dishman Carbogen Amcis Limited): RSI = 47.68, Price = ₹271.65
# FDC (FDC Limited): RSI = 47.66, Price = ₹487.30
# SWARAJENG (Swaraj Engines Limited): RSI = 47.65, Price = ₹2956.80
# BEARDSELL (Beardsell Limited): RSI = 47.65, Price = ₹39.25
# ISEC (ICICI Securities Limited): RSI = 47.59, Price = ₹826.70
# MANAKSIA (Manaksia Limited): RSI = 47.57, Price = ₹84.20
# AJANTPHARM (Ajanta Pharma Limited): RSI = 47.56, Price = ₹2821.30
# SURAJLTD (Suraj Limited): RSI = 47.46, Price = ₹504.70
# TRACXN (Tracxn Technologies Limited): RSI = 47.44, Price = ₹73.90
# CARTRADE (CarTrade Tech Limited): RSI = 47.44, Price = ₹1582.10
# ZENTEC (Zen Technologies Limited): RSI = 47.41, Price = ₹2457.40
# SHIVAMILLS (Shiva Mills Limited): RSI = 47.40, Price = ₹97.74
# GOKUL (Gokul Refoils & Solvent Limited): RSI = 47.35, Price = ₹61.00
# WCIL (N/A): RSI = 47.33, Price = ₹110.33
# BANARISUG (Bannari Amman Sugars Limited): RSI = 47.31, Price = ₹3672.40
# ICICIPRULI (ICICI Prudential Life Insurance Company Limited): RSI = 47.29, Price = ₹648.45
# WSTCSTPAPR (West Coast Paper Mills Limited): RSI = 47.25, Price = ₹549.05
# ELECON (Elecon Engineering Company Limited): RSI = 47.24, Price = ₹595.10
# IDFCFIRSTB (IDFC First Bank Limited): RSI = 47.21, Price = ₹61.11
# CHEMCON (Chemcon Speciality Chemicals Limited): RSI = 47.19, Price = ₹226.80
# BALAXI (Balaxi Pharmaceuticals Limited): RSI = 47.17, Price = ₹72.97
# SANSTAR (N/A): RSI = 47.16, Price = ₹115.45
# VEEDOL (Veedol Corporation Limited): RSI = 47.14, Price = ₹1675.75
# WHEELS (Wheels India Limited): RSI = 46.98, Price = ₹697.40
# TOLINS (N/A): RSI = 46.98, Price = ₹198.53
# VARROC (Varroc Engineering Limited): RSI = 46.93, Price = ₹586.15
# IMFA (Indian Metals and Ferro Alloys Limited): RSI = 46.93, Price = ₹877.10
# VASCONEQ (Vascon Engineers Limited): RSI = 46.91, Price = ₹52.92
# INNOVANA (N/A): RSI = 46.90, Price = ₹433.60
# GUJALKALI (Gujarat Alkalies and Chemicals Limited): RSI = 46.89, Price = ₹736.90
# CHOICEIN (Choice International Limited): RSI = 46.88, Price = ₹526.70
# ESAFSFB (ESAF Small Finance Bank): RSI = 46.86, Price = ₹37.95
# GRMOVER (GRM Overseas Limited): RSI = 46.82, Price = ₹188.90
# BLSE (N/A): RSI = 46.81, Price = ₹203.15
# RIIL (Reliance Industrial Infrastructure Limited): RSI = 46.80, Price = ₹1048.40
# CAMPUS (Campus Activewear Limited): RSI = 46.75, Price = ₹281.50
# GOLDENTOBC (Golden Tobacco Limited): RSI = 46.71, Price = ₹38.00
# SPAL (S.P. Apparels Limited): RSI = 46.69, Price = ₹896.05
# MANKIND (Mankind Pharma Limited): RSI = 46.66, Price = ₹2760.20
# HGINFRA (H.G. Infra Engineering Limited): RSI = 46.65, Price = ₹1408.15
# AMDIND (AMD Industries Limited): RSI = 46.65, Price = ₹59.58
# AMBICAAGAR (Ambica Agarbathies Aroma & Industries Limited): RSI = 46.64, Price = ₹30.32
# IMPEXFERRO (Impex Ferro Tech Limited): RSI = 46.60, Price = ₹2.82
# WIPRO (Wipro Limited): RSI = 46.59, Price = ₹301.80
# SUPERHOUSE (Superhouse Limited): RSI = 46.57, Price = ₹199.99
# KFINTECH (KFin Technologies Limited): RSI = 46.57, Price = ₹1400.00
# VIPIND (V.I.P. Industries Limited): RSI = 46.57, Price = ₹458.40
# GALLANTT (Gallantt Ispat Limited): RSI = 46.49, Price = ₹332.55
# LTFOODS (LT Foods Limited): RSI = 46.47, Price = ₹403.55
# SECURKLOUD (SecureKloud Technologies Limited): RSI = 46.46, Price = ₹31.75
# GKWLIMITED (GKW Limited): RSI = 46.43, Price = ₹2410.00
# MEDPLUS (MedPlus Health Services Limited): RSI = 46.40, Price = ₹836.35
# SINTERCOM (Sintercom India Limited): RSI = 46.36, Price = ₹162.27
# COSMOFIRST (Cosmo First Limited): RSI = 46.36, Price = ₹915.90
# DEN (DEN Networks Limited): RSI = 46.33, Price = ₹41.44
# KRSNAA (Krsnaa Diagnostics Limited): RSI = 46.30, Price = ₹876.95
# GULPOLY (Gulshan Polyols Limited): RSI = 46.25, Price = ₹170.98
# SHAH (Shah Metacorp Limited): RSI = 46.20, Price = ₹4.17
# SYRMA (Syrma SGS Technology Limited): RSI = 46.18, Price = ₹580.75
# DGCONTENT (Digicontent Limited): RSI = 46.18, Price = ₹58.52
# ALICON (Alicon Castalloy Limited): RSI = 46.14, Price = ₹1039.70
# AETHER (Aether Industries Limited): RSI = 46.12, Price = ₹864.60
# BANCOINDIA (Banco Products (India) Limited): RSI = 46.12, Price = ₹476.20
# SUNDARMHLD (Sundaram Finance Holdings Limited): RSI = 46.09, Price = ₹285.80
# UTIAMC (UTI Asset Management Company Limited): RSI = 46.06, Price = ₹1202.25
# BORORENEW (Borosil Renewables Limited): RSI = 46.03, Price = ₹587.10
# INDSWFTLTD (Ind-Swift Limited): RSI = 46.02, Price = ₹27.55
# DONEAR (Donear Industries Limited): RSI = 46.01, Price = ₹153.61
# STOVEKRAFT (Stove Kraft Limited): RSI = 45.99, Price = ₹844.90
# JKIL (J. Kumar Infraprojects Limited): RSI = 45.97, Price = ₹741.30
# MUKKA (Mukka Proteins Limited): RSI = 45.96, Price = ₹38.15
# AROGRANITE (Aro Granite Industries Limited): RSI = 45.96, Price = ₹46.15
# ADANIPOWER (Adani Power Limited): RSI = 45.92, Price = ₹486.95
# REGENCERAM (Regency Ceramics Limited): RSI = 45.88, Price = ₹53.03
# MASTEK (Mastek Limited): RSI = 45.79, Price = ₹2984.00
# KIRLOSBROS (Kirloskar Brothers Limited): RSI = 45.75, Price = ₹2078.05
# SYMPHONY (Symphony Limited): RSI = 45.73, Price = ₹1288.00
# ARVINDFASN (Arvind Fashions Limited): RSI = 45.72, Price = ₹513.90
# EXCELINDUS (Excel Industries Limited): RSI = 45.71, Price = ₹1269.00
# FORCEMOT (Force Motors Limited): RSI = 45.69, Price = ₹6533.90
# WALCHANNAG (Walchandnagar Industries Limited): RSI = 45.67, Price = ₹253.25
# CONFIPET (Confidence Petroleum India Limited): RSI = 45.63, Price = ₹70.19
# GENUSPOWER (Genus Power Infrastructures Limited): RSI = 45.62, Price = ₹378.40
# IGARASHI (Igarashi Motors India Limited): RSI = 45.61, Price = ₹688.75
# BALKRISIND (Balkrishna Industries Limited): RSI = 45.59, Price = ₹2748.65
# ARIHANTCAP (Arihant Capital Markets Limited): RSI = 45.57, Price = ₹96.27
# SURANAT&P (Surana Telecom and Power Limited): RSI = 45.57, Price = ₹22.40
# JINDRILL (Jindal Drilling & Industries Limited): RSI = 45.57, Price = ₹742.45
# MOTISONS (N/A): RSI = 45.57, Price = ₹26.80
# SUVEN (Suven Life Sciences Limited): RSI = 45.56, Price = ₹130.41
# APCL (Anjani Portland Cement Limited): RSI = 45.56, Price = ₹157.99
# LATENTVIEW (Latent View Analytics Limited): RSI = 45.55, Price = ₹462.50
# JLHL (Jupiter Life Line Hospitals Limited): RSI = 45.54, Price = ₹1551.00
# RGL (Renaissance Global Limited): RSI = 45.52, Price = ₹173.02
# BAJAJELEC (Bajaj Electricals Limited): RSI = 45.52, Price = ₹761.60
# IRISDOREME (Iris Clothings Limited): RSI = 45.51, Price = ₹61.36
# MANGALAM (Mangalam Drugs & Organics Limited): RSI = 45.51, Price = ₹111.74
# CLEAN (Clean Science and Technology Limited): RSI = 45.50, Price = ₹1410.95
# ALMONDZ (Almondz Global Securities Limited): RSI = 45.50, Price = ₹32.50
# MANORG (Mangalam Organics Limited): RSI = 45.49, Price = ₹420.20
# CINELINE (Cineline India Limited): RSI = 45.47, Price = ₹125.00
# UNICHEMLAB (Unichem Laboratories Limited): RSI = 45.46, Price = ₹702.95
# CORALFINAC (Coral India Finance and Housing Limited): RSI = 45.45, Price = ₹50.19
# ALKEM (Alkem Laboratories Limited): RSI = 45.43, Price = ₹5356.90
# ABSLAMC (Aditya Birla Sun Life AMC Limited): RSI = 45.41, Price = ₹783.60
# GATEWAY (Gateway Distriparks Limited): RSI = 45.40, Price = ₹79.40
# CAREERP (Career Point Limited): RSI = 45.36, Price = ₹385.10
# IRB (IRB Infrastructure Developers Limited): RSI = 45.34, Price = ₹53.55
# AFFORDABLE (Affordable Robotic & Automation Limited): RSI = 45.33, Price = ₹622.50
# KALAMANDIR (Sai Silks (Kalamandir) Limited): RSI = 45.32, Price = ₹164.25
# DIVISLAB (Divi's Laboratories Limited): RSI = 45.28, Price = ₹5760.65
# TEGA (Tega Industries Limited): RSI = 45.26, Price = ₹1589.20
# SIKKO (Sikko Industries Limited): RSI = 45.22, Price = ₹95.99
# MIRCELECTR (MIRC Electronics Limited): RSI = 45.17, Price = ₹22.10
# RBA (Restaurant Brands Asia Limited): RSI = 45.17, Price = ₹78.02
# INCREDIBLE (Incredible Industries Limited): RSI = 45.16, Price = ₹44.71
# UMAEXPORTS (Uma Exports Limited): RSI = 45.16, Price = ₹103.66
# RUBFILA (Rubfila International Limited): RSI = 45.16, Price = ₹77.52
# SRGHFL (SRG Housing Finance Limited): RSI = 45.16, Price = ₹367.45
# DAMODARIND (Damodar Industries Limited): RSI = 45.16, Price = ₹41.74
# BBOX (Black Box Limited): RSI = 45.14, Price = ₹625.70
# SENCO (Senco Gold Limited): RSI = 45.12, Price = ₹1069.35
# GOODLUCK (Goodluck India Limited): RSI = 45.11, Price = ₹903.75
# SHARDACROP (Sharda Cropchem Limited): RSI = 45.10, Price = ₹763.15
# IOLCP (IOL Chemicals and Pharmaceuticals Limited): RSI = 45.08, Price = ₹412.95
# TATAINVEST (Tata Investment Corporation Limited): RSI = 45.07, Price = ₹6415.40
# BASML (Bannari Amman Spinning Mills Ltd): RSI = 45.07, Price = ₹50.84
# RALLIS (Rallis India Limited): RSI = 45.02, Price = ₹289.70
# SOLARINDS (Solar Industries India Limited): RSI = 45.02, Price = ₹9535.95
# SANCO (Sanco Industries Limited): RSI = 45.00, Price = ₹4.06
# ASAHISONG (Asahi Songwon Colors Limited): RSI = 44.97, Price = ₹352.25
# TEXMOPIPES (Texmo Pipes and Products Limited): RSI = 44.97, Price = ₹63.72
# VIRINCHI (Virinchi Limited): RSI = 44.96, Price = ₹27.45
# MURUDCERA (Murudeshwar Ceramics Ltd.): RSI = 44.94, Price = ₹49.63
# ALANKIT (Alankit Limited): RSI = 44.93, Price = ₹20.60
# SSWL (Steel Strips Wheels Limited): RSI = 44.92, Price = ₹196.41
# KANORICHEM (Kanoria Chemicals & Industries Limited): RSI = 44.90, Price = ₹113.47
# TRF (TRF Limited): RSI = 44.90, Price = ₹413.05
# SHAREINDIA (Share India Securities Limited): RSI = 44.87, Price = ₹287.50
# SHILPAMED (Shilpa Medicare Limited): RSI = 44.83, Price = ₹789.60
# METROBRAND (Metro Brands Limited): RSI = 44.83, Price = ₹1253.35
# MTARTECH (MTAR Technologies Limited): RSI = 44.80, Price = ₹1670.35
# INTERARCH (N/A): RSI = 44.79, Price = ₹1569.85
# KECL (Kirloskar Electric Company Limited): RSI = 44.75, Price = ₹176.07
# RPGLIFE (RPG Life Sciences Limited): RSI = 44.73, Price = ₹2126.00
# AHLADA (Ahlada Engineers Limited): RSI = 44.72, Price = ₹91.96
# PSPPROJECT (PSP Projects Limited): RSI = 44.71, Price = ₹665.50
# MOL (Meghmani Organics Limited): RSI = 44.71, Price = ₹79.84
# AIRAN (Airan Limited): RSI = 44.70, Price = ₹33.44
# BHARATGEAR (Bharat Gears Limited): RSI = 44.69, Price = ₹96.31
# FINOPB (Fino Payments Bank Limited): RSI = 44.68, Price = ₹311.05
# SOFTTECH (SoftTech Engineers Limited): RSI = 44.67, Price = ₹471.30
# KANPRPLA (Kanpur Plastipack Limited): RSI = 44.65, Price = ₹123.41
# HITECHGEAR (The Hi-Tech Gears Limited): RSI = 44.61, Price = ₹805.00
# GREENPANEL (Greenpanel Industries Limited): RSI = 44.57, Price = ₹352.25
# SIYSIL (Siyaram Silk Mills Limited): RSI = 44.54, Price = ₹883.60
# LASA (Lasa Supergenerics Limited): RSI = 44.54, Price = ₹27.13
# HPIL (Hindprakash Industries Limited): RSI = 44.48, Price = ₹145.30
# HINDPETRO (Hindustan Petroleum Corporation Limited): RSI = 44.46, Price = ₹390.15
# SHRENIK (Shrenik Limited): RSI = 44.44, Price = ₹0.76
# PRUDENT (Prudent Corporate Advisory Services Limited): RSI = 44.43, Price = ₹2727.50
# BALPHARMA (Bal Pharma Limited): RSI = 44.41, Price = ₹117.74
# APLAPOLLO (APL Apollo Tubes Limited): RSI = 44.41, Price = ₹1525.45
# GTPL (GTPL Hathway Limited): RSI = 44.40, Price = ₹133.95
# HITECHCORP (Hitech Corporation Limited): RSI = 44.38, Price = ₹232.72
# DHRUV (Dhruv Consultancy Services Limited): RSI = 44.35, Price = ₹117.93
# MOTILALOFS (Motilal Oswal Financial Services Limited): RSI = 44.34, Price = ₹892.60
# HARRMALAYA (Harrisons Malayalam Limited): RSI = 44.33, Price = ₹291.60
# LYPSAGEMS (Lypsa Gems & Jewellery Limited): RSI = 44.33, Price = ₹7.34
# WOCKPHARMA (Wockhardt Limited): RSI = 44.33, Price = ₹1403.65
# APCOTEXIND (Apcotex Industries Limited): RSI = 44.32, Price = ₹371.00
# SOTL (Savita Oil Technologies Limited): RSI = 44.30, Price = ₹536.10
# COCHINSHIP (Cochin Shipyard Limited): RSI = 44.22, Price = ₹1449.60
# STYLEBAAZA (Baazar Style Retail Limited): RSI = 44.21, Price = ₹311.70
# WELCORP (Welspun Corp Limited): RSI = 44.15, Price = ₹754.90
# DYCL (Dynamic Cables Limited): RSI = 44.14, Price = ₹946.95
# REPCOHOME (Repco Home Finance Limited): RSI = 44.14, Price = ₹410.00
# CYBERTECH (CyberTech Systems and Software Limited): RSI = 44.06, Price = ₹214.85
# SAHYADRI (Sahyadri Industries Limited): RSI = 44.00, Price = ₹308.45
# MANOMAY (Manomay Tex India Limited): RSI = 43.98, Price = ₹214.80
# VBL (Varun Beverages Limited): RSI = 43.95, Price = ₹598.80
# BIOFILCHEM (Biofil Chemicals and Pharmaceuticals Limited): RSI = 43.94, Price = ₹56.74
# EIHAHOTELS (EIH Associated Hotels Limited): RSI = 43.92, Price = ₹397.55
# TOUCHWOOD (Touchwood Entertainment Limited): RSI = 43.92, Price = ₹145.01
# GLOBAL (Global Education Limited): RSI = 43.90, Price = ₹69.87
# WINDLAS (Windlas Biotech Limited): RSI = 43.90, Price = ₹1004.80
# ANDHRSUGAR (The Andhra Sugars Limited): RSI = 43.86, Price = ₹91.91
# VENKEYS (Venky's (India) Limited): RSI = 43.86, Price = ₹1720.65
# SUNPHARMA (Sun Pharmaceutical Industries Limited): RSI = 43.83, Price = ₹1784.35
# TEMBO (Tembo Global Industries Limited): RSI = 43.83, Price = ₹764.35
# ADANIENSOL (Adani Energy Solutions Limited): RSI = 43.82, Price = ₹742.30
# MAHASTEEL (Mahamaya Steel Industries Limited): RSI = 43.79, Price = ₹192.98
# MAPMYINDIA (C. E. Info Systems Limited): RSI = 43.76, Price = ₹1641.65
# CEREBRAINT (Cerebra Integrated Technologies Limited): RSI = 43.75, Price = ₹9.66
# XPROINDIA (Xpro India Limited): RSI = 43.73, Price = ₹1500.05
# LCCINFOTEC (LCC Infotech Limited): RSI = 43.71, Price = ₹9.10
# TVSELECT (TVS Electronics Limited): RSI = 43.69, Price = ₹386.80
# KAPSTON (Kapston Services Limited): RSI = 43.65, Price = ₹259.00
# ALBERTDAVD (Albert David Limited): RSI = 43.60, Price = ₹1270.05
# TCI (Transport Corporation of India Limited): RSI = 43.60, Price = ₹1056.90
# ASHOKA (Ashoka Buildcon Limited): RSI = 43.60, Price = ₹274.80
# MMTC (MMTC Limited): RSI = 43.59, Price = ₹71.35
# AWHCL (Antony Waste Handling Cell Limited): RSI = 43.58, Price = ₹619.30
# BALUFORGE (Balu Forge Industries Limited): RSI = 43.58, Price = ₹746.15
# SUMIT (Sumit Woods Limited): RSI = 43.51, Price = ₹141.94
# HAPPYFORGE (N/A): RSI = 43.49, Price = ₹995.05
# HIKAL (Hikal Limited): RSI = 43.49, Price = ₹362.30
# MICEL (MIC Electronics Limited): RSI = 43.49, Price = ₹80.46
# HECPROJECT (HEC Infra Projects Limited): RSI = 43.47, Price = ₹115.75
# JUBLINGREA (Jubilant Ingrevia Limited): RSI = 43.42, Price = ₹734.10
# SANDUMA (The Sandur Manganese & Iron Ores Limited): RSI = 43.39, Price = ₹393.60
# FEDERALBNK (The Federal Bank Limited): RSI = 43.38, Price = ₹190.20
# DVL (Dhunseri Ventures Limited): RSI = 43.37, Price = ₹349.55
# SHREDIGCEM (Shree Digvijay Cement Company Limited): RSI = 43.36, Price = ₹83.08
# GPTINFRA (GPT Infraprojects Limited): RSI = 43.35, Price = ₹131.82
# ATUL (Atul Ltd): RSI = 43.31, Price = ₹6887.40
# COUNCODOS (Country Condo's Limited): RSI = 43.28, Price = ₹6.37
# FOSECOIND (Foseco India Limited): RSI = 43.28, Price = ₹4030.00
# LGBBROSLTD (L.G. Balakrishnan & Bros Limited): RSI = 43.18, Price = ₹1254.80
# AGROPHOS (Agro Phos (India) Limited): RSI = 43.18, Price = ₹39.28
# GICHSGFIN (GIC Housing Finance Limited): RSI = 43.17, Price = ₹195.72
# YASHO (Yasho Industries Limited): RSI = 43.16, Price = ₹2004.40
# INDIGO (InterGlobe Aviation Limited): RSI = 43.11, Price = ₹4257.45
# GSFC (Gujarat State Fertilizers & Chemicals Limited): RSI = 43.08, Price = ₹196.44
# IXIGO (N/A): RSI = 43.06, Price = ₹155.45
# RAILTEL (RailTel Corporation of India Limited): RSI = 43.06, Price = ₹384.85
# INTLCONV (International Conveyors Limited): RSI = 43.02, Price = ₹82.05
# ...
# 524576 (Vivid Global Industries Limited): RSI = 45.56, Price = ₹19.94
# 522105 (N/A): RSI = 45.55, Price = ₹58.41
# 540405 (Oceanic Foods Limited): RSI = 45.54, Price = ₹50.00
# 524748 (N/A): RSI = 45.53, Price = ₹42.00
# 513309 (N/A): RSI = 45.49, Price = ₹13.56
# 539399 (Bella Casa Fashion & Retail Limited): RSI = 45.41, Price = ₹567.05
# 532070 (N/A): RSI = 45.35, Price = ₹202.10
# 500168 (Goodyear India Limited): RSI = 45.28, Price = ₹1019.30
# 520123 (N/A): RSI = 45.26, Price = ₹115.55
# 590109 (Nippon India ETF Nifty 50 Shariah BeES): RSI = 45.25, Price = ₹536.92
# 515145 (Hindusthan National Glass & Industries Limited): RSI = 45.24, Price = ₹23.99
# 506528 (N/A): RSI = 45.20, Price = ₹3490.00
# 516096 (N/A): RSI = 45.16, Price = ₹291.00
# 531952 (N/A): RSI = 45.11, Price = ₹98.40
# 500165 (Kansai Nerolac Paints Limited): RSI = 45.08, Price = ₹257.50
# 526881 (63 moons technologies limited): RSI = 45.08, Price = ₹904.00
# 539518 (Uday Jewellery Industries Limited): RSI = 45.06, Price = ₹148.20
# 539527 (Creative Castings Limited): RSI = 44.98, Price = ₹737.25
# 506605 (N/A): RSI = 44.95, Price = ₹2626.55
# 509438 (N/A): RSI = 44.94, Price = ₹8226.90
# 523694 (Apcotex Industries Limited): RSI = 44.86, Price = ₹367.90
# 500420 (Torrent Pharmaceuticals Limited): RSI = 44.85, Price = ₹3325.25
# 526161 (N/A): RSI = 44.81, Price = ₹155.00
# 518011 (N/A): RSI = 44.81, Price = ₹83.24
# 523550 (N/A): RSI = 44.80, Price = ₹78.72
# 533152 (MBL Infrastructures Limited): RSI = 44.80, Price = ₹63.54
# 538081 (Haria Apparels Limited): RSI = 44.79, Price = ₹5.18
# 508989 (Navneet Education Limited): RSI = 44.77, Price = ₹139.50
# 540575 (Star Cement Limited): RSI = 44.74, Price = ₹218.50
# 534532 (Lypsa Gems & Jewellery Limited): RSI = 44.74, Price = ₹7.28
# 538979 (Greenlam Industries Limited): RSI = 44.73, Price = ₹562.40
# 534691 (Comfort Commotrade Limited): RSI = 44.73, Price = ₹43.89
# 538365 (Incredible Industries Limited): RSI = 44.61, Price = ₹46.00
# 504392 (Krishna Ventures Limited): RSI = 44.61, Price = ₹67.18
# 539658 (TeamLease Services Limited): RSI = 44.58, Price = ₹2837.50
# 539336 (Gujarat Gas Limited): RSI = 44.56, Price = ₹500.50
# 539963 (Zeal Aqua Limited): RSI = 44.55, Price = ₹12.57
# 535754 (Orient Cement Limited): RSI = 44.53, Price = ₹338.00
# 534615 (North Eastern Carrying Corporation Limited): RSI = 44.52, Price = ₹34.45
# 534623 (Jupiter Infomedia Limited): RSI = 44.52, Price = ₹50.80
# 540065 (RBL Bank Limited): RSI = 44.49, Price = ₹161.85
# 524634 (N/A): RSI = 44.46, Price = ₹499.20
# 534741 (Virtual Global Education Limited): RSI = 44.44, Price = ₹0.76
# 530665 (N/A): RSI = 44.39, Price = ₹5.49
# 526751 (N/A): RSI = 44.39, Price = ₹26.16
# 533581 (PG Electroplast Limited): RSI = 44.38, Price = ₹950.65
# 539448 (InterGlobe Aviation Limited): RSI = 44.35, Price = ₹4259.10
# 532271 (N/A): RSI = 44.34, Price = ₹3.20
# 530979 (India Home Loan Limited): RSI = 44.31, Price = ₹35.01
# 540702 (Lasa Supergenerics Limited): RSI = 44.28, Price = ₹27.10
# 500319 (N/A): RSI = 44.25, Price = ₹113.45
# 505250 (N/A): RSI = 44.19, Price = ₹117.00
# 505650 (N/A): RSI = 44.18, Price = ₹18.32
# 503100 (The Phoenix Mills Limited): RSI = 44.15, Price = ₹1696.55
# 524520 (KMC Speciality Hospitals (India) Limited): RSI = 44.13, Price = ₹77.04
# 524717 (N/A): RSI = 44.13, Price = ₹754.00
# 526217 (Hitech Corporation Limited): RSI = 44.10, Price = ₹241.00
# 504058 (Indo National Limited): RSI = 44.10, Price = ₹554.40
# 514264 (N/A): RSI = 44.07, Price = ₹20.84
# 509423 (Sanathnagar Enterprises Limited): RSI = 44.05, Price = ₹40.00
# 500660 (GlaxoSmithKline Pharmaceuticals Limited): RSI = 44.03, Price = ₹2207.85
# 521149 (Prime Urban Development India Limited): RSI = 44.02, Price = ₹12.64
# 532896 (Magnum Ventures Limited): RSI = 43.98, Price = ₹39.04
# 533170 (Tamboli Industries Limited): RSI = 43.97, Price = ₹192.80
# 539404 (Satin Creditcare Network Limited): RSI = 43.96, Price = ₹155.55
# 540710 (Capacit'e Infraprojects Limited): RSI = 43.94, Price = ₹420.90
# 531508 (Eveready Industries India Limited): RSI = 43.94, Price = ₹388.30
# 500327 (Pil Italica Lifestyle Limited): RSI = 43.89, Price = ₹13.70
# 513548 (N/A): RSI = 43.89, Price = ₹299.10
# 520051 (Jamna Auto Industries Limited): RSI = 43.88, Price = ₹97.41
# 526721 (N/A): RSI = 43.85, Price = ₹131.65
# 502090 (Sagar Cements Limited): RSI = 43.82, Price = ₹220.10
# 500870 (Castrol India Limited): RSI = 43.77, Price = ₹200.85
# 512149 (N/A): RSI = 43.75, Price = ₹0.82
# 540526 (IRB InvIT Fund): RSI = 43.75, Price = ₹60.09
# 531233 (N/A): RSI = 43.68, Price = ₹30.61
# 539984 (Hindusthan Urban Infrastructure Limited): RSI = 43.68, Price = ₹2484.20
# 532485 (N/A): RSI = 43.66, Price = ₹76.17
# 532268 (Accelya Solutions India Limited): RSI = 43.64, Price = ₹1541.95
# 511218 (Shriram Finance Limited): RSI = 43.64, Price = ₹579.63
# 540210 (Heads UP Ventures Limited): RSI = 43.64, Price = ₹11.46
# 506003 (N/A): RSI = 43.56, Price = ₹57.11
# 533202 (Satchmo Holdings Limited): RSI = 43.54, Price = ₹4.05
# 532410 (N/A): RSI = 43.53, Price = ₹31.62
# 524136 (N/A): RSI = 43.50, Price = ₹602.00
# 531335 (Zydus Wellness Limited): RSI = 43.49, Price = ₹1949.45
# 540647 (Ganges Securities Limited): RSI = 43.48, Price = ₹194.55
# 530557 (N/A): RSI = 43.48, Price = ₹0.78
# 515059 (N/A): RSI = 43.46, Price = ₹56.45
# 511493 (N/A): RSI = 43.44, Price = ₹11.91
# 500650 (Excel Industries Limited): RSI = 43.42, Price = ₹1291.40
# 516108 (N/A): RSI = 43.33, Price = ₹104.60
# 539196 (Amba Enterprises Limited): RSI = 43.32, Price = ₹219.35
# 503624 (N/A): RSI = 43.30, Price = ₹10.11
# 523648 (Plastiblends India Limited): RSI = 43.28, Price = ₹246.85
# 523850 (N/A): RSI = 43.27, Price = ₹460.05
# 530341 (N/A): RSI = 43.27, Price = ₹147.05
# 533023 (ZF Commercial Vehicle Control Systems India Limited): RSI = 43.24, Price = ₹11469.60
# 500367 (N/A): RSI = 43.19, Price = ₹78.49
# 532531 (Strides Pharma Science Limited): RSI = 43.18, Price = ₹668.85
# 517569 (KEI Industries Limited): RSI = 43.17, Price = ₹4264.00
# 533088 (Mahindra Holidays & Resorts India Limited): RSI = 43.17, Price = ₹369.65
# 524480 (N/A): RSI = 43.15, Price = ₹632.00
# 511764 (N/A): RSI = 43.15, Price = ₹47.10
# 533608 (RDB Rasayans Limited): RSI = 43.14, Price = ₹160.20
# 500422 (Transchem Limited): RSI = 43.12, Price = ₹48.95
# 500250 (L.G. Balakrishnan & Bros Limited): RSI = 43.01, Price = ₹1295.30
# 532806 (AI Champdany Industries Limited): RSI = 42.98, Price = ₹53.78
# 507759 (N/A): RSI = 42.98, Price = ₹23.03
# 526113 (N/A): RSI = 42.97, Price = ₹20.58
# 524703 (N/A): RSI = 42.95, Price = ₹54.86
# 531861 (N/A): RSI = 42.95, Price = ₹51.37
# 533193 (Kirloskar Electric Company Limited): RSI = 42.92, Price = ₹185.80
# 524218 (Resonance Specialties Limited): RSI = 42.90, Price = ₹99.32
# 533168 (Rossell India Limited): RSI = 42.90, Price = ₹76.87
# 533096 (Adani Power Limited): RSI = 42.88, Price = ₹504.40
# 532466 (Oracle Financial Services Software Limited): RSI = 42.84, Price = ₹11983.90
# 532701 (N/A): RSI = 42.82, Price = ₹15.29
# 526409 (Kkalpana Industries (India) Limited): RSI = 42.82, Price = ₹15.84
# 501848 (Global Offshore Services Limited): RSI = 42.78, Price = ₹111.75
# 511359 (N/A): RSI = 42.76, Price = ₹88.80
# 540757 (Sheetal Cool Products Limited): RSI = 42.76, Price = ₹329.85
# 523606 (N/A): RSI = 42.75, Price = ₹2496.50
# 526117 (N/A): RSI = 42.75, Price = ₹481.00
# 513369 (N/A): RSI = 42.74, Price = ₹105.10
# 539126 (MEP Infrastructure Developers Limited): RSI = 42.73, Price = ₹3.05
# 532892 (Motilal Oswal Financial Services Limited): RSI = 42.70, Price = ₹939.60
# 519359 (N/A): RSI = 42.70, Price = ₹71.39
# 531082 (Alankit Limited): RSI = 42.68, Price = ₹21.56
# 533260 (Career Point Limited): RSI = 42.67, Price = ₹389.85
# 539784 (LIC MF Nifty 100 ETF): RSI = 42.66, Price = ₹261.16
# 513488 (N/A): RSI = 42.63, Price = ₹38.73
# 517385 (Symphony Limited): RSI = 42.63, Price = ₹1298.90
# 532764 (GeeCee Ventures Limited): RSI = 42.58, Price = ₹432.00
# 531862 (Bharat Agri Fert and Realty Limited): RSI = 42.57, Price = ₹72.25
# 512634 (Savera Industries Limited): RSI = 42.56, Price = ₹165.85
# 540743 (Godrej Agrovet Limited): RSI = 42.53, Price = ₹739.65
# 530697 (N/A): RSI = 42.51, Price = ₹38.79
# 518075 (N/A): RSI = 42.50, Price = ₹459.95
# 512175 (N/A): RSI = 42.49, Price = ₹8.06
# 539255 (Star Delta Transformers Limited): RSI = 42.48, Price = ₹910.35
# 530809 (N/A): RSI = 42.45, Price = ₹62.89
# 590024 (The Fertilisers And Chemicals Travancore Limited): RSI = 42.44, Price = ₹963.40
# 513687 (N/A): RSI = 42.41, Price = ₹4.51
# 526717 (N/A): RSI = 42.39, Price = ₹149.60
# 530643 (Eco Recycling Limited): RSI = 42.31, Price = ₹902.35
# 537707 (ETT Limited): RSI = 42.30, Price = ₹16.36
# 531041 (N/A): RSI = 42.27, Price = ₹488.25
# 532674 (Bannari Amman Spinning Mills Ltd): RSI = 42.22, Price = ₹53.54
# 513709 (N/A): RSI = 42.18, Price = ₹352.30
# 533285 (RDB Infrastructure and Power Limited): RSI = 42.16, Price = ₹517.30
# 513513 (N/A): RSI = 42.16, Price = ₹10.55
# 538635 (Snowman Logistics Limited): RSI = 42.14, Price = ₹69.01
# 540692 (Apex Frozen Foods Limited): RSI = 42.12, Price = ₹251.95
# 538795 (Shree Ajit Pulp and Paper Limited): RSI = 42.11, Price = ₹207.30
# 532398 (Usha Martin Education & Solutions Limited): RSI = 42.08, Price = ₹6.86
# 520021 (Omax Autos Limited): RSI = 42.07, Price = ₹113.90
# 540777 (HDFC Life Insurance Company Limited): RSI = 42.06, Price = ₹617.55
# 540133 (ICICI Prudential Life Insurance Company Limited): RSI = 42.05, Price = ₹652.50
# 532776 (Shivam Autotech Limited): RSI = 41.99, Price = ₹44.28
# 540393 (Sarthak Metals Limited): RSI = 41.97, Price = ₹159.60
# 540749 (MAS Financial Services Limited): RSI = 41.96, Price = ₹261.60
# 507981 (N/A): RSI = 41.95, Price = ₹94.71
# 500317 (Oswal Agro Mills Limited): RSI = 41.93, Price = ₹70.07
# 540956 (N/A): RSI = 41.89, Price = ₹28.96
# 526500 (N/A): RSI = 41.89, Price = ₹52.40
# 524828 (N/A): RSI = 41.88, Price = ₹335.55
# 530973 (N/A): RSI = 41.85, Price = ₹90.98
# 532807 (Cineline India Limited): RSI = 41.84, Price = ₹129.60
# 501945 (Dhenu Buildcon Infra Limited): RSI = 41.83, Price = ₹5.98
# 590134 (Madras Fertilizers Limited): RSI = 41.83, Price = ₹98.95
# 532975 (N/A): RSI = 41.79, Price = ₹20.23
# 500104 (Hindustan Petroleum Corporation Limited): RSI = 41.78, Price = ₹391.10
# 540716 (ICICI Lombard General Insurance Company Limited): RSI = 41.78, Price = ₹1859.55
# 513063 (N/A): RSI = 41.76, Price = ₹33.97
# 515085 (N/A): RSI = 41.71, Price = ₹7.17
# 517546 (N/A): RSI = 41.70, Price = ₹115.60
# 523840 (N/A): RSI = 41.69, Price = ₹35.34
# 526073 (N/A): RSI = 41.67, Price = ₹1028.15
# 530997 (N/A): RSI = 41.65, Price = ₹180.95
# 516106 (N/A): RSI = 41.64, Price = ₹11.31
# 541353 (Innovators Façade Systems Limited): RSI = 41.63, Price = ₹220.05
# 524667 (Savita Oil Technologies Limited): RSI = 41.63, Price = ₹554.00
# 500179 (HCL Infosystems Limited): RSI = 41.60, Price = ₹15.81
# 533212 (GKB Ophthalmics Limited): RSI = 41.59, Price = ₹97.10
# 540565 (India Grid Trust): RSI = 41.56, Price = ₹143.70
# 530131 (Udaipur Cement Works Limited): RSI = 41.56, Price = ₹29.34
# 533014 (N/A): RSI = 41.54, Price = ₹80.74
# 540124 (G N A Axles Limited): RSI = 41.54, Price = ₹409.35
# 514300 (Pioneer Embroideries Limited): RSI = 41.52, Price = ₹54.79
# 538891 (Magellanic Cloud Limited): RSI = 41.50, Price = ₹65.37
# 533164 (Texmo Pipes and Products Limited): RSI = 41.48, Price = ₹66.09
# 538567 (Gulf Oil Lubricants India Limited): RSI = 41.47, Price = ₹1137.00
# 519224 (Williamson Magor & Co. Limited): RSI = 41.43, Price = ₹39.05
# 533477 (Enkei Wheels (India) Limited): RSI = 41.41, Price = ₹654.95
# 533270 (Bedmutha Industries Limited): RSI = 41.38, Price = ₹200.00
# 540268 (TruCap Finance Limited): RSI = 41.33, Price = ₹15.26
# 533482 (Kridhan Infra Limited): RSI = 41.32, Price = ₹6.13
# 532977 (Bajaj Auto Limited): RSI = 41.29, Price = ₹8642.25
# 500335 (Birla Corporation Limited): RSI = 41.28, Price = ₹1221.95
# 533286 (MOIL Limited): RSI = 41.27, Price = ₹338.25
# 531539 (N/A): RSI = 41.26, Price = ₹39.57
# 526642 (Mirza International Limited): RSI = 41.25, Price = ₹36.72
# 517477 (N/A): RSI = 41.25, Price = ₹397.60
# 532842 (Sree Rayalaseema Hi-Strength Hypo Limited): RSI = 41.25, Price = ₹777.65
# 524731 (N/A): RSI = 41.23, Price = ₹1228.10
# 530343 (Genus Power Infrastructures Limited): RSI = 41.23, Price = ₹387.90
# 539018 (Beekay Steel Industries Limited): RSI = 41.21, Price = ₹670.65
# 531595 (Capri Global Capital Limited): RSI = 41.14, Price = ₹189.30
# 506618 (Punjab Chemicals and Crop Protection Limited): RSI = 41.13, Price = ₹994.00
# 531859 (N/A): RSI = 41.09, Price = ₹303.95
# 539227 (Loyal Equipments Limited): RSI = 41.09, Price = ₹273.90
# 502450 (Seshasayee Paper and Boards Limited): RSI = 41.08, Price = ₹304.05
# 532209 (The Jammu and Kashmir Bank Limited): RSI = 40.99, Price = ₹96.75
# 504093 (Panasonic Energy India Co. Ltd.): RSI = 40.98, Price = ₹445.30
# 513729 (Aro Granite Industries Limited): RSI = 40.97, Price = ₹46.25
# 526849 (Banaras Beads Limited): RSI = 40.96, Price = ₹129.45
# 523736 (Dhunseri Ventures Limited): RSI = 40.94, Price = ₹351.20
# 533758 (APL Apollo Tubes Limited): RSI = 40.93, Price = ₹1538.80
# 526839 (Shelter Infra Projects Limited): RSI = 40.93, Price = ₹18.44
# 533452 (Delphi World Money Limited): RSI = 40.89, Price = ₹203.05
# 531266 (V.S.T. Tillers Tractors Limited): RSI = 40.85, Price = ₹4925.65
# 500304 (NIIT Limited): RSI = 40.82, Price = ₹187.20
# 532407 (N/A): RSI = 40.81, Price = ₹209.60
# 538521 (Yaan Enterprises Limited): RSI = 40.79, Price = ₹79.53
# 524408 (N/A): RSI = 40.78, Price = ₹171.25
# 539871 (Thyrocare Technologies Limited): RSI = 40.78, Price = ₹935.00
# 531289 (National Fittings Limited): RSI = 40.76, Price = ₹132.35
# 531900 (CCL International Limited): RSI = 40.69, Price = ₹30.76
# 530309 (N/A): RSI = 40.66, Price = ₹23.88
# 532173 (CyberTech Systems and Software Limited): RSI = 40.66, Price = ₹216.45
# 504988 (N/A): RSI = 40.65, Price = ₹1302.30
# 526616 (N/A): RSI = 40.65, Price = ₹64.20
# 530427 (N/A): RSI = 40.57, Price = ₹90.00
# 505840 (N/A): RSI = 40.55, Price = ₹34.70
# 532613 (VIP Clothing Limited): RSI = 40.54, Price = ₹44.34
# 526668 (Kamat Hotels (India) Limited): RSI = 40.50, Price = ₹225.35
# 511754 (N/A): RSI = 40.48, Price = ₹695.50
# 517372 (N/A): RSI = 40.48, Price = ₹441.40
# 512131 (Signet Industries Limited): RSI = 40.47, Price = ₹68.85
# 530723 (N/A): RSI = 40.45, Price = ₹145.00
# 500209 (Infosys Limited): RSI = 40.44, Price = ₹1933.15
# 531499 (N/A): RSI = 40.43, Price = ₹6.67
# 532354 (Virgo Global Limited): RSI = 40.43, Price = ₹7.23
# 531273 (N/A): RSI = 40.43, Price = ₹2.94
# 537069 (Arnold Holdings Ltd.): RSI = 40.42, Price = ₹42.91
# 541006 (N/A): RSI = 40.42, Price = ₹20.00
# 537292 (Agri-tech (India) Limited): RSI = 40.42, Price = ₹196.95
# 535458 (NRB Industrial Bearings Limited): RSI = 40.41, Price = ₹23.96
# 504341 (N/A): RSI = 40.40, Price = ₹125.45
# 502180 (Shree Digvijay Cement Company Ltd.): RSI = 40.39, Price = ₹84.84
# 523660 (The Waterbase Limited): RSI = 40.32, Price = ₹71.95
# 526755 (N/A): RSI = 40.30, Price = ₹7.69
# 511147 (N/A): RSI = 40.24, Price = ₹101.90
# 540769 (The New India Assurance Company Limited): RSI = 40.24, Price = ₹194.60
# 511413 (Crest Ventures Limited): RSI = 40.22, Price = ₹434.85
# 514326 (Patspin India Limited): RSI = 40.19, Price = ₹12.63
# 531234 (N/A): RSI = 40.18, Price = ₹118.00
# 517146 (Usha Martin Limited): RSI = 40.16, Price = ₹369.35
# 539254 (Adani Transmission Limited): RSI = 40.15, Price = ₹770.25
# 522275 (GE T&D India Limited): RSI = 40.15, Price = ₹1991.50
# 531398 (Source Natural Foods and Herbal Supplements Limited): RSI = 40.14, Price = ₹182.35
# 533019 (N/A): RSI = 40.10, Price = ₹2420.00
# 504879 (Orient Abrasives Limited): RSI = 40.10, Price = ₹48.73
# 526608 (Electrotherm (India) Limited): RSI = 40.10, Price = ₹1223.15
# 590062 (The Andhra Sugars Limited): RSI = 40.06, Price = ₹93.87
# 524200 (Vinati Organics Limited): RSI = 40.03, Price = ₹1702.45
# 530991 (N/A): RSI = 40.02, Price = ₹71.50
# 517421 (Butterfly Gandhimathi Appliances Limited): RSI = 40.02, Price = ₹779.00
# 500444 (West Coast Paper Mills Limited): RSI = 40.00, Price = ₹552.20
# 539621 (BCL Enterprises Limited): RSI = 40.00, Price = ₹0.94
# 531025 (Visagar Financial Services Limited): RSI = 40.00, Price = ₹0.75
#
# Daily analysis complete. Results saved in stock_analysis\daily_results
