# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()


    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def calculate_ema(self, data, length, source='Close', offset=0, smoothing_length=9):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            smoothing_length (int): Length of initial SMA smoothing
            
        Returns:
            pd.Series: EMA values
        """
        if isinstance(data, pd.Series):
            series_data = data
        else:
            series_data = data[source]
            
        # First calculate SMA as the smoothing line
        sma = series_data.rolling(window=smoothing_length).mean()
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=series_data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(series_data)):
            ema.iloc[i] = (series_data.iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def calculate_tema(self, data, length, source='Close'):
        """
        Calculate the Triple Exponential Moving Average (TEMA) for the given data.
        
        Formula: TEMA = (3 * EMA1) - (3 * EMA2) + EMA3
        Where:
            EMA1 = EMA(price, length)
            EMA2 = EMA(EMA1, length)
            EMA3 = EMA(EMA2, length)
        """
        # Get price series
        if isinstance(data, pd.Series):
            prices = data
        else:
            prices = data[source]
        
        # Calculate multiplier
        multiplier = 2 / (length + 1)
        
        # Calculate EMA1
        ema1 = prices.copy()
        for i in range(1, len(prices)):
            ema1.iloc[i] = (prices.iloc[i] * multiplier) + (ema1.iloc[i-1] * (1 - multiplier))
        
        # Calculate EMA2
        ema2 = ema1.copy()
        for i in range(1, len(ema1)):
            ema2.iloc[i] = (ema1.iloc[i] * multiplier) + (ema2.iloc[i-1] * (1 - multiplier))
        
        # Calculate EMA3
        ema3 = ema2.copy()
        for i in range(1, len(ema2)):
            ema3.iloc[i] = (ema2.iloc[i] * multiplier) + (ema3.iloc[i-1] * (1 - multiplier))
        
        # Calculate TEMA
        tema = (3 * ema1) - (3 * ema2) + ema3
        
        # Replace first 'length' periods with NaN as they won't have enough data
        tema.iloc[:length-1] = np.nan
        
        return tema

    def get_stock_data(self, symbol, exchange='NSE', days=200):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            time.sleep(1)  # Add a delay of 1 second between requests
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty:
                return None, None, None, None

            # Calculate EMAs
            if len(hist_data) >= 9:
                hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close')
            else:
                hist_data['EMA_9'] = float('nan')
                
            if len(hist_data) >= 21:
                hist_data['EMA_21'] = self.calculate_ema(hist_data, length=21, source='Close')
            else:
                hist_data['EMA_21'] = float('nan')
                
            if len(hist_data) >= 50:
                try:
                    hist_data['EMA_50'] = self.calculate_ema(hist_data, length=50, source='Close')
                    hist_data['TEMA_50'] = self.calculate_tema(hist_data, length=50, source='Close')
                    # Add debug print
                    print(f"Debug - {symbol} TEMA calculation successful")
                    print(f"Last TEMA value: {hist_data['TEMA_50'].iloc[-1]}")
                except Exception as e:
                    print(f"Error calculating TEMA for {symbol}: {e}")
                    hist_data['EMA_50'] = float('nan')
                    hist_data['TEMA_50'] = float('nan')
            else:
                hist_data['EMA_50'] = float('nan')
                hist_data['TEMA_50'] = float('nan')
            
            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            return None, None, None, None
        
    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'EMA_21': hist_data['EMA_21'].iloc[-1] if 'EMA_21' in hist_data else 'N/A',
                            'EMA_50': hist_data['EMA_50'].iloc[-1] if 'EMA_50' in hist_data else 'N/A',
                            'TEMA_50': hist_data['TEMA_50'].iloc[-1] if 'TEMA_50' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results


    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2061 NSE and 3026 BSE stocks
# Last TEMA value: 471.1093381943053
# Debug - ASMS TEMA calculation successful
# Last TEMA value: 21.185444675381234
# Debug - ASTEC TEMA calculation successful
# Last TEMA value: 1082.5629460929697
# Debug - ASPINWALL TEMA calculation successful
# Last TEMA value: 304.81532546631865
# Debug - ASTERDM TEMA calculation successful
# Last TEMA value: 516.8535408457869
# Debug - ASTRAL TEMA calculation successful
# Last TEMA value: 1525.405506200071
# Debug - ASTRAMICRO TEMA calculation successful
# Last TEMA value: 768.6841993950117
# Debug - ASTRAZEN TEMA calculation successful
# Last TEMA value: 6866.576660636626
# Debug - ATALREAL TEMA calculation successful
# Last TEMA value: 13.955676804222962
# Debug - ASTRON TEMA calculation successful
# Last TEMA value: 19.994048535651494
# Debug - ATAM TEMA calculation successful
# Last TEMA value: 129.18829063550004
# Debug - ATFL TEMA calculation successful
# Last TEMA value: 914.0258652801465
# Debug - ATGL TEMA calculation successful
# Last TEMA value: 681.5932999751427
# Debug - ATL TEMA calculation successful
# Last TEMA value: 34.92834546474698
# Debug - ATLANTAA TEMA calculation successful
# Last TEMA value: 44.58394733843024
# Debug - ATLASCYCLE TEMA calculation successful
# Last TEMA value: 122.28714906592015
# Debug - ATULAUTO TEMA calculation successful
# Last TEMA value: 534.335152148881
# Debug - ATUL TEMA calculation successful
# Last TEMA value: 6668.132835558222
# Debug - AUBANK TEMA calculation successful
# Last TEMA value: 564.368686056698
# Debug - AURIONPRO TEMA calculation successful
# Last TEMA value: 1667.2699433231953
# Debug - AUROPHARMA TEMA calculation successful
# Last TEMA value: 1190.8323075161934
# Debug - AURUM TEMA calculation successful
# Last TEMA value: 243.98920549575817
# Debug - AUSOMENT TEMA calculation successful
# Last TEMA value: 97.48945191804307
# Debug - AUTOAXLES TEMA calculation successful
# Last TEMA value: 1772.0780811078434
# Debug - AUTOIND TEMA calculation successful
# Last TEMA value: 100.96297725775895
# Debug - AVADHSUGAR TEMA calculation successfulDebug - AVALON TEMA calculation successful
# Last TEMA value: 934.0340751823815
#
# Last TEMA value: 447.2242776326707
# Debug - AVANTIFEED TEMA calculation successful
# Last TEMA value: 645.82974170003
# Debug - AVANTEL TEMA calculation successful
# Last TEMA value: 141.94084384640163
# Debug - AVL TEMA calculation successful
# Last TEMA value: 514.2426773567142
# Debug - AVG TEMA calculation successful
# Last TEMA value: 314.9130336714392
# Debug - AVONMORE TEMA calculation successful
# Last TEMA value: 24.232227904191937
# Debug - AVROIND TEMA calculation successful
# Last TEMA value: 226.69896988830362
# Debug - AVTNPL TEMA calculation successful
# Last TEMA value: 71.53333360930569
# Debug - AWFIS TEMA calculation successful
# Last TEMA value: 714.8868026145711
# Debug - AWHCL TEMA calculation successful
# Last TEMA value: 587.7697964265972
# Debug - AWL TEMA calculation successful
# Last TEMA value: 286.59050805669716
# Debug - AXISCADES TEMA calculation successful
# Last TEMA value: 758.2554550680028
# Debug - AXITA TEMA calculation successful
# Last TEMA value: 10.15953182129118
# Debug - AXISBANK TEMA calculation successful
# Last TEMA value: 1028.7508875008455
# Last TEMA value: 49.79969653919503
# Debug - BATAINDIA TEMA calculation successful
# Last TEMA value: 1366.4657592611302
# Debug - BAYERCROP TEMA calculation successful
# Last TEMA value: 5210.895061730954
# Debug - BBL TEMA calculation successfulDebug - BBOX TEMA calculation successful
# Last TEMA value: 658.458686143407
#
# Last TEMA value: 3313.6966868116833
# Debug - BBTCL TEMA calculation successful
# Last TEMA value: 197.02467936473215
# Debug - BBTC TEMA calculation successful
# Last TEMA value: 1944.71249533413
# Debug - BCLIND TEMA calculation successful
# Last TEMA value: 47.50471310590068
# Debug - BCONCEPTS TEMA calculation successful
# Last TEMA value: 443.91356012138965
# Debug - BDL TEMA calculation successful
# Last TEMA value: 1224.987012615053
# Debug - BEARDSELL TEMA calculation successful
# Last TEMA value: 38.324208713386426
# Debug - BECTORFOOD TEMA calculation successful
# Last TEMA value: 1512.2637382062746
# Debug - BEDMUTHA TEMA calculation successful
# Last TEMA value: 201.19659590344926
# Debug - BERGEPAINT TEMA calculation successful
# Last TEMA value: 442.4230546803856
# Debug - BEML TEMA calculation successful
# Last TEMA value: 3816.1627701703815
# Debug - BFINVEST TEMA calculation successful
# Last TEMA value: 614.6267060509101
# Debug - BEPL TEMA calculation successful
# Last TEMA value: 126.3750005778817
# Debug - BESTAGRO TEMA calculation successful
# Last TEMA value: 582.478150638256
# Debug - BEL TEMA calculation successful
# Last TEMA value: 282.12403985357815
# Debug - BFUTILITIE TEMA calculation successful
# Last TEMA value: 910.5122966130948
# Debug - BGRENERGY TEMA calculation successful
# Last TEMA value: 129.15591087666735
# Debug - BHAGERIA TEMA calculation successful
# Last TEMA value: 185.49352445835504
# Debug - BHAGCHEM TEMA calculation successful
# Last TEMA value: 289.66827157799264
# Debug - BHAGYANGR TEMA calculation successful
# Last TEMA value: 91.26486030934007
# Debug - BHARATGEAR TEMA calculation successful
# Last TEMA value: 96.94589662262976
# Debug - BHARATFORG TEMA calculation successful
# Last TEMA value: 1206.7357250986197
# Debug - BHARATRAS TEMA calculation successful
# Last TEMA value: 9661.185477782887
# Debug - BHANDARI TEMA calculation successfulDebug - BHARATWIRE TEMA calculation successful
# Last TEMA value: 197.35690525417397
#
# Last TEMA value: 6.856311333860834
# Debug - BHARTIARTL TEMA calculation successful
# Last TEMA value: 1601.0046799423912
# Debug - BHARTIHEXA TEMA calculation successful
# Last TEMA value: 1416.7453546757474
# Debug - BHEL TEMA calculation successful
# Last TEMA value: 212.61504445439135
# Debug - BIGBLOC TEMA calculation successfulDebug - BIKAJI TEMA calculation successful
# Last TEMA value: 695.5896072974856
#
# Last TEMA value: 93.33776928088682
# Debug - BIL TEMA calculation successful
# Last TEMA value: 804.7560747443323
# Debug - BINANIIND TEMA calculation successful
# Last TEMA value: 13.334453899509562
# Debug - BIOCON TEMA calculation successful
# Last TEMA value: 381.9617539795083
# Debug - BIOFILCHEM TEMA calculation successful
# Last TEMA value: 55.419624224151406
# Debug - BIRLACABLE TEMA calculation successful
# Last TEMA value: 199.3273478071623
# Debug - BIRLACORPN TEMA calculation successful
# Last TEMA value: 1215.6060136365427
# Debug - BIRLAMONEY TEMA calculation successful
# Last TEMA value: 244.59090196321327
# Debug - BLAL TEMA calculation successful
# Last TEMA value: 229.05098115607106
# Debug - BLBLIMITED TEMA calculation successful
# Last TEMA value: 19.28342867444061
# Debug - BLISSGVS TEMA calculation successful
# Last TEMA value: 173.09718655938323
# Debug - BLKASHYAP TEMA calculation successful
# Last TEMA value: 75.18815902059723
# Debug - BLS TEMA calculation successful
# Last TEMA value: 482.99774857338866
# Debug - BLSE TEMA calculation successful
# Last TEMA value: 197.94434877502277
# Debug - BLUECHIP TEMA calculation successful
# Last TEMA value: 9.1408767285097
# Debug - BLUECOAST TEMA calculation successful
# Last TEMA value: 22.502210177292344
# Debug - BLUEJET TEMA calculation successful
# Last TEMA value: 592.7601558010822
# Debug - BLUEDART TEMA calculation successful
# Last TEMA value: 6381.110551948544
# Debug - BODALCHEM TEMA calculation successful
# Last TEMA value: 64.06030742284686
# Debug - BOROLTD TEMA calculation successful
# Last TEMA value: 391.5394470754857
# Debug - BOMDYEING TEMA calculation successful
# Last TEMA value: 168.7351964840532
# Debug - BLUESTARCO TEMA calculation successful
# Last TEMA value: 2039.0590258152442
# Debug - BORORENEW TEMA calculation successful
# Last TEMA value: 593.9689472538885
# Debug - BOROSCI TEMA calculation successful
# Last TEMA value: 160.70929168567693
# Debug - BPCL TEMA calculation successful
# Last TEMA value: 271.53247072280476
# Debug - BPL TEMA calculation successful
# Last TEMA value: 102.86191776501869
# Debug - BRIGADE TEMA calculation successful
# Last TEMA value: 1170.4786112698096
# Debug - BOSCHLTD TEMA calculation successful
# Last TEMA value: 32011.11930293459
# Debug - BRNL TEMA calculation successful
# Last TEMA value: 45.77190413128619
# Debug - BRITANNIA TEMA calculation successful
# Last TEMA value: 4680.827714933683
# Debug - BROOKS TEMA calculation successful
# Last TEMA value: 180.18306653736857
# Debug - BSE TEMA calculation successful
# Last TEMA value: 5766.1366597013075
# Debug - BSHSL TEMA calculation successful
# Last TEMA value: 141.29055190227234
# Debug - BSL TEMA calculation successful
# Last TEMA value: 261.7789311644883
# Debug - BSOFT TEMA calculation successful
# Last TEMA value: 542.688540427639
# Debug - BTML TEMA calculation successful
# Last TEMA value: 11.743236336820676
# Debug - BURNPUR TEMA calculation successful
# Last TEMA value: 6.517673842681393
# Debug - BUTTERFLY TEMA calculation successful
# Last TEMA value: 732.0966103628296
# Debug - BYKE TEMA calculation successfulDebug - BVCL TEMA calculation successful
# Last TEMA value: 46.76004985430205
#
# Last TEMA value: 93.82985884523703
# CAMLIN-RE.NS: Period '1mo' is invalid, must be one of ['1d', '5d']
# Debug - CALSOFT TEMA calculation successful
# Last TEMA value: 13.255396128373818
# Debug - CAMPUS TEMA calculation successful
# Last TEMA value: 288.3555096569614
# Debug - CAMLINFINE TEMA calculation successful
# Last TEMA value: 135.88392705953657
# Debug - CANTABIL TEMA calculation successful
# Last TEMA value: 296.70040430383506
# Debug - CHEVIOT TEMA calculation successfulDebug - CHOICEIN TEMA calculation successful
# Last TEMA value: 541.0258660627455
#
# Last TEMA value: 1259.9444217560097
# Debug - CHOLAFIN TEMA calculation successful
# Last TEMA value: 1229.3815483664591
# Debug - CHOLAHLDNG TEMA calculation successful
# Last TEMA value: 1407.107135162024
# Debug - CIEINDIA TEMA calculation successful
# Last TEMA value: 463.15624447992525
# Debug - CIGNITITEC TEMA calculation successful
# Last TEMA value: 1720.8277235225078
# Debug - CINELINE TEMA calculation successful
# Last TEMA value: 121.14487973542448
# Debug - CINEVISTA TEMA calculation successful
# Last TEMA value: 17.95976376185335
# Debug - CIPLA TEMA calculation successful
# Last TEMA value: 1452.1047822533399
# Debug - CLEAN TEMA calculation successful
# Last TEMA value: 1411.5955143971357
# Debug - CLEDUCATE TEMA calculation successful
# Last TEMA value: 113.14740937638035
# Debug - CLSEL TEMA calculation successful
# Last TEMA value: 396.8593888420867
# Debug - CMSINFO TEMA calculation successful
# Last TEMA value: 449.31703035523594
# Debug - COALINDIA TEMA calculation successful
# Last TEMA value: 367.6640598391279
# Debug - COASTCORP TEMA calculation successful
# Last TEMA value: 244.809953758492
# Debug - COCHINSHIP TEMA calculation successful
# Last TEMA value: 1501.2054612867169
# Debug - COMSYN TEMA calculation successful
# Last TEMA value: 82.78403367587907
# Debug - COLPAL TEMA calculation successful
# Last TEMA value: 2637.315947699625
# Debug - COFORGE TEMA calculation successful
# Last TEMA value: 9388.037210683768
# Debug - COMPUSOFT TEMA calculation successful
# Last TEMA value: 26.244112084767515
# Debug - CONCORDBIO TEMA calculation successful
# Last TEMA value: 2258.772256528614
# Debug - CONCOR TEMA calculation successful
# Last TEMA value: 756.7654041380348
# Debug - CONFIPET TEMA calculation successful
# Last TEMA value: 70.61324981477941
# Debug - CONSOFINVT TEMA calculation successful
# Last TEMA value: 202.72856668433005
# Debug - CONTROLPR TEMA calculation successful
# Last TEMA value: 720.6954425902813
# Debug - CORALFINAC TEMA calculation successful
# Last TEMA value: 51.096422682294914
# Debug - CORDSCABLE TEMA calculation successful
# Last TEMA value: 187.83404657143706
# Debug - COROMANDEL TEMA calculation successful
# Last TEMA value: 1916.0396687348314
# Debug - COSMOFIRST TEMA calculation successful
# Last TEMA value: 932.5459567922451
# Debug - COUNCODOS TEMA calculation successful
# Last TEMA value: 6.541190591364862
# Debug - CREATIVE TEMA calculation successful
# Last TEMA value: 921.1282823154913
# Debug - CRAFTSMAN TEMA calculation successful
# Last TEMA value: 4966.236684372898
# Debug - CREATIVEYE TEMA calculation successful
# Last TEMA value: 7.4508986063913785
# Debug - CREDITACC TEMA calculation successful
# Last TEMA value: 913.9288066841821
# Debug - CREST TEMA calculation successful
# Last TEMA value: 422.2556259490944
# Debug - CRISIL TEMA calculation successful
# Last TEMA value: 5932.014449689494
# Debug - CSLFINANCE TEMA calculation successful
# Last TEMA value: 296.47948677279504
# Debug - CSBBANK TEMA calculation successful
# Last TEMA value: 312.7768126224305
# Debug - CROWN TEMA calculation successful
# Last TEMA value: 203.755163643615
# Debug - CROMPTON TEMA calculation successful
# Last TEMA value: 362.0471177768777
# Debug - CTE TEMA calculation successful
# Last TEMA value: 102.44998555842929
# Debug - CUBEXTUB TEMA calculation successful
# Last TEMA value: 101.99532450280871
# Debug - CUB TEMA calculation successful
# Last TEMA value: 171.85616750477803
# Debug - CUMMINSIND TEMA calculation successful
# Last TEMA value: 2998.7366808092697
# Debug - CUPID TEMA calculation successful
# Last TEMA value: 73.11660912321163
# Debug - CYBERMEDIA TEMA calculation successful
# Last TEMA value: 24.437068226004808
# Debug - CYBERTECH TEMA calculation successful
# Last TEMA value: 1603.496794641979
# Debug - CYIENT TEMA calculation successful
# Last TEMA value: 1775.1663425830268
# Debug - CYIENTDLM TEMA calculation successful
# Last TEMA value: 621.5700847762271
# Debug - DABUR TEMA calculation successful
# Last TEMA value: 506.9692126398853
# Debug - DALBHARAT TEMA calculation successful
# Last TEMA value: 1750.7188126940503
# Debug - DALMIASUG TEMA calculation successful
# Last TEMA value: 341.57149479194237
# Debug - DAMODARIND TEMA calculation successful
# Last TEMA value: 41.08000830373669
# Debug - DANGEE TEMA calculation successful
# Last TEMA value: 7.1076148041657365
# Debug - DATAMATICS TEMA calculation successful
# Last TEMA value: 657.7222207527551
# Debug - DATAPATTNS TEMA calculation successful
# Last TEMA value: 2324.6438530111764
# Debug - DBL TEMA calculation successful
# Last TEMA value: 426.1055063645883
# Debug - DBEIL TEMA calculation successful
# Last TEMA value: 185.2620759560312
# Debug - DAVANGERE TEMA calculation successful
# Last TEMA value: 5.517987307262587
# Debug - DBCORP TEMA calculation successful
# Last TEMA value: 280.6004515950059
# Debug - DBOL TEMA calculation successful
# Last TEMA value: 104.97790121696065
# Debug - DBREALTY TEMA calculation successful
# Last TEMA value: 167.44168554581194
# Debug - DBSTOCKBRO TEMA calculation successful
# Last TEMA value: 44.35212377282664
# Debug - DCAL TEMA calculation successful
# Last TEMA value: 280.840088998415
# Debug - DCBBANK TEMA calculation successful
# Last TEMA value: 117.20175476346431
# Debug - DCI TEMA calculation successful
# Last TEMA value: 362.22978730294625
# Debug - DCMFINSERV TEMA calculation successful
# Last TEMA value: 7.134879789382729
# Debug - DCM TEMA calculation successful
# Last TEMA value: 109.55813722774849
# Debug - DCMNVL TEMA calculation successful
# Last TEMA value: 200.86807275099073
# Debug - DCMSRIND TEMA calculation successful
# Last TEMA value: 179.77504337940778
# Debug - DCMSHRIRAM TEMA calculation successful
# Last TEMA value: 1072.0387896539623
# Debug - DCW TEMA calculation successful
# Last TEMA value: 82.75793947475104
# Debug - DCXINDIA TEMA calculation successful
# Last TEMA value: 368.9725026530049
# Debug - DEEDEV TEMA calculation successful
# Last TEMA value: 305.4730667381258
# Debug - DECCANCE TEMA calculation successful
# Last TEMA value: 711.9126273930056
# Debug - DEEPAKFERT TEMA calculation successful
# Last TEMA value: 1167.445000144662
# Debug - DEEPAKNTR TEMA calculation successful
# Last TEMA value: 2367.534334481921
# Debug - DEEPINDS TEMA calculation successful
# Last TEMA value: 586.0546055480618
# Debug - DELHIVERY TEMA calculation successful
# Last TEMA value: 332.2782690575695
# Debug - DELPHIFX TEMA calculation successful
# Last TEMA value: 183.5901059343425
# Debug - DELTACORP TEMA calculation successful
# Last TEMA value: 110.519344733344
# Debug - DELTAMAGNT TEMA calculation successful
# Last TEMA value: 108.42524637736021
# Debug - DENORA TEMA calculation successful
# Last TEMA value: 1141.487230514277
# Debug - DEN TEMA calculation successful
# Last TEMA value: 40.08647433602434
# Debug - DEVIT TEMA calculation successful
# Last TEMA value: 171.09388930892072
# Debug - DEVYANI TEMA calculation successful
# Last TEMA value: 186.2799291460121
# Debug - DHAMPURSUG TEMA calculation successful
# Last TEMA value: 149.10051470561402
# Debug - DGCONTENT TEMA calculation successfulDebug - DHANBANK TEMA calculation successful
# Last TEMA value: 27.547512697304626
#
# Last TEMA value: 63.69111337353662
# Debug - DHANI TEMA calculation successful
# Last TEMA value: 99.324677619268
# Debug - DHRUV TEMA calculation successful
# Last TEMA value: 116.5038677179156
# Debug - DHARMAJ TEMA calculation successful
# Last TEMA value: 247.41764196517875
# Debug - DHANUKA TEMA calculation successful
# Last TEMA value: 1411.3447518964306
# Debug - DHUNINV TEMA calculation successful
# Last TEMA value: 1803.2155497229921
# Debug - DIACABS TEMA calculation successful
# Last TEMA value: 134.57699016323755
# Debug - DIAMONDYD TEMA calculation successful
# Last TEMA value: 1110.94166981942
# Debug - DIAMINESQ TEMA calculation successful
# Last TEMA value: 476.1324995214561
# Debug - DICIND TEMA calculation successful
# Last TEMA value: 637.333820792939
# Debug - DIGIDRIVE TEMA calculation successful
# Last TEMA value: 42.358739684909565
# Debug - DIGJAMLMTD TEMA calculation successful
# Last TEMA value: 55.14962113084164
# Debug - DIFFNKG TEMA calculation successful
# Last TEMA value: 327.8057851201166
# Debug - DIGISPICE TEMA calculation successful
# Last TEMA value: 29.351963752908063
# Debug - DIL TEMA calculation successful
# Last TEMA value: 2.6843464645461186
# Debug - DISHTV TEMA calculation successful
# Last TEMA value: 8.88536210991274
# Debug - DIVISLAB TEMA calculation successful
# Last TEMA value: 5916.920194581041
# Debug - DIVGIITTS TEMA calculation successful
# Last TEMA value: 608.8308568573348
# Debug - DIXON TEMA calculation successful
# Last TEMA value: 17834.97667679155
# Debug - DJML TEMA calculation successful
# Last TEMA value: 177.51059359471415
# Debug - DLF TEMA calculation successful
# Last TEMA value: 770.5942657256311
# Debug - DLINKINDIA TEMA calculation successful
# Last TEMA value: 529.9518919237145
# Debug - DMART TEMA calculation successful
# Last TEMA value: 3534.0117759587856
# Debug - DMCC TEMA calculation successful
# Last TEMA value: 369.41715146703103
# Debug - DNAMEDIA TEMA calculation successful
# Last TEMA value: 6.155132468200422
# Debug - DOLATALGO TEMA calculation successful
# Last TEMA value: 112.76862499971841
# Debug - DODLA TEMA calculation successful
# Last TEMA value: 1158.273666792497
# Debug - DOLLAR TEMA calculation successful
# Last TEMA value: 446.20881916017936
# Debug - DOLPHIN TEMA calculation successful
# Last TEMA value: 539.8725160905739
# Debug - DOMS TEMA calculation successful
# Last TEMA value: 2621.0246667690653
# Debug - DONEAR TEMA calculation successful
# Last TEMA value: 162.222615241903
# Debug - DPABHUSHAN TEMA calculation successful
# Last TEMA value: 1467.5380616711009
# Debug - DPSCLTD TEMA calculation successfulDebug - DPWIRES TEMA calculation successful
#
# Last TEMA value: 15.963110287383056
# Last TEMA value: 320.59763239478303
# Debug - DREAMFOLKS TEMA calculation successful
# Debug - DRCSYSTEMS TEMA calculation successful
# Last TEMA value: 28.92025844484122
# Last TEMA value: 365.71444785933636
# Debug - DREDGECORP TEMA calculation successful
# Last TEMA value: 767.572582161283
# Debug - DRREDDY TEMA calculation successful
# Last TEMA value: 1344.7467403422343
# Debug - DTIL TEMA calculation successful
# Last TEMA value: 250.3978973599901
# Debug - DSSL TEMA calculation successful
# Last TEMA value: 1404.3014641167542
# Debug - DUCON TEMA calculation successful
# Last TEMA value: 7.132826685999328
# Debug - DVL TEMA calculation successful
# Last TEMA value: 338.1983247618012
# Debug - DYCL TEMA calculation successful
# Last TEMA value: 991.2220059263141
# Debug - DYNAMATECH TEMA calculation successful
# Last TEMA value: 7924.622510059823
# Debug - DYNPRO TEMA calculation successful
# Last TEMA value: 371.889638772057
# Debug - DWARKESH TEMA calculation successful
# Last TEMA value: 50.36584818852744
# Debug - E2E TEMA calculation successful
# Last TEMA value: 4000.6811693346676
# Debug - EASEMYTRIP TEMA calculation successful
# Last TEMA value: 14.807046538233529
# Debug - ECLERX TEMA calculation successful
# Last TEMA value: 3399.452996516591
# Debug - ECOSMOBLTY TEMA calculation successful
# Last TEMA value: 237.3134608140096
# Debug - EIDPARRY TEMA calculation successful
# Last TEMA value: 869.4513837307051
# Debug - EDELWEISS TEMA calculation successful
# Last TEMA value: 117.93545562926623
# Debug - EICHERMOT TEMA calculation successful
# Last TEMA value: 5064.087174650837
# Debug - EIFFL TEMA calculation successful
# Last TEMA value: 191.81824493830084
# Debug - EIHAHOTELS TEMA calculation successful
# Last TEMA value: 411.9898011032377
# Debug - EIMCOELECO TEMA calculation successful
# Last TEMA value: 1944.9310128975212
# Debug - EKC TEMA calculation successful
# Last TEMA value: 169.81816910867113
# Debug - ELDEHSG TEMA calculation successful
# Last TEMA value: 862.4282104622124
# Debug - EIHOTEL TEMA calculation successful
# Last TEMA value: 415.81069522135846
# Debug - ELECON TEMA calculation successful
# Last TEMA value: 605.7915579531632
# Debug - ELECTCAST TEMA calculation successful
# Last TEMA value: 123.45711513128222
# Debug - ELECTHERM TEMA calculation successfulDebug - ELGIEQUIP TEMA calculation successful
# Last TEMA value: 542.4701972603673
#
# Last TEMA value: 1196.3385082864236
# Debug - ELGIRUBCO TEMA calculation successful
# Last TEMA value: 125.87313190761623
# Debug - EMAMILTD TEMA calculation successful
# Last TEMA value: 557.5746040645124
# Debug - EMAMIPAP TEMA calculation successful
# Last TEMA value: 108.09368178142448
# Debug - ELIN TEMA calculation successful
# Last TEMA value: 180.78226482883073
# Debug - EMCURE TEMA calculation successful
# Last TEMA value: 1393.2834795309598
# Debug - EMBDL TEMA calculation successful
# Last TEMA value: 134.25703470561254
# Debug - EMKAY TEMA calculation successful
# Last TEMA value: 305.1692390484961
# Debug - EMIL TEMA calculation successful
# Last TEMA value: 154.07604067580195
# Debug - EMSLIMITED TEMA calculation successful
# Last TEMA value: 845.7164927960257
# Debug - EMMBI TEMA calculation successful
# Last TEMA value: 148.26778826915296
# Debug - ENDURANCE TEMA calculation successful
# Last TEMA value: 2069.579298212551
# Debug - EMUDHRA TEMA calculation successful
# Last TEMA value: 948.1268665310583
# Debug - ENERGYDEV TEMA calculation successful
# Last TEMA value: 26.815884568827247
# Debug - ENIL TEMA calculation successful
# Last TEMA value: 167.34419202351873
# Debug - ENGINERSIN TEMA calculation successful
# Last TEMA value: 178.0141630880474
# Debug - ENTERO TEMA calculation successful
# Last TEMA value: 1383.280216162669
# Debug - EPIGRAL TEMA calculation successful
# Last TEMA value: 1720.9568247956252
# Debug - EPACK TEMA calculation successful
# Last TEMA value: 571.0282361903282
# Debug - EQUIPPP TEMA calculation successful
# Last TEMA value: 25.157975855812012
# Debug - ERIS TEMA calculation successful
# Last TEMA value: 1293.7982390424145
# Debug - ESABINDIA TEMA calculation successfulDebug - EPL TEMA calculation successful
# Last TEMA value: 244.65232579924464
#
# Last TEMA value: 5384.962648161359
# Debug - EQUITASBNK TEMA calculation successful
# Last TEMA value: 68.84987382780783
# Debug - ESAFSFB TEMA calculation successful
# Last TEMA value: 37.80388997159841
# Debug - ESCORTS TEMA calculation successful
# Last TEMA value: 3351.8702375068942
# Debug - ESSARSHPNG TEMA calculation successful
# Last TEMA value: 34.189620578263884
# Debug - ESSENTIA TEMA calculation successful
# Last TEMA value: 3.1456237967961536
# Debug - ESTER TEMA calculation successful
# Last TEMA value: 155.20627483918048
# Debug - EUROTEXIND TEMA calculation successful
# Last TEMA value: 14.900832514699784
# Debug - EUREKAFORB TEMA calculation successful
# Last TEMA value: 577.2415188605938
# Debug - ETHOSLTD TEMA calculation successful
# Last TEMA value: 2735.258860340914
# Debug - EVEREADY TEMA calculation successful
# Last TEMA value: 372.7897871823031
# Debug - EXCEL TEMA calculation successful
# Last TEMA value: 0.9914831281699897
# Debug - EVERESTIND TEMA calculation successful
# Last TEMA value: 666.9959660177622
# Debug - EXCELINDUS TEMA calculation successful
# Last TEMA value: 1226.1380998383204
# Debug - EXICOM TEMA calculation successful
# Last TEMA value: 238.25386009444514
# Debug - EXIDEIND TEMA calculation successful
# Last TEMA value: 390.67097039534815
# Debug - FACT TEMA calculation successfulDebug - EXXARO TEMA calculation successful
# Last TEMA value: 9.31399639564324
#
# Last TEMA value: 955.4730301777954
# Debug - EXPLEOSOL TEMA calculation successful
# Last TEMA value: 1362.2068518855108
# Debug - FAZE3Q TEMA calculation successful
# Last TEMA value: 417.887170157943
# Debug - FCL TEMA calculation successful
# Last TEMA value: 308.16601915534756
# Debug - FAIRCHEMOR TEMA calculation successful
# Last TEMA value: 1090.9594719003878
# Debug - FCSSOFT TEMA calculation successful
# Last TEMA value: 3.2024306485541754
# Debug - FDC TEMA calculation successful
# Last TEMA value: 483.2344366132587
# Debug - FEDFINA TEMA calculation successful
# Last TEMA value: 99.41006968565344
# Debug - FEL TEMA calculation successful
# Last TEMA value: 0.6029772403666941
# Debug - FEDERALBNK TEMA calculation successful
# Last TEMA value: 195.1339372714418
# Debug - FIBERWEB TEMA calculation successful
# Last TEMA value: 56.72796156939482
# Debug - FELDVR TEMA calculation successful
# Last TEMA value: 4.988839062567275
# Debug - FIEMIND TEMA calculation successful
# Last TEMA value: 1440.855619299825
# Debug - FILATEX TEMA calculation successful
# Last TEMA value: 56.830860057064626
# Debug - FILATFASH TEMA calculation successful
# Last TEMA value: 0.6835631668933204
# Debug - FINOPB TEMA calculation successful
# Last TEMA value: 295.7645496661142
# Debug - FINCABLES TEMA calculation successful
# Last TEMA value: 1057.3319583067691
# Debug - FINEORG TEMA calculation successful
# Last TEMA value: 4383.052341007933
# Debug - FINPIPE TEMA calculation successful
# Last TEMA value: 214.20468394151862
# Debug - FIRSTCRY TEMA calculation successful
# Last TEMA value: 541.709297276814
# Debug - FIVESTAR TEMA calculation successful
# Last TEMA value: 696.5892131706591
# Debug - FLAIR TEMA calculation successful
# Last TEMA value: 271.08982505404816
# Debug - FLEXITUFF TEMA calculation successful
# Last TEMA value: 62.38283492088664
# Debug - FLFL TEMA calculation successful
# Last TEMA value: 2.0530587616249663
# Debug - FLUOROCHEM TEMA calculation successful
# Last TEMA value: 3864.286058358015
# Debug - FMGOETZE TEMA calculation successful
# Last TEMA value: 385.5219295849995
# Debug - FMNL TEMA calculation successful
# Last TEMA value: 27.108075277583108
# Debug - FOCUS TEMA calculation successful
# Last TEMA value: 119.98393079987046
# Debug - FOODSIN TEMA calculation successful
# Last TEMA value: 110.71667395993478
# Debug - FORCEMOT TEMA calculation successful
# Last TEMA value: 6584.919275762071
# Debug - FORTIS TEMA calculation successful
# Last TEMA value: 694.2913957803569
# Debug - FOSECOIND TEMA calculation successful
# Last TEMA value: 3910.372723735518
# Debug - FSL TEMA calculation successful
# Last TEMA value: 388.917016562857
# Debug - FUSION TEMA calculation successful
# Last TEMA value: 175.90203273013384
# Debug - GABRIEL TEMA calculation successful
# Last TEMA value: 462.94115622449567
# Debug - GAEL TEMA calculation successful
# Last TEMA value: 118.52638583788166
# Debug - GAIL TEMA calculation successful
# Last TEMA value: 179.47596932272762
# Debug - GALAXYSURF TEMA calculation successful
# Last TEMA value: 2410.835048892897
# Debug - GALAPREC TEMA calculation successful
# Last TEMA value: 1239.9868035738255
# Debug - GALLANTT TEMA calculation successful
# Last TEMA value: 333.4845723843815
# Debug - GANDHAR TEMA calculation successful
# Last TEMA value: 203.24635911690282
# Debug - GANECOS TEMA calculation successful
# Last TEMA value: 1778.5344421741477
# Debug - GANESHBE TEMA calculation successful
# Last TEMA value: 131.49707799109316
# Debug - GANDHITUBE TEMA calculation successful
# Last TEMA value: 759.6300694557376
# Debug - GANESHHOUC TEMA calculation successful
# Last TEMA value: 1323.0297266537573
# Debug - GANGAFORGE TEMA calculation successful
# Last TEMA value: 6.877658516784312
# Debug - GARUDA TEMA calculation successful
# Last TEMA value: 135.35979770281563
# Debug - GARFIBRES TEMA calculation successful
# Last TEMA value: 839.719852299761
# Debug - GANGESSECU TEMA calculation successful
# Last TEMA value: 191.50483209654024
# Debug - GATECH TEMA calculation successful
# Last TEMA value: 0.7121153036553168
# Debug - GATECHDVR TEMA calculation successful
# Last TEMA value: 0.9730670237688166
# Debug - GATEWAY TEMA calculation successful
# Last TEMA value: 78.73039567859236
# Debug - GAYAPROJ TEMA calculation successful
# Last TEMA value: 7.97857304040914
# Debug - GEECEE TEMA calculation successful
# Last TEMA value: 417.13244645128117
# Debug - GENCON TEMA calculation successfulDebug - GEEKAYWIRE TEMA calculation successful
# Last TEMA value: 93.53063045845818
#
# Last TEMA value: 40.999467087043016
# Debug - GENESYS TEMA calculation successful
# Last TEMA value: 1005.990755166086
# Debug - GENSOL TEMA calculation successful
# Last TEMA value: 742.153614817858
# Debug - GENUSPAPER TEMA calculation successful
# Last TEMA value: 20.310094604978715
# Debug - GENUSPOWER TEMA calculation successful
# Last TEMA value: 373.43909717537355
# Debug - GEPIL TEMA calculation successfulDebug - GEOJITFSL TEMA calculation successful
# Last TEMA value: 102.92817377083435
#
# Last TEMA value: 340.4494555327382
# Debug - GESHIP TEMA calculation successful
# Last TEMA value: 909.7883192445245
# Debug - GFLLIMITED TEMA calculation successful
# Last TEMA value: 80.9009186762639
# Debug - GHCL TEMA calculation successful
# Last TEMA value: 720.4494377327989
# Debug - GHCLTEXTIL TEMA calculation successful
# ...
# 505827 (N/A): RSI = 44.10, Price = ₹369.55
# 509760 (N/A): RSI = 44.10, Price = ₹54.52
# 509009 (AuSom Enterprise Limited): RSI = 44.07, Price = ₹103.75
# 524820 (Panama Petrochem Limited): RSI = 44.05, Price = ₹366.15
# 523319 (Balmer Lawrie & Co. Ltd.): RSI = 44.04, Price = ₹205.75
# 526899 (N/A): RSI = 44.04, Price = ₹18.31
# 526650 (Tourism Finance Corporation of India Limited): RSI = 44.03, Price = ₹150.90
# 521018 (Maral Overseas Limited): RSI = 44.03, Price = ₹80.84
# 539807 (Infibeam Avenues Limited): RSI = 44.03, Price = ₹24.40
# 531979 (N/A): RSI = 44.01, Price = ₹72.64
# 530263 (N/A): RSI = 44.00, Price = ₹0.87
# 534076 (RHI Magnesita India Limited): RSI = 43.95, Price = ₹494.00
# 539730 (Fredun Pharmaceuticals Limited): RSI = 43.94, Price = ₹689.50
# 521200 (Suryalakshmi Cotton Mills Limited): RSI = 43.94, Price = ₹81.53
# 524218 (Resonance Specialties Limited): RSI = 43.94, Price = ₹95.45
# 506528 (N/A): RSI = 43.93, Price = ₹3359.00
# 500488 (Abbott India Limited): RSI = 43.93, Price = ₹27951.80
# 538730 (PDS Limited): RSI = 43.92, Price = ₹530.35
# 535601 (Sreeleathers Limited): RSI = 43.91, Price = ₹247.50
# 500412 (Thirumalai Chemicals Limited): RSI = 43.88, Price = ₹303.40
# 533263 (Orient Green Power Company Limited): RSI = 43.88, Price = ₹16.44
# 532173 (CyberTech Systems and Software Limited): RSI = 43.87, Price = ₹209.45
# 538666 (Sharda Cropchem Limited): RSI = 43.85, Price = ₹727.45
# 526717 (N/A): RSI = 43.83, Price = ₹149.00
# 533146 (D-Link (India) Limited): RSI = 43.83, Price = ₹520.75
# 500346 (N/A): RSI = 43.82, Price = ₹53.72
# 526481 (Phoenix International Limited): RSI = 43.77, Price = ₹59.00
# 540642 (Salasar Techno Engineering Limited): RSI = 43.77, Price = ₹13.09
# 538706 (Ultracab (India) Limited): RSI = 43.76, Price = ₹15.82
# 531025 (Visagar Financial Services Limited): RSI = 43.75, Price = ₹0.73
# 533296 (Future Market Networks Limited): RSI = 43.75, Price = ₹23.17
# 511012 (N/A): RSI = 43.75, Price = ₹1.52
# 532290 (BLB Limited): RSI = 43.73, Price = ₹19.39
# 511066 (Sakthi Finance Limited): RSI = 43.71, Price = ₹57.99
# 590025 (Ginni Filaments Limited): RSI = 43.67, Price = ₹30.10
# 533160 (D B Realty Limited): RSI = 43.64, Price = ₹167.55
# 539784 (LIC MF Nifty 100 ETF): RSI = 43.60, Price = ₹253.71
# 500067 (Blue Star Limited): RSI = 43.54, Price = ₹1923.35
# 503100 (The Phoenix Mills Limited): RSI = 43.53, Price = ₹1644.35
# 500043 (Bata India Limited): RSI = 43.53, Price = ₹1310.85
# 522229 (N/A): RSI = 43.52, Price = ₹399.30
# 524667 (Savita Oil Technologies Limited): RSI = 43.47, Price = ₹513.35
# 511208 (IL&FS Investment Managers Limited): RSI = 43.47, Price = ₹10.55
# 505163 (ZF Steering Gear (India) Limited): RSI = 43.46, Price = ₹1386.05
# 532985 (Kotak BSE Sensex ETF): RSI = 43.43, Price = ₹83.17
# 538365 (Incredible Industries Limited): RSI = 43.41, Price = ₹48.61
# 500257 (Lupin Limited): RSI = 43.37, Price = ₹2111.80
# 540954 (N/A): RSI = 43.37, Price = ₹48.50
# 500840 (EIH Limited): RSI = 43.35, Price = ₹398.70
# 500150 (Foseco India Limited): RSI = 43.35, Price = ₹3934.45
# 523369 (DCM Shriram Industries Limited): RSI = 43.33, Price = ₹176.40
# 521064 (Trident Limited): RSI = 43.33, Price = ₹32.13
# 504212 (Universal Cables Limited): RSI = 43.32, Price = ₹747.30
# 531437 (N/A): RSI = 43.29, Price = ₹36.31
# 533260 (Career Point Limited): RSI = 43.27, Price = ₹360.50
# 506405 (DMCC Speciality Chemicals Limited): RSI = 43.26, Price = ₹357.75
# 523842 (Super Tannery Limited): RSI = 43.25, Price = ₹10.97
# 500370 (Salora International Limited): RSI = 43.24, Price = ₹65.55
# 532776 (Shivam Autotech Limited): RSI = 43.23, Price = ₹40.80
# 506525 (Kanoria Chemicals & Industries Limited): RSI = 43.22, Price = ₹109.10
# 513513 (N/A): RSI = 43.21, Price = ₹10.23
# 521216 (N/A): RSI = 43.18, Price = ₹186.40
# 533344 (PTC India Financial Services Limited): RSI = 43.17, Price = ₹38.69
# 519097 (N/A): RSI = 43.13, Price = ₹27.98
# 512393 (N/A): RSI = 43.12, Price = ₹81.00
# 506734 (Mysore Petro Chemicals Limited): RSI = 43.09, Price = ₹147.50
# 531862 (Bharat Agri Fert and Realty Limited): RSI = 43.07, Price = ₹68.82
# 531041 (N/A): RSI = 43.07, Price = ₹477.00
# 532674 (Bannari Amman Spinning Mills Ltd): RSI = 43.04, Price = ₹48.80
# 533282 (Gravita India Limited): RSI = 43.04, Price = ₹2130.10
# 539300 (A.K. Spintex Limited): RSI = 42.99, Price = ₹699.00
# 537291 (Nath Bio-Genes (India) Limited): RSI = 42.98, Price = ₹180.25
# 540203 (Sheela Foam Limited): RSI = 42.98, Price = ₹942.80
# 513349 (Ajmera Realty & Infra India Limited): RSI = 42.97, Price = ₹996.40
# 540699 (Dixon Technologies (India) Limited): RSI = 42.95, Price = ₹17231.75
# 538987 (Talbros Engineering Limited): RSI = 42.95, Price = ₹585.45
# 520066 (Jay Bharat Maruti Limited): RSI = 42.93, Price = ₹81.61
# 540192 (LKP Securities Limited): RSI = 42.92, Price = ₹25.92
# 538476 (Capital Trade Links Limited): RSI = 42.91, Price = ₹47.00
# 526113 (N/A): RSI = 42.89, Price = ₹19.82
# 532478 (United Breweries Limited): RSI = 42.89, Price = ₹1951.50
# 531726 (Panchsheel Organics Limited): RSI = 42.89, Price = ₹195.80
# 500213 (N/A): RSI = 42.85, Price = ₹652.90
# 509945 (N/A): RSI = 42.85, Price = ₹1764.00
# 500444 (West Coast Paper Mills Limited): RSI = 42.84, Price = ₹540.15
# 505872 (N/A): RSI = 42.83, Price = ₹695.15
# 530711 (N/A): RSI = 42.83, Price = ₹89.05
# 511355 (N/A): RSI = 42.83, Price = ₹17.65
# 506981 (N/A): RSI = 42.82, Price = ₹174.00
# 519262 (N/A): RSI = 42.80, Price = ₹26.50
# 506808 (N/A): RSI = 42.79, Price = ₹92.41
# 500089 (DIC India Limited): RSI = 42.79, Price = ₹640.00
# 522152 (N/A): RSI = 42.79, Price = ₹105.80
# 532443 (Cera Sanitaryware Limited): RSI = 42.78, Price = ₹6903.75
# 501298 (N/A): RSI = 42.77, Price = ₹5619.00
# 533285 (RDB Infrastructure and Power Limited): RSI = 42.74, Price = ₹513.70
# 520075 (N/A): RSI = 42.71, Price = ₹164.50
# 504132 (N/A): RSI = 42.71, Price = ₹904.50
# 531216 (Comfort Intech Limited): RSI = 42.67, Price = ₹12.14
# 524818 (N/A): RSI = 42.65, Price = ₹110.15
# 531082 (Alankit Limited): RSI = 42.64, Price = ₹20.53
# 512443 (N/A): RSI = 42.64, Price = ₹8.37
# 530367 (NRB Bearings Limited): RSI = 42.60, Price = ₹268.10
# 511377 (N/A): RSI = 42.60, Price = ₹35.00
# 522267 (N/A): RSI = 42.59, Price = ₹78.70
# 506943 (J. B. Chemicals & Pharmaceuticals Limited): RSI = 42.59, Price = ₹1747.50
# 532123 (N/A): RSI = 42.58, Price = ₹11.85
# 533543 (Brooks Laboratories Limited): RSI = 42.57, Price = ₹167.00
# 511577 (N/A): RSI = 42.56, Price = ₹20.58
# 524520 (KMC Speciality Hospitals (India) Limited): RSI = 42.55, Price = ₹73.24
# 540755 (General Insurance Corporation of India): RSI = 42.53, Price = ₹438.10
# 500317 (Oswal Agro Mills Limited): RSI = 42.52, Price = ₹65.70
# 523269 (Advani Hotels & Resorts (India) Limited): RSI = 42.50, Price = ₹65.31
# 517356 (N/A): RSI = 42.50, Price = ₹2.54
# 533608 (RDB Rasayans Limited): RSI = 42.50, Price = ₹151.65
# 531842 (N/A): RSI = 42.46, Price = ₹42.23
# 524828 (N/A): RSI = 42.46, Price = ₹341.05
# 534639 (Vinayak Polycon International Limited): RSI = 42.45, Price = ₹36.47
# 500469 (The Federal Bank Limited): RSI = 42.44, Price = ₹191.55
# 505978 (N/A): RSI = 42.43, Price = ₹4948.30
# 539742 (Simbhaoli Sugars Limited): RSI = 42.40, Price = ₹18.80
# 540544 (PSP Projects Limited): RSI = 42.39, Price = ₹651.70
# 500268 (Manali Petrochemicals Limited): RSI = 42.39, Price = ₹60.87
# 590005 (Tide Water Oil Co. (India) Limited): RSI = 42.38, Price = ₹1594.90
# 540691 (Aditya Birla Capital Limited): RSI = 42.36, Price = ₹177.10
# 524703 (N/A): RSI = 42.35, Price = ₹54.00
# 530821 (SSPDL Limited): RSI = 42.32, Price = ₹20.99
# 538634 (Vasundhara Rasayans Limited): RSI = 42.31, Price = ₹285.35
# 516108 (N/A): RSI = 42.31, Price = ₹103.20
# 531273 (N/A): RSI = 42.31, Price = ₹2.82
# 530129 (N/A): RSI = 42.30, Price = ₹1754.35
# 538778 (Kalyan Capitals Limited): RSI = 42.30, Price = ₹12.34
# 524408 (N/A): RSI = 42.28, Price = ₹161.10
# 505368 (Revathi Equipment Limited): RSI = 42.24, Price = ₹366.45
# 500166 (Goodricke Group Limited): RSI = 42.21, Price = ₹269.95
# 507960 (N/A): RSI = 42.20, Price = ₹312.05
# 502873 (N/A): RSI = 42.19, Price = ₹122.05
# 539523 (Alkem Laboratories Limited): RSI = 42.19, Price = ₹5251.20
# 517380 (Igarashi Motors India Limited): RSI = 42.17, Price = ₹667.20
# 532893 (VTM Limited): RSI = 42.17, Price = ₹170.75
# 533292 (A2Z Infra Engineering Limited): RSI = 42.13, Price = ₹22.72
# 532234 (National Aluminium Company Limited): RSI = 42.05, Price = ₹205.25
# 523151 (N/A): RSI = 42.04, Price = ₹7.45
# 531822 (Rodium Realty Limited): RSI = 42.01, Price = ₹149.00
# 539871 (Thyrocare Technologies Limited): RSI = 41.99, Price = ₹851.80
# 530043 (N/A): RSI = 41.98, Price = ₹287.70
# 524522 (N/A): RSI = 41.97, Price = ₹50.77
# 524164 (IOL Chemicals and Pharmaceuticals Limited): RSI = 41.97, Price = ₹389.60
# 534091 (Multi Commodity Exchange of India Limited): RSI = 41.92, Price = ₹6032.75
# 507789 (Jagsonpal Pharmaceuticals Limited): RSI = 41.90, Price = ₹218.00
# 511451 (N/A): RSI = 41.89, Price = ₹11.39
# 533632 (Onelife Capital Advisors Limited): RSI = 41.89, Price = ₹16.27
# 532029 (Sindhu Trade Links Limited): RSI = 41.88, Price = ₹21.03
# 540065 (RBL Bank Limited): RSI = 41.87, Price = ₹155.10
# 500039 (Banco Products (India) Limited): RSI = 41.87, Price = ₹462.20
# 512634 (Savera Industries Limited): RSI = 41.86, Price = ₹162.50
# 502355 (Balkrishna Industries Limited): RSI = 41.86, Price = ₹2704.40
# 532641 (Nandan Denim Limited): RSI = 41.85, Price = ₹4.69
# 590062 (The Andhra Sugars Limited): RSI = 41.84, Price = ₹89.66
# 533506 (Inventure Growth & Securities Limited): RSI = 41.82, Price = ₹1.99
# 532656 (N/A): RSI = 41.81, Price = ₹4.64
# 524640 (Archit Organosys Limited): RSI = 41.81, Price = ₹44.63
# 534742 (Zuari Agro Chemicals Limited): RSI = 41.80, Price = ₹203.55
# 523465 (N/A): RSI = 41.79, Price = ₹46.02
# 518011 (N/A): RSI = 41.75, Price = ₹84.21
# 504058 (Indo National Limited): RSI = 41.75, Price = ₹529.70
# 501700 (N/A): RSI = 41.75, Price = ₹13.94
# 513599 (Hindustan Copper Limited): RSI = 41.73, Price = ₹247.40
# 533014 (N/A): RSI = 41.73, Price = ₹76.96
# 500136 (Ester Industries Limited): RSI = 41.68, Price = ₹149.25
# 538422 (Jackson Investments Limited): RSI = 41.67, Price = ₹0.74
# 537800 (Mangalam Industrial Finance Limited): RSI = 41.67, Price = ₹3.24
# 531092 (Om Infra Limited): RSI = 41.66, Price = ₹150.55
# 511559 (Times Guaranty Limited): RSI = 41.65, Price = ₹173.55
# 504076 (N/A): RSI = 41.64, Price = ₹91.67
# 532455 (N/A): RSI = 41.63, Price = ₹22.25
# 513498 (N/A): RSI = 41.61, Price = ₹250.20
# 524019 (Kingfa Science & Technology (India) Limited): RSI = 41.60, Price = ₹3114.00
# 531845 (Zenith Steel Pipes & Industries Limited): RSI = 41.60, Price = ₹7.60
# 532725 (Solar Industries India Limited): RSI = 41.56, Price = ₹9710.45
# 500151 (Golden Tobacco Limited): RSI = 41.55, Price = ₹38.21
# 504036 (Hind Rectifiers Limited): RSI = 41.55, Price = ₹1290.50
# 533289 (Kesar Terminals & Infrastructure Limited): RSI = 41.55, Price = ₹72.03
# 523704 (Mastek Limited): RSI = 41.54, Price = ₹2750.75
# 537707 (ETT Limited): RSI = 41.52, Price = ₹15.81
# 509423 (Sanathnagar Enterprises Limited): RSI = 41.51, Price = ₹36.92
# 535566 (KIFS Financial Services Limited): RSI = 41.51, Price = ₹149.00
# 500058 (N/A): RSI = 41.48, Price = ₹15.83
# 520073 (N/A): RSI = 41.42, Price = ₹830.35
# 531923 (N/A): RSI = 41.42, Price = ₹114.10
# 505358 (Integra Engineering India Limited): RSI = 41.40, Price = ₹231.60
# 530185 (N/A): RSI = 41.40, Price = ₹7.72
# 530829 (N/A): RSI = 41.39, Price = ₹56.31
# 522249 (Mayur Uniquoters Limited): RSI = 41.35, Price = ₹575.30
# 539267 (Samsrita Labs Limited): RSI = 41.35, Price = ₹22.01
# 500159 (MetroGlobal Limited): RSI = 41.34, Price = ₹146.95
# 538092 (Shri Vasuprada Plantations Limited): RSI = 41.33, Price = ₹122.70
# 541005 (N/A): RSI = 41.29, Price = ₹85.28
# 523648 (Plastiblends India Limited): RSI = 41.29, Price = ₹231.50
# 533552 (Rupa & Company Limited): RSI = 41.28, Price = ₹235.45
# 500780 (Zuari Industries Limited): RSI = 41.26, Price = ₹301.45
# 523457 (Linde India Limited): RSI = 41.26, Price = ₹5805.30
# 540956 (N/A): RSI = 41.25, Price = ₹27.25
# 509040 (N/A): RSI = 41.22, Price = ₹175.00
# 533217 (Hindustan Media Ventures Limited): RSI = 41.19, Price = ₹89.00
# 532853 (Asahi Songwon Colors Limited): RSI = 41.18, Price = ₹319.40
# 531867 (N/A): RSI = 41.18, Price = ₹4.98
# 500128 (Electrosteel Castings Limited): RSI = 41.16, Price = ₹126.75
# 540133 (ICICI Prudential Life Insurance Company Limited): RSI = 41.15, Price = ₹645.70
# 540769 (The New India Assurance Company Limited): RSI = 41.12, Price = ₹193.35
# 521070 (Alok Industries Limited): RSI = 41.11, Price = ₹20.00
# 503349 (N/A): RSI = 41.10, Price = ₹7231.50
# 533259 (Sastasundar Ventures Limited): RSI = 41.10, Price = ₹295.20
# 530825 (N/A): RSI = 41.02, Price = ₹242.40
# 507180 (Kesar Enterprises Limited): RSI = 41.02, Price = ₹126.00
# 504392 (Krishna Ventures Limited): RSI = 41.01, Price = ₹53.83
# 506003 (N/A): RSI = 41.01, Price = ₹55.50
# 570002 (Future Enterprises Limited): RSI = 41.00, Price = ₹4.89
# 532922 (Edelweiss Financial Services Limited): RSI = 40.94, Price = ₹114.40
# 531861 (N/A): RSI = 40.90, Price = ₹49.17
# 514264 (N/A): RSI = 40.90, Price = ₹18.75
# 540701 (Dishman Carbogen Amcis Limited): RSI = 40.88, Price = ₹246.65
# 523550 (N/A): RSI = 40.84, Price = ₹75.03
# 539559 (Deep Diamond India Limited): RSI = 40.83, Price = ₹5.96
# 500239 (N/A): RSI = 40.82, Price = ₹23.90
# 500227 (Jindal Poly Films Limited): RSI = 40.80, Price = ₹850.45
# 531223 (N/A): RSI = 40.77, Price = ₹47.52
# 524109 (Kabra Extrusiontechnik Limited): RSI = 40.77, Price = ₹466.80
# 523405 (JM Financial Limited): RSI = 40.76, Price = ₹117.25
# 532740 (Lokesh Machines Limited): RSI = 40.74, Price = ₹305.70
# 532284 (N/A): RSI = 40.72, Price = ₹69.95
# 526471 (N/A): RSI = 40.72, Price = ₹41.00
# 532056 (N/A): RSI = 40.65, Price = ₹57.33
# 539939 (Yash Chemex Limited): RSI = 40.64, Price = ₹49.60
# 506685 (N/A): RSI = 40.64, Price = ₹525.65
# 523618 (Dredging Corporation of India Limited): RSI = 40.50, Price = ₹757.95
# 506128 (Parnax Lab Limited): RSI = 40.50, Price = ₹156.25
# 539268 (Syngene International Limited): RSI = 40.49, Price = ₹819.55
# 538539 (Annvrridhhi Ventures Limited): RSI = 40.49, Price = ₹22.53
# 535754 (Orient Cement Limited): RSI = 40.48, Price = ₹339.35
# 500179 (HCL Infosystems Limited): RSI = 40.48, Price = ₹15.08
# 515043 (N/A): RSI = 40.47, Price = ₹123.50
# 512131 (Signet Industries Limited): RSI = 40.47, Price = ₹68.80
# 500356 (Shree Rama Newsprint Limited): RSI = 40.46, Price = ₹16.83
# 523283 (Superhouse Limited): RSI = 40.44, Price = ₹199.10
# 507864 (N/A): RSI = 40.42, Price = ₹79.24
# 520056 (Sundaram-Clayton Limited): RSI = 40.40, Price = ₹9917.20
# 523229 (N/A): RSI = 40.38, Price = ₹89.49
# 530695 (N/A): RSI = 40.38, Price = ₹36.00
# 532410 (N/A): RSI = 40.37, Price = ₹30.27
# 511549 (N/A): RSI = 40.36, Price = ₹147.65
# 532911 (N/A): RSI = 40.35, Price = ₹23.92
# 533206 (SJVN Limited): RSI = 40.33, Price = ₹100.75
# 533168 (Rossell India Limited): RSI = 40.33, Price = ₹72.05
# 533385 (Motilal Oswal NASDAQ 100 ETF): RSI = 40.31, Price = ₹204.77
# 522231 (N/A): RSI = 40.31, Price = ₹293.10
# 505800 (Rane Holdings Limited): RSI = 40.29, Price = ₹1608.70
# 538607 (Toyam Sports Limited): RSI = 40.28, Price = ₹2.05
# 515085 (N/A): RSI = 40.27, Price = ₹7.20
# 539841 (Lancer Container Lines Limited): RSI = 40.26, Price = ₹33.17
# 500012 (The Andhra Petrochemicals Limited): RSI = 40.25, Price = ₹70.58
# 540724 (Prataap Snacks Limited): RSI = 40.23, Price = ₹1074.90
# 500878 (CEAT Limited): RSI = 40.22, Price = ₹3021.30
# 511359 (N/A): RSI = 40.17, Price = ₹87.08
# 522029 (Windsor Machines Limited): RSI = 40.12, Price = ₹338.95
# 509567 (Goa Carbon Limited): RSI = 40.09, Price = ₹644.35
# 517546 (N/A): RSI = 40.08, Price = ₹107.20
# 526371 (NMDC Limited): RSI = 40.08, Price = ₹66.63
# 539176 (Hawa Engineers Limited): RSI = 40.07, Price = ₹208.30
# 531381 (Arihant Foundations & Housing Limited): RSI = 40.06, Price = ₹783.55
# 540025 (Advanced Enzyme Technologies Limited): RSI = 40.06, Price = ₹339.75
# 526839 (Shelter Infra Projects Limited): RSI = 40.05, Price = ₹17.00
# 500335 (Birla Corporation Limited): RSI = 40.04, Price = ₹1187.10
# 535267 (Comfort Fincap Limited): RSI = 40.00, Price = ₹9.93
#
# Daily analysis complete. Results saved in stock_analysis\daily_results

# %%
# !pip install --upgrade yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\leela mohan\anaconda3\lib\site-packages (0.2.51)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\leela mohan\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\leela mohan\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\leela mohan\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\leela mohan\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\leela mohan\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\leela mohan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leela mohan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leela mohan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leela mohan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.5.7)
