# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:

    def __init__(self):
            self.base_dir = 'stock_analysis'
            self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
            self.results_dir = os.path.join(self.base_dir, 'daily_results')
            self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
            self.setup_directories()
            self.load_delisted_stocks()
            self.session = requests.Session()  # Reuse session for better performance

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def get_stock_data(self, symbol, exchange='NSE', days=60):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)  # Changed from add to append
                self.save_delisted_stocks()  # Save immediately after adding
                return None, None, None, None

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)  # Changed from add to append
            self.save_delisted_stocks()  # Save immediately after adding
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2062 NSE and 3026 BSE stocks
# DHAN-RE.NS: Period '1mo' is invalid, must be one of ['1d', '5d']
# INDOFARM.NS: Period '1mo' is invalid, must be one of ['1d', '5d', 'ytd', 'max']
# $KALYANI.NS: possibly delisted; no price data found  (1d 2024-11-10 13:15:54.587470 -> 2025-01-09 13:15:54.587470)
# $MOKSH-RE.NS: possibly delisted; no price data found  (1d 2024-11-10 13:16:15.487805 -> 2025-01-09 13:16:15.487805)
# NSE analysis complete. Results saved to stock_analysis\daily_results\nse_analysis_20250109.xlsx
#
# NSE Stocks with RSI >= 40:
# AARVEEDEN (Aarvee Denims and Exports Ltd.): RSI = 100.00, Price = ₹129.00
# BGRENERGY (BGR Energy Systems Limited): RSI = 100.00, Price = ₹114.39
# BLUECOAST (Blue Coast Hotels Limited): RSI = 100.00, Price = ₹21.84
# VISASTEEL (VISA Steel Limited): RSI = 100.00, Price = ₹45.48
# NIRAJISPAT (Niraj Ispat Industries Limited): RSI = 100.00, Price = ₹245.18
# ATLASCYCLE (Atlas Cycles (Haryana) Limited): RSI = 100.00, Price = ₹102.56
# FSC (Future Supply Chain Solutions Limited): RSI = 96.77, Price = ₹2.49
# INDOTHAI (Indo Thai Securities Limited): RSI = 94.57, Price = ₹1648.95
# PTCIL (PTC Industries Limited): RSI = 92.92, Price = ₹17424.75
# SVLL (Shree Vasu Logistics Limited): RSI = 91.62, Price = ₹386.95
# AXISCADES (AXISCADES Technologies Limited): RSI = 90.15, Price = ₹809.15
# BROOKS (Brooks Laboratories Limited): RSI = 88.43, Price = ₹189.58
# SHAKTIPUMP (Shakti Pumps (India) Limited): RSI = 87.28, Price = ₹1344.85
# PGIL (Pearl Global Industries Limited): RSI = 87.14, Price = ₹1567.85
# NORBTEAEXP (Norben Tea & Exports Limited): RSI = 85.50, Price = ₹26.65
# AVONMORE (Avonmore Capital & Management Services Limited): RSI = 83.05, Price = ₹27.24
# INDIACEM (The India Cements Limited): RSI = 82.22, Price = ₹377.20
# ORIENTTECH (N/A): RSI = 81.24, Price = ₹600.45
# ARIHANTSUP (Arihant Superstructures Limited): RSI = 80.99, Price = ₹542.90
# JUBLFOOD (Jubilant FoodWorks Limited): RSI = 80.55, Price = ₹750.40
# GARUDA (N/A): RSI = 80.40, Price = ₹146.90
# ASMS (Bartronics India Limited): RSI = 80.37, Price = ₹23.96
# MEGASOFT (Megasoft Limited): RSI = 79.27, Price = ₹107.60
# CAPITALSFB (Capital Small Finance Bank Limited): RSI = 78.94, Price = ₹309.00
# SUNCLAY (Sundaram-Clayton Limited): RSI = 78.93, Price = ₹2846.75
# SPANDANA (Spandana Sphoorty Financial Limited): RSI = 78.78, Price = ₹476.35
# ANANTRAJ (Anant Raj Limited): RSI = 78.44, Price = ₹935.55
# UNIVASTU (Univastu India Limited): RSI = 78.34, Price = ₹287.45
# MEGASTAR (Megastar Foods Limited): RSI = 78.06, Price = ₹288.31
# DCXINDIA (DCX Systems Limited): RSI = 77.93, Price = ₹377.30
# PIGL (Power & Instrumental (Gujarat) Limited): RSI = 77.64, Price = ₹397.15
# BTML (Bodhi Tree Multimedia Limited): RSI = 77.60, Price = ₹12.90
# USK (Udayshivakumar Infra Limited): RSI = 77.46, Price = ₹58.40
# APOLLO (Apollo Micro Systems Limited): RSI = 77.11, Price = ₹133.55
# AVROIND (Avro India Limited): RSI = 76.88, Price = ₹217.92
# GLENMARK (Glenmark Pharmaceuticals Limited): RSI = 76.83, Price = ₹1627.90
# EPACK (EPACK Durable Limited): RSI = 76.22, Price = ₹629.80
# COFFEEDAY (Coffee Day Enterprises Limited): RSI = 75.69, Price = ₹30.28
# SEYAIND (Seya Industries Limited): RSI = 75.66, Price = ₹29.55
# LFIC (Lakshmi Finance & Industrial Corporation Limited): RSI = 75.61, Price = ₹249.78
# IPCALAB (Ipca Laboratories Limited): RSI = 75.61, Price = ₹1693.85
# PROZONER (Prozone Realty Limited): RSI = 75.46, Price = ₹36.00
# DIAMONDYD (Prataap Snacks Limited): RSI = 75.32, Price = ₹1145.70
# LLOYDSME (Lloyds Metals and Energy Limited): RSI = 75.24, Price = ₹1427.30
# RAMAPHO (Rama Phosphates Limited): RSI = 74.84, Price = ₹241.03
# COROMANDEL (Coromandel International Limited): RSI = 74.70, Price = ₹1937.65
# ZOTA (Zota Health Care Limited): RSI = 73.66, Price = ₹973.20
# KILITCH (Kilitch Drugs (India) Limited): RSI = 73.59, Price = ₹346.05
# AMBER (Amber Enterprises India Limited): RSI = 73.51, Price = ₹7791.05
# KIMS (Krishna Institute of Medical Sciences Limited): RSI = 73.48, Price = ₹649.95
# AEGISLOG (N/A): RSI = 73.35, Price = ₹948.05
# JSWHL (JSW Holdings Limited): RSI = 73.31, Price = ₹18200.10
# ASIANHOTNR (Asian Hotels (North) Limited): RSI = 73.20, Price = ₹295.00
# EICHERMOT (Eicher Motors Limited): RSI = 73.13, Price = ₹5163.20
# TATACONSUM (Tata Consumer Products Limited): RSI = 72.99, Price = ₹961.60
# KALYANIFRG (Kalyani Forge Limited): RSI = 72.89, Price = ₹811.55
# INNOVACAP (Innova Captab Limited): RSI = 72.58, Price = ₹1187.70
# WORTH (Worth Peripherals Limited): RSI = 72.58, Price = ₹172.01
# JTLIND (JTL Industries Limited): RSI = 72.34, Price = ₹109.82
# DRREDDY (Dr. Reddy's Laboratories Limited): RSI = 72.34, Price = ₹1370.75
# MEDICO (Medico Remedies Limited): RSI = 72.21, Price = ₹61.10
# ABDL (N/A): RSI = 71.97, Price = ₹427.10
# LLOYDSENT (Lloyds Enterprises Limited): RSI = 71.96, Price = ₹57.66
# GODREJCP (Godrej Consumer Products Limited): RSI = 71.75, Price = ₹1156.25
# NH (Narayana Hrudayalaya Limited): RSI = 71.55, Price = ₹1365.40
# CREDITACC (CreditAccess Grameen Limited): RSI = 71.50, Price = ₹1029.10
# OILCOUNTUB (Oil Country Tubular Limited): RSI = 71.30, Price = ₹67.70
# MBAPL (Madhya Bharat Agro Products Limited): RSI = 71.17, Price = ₹245.50
# HMT (HMT Limited): RSI = 71.02, Price = ₹76.00
# LAURUSLABS (Laurus Labs Limited): RSI = 70.87, Price = ₹611.10
# VIJAYA (Vijaya Diagnostic Centre Limited): RSI = 70.87, Price = ₹1209.10
# OMKARCHEM (Omkar Speciality Chemicals Limited): RSI = 70.57, Price = ₹9.51
# ASTERDM (Aster DM Healthcare Limited): RSI = 70.43, Price = ₹521.60
# FMNL (Future Market Networks Limited): RSI = 70.04, Price = ₹26.49
# VAKRANGEE (Vakrangee Limited): RSI = 69.93, Price = ₹37.22
# CALSOFT (California Software Company Limited): RSI = 69.93, Price = ₹19.78
# MARUTI (Maruti Suzuki India Limited): RSI = 69.88, Price = ₹11822.00
# AARTIPHARM (Aarti Pharmalabs Limited): RSI = 69.40, Price = ₹654.55
# GMRP&UI (GMR Power And Urban Infra Limited): RSI = 69.27, Price = ₹127.50
# DEVYANI (Devyani International Limited): RSI = 68.94, Price = ₹191.01
# DECCANCE (Deccan Cements Limited): RSI = 68.68, Price = ₹714.30
# VASWANI (Vaswani Industries Limited): RSI = 68.55, Price = ₹54.64
# MGEL (Mangalam Global Enterprise Limited): RSI = 68.50, Price = ₹28.95
# MANCREDIT (Mangal Credit and Fincorp Limited): RSI = 68.49, Price = ₹166.51
# ATALREAL (Atal Realtech Limited): RSI = 68.45, Price = ₹14.20
# MARATHON (Marathon Nextgen Realty Limited): RSI = 68.42, Price = ₹689.15
# SMSLIFE (SMS Lifesciences India Limited): RSI = 68.39, Price = ₹1250.00
# ONGC (Oil and Natural Gas Corporation Limited): RSI = 68.38, Price = ₹271.33
# ASHAPURMIN (Ashapura Minechem Limited): RSI = 68.36, Price = ₹484.65
# MVGJL (Manoj Vaibhav Gems 'N' Jewellers Limited): RSI = 68.31, Price = ₹294.90
# UNIVCABLES (Universal Cables Limited): RSI = 68.28, Price = ₹853.25
# SCHAEFFLER (Schaeffler India Limited): RSI = 67.96, Price = ₹3525.50
# SILVERTUC (Silver Touch Technologies Limited): RSI = 67.74, Price = ₹708.45
# ITI (ITI Limited): RSI = 67.63, Price = ₹479.50
# INDOTECH (Indo Tech Transformers Limited): RSI = 67.57, Price = ₹3592.35
# DEVIT (Dev Information Technology Limited): RSI = 67.31, Price = ₹176.09
# AURUM (Aurum PropTech Limited): RSI = 67.02, Price = ₹254.68
# IFBIND (IFB Industries Limited): RSI = 67.00, Price = ₹1977.65
# NACLIND (NACL Industries Limited): RSI = 66.94, Price = ₹67.18
# WEBELSOLAR (Websol Energy System Limited): RSI = 66.90, Price = ₹1836.75
# PRAXIS (Praxis Home Retail Limited): RSI = 66.89, Price = ₹22.40
# NARMADA (Narmada Agrobase Limited): RSI = 66.83, Price = ₹21.81
# ABBOTINDIA (Abbott India Limited): RSI = 66.78, Price = ₹29608.25
# MAZDA (Mazda Limited): RSI = 66.77, Price = ₹1760.65
# DHANI (Dhani Services Limited): RSI = 66.64, Price = ₹102.29
# DMART (Avenue Supermarts Limited): RSI = 66.55, Price = ₹3843.00
# BLUECHIP (Blue Chip India Limited): RSI = 66.52, Price = ₹8.93
# SAPPHIRE (Sapphire Foods India Limited): RSI = 66.47, Price = ₹336.45
# LUPIN (Lupin Limited): RSI = 66.45, Price = ₹2252.15
# POWERINDIA (Hitachi Energy India Limited): RSI = 66.40, Price = ₹14305.10
# V2RETAIL (V2 Retail Limited): RSI = 66.10, Price = ₹1748.60
# NDRAUTO (NDR Auto Components Limited): RSI = 66.06, Price = ₹815.00
# IRIS (IRIS Business Services Limited): RSI = 66.01, Price = ₹476.90
# SBILIFE (SBI Life Insurance Company Limited): RSI = 65.89, Price = ₹1463.15
# SAGILITY (N/A): RSI = 65.78, Price = ₹52.05
# ALPA (Alpa Laboratories Limited): RSI = 65.49, Price = ₹129.00
# PARADEEP (Paradeep Phosphates Limited): RSI = 65.28, Price = ₹121.30
# CANTABIL (Cantabil Retail India Limited): RSI = 65.11, Price = ₹300.85
# SRF (SRF Limited): RSI = 65.08, Price = ₹2350.95
# OIL (Oil India Limited): RSI = 65.02, Price = ₹491.70
# VINCOFE (Vintage Coffee and Beverages Limited): RSI = 64.95, Price = ₹125.51
# AMIORG (Ami Organics Limited): RSI = 64.83, Price = ₹2340.25
# LORDSCHLO (Lords Chloro Alkali Limited): RSI = 64.63, Price = ₹202.20
# INDGN (N/A): RSI = 64.49, Price = ₹630.60
# VLEGOV (VL E-Governance & IT Solutions Limited): RSI = 64.35, Price = ₹179.00
# ATFL (Agro Tech Foods Limited): RSI = 64.27, Price = ₹953.95
# JKCEMENT (J.K. Cement Limited): RSI = 64.17, Price = ₹4760.00
# NEWGEN (Newgen Software Technologies Limited): RSI = 64.10, Price = ₹1642.65
# SUVIDHAA (Suvidhaa Infoserve Limited): RSI = 64.08, Price = ₹7.11
# NESCO (Nesco Limited): RSI = 63.97, Price = ₹1028.00
# TECILCHEM (Tecil Chemicals and Hydro Power Ltd.): RSI = 63.84, Price = ₹25.90
# HSCL (Himadri Speciality Chemical Limited): RSI = 63.82, Price = ₹572.40
# AKUMS (N/A): RSI = 63.66, Price = ₹618.50
# EQUITASBNK (Equitas Small Finance Bank Limited): RSI = 63.48, Price = ₹67.62
# CAPLIPOINT (Caplin Point Laboratories Limited): RSI = 63.35, Price = ₹2583.25
# AWL (Adani Wilmar Limited): RSI = 63.34, Price = ₹324.25
# FORTIS (Fortis Healthcare Limited): RSI = 63.26, Price = ₹723.90
# ORIENTALTL (Oriental Trimex Limited): RSI = 63.26, Price = ₹10.38
# KINGFA (Kingfa Science & Technology (India) Limited): RSI = 63.26, Price = ₹3678.90
# FSL (Firstsource Solutions Limited): RSI = 63.00, Price = ₹396.60
# ASTRON (Astron Paper & Board Mill Limited): RSI = 62.92, Price = ₹20.65
# GUJRAFFIA (Gujarat Raffia Industries Limited): RSI = 62.90, Price = ₹90.04
# SAREGAMA (Saregama India Limited): RSI = 62.79, Price = ₹548.45
# AARTECH (Aartech Solonics Limited): RSI = 62.65, Price = ₹90.59
# FUSION (Fusion Finance Limited): RSI = 62.49, Price = ₹189.33
# BAJFINANCE (Bajaj Finance Limited): RSI = 62.37, Price = ₹7355.40
# MTARTECH (MTAR Technologies Limited): RSI = 62.36, Price = ₹1701.70
# ALPHAGEO (Alphageo (India) Limited): RSI = 62.35, Price = ₹466.30
# GOLDIAM (Goldiam International Limited): RSI = 62.32, Price = ₹478.95
# MONARCH (Monarch Networth Capital Limited): RSI = 62.31, Price = ₹464.45
# BAJAJFINSV (Bajaj Finserv Ltd.): RSI = 62.24, Price = ₹1697.00
# SUNFLAG (Sunflag Iron and Steel Company Limited): RSI = 62.24, Price = ₹300.75
# SURAJLTD (Suraj Limited): RSI = 62.22, Price = ₹517.55
# SHRADHA (Shradha Infraprojects Limited): RSI = 62.22, Price = ₹92.59
# JUSTDIAL (Just Dial Limited): RSI = 62.07, Price = ₹1071.00
# AIIL (Authum Investment & Infrastructure Limited): RSI = 62.02, Price = ₹1891.35
# GUJAPOLLO (Gujarat Apollo Industries Limited): RSI = 62.00, Price = ₹363.60
# LLOYDSENGG (Lloyds Engineering Works Limited): RSI = 61.98, Price = ₹87.78
# GUFICBIO (Gufic Biosciences Limited): RSI = 61.73, Price = ₹465.90
# GTPL (GTPL Hathway Limited): RSI = 61.69, Price = ₹150.26
# TATAMOTORS (Tata Motors Limited): RSI = 61.66, Price = ₹794.95
# VARDMNPOLY (Vardhman Polytex Limited): RSI = 61.45, Price = ₹14.81
# PATANJALI (Patanjali Foods Limited): RSI = 61.26, Price = ₹1855.60
# ASIANENE (Asian Energy Services Limited): RSI = 61.24, Price = ₹405.70
# M&MFIN (Mahindra & Mahindra Financial Services Limited): RSI = 61.21, Price = ₹278.75
# GREAVESCOT (Greaves Cotton Limited): RSI = 61.18, Price = ₹274.95
# HOMEFIRST (Home First Finance Company India Limited): RSI = 60.93, Price = ₹1054.70
# EUREKAFORB (Eureka Forbes Limited): RSI = 60.85, Price = ₹598.40
# A2ZINFRA (A2Z Infra Engineering Limited): RSI = 60.81, Price = ₹24.17
# SUPERSPIN (Super Spinning Mills Limited): RSI = 60.79, Price = ₹14.35
# IREDA (Indian Renewable Energy Development Agency Limited): RSI = 60.74, Price = ₹223.38
# SIGNATURE (Signatureglobal (India) Limited): RSI = 60.72, Price = ₹1362.75
# THOMASCOTT (Thomas Scott (India) Limited): RSI = 60.68, Price = ₹469.90
# FLEXITUFF (Flexituff Ventures International Limited): RSI = 60.61, Price = ₹65.69
# POKARNA (Pokarna Limited): RSI = 60.57, Price = ₹1384.45
# ASTRAZEN (AstraZeneca Pharma India Limited): RSI = 60.51, Price = ₹6882.10
# TAJGVK (TAJGVK Hotels & Resorts Limited): RSI = 60.42, Price = ₹424.00
# WELENT (Welspun Enterprises Limited): RSI = 60.37, Price = ₹631.55
# ASHIANA (Ashiana Housing Limited): RSI = 60.28, Price = ₹382.15
# EMMBI (Emmbi Industries Limited): RSI = 60.22, Price = ₹157.93
# SALZERELEC (Salzer Electronics Limited): RSI = 60.21, Price = ₹1540.60
# MANGCHEFER (Mangalore Chemicals & Fertilizers Limited): RSI = 60.20, Price = ₹170.60
# DCI (DC Infotech and Communication Limited): RSI = 60.17, Price = ₹372.65
# GHCL (GHCL Limited): RSI = 60.13, Price = ₹719.70
# SUNPHARMA (Sun Pharmaceutical Industries Limited): RSI = 60.08, Price = ₹1837.75
# PARKHOTELS (N/A): RSI = 60.01, Price = ₹199.30
# HINDUNILVR (Hindustan Unilever Limited): RSI = 60.00, Price = ₹2401.00
# KIOCL (KIOCL Limited): RSI = 59.96, Price = ₹418.35
# EMBDL (N/A): RSI = 59.87, Price = ₹143.34
# GENESYS (Genesys International Corporation Limited): RSI = 59.82, Price = ₹987.65
# INDORAMA (Indo Rama Synthetics (India) Limited): RSI = 59.81, Price = ₹43.94
# BATAINDIA (Bata India Limited): RSI = 59.79, Price = ₹1418.15
# SIGNPOST (Signpost India Limited): RSI = 59.72, Price = ₹383.90
# SBICARD (SBI Cards and Payment Services Limited): RSI = 59.68, Price = ₹737.25
# SHAILY (Shaily Engineering Plastics Limited): RSI = 59.64, Price = ₹1573.05
# MTEDUCARE (MT Educare Limited): RSI = 59.60, Price = ₹2.72
# PFIZER (Pfizer Limited): RSI = 59.55, Price = ₹5340.00
# CAMLINFINE (Camlin Fine Sciences Limited): RSI = 59.52, Price = ₹134.67
# BIOCON (Biocon Limited): RSI = 59.48, Price = ₹371.20
# PFOCUS (Prime Focus Limited): RSI = 59.45, Price = ₹133.54
# LAGNAM (Lagnam Spintex Limited): RSI = 59.39, Price = ₹124.43
# APARINDS (APAR Industries Limited): RSI = 59.34, Price = ₹10578.25
# JINDRILL (Jindal Drilling & Industries Limited): RSI = 59.27, Price = ₹793.05
# RAJRATAN (Rajratan Global Wire Limited): RSI = 59.21, Price = ₹507.70
# CONCORDBIO (Concord Biotech Limited): RSI = 59.19, Price = ₹2262.90
# HISARMETAL (Hisar Metal Industries Limited): RSI = 59.09, Price = ₹210.00
# BRITANNIA (Britannia Industries Limited): RSI = 59.08, Price = ₹4859.90
# BLKASHYAP (B.L. Kashyap and Sons Limited): RSI = 59.05, Price = ₹81.73
# HILTON (Hilton Metal Forging Limited): RSI = 59.04, Price = ₹108.39
# BHAGERIA (Bhageria Industries Limited): RSI = 59.03, Price = ₹206.00
# AMNPLST (Amines & Plasticizers Limited): RSI = 58.97, Price = ₹309.05
# INDSWFTLAB (Ind-Swift Laboratories Limited): RSI = 58.92, Price = ₹108.96
# JYOTHYLAB (Jyothy Labs Limited): RSI = 58.91, Price = ₹400.40
# GLFL (Gujarat Lease Financing Limited): RSI = 58.88, Price = ₹7.88
# E2E (E2E Networks Limited): RSI = 58.87, Price = ₹4301.30
# GANESHHOUC (Ganesh Housing Corporation Limited): RSI = 58.81, Price = ₹1325.05
# GLAND (Gland Pharma Limited): RSI = 58.70, Price = ₹1831.35
# POWERMECH (Power Mech Projects Limited): RSI = 58.66, Price = ₹2798.10
# PVP (PVP Ventures Limited): RSI = 58.65, Price = ₹31.97
# AJOONI (Ajooni Biotech Limited): RSI = 58.60, Price = ₹7.82
# KOTHARIPRO (Kothari Products Limited): RSI = 58.59, Price = ₹185.74
# UNOMINDA (Uno Minda Limited): RSI = 58.56, Price = ₹1074.25
# PARAS (Paras Defence and Space Technologies Limited): RSI = 58.56, Price = ₹1110.70
# TARIL (N/A): RSI = 58.50, Price = ₹1200.00
# ORCHPHARMA (Orchid Pharma Limited): RSI = 58.45, Price = ₹1877.75
# SEQUENT (Sequent Scientific Limited): RSI = 58.40, Price = ₹192.69
# EMCURE (N/A): RSI = 58.35, Price = ₹1446.10
# HONAUT (Honeywell Automation India Limited): RSI = 58.32, Price = ₹42260.00
# KFINTECH (KFin Technologies Limited): RSI = 58.27, Price = ₹1445.45
# MUKTAARTS (Mukta Arts Limited): RSI = 58.26, Price = ₹93.78
# BERGEPAINT (Berger Paints India Limited): RSI = 58.23, Price = ₹461.95
# GALAPREC (N/A): RSI = 58.21, Price = ₹1235.05
# JISLJALEQS (Jain Irrigation Systems Limited): RSI = 58.21, Price = ₹76.02
# SPENCERS (Spencer's Retail Limited): RSI = 58.17, Price = ₹88.89
# TITAN (Titan Company Limited): RSI = 58.16, Price = ₹3484.05
# GRANULES (Granules India Limited): RSI = 58.01, Price = ₹614.40
# AKZOINDIA (Akzo Nobel India Limited): RSI = 58.01, Price = ₹3747.75
# ARKADE (N/A): RSI = 57.98, Price = ₹178.80
# DATAMATICS (Datamatics Global Services Limited): RSI = 57.96, Price = ₹682.70
# AUROPHARMA (Aurobindo Pharma Limited): RSI = 57.90, Price = ₹1281.65
# INDSWFTLTD (Ind-Swift Limited): RSI = 57.90, Price = ₹29.34
# NUCLEUS (Nucleus Software Exports Limited): RSI = 57.84, Price = ₹1095.35
# MINDACORP (Minda Corporation Limited): RSI = 57.81, Price = ₹532.90
# ASALCBR (Associated Alcohols & Breweries Limited): RSI = 57.73, Price = ₹1170.20
# CREATIVE (Creative Newtech Limited): RSI = 57.70, Price = ₹983.40
# KAUSHALYA (Kaushalya Infrastructure Development Corporation Limited): RSI = 57.59, Price = ₹1053.45
# AZAD (N/A): RSI = 57.55, Price = ₹1798.95
# SAURASHCEM (Saurashtra Cement Limited): RSI = 57.51, Price = ₹114.17
# INDRAMEDCO (Indraprastha Medical Corporation Limited): RSI = 57.48, Price = ₹533.50
# ARVINDFASN (Arvind Fashions Limited): RSI = 57.47, Price = ₹527.95
# XTGLOBAL (XTGlobal Infotech Limited): RSI = 57.32, Price = ₹46.12
# JINDWORLD (Jindal Worldwide Limited): RSI = 57.25, Price = ₹438.50
# PRAENG (Prajay Engineers Syndicate Limited): RSI = 57.25, Price = ₹32.33
# NURECA (Nureca Limited): RSI = 57.25, Price = ₹304.55
# ESTER (Ester Industries Limited): RSI = 57.22, Price = ₹164.37
# ZEEMEDIA (Zee Media Corporation Limited): RSI = 57.19, Price = ₹20.30
# VISAKAIND (Visaka Industries Limited): RSI = 57.02, Price = ₹98.53
# PARASPETRO (Paras Petrofils Limited): RSI = 56.99, Price = ₹3.12
# MUTHOOTFIN (Muthoot Finance Limited): RSI = 56.86, Price = ₹2179.20
# TI (Tilaknagar Industries Ltd.): RSI = 56.85, Price = ₹429.35
# ALLDIGI (Alldigi Tech Limited): RSI = 56.85, Price = ₹1031.80
# RBZJEWEL (RBZ Jewellers Limited): RSI = 56.84, Price = ₹221.46
# MITTAL (Mittal Life Style Limited): RSI = 56.82, Price = ₹2.25
# ZENTEC (Zen Technologies Limited): RSI = 56.79, Price = ₹2468.85
# JAIPURKURT (Nandani Creation Limited): RSI = 56.73, Price = ₹36.45
# OBCL (Orissa Bengal Carrier Limited): RSI = 56.69, Price = ₹57.45
# AWFIS (N/A): RSI = 56.67, Price = ₹747.45
# PREMIERPOL (Premier Polyfilm Ltd.): RSI = 56.62, Price = ₹78.53
# SUBROS (Subros Limited): RSI = 56.61, Price = ₹664.50
# LGHL (N/A): RSI = 56.48, Price = ₹522.00
# CHOLAHLDNG (Cholamandalam Financial Holdings Limited): RSI = 56.43, Price = ₹1542.30
# TBOTEK (N/A): RSI = 56.39, Price = ₹1741.40
# NESTLEIND (Nestlé India Limited): RSI = 56.30, Price = ₹2219.90
# DABUR (Dabur India Limited): RSI = 56.26, Price = ₹513.75
# ORICONENT (Oricon Enterprises Limited): RSI = 56.14, Price = ₹39.91
# PRIVISCL (Privi Speciality Chemicals Limited): RSI = 56.06, Price = ₹1851.00
# KAVVERITEL (Kavveri Defence & Wireless Technologies Limited): RSI = 56.00, Price = ₹58.38
# CIPLA (Cipla Limited): RSI = 55.91, Price = ₹1494.90
# SFL (Sheela Foam Limited): RSI = 55.87, Price = ₹1004.20
# SAMMAANCAP (Sammaan Capital Limited): RSI = 55.74, Price = ₹159.15
# ASTEC (Astec LifeSciences Limited): RSI = 55.74, Price = ₹1143.85
# JCHAC (Johnson Controls-Hitachi Air Conditioning India Limited): RSI = 55.71, Price = ₹1862.90
# JSFB (Jana Small Finance Bank Limited): RSI = 55.63, Price = ₹406.65
# TVSELECT (TVS Electronics Limited): RSI = 55.57, Price = ₹405.55
# SYNGENE (Syngene International Limited): RSI = 55.48, Price = ₹871.05
# SETCO (Setco Automotive Limited): RSI = 55.48, Price = ₹20.31
# TATVA (Tatva Chintan Pharma Chem Limited): RSI = 55.47, Price = ₹892.00
# DCAL (Dishman Carbogen Amcis Limited): RSI = 55.39, Price = ₹291.85
# BAFNAPH (Bafna Pharmaceuticals Limited): RSI = 55.37, Price = ₹82.35
# JBCHEPHARM (J. B. Chemicals & Pharmaceuticals Limited): RSI = 55.29, Price = ₹1896.35
# PIXTRANS (PIX Transmissions Limited): RSI = 55.29, Price = ₹2456.65
# NEULANDLAB (Neuland Laboratories Limited): RSI = 55.18, Price = ₹14858.70
# TVTODAY (T.V. Today Network Limited): RSI = 55.08, Price = ₹208.26
# MANKIND (Mankind Pharma Limited): RSI = 55.07, Price = ₹2879.55
# KARMAENG (Karma Energy Limited): RSI = 55.06, Price = ₹73.10
# CHOLAFIN (Cholamandalam Investment and Finance Company Limited): RSI = 55.05, Price = ₹1275.25
# KABRAEXTRU (Kabra Extrusiontechnik Limited): RSI = 55.02, Price = ₹535.20
# GLOBE (Globe Textiles (India) Limited): RSI = 55.00, Price = ₹5.19
# TCLCONS (Tantia Constructions Limited): RSI = 54.98, Price = ₹46.41
# DSSL (Dynacons Systems & Solutions Limited): RSI = 54.90, Price = ₹1517.15
# DBSTOCKBRO (DB (International) Stock Brokers Limited): RSI = 54.85, Price = ₹45.28
# IDEA (Vodafone Idea Limited): RSI = 54.76, Price = ₹7.99
# BLUESTARCO (Blue Star Limited): RSI = 54.73, Price = ₹2105.65
# AVALON (Avalon Technologies Limited): RSI = 54.69, Price = ₹938.30
# BALKRISHNA (Balkrishna Paper Mills Limited): RSI = 54.69, Price = ₹24.88
# REPL (Rudrabhishek Enterprises Limited): RSI = 54.62, Price = ₹316.85
# SOUTHBANK (The South Indian Bank Limited): RSI = 54.62, Price = ₹25.93
# INTELLECT (Intellect Design Arena Limited): RSI = 54.61, Price = ₹901.75
# AJANTPHARM (Ajanta Pharma Limited): RSI = 54.53, Price = ₹2965.55
# HEUBACHIND (Heubach Colorants India Limited): RSI = 54.45, Price = ₹547.95
# INDUSINDBK (IndusInd Bank Limited): RSI = 54.35, Price = ₹981.05
# STARTECK (Starteck Finance Limited): RSI = 54.28, Price = ₹310.80
# ADANIENT (Adani Enterprises Limited): RSI = 54.26, Price = ₹2515.25
# TANLA (Tanla Platforms Limited): RSI = 54.22, Price = ₹702.15
# AARTIDRUGS (Aarti Drugs Limited): RSI = 54.17, Price = ₹443.00
# WEWIN (We Win Limited): RSI = 54.17, Price = ₹89.25
# DOLPHIN (Dolphin Offshore Enterprises (India) Limited): RSI = 54.07, Price = ₹562.00
# GANGAFORGE (Ganga Forging Limited): RSI = 54.02, Price = ₹6.81
# KSCL (Kaveri Seed Company Limited): RSI = 53.96, Price = ₹921.05
# LTF (L&T Finance Limited): RSI = 53.87, Price = ₹143.40
# HINDMOTORS (Hindustan Motors Limited): RSI = 53.83, Price = ₹27.56
# SHANTI (Shanti Overseas (India) Limited): RSI = 53.83, Price = ₹16.73
# CARTRADE (CarTrade Tech Limited): RSI = 53.83, Price = ₹1543.45
# SHEKHAWATI (Shekhawati Industries Limited): RSI = 53.74, Price = ₹31.95
# WELINV (Welspun Investments and Commercials Limited): RSI = 53.72, Price = ₹932.50
# MATRIMONY (Matrimony.com Limited): RSI = 53.69, Price = ₹668.60
# RVTH (Revathi Equipment India Limited): RSI = 53.65, Price = ₹2111.35
# HYUNDAI (N/A): RSI = 53.64, Price = ₹1811.40
# IL&FSENGG (IL&FS Engineering and Construction Company Limited): RSI = 53.63, Price = ₹43.00
# IIFL (IIFL Finance Limited): RSI = 53.60, Price = ₹434.60
# SHALPAINTS (Shalimar Paints Limited): RSI = 53.60, Price = ₹127.10
# ITDC (India Tourism Development Corporation Limited): RSI = 53.57, Price = ₹659.80
# RICOAUTO (Rico Auto Industries Limited): RSI = 53.57, Price = ₹90.53
# BEARDSELL (Beardsell Limited): RSI = 53.55, Price = ₹40.86
# SDBL (Som Distilleries & Breweries Limited): RSI = 53.50, Price = ₹115.27
# UJJIVANSFB (Ujjivan Small Finance Bank Limited): RSI = 53.44, Price = ₹35.44
# HOVS (HOV Services Limited): RSI = 53.41, Price = ₹75.01
# JINDALSTEL (Jindal Steel & Power Limited): RSI = 53.40, Price = ₹932.25
# SANCO (Sanco Industries Limited): RSI = 53.37, Price = ₹4.22
# JTEKTINDIA (JTEKT India Limited): RSI = 53.37, Price = ₹164.68
# ZEEL (Zee Entertainment Enterprises Limited): RSI = 53.36, Price = ₹133.77
# UPL (UPL Limited): RSI = 53.35, Price = ₹539.55
# IGL (Indraprastha Gas Limited): RSI = 53.34, Price = ₹407.45
# GRPLTD (GRP Limited): RSI = 53.28, Price = ₹3299.00
# THEMISMED (Themis Medicare Limited): RSI = 53.14, Price = ₹275.40
# AUBANK (AU Small Finance Bank Limited): RSI = 53.09, Price = ₹566.45
# APLLTD (Alembic Pharmaceuticals Limited): RSI = 53.06, Price = ₹1065.75
# COFORGE (Coforge Limited): RSI = 53.04, Price = ₹9558.00
# MRPL (Mangalore Refinery and Petrochemicals Limited): RSI = 53.03, Price = ₹148.48
# ELGIRUBCO (Elgi Rubber Company Limited): RSI = 53.01, Price = ₹130.00
# GOKUL (Gokul Refoils & Solvent Limited): RSI = 52.98, Price = ₹62.05
# KOHINOOR (Kohinoor Foods Limited): RSI = 52.96, Price = ₹41.45
# MAHESHWARI (Maheshwari Logistics Limited): RSI = 52.96, Price = ₹63.53
# RELIANCE (Reliance Industries Limited): RSI = 52.95, Price = ₹1265.50
# POLYPLEX (Polyplex Corporation Limited): RSI = 52.94, Price = ₹1404.55
# KELLTONTEC (Kellton Tech Solutions Limited): RSI = 52.93, Price = ₹166.95
# INDOWIND (Indowind Energy Limited): RSI = 52.87, Price = ₹25.23
# MOTISONS (N/A): RSI = 52.85, Price = ₹27.72
# CINEVISTA (Cinevista Limited): RSI = 52.77, Price = ₹18.98
# LINDEINDIA (Linde India Limited): RSI = 52.71, Price = ₹6561.95
# ROHLTD (Royal Orchid Hotels Limited): RSI = 52.69, Price = ₹359.50
# MANINDS (Man Industries (India) Limited): RSI = 52.64, Price = ₹344.00
# M&M (Mahindra & Mahindra Limited): RSI = 52.59, Price = ₹3086.10
# MANAKCOAT (Manaksia Coated Metals & Industries Limited): RSI = 52.59, Price = ₹111.50
# ARMANFIN (Arman Financial Services Limited): RSI = 52.58, Price = ₹1293.15
# CAMPUS (Campus Activewear Limited): RSI = 52.57, Price = ₹294.30
# CENTURYPLY (Century Plyboards (India) Limited): RSI = 52.56, Price = ₹823.15
# RAINBOW (Rainbow Children's Medicare Limited): RSI = 52.56, Price = ₹1613.70
# ALMONDZ (Almondz Global Securities Limited): RSI = 52.52, Price = ₹33.76
# POLYMED (Poly Medicure Limited): RSI = 52.51, Price = ₹2756.30
# SSWL (Steel Strips Wheels Limited): RSI = 52.49, Price = ₹201.53
# KHANDSE (Khandwala Securities Limited): RSI = 52.48, Price = ₹28.00
# MGL (Mahanagar Gas Limited): RSI = 52.48, Price = ₹1252.55
# MANGLMCEM (Mangalam Cement Limited): RSI = 52.42, Price = ₹941.55
# BAJAJHCARE (Bajaj HealthCare Limited): RSI = 52.41, Price = ₹576.70
# CHEMBOND (Chembond Chemicals Limited): RSI = 52.39, Price = ₹593.85
# GILLETTE (Gillette India Limited): RSI = 52.33, Price = ₹9822.35
# MANINFRA (Man Infraconstruction Limited): RSI = 52.32, Price = ₹240.00
# AUTOAXLES (Automotive Axles Limited): RSI = 52.23, Price = ₹1798.45
# FORCEMOT (Force Motors Limited): RSI = 52.19, Price = ₹6689.60
# CEATLTD (CEAT Limited): RSI = 52.17, Price = ₹3120.05
# AARON (Aaron Industries Limited): RSI = 52.13, Price = ₹366.80
# DELPHIFX (Delphi World Money Limited): RSI = 52.02, Price = ₹207.77
# SBFC (SBFC Finance Limited): RSI = 51.97, Price = ₹87.63
# RAMKY (Ramky Infrastructure Limited): RSI = 51.90, Price = ₹632.00
# NAVINFLUOR (Navin Fluorine International Limited): RSI = 51.83, Price = ₹3493.15
# SMSPHARMA (SMS Pharmaceuticals Limited): RSI = 51.73, Price = ₹241.30
# BLUEJET (Blue Jet Healthcare Limited): RSI = 51.70, Price = ₹585.70
# MAXHEALTH (Max Healthcare Institute Limited): RSI = 51.68, Price = ₹1203.20
# AETHER (Aether Industries Limited): RSI = 51.65, Price = ₹900.00
# RPEL (Raghav Productivity Enhancers Limited): RSI = 51.63, Price = ₹738.25
# ROML (Raj Oil Mills Limited): RSI = 51.58, Price = ₹56.22
# CONTROLPR (Control Print Limited): RSI = 51.48, Price = ₹723.80
# MANAKALUCO (Manaksia Aluminium Company Limited): RSI = 51.46, Price = ₹30.20
# MANAPPURAM (Manappuram Finance Limited): RSI = 51.46, Price = ₹179.98
# COLPAL (Colgate-Palmolive (India) Limited): RSI = 51.45, Price = ₹2789.75
# PGEL (PG Electroplast Limited): RSI = 51.34, Price = ₹950.50
# CCCL (Consolidated Construction Consortium Limited): RSI = 51.29, Price = ₹17.46
# ARTEMISMED (Artemis Medicare Services Limited): RSI = 51.26, Price = ₹337.35
# ABMINTLLTD (ABM International Limited): RSI = 51.20, Price = ₹66.90
# CHENNPETRO (Chennai Petroleum Corporation Limited): RSI = 51.19, Price = ₹609.90
# SASKEN (Sasken Technologies Limited): RSI = 51.18, Price = ₹2150.00
# RESPONIND (Responsive Industries Limited): RSI = 51.11, Price = ₹264.36
# DIVISLAB (Divi's Laboratories Limited): RSI = 51.09, Price = ₹5868.40
# ALKEM (Alkem Laboratories Limited): RSI = 51.07, Price = ₹5509.00
# VOLTAS (Voltas Limited): RSI = 51.06, Price = ₹1764.45
# MEDIASSIST (N/A): RSI = 51.03, Price = ₹610.70
# INCREDIBLE (Incredible Industries Limited): RSI = 51.01, Price = ₹46.76
# OPTIEMUS (Optiemus Infracom Limited): RSI = 50.91, Price = ₹747.95
# CONFIPET (Confidence Petroleum India Limited): RSI = 50.89, Price = ₹73.20
# ATGL (Adani Total Gas Limited): RSI = 50.86, Price = ₹704.95
# 20MICRONS (20 Microns Limited): RSI = 50.85, Price = ₹245.47
# GREENLAM (Greenlam Industries Limited): RSI = 50.84, Price = ₹569.80
# RKFORGE (Ramkrishna Forgings Limited): RSI = 50.82, Price = ₹903.20
# KRSNAA (Krsnaa Diagnostics Limited): RSI = 50.80, Price = ₹920.30
# STCINDIA (The State Trading Corporation of India Limited): RSI = 50.73, Price = ₹160.50
# LUMAXTECH (Lumax Auto Technologies Limited): RSI = 50.65, Price = ₹636.00
# HEIDELBERG (HeidelbergCement India Limited): RSI = 50.63, Price = ₹215.64
# SICALLOG (Sical Logistics Limited): RSI = 50.61, Price = ₹146.79
# WELCORP (Welspun Corp Limited): RSI = 50.59, Price = ₹789.80
# HUBTOWN (Hubtown Limited): RSI = 50.57, Price = ₹285.50
# INTLCONV (International Conveyors Limited): RSI = 50.56, Price = ₹85.77
# SOFTTECH (SoftTech Engineers Limited): RSI = 50.55, Price = ₹492.95
# ZYDUSLIFE (Zydus Lifesciences Limited): RSI = 50.51, Price = ₹981.45
# AVANTIFEED (Avanti Feeds Limited): RSI = 50.50, Price = ₹640.05
# UGROCAP (UGRO Capital Limited): RSI = 50.45, Price = ₹238.00
# VINEETLAB (Vineet Laboratories Limited): RSI = 50.44, Price = ₹58.87
# JISLDVREQS (Jain Irrigation Systems Limited): RSI = 50.39, Price = ₹36.64
# JAYNECOIND (Jayaswal Neco Industries Limited): RSI = 50.38, Price = ₹41.59
# GODREJAGRO (Godrej Agrovet Limited): RSI = 50.37, Price = ₹748.80
# IRB (IRB Infrastructure Developers Limited): RSI = 50.34, Price = ₹57.27
# SENCO (Senco Gold Limited): RSI = 50.31, Price = ₹1127.50
# JSWINFRA (JSW Infrastructure Limited): RSI = 50.29, Price = ₹318.70
# PNBHOUSING (PNB Housing Finance Limited): RSI = 50.27, Price = ₹873.90
# GOODLUCK (Goodluck India Limited): RSI = 50.27, Price = ₹955.15
# IXIGO (N/A): RSI = 50.24, Price = ₹158.85
# GLS (Alivus Life Sciences Limited): RSI = 50.23, Price = ₹1018.35
# ZEELEARN (Zee Learn Limited): RSI = 50.22, Price = ₹8.48
# DANGEE (Dangee Dums Limited): RSI = 50.22, Price = ₹7.08
# LYPSAGEMS (Lypsa Gems & Jewellery Limited): RSI = 50.17, Price = ₹7.65
# KRN (N/A): RSI = 50.14, Price = ₹760.50
# NILKAMAL (Nilkamal Limited): RSI = 50.14, Price = ₹1892.25
# PRECAM (Precision Camshafts Limited): RSI = 50.13, Price = ₹359.35
# INFOBEAN (InfoBeans Technologies Limited): RSI = 50.12, Price = ₹430.65
# RBA (Restaurant Brands Asia Limited): RSI = 50.12, Price = ₹80.42
# ENIL (Entertainment Network (India) Limited): RSI = 50.11, Price = ₹178.00
# MANGALAM (Mangalam Drugs & Organics Limited): RSI = 50.03, Price = ₹116.38
# MBECL (McNally Bharat Engineering Company Limited): RSI = 50.03, Price = ₹4.37
# DGCONTENT (Digicontent Limited): RSI = 50.02, Price = ₹61.40
# PREMIER (Premier Limited): RSI = 50.00, Price = ₹3.45
# BEDMUTHA (Bedmutha Industries Limited): RSI = 49.96, Price = ₹203.92
# ASHOKLEY (Ashok Leyland Limited): RSI = 49.88, Price = ₹222.73
# SATIN (Satin Creditcare Network Limited): RSI = 49.86, Price = ₹155.60
# RELINFRA (Reliance Infrastructure Limited): RSI = 49.83, Price = ₹292.25
# RPGLIFE (RPG Life Sciences Limited): RSI = 49.80, Price = ₹2253.30
# ONEPOINT (One Point One Solutions Limited): RSI = 49.76, Price = ₹55.35
# ZENSARTECH (Zensar Technologies Limited): RSI = 49.75, Price = ₹788.90
# BASML (Bannari Amman Spinning Mills Ltd): RSI = 49.75, Price = ₹53.66
# WINDLAS (Windlas Biotech Limited): RSI = 49.75, Price = ₹1055.65
# AJMERA (Ajmera Realty & Infra India Limited): RSI = 49.70, Price = ₹1117.90
# HCL-INSYS (HCL Infosystems Limited): RSI = 49.69, Price = ₹15.93
# ESAFSFB (ESAF Small Finance Bank): RSI = 49.61, Price = ₹39.05
# ONWARDTEC (Onward Technologies Limited): RSI = 49.61, Price = ₹320.00
# UNITEDTEA (The United Nilgiri Tea Estates Company Limited): RSI = 49.60, Price = ₹548.15
# PAR (Par Drugs and Chemicals Limited): RSI = 49.50, Price = ₹203.75
# SPAL (S.P. Apparels Limited): RSI = 49.50, Price = ₹928.05
# SHALBY (Shalby Limited): RSI = 49.48, Price = ₹230.93
# MANORG (Mangalam Organics Limited): RSI = 49.44, Price = ₹425.25
# SUNDRMBRAK (Sundaram Brake Linings Limited): RSI = 49.39, Price = ₹1135.25
# TRIGYN (Trigyn Technologies Limited): RSI = 49.36, Price = ₹111.54
# UNITDSPR (N/A): RSI = 49.35, Price = ₹1575.80
# AAVAS (Aavas Financiers Limited): RSI = 49.34, Price = ₹1680.75
# ASPINWALL (Aspinwall and Company Limited): RSI = 49.32, Price = ₹311.00
# RACE (Race Eco Chain Limited): RSI = 49.30, Price = ₹345.00
# INTERARCH (N/A): RSI = 49.29, Price = ₹1694.85
# GICRE (General Insurance Corporation of India): RSI = 49.29, Price = ₹446.70
# ACCELYA (Accelya Solutions India Limited): RSI = 49.28, Price = ₹1529.70
# NILAINFRA (Nila Infrastructures Limited): RSI = 49.22, Price = ₹13.83
# KIRLOSBROS (Kirloskar Brothers Limited): RSI = 49.15, Price = ₹2225.60
# BLISSGVS (Bliss GVS Pharma Limited): RSI = 49.14, Price = ₹168.67
# RALLIS (Rallis India Limited): RSI = 49.09, Price = ₹297.90
# REFEX (Refex Industries Limited): RSI = 49.09, Price = ₹501.80
# BALPHARMA (Bal Pharma Limited): RSI = 49.08, Price = ₹120.60
# EMAMILTD (Emami Limited): RSI = 49.04, Price = ₹583.60
# AFCONS (N/A): RSI = 49.04, Price = ₹527.90
# SANOFICONR (N/A): RSI = 48.96, Price = ₹4850.00
# BLS (BLS International Services Limited): RSI = 48.95, Price = ₹482.25
# DIAMINESQ (Diamines and Chemicals Limited): RSI = 48.94, Price = ₹497.20
# RITCO (Ritco Logistics Limited): RSI = 48.94, Price = ₹400.20
# TGBHOTELS (TGB Banquets and Hotels Limited): RSI = 48.91, Price = ₹14.21
# KMEW (Knowledge Marine & Engineering Works Limited): RSI = 48.90, Price = ₹2123.35
# KECL (Kirloskar Electric Company Limited): RSI = 48.89, Price = ₹185.67
# BHARTIARTL (Bharti Airtel Limited): RSI = 48.87, Price = ₹1599.20
# TARSONS (Tarsons Products Limited): RSI = 48.85, Price = ₹408.00
# PRAJIND (Praj Industries Limited): RSI = 48.79, Price = ₹799.50
# RPSGVENT (RPSG Ventures Limited): RSI = 48.79, Price = ₹1089.35
# BAJAJHLDNG (Bajaj Holdings & Investment Limited): RSI = 48.78, Price = ₹11218.30
# AIAENG (AIA Engineering Limited): RSI = 48.77, Price = ₹3420.10
# ROSSARI (Rossari Biotech Limited): RSI = 48.74, Price = ₹808.45
# MMTC (MMTC Limited): RSI = 48.69, Price = ₹76.22
# SIGMA (Sigma Solve Limited): RSI = 48.63, Price = ₹343.50
# BIRLACORPN (Birla Corporation Limited): RSI = 48.62, Price = ₹1232.95
# HPIL (Hindprakash Industries Limited): RSI = 48.59, Price = ₹154.20
# GLOBALE (Globale Tessile Limited): RSI = 48.51, Price = ₹28.75
# 3MINDIA (3M India Limited): RSI = 48.51, Price = ₹30775.05
# MARICO (Marico Limited): RSI = 48.51, Price = ₹638.40
# NGIL (Nakoda Group of Industries Limited): RSI = 48.50, Price = ₹40.30
# IMPEXFERRO (Impex Ferro Tech Limited): RSI = 48.48, Price = ₹2.90
# NUVOCO (Nuvoco Vistas Corporation Limited): RSI = 48.44, Price = ₹354.20
# KNRCON (KNR Constructions Limited): RSI = 48.43, Price = ₹336.70
# PRICOLLTD (Pricol Limited): RSI = 48.42, Price = ₹559.65
# DEEPINDS (Deep Industries Limited): RSI = 48.40, Price = ₹605.95
# BORORENEW (Borosil Renewables Limited): RSI = 48.33, Price = ₹603.10
# INNOVANA (N/A): RSI = 48.33, Price = ₹464.15
# ASIANPAINT (Asian Paints Limited): RSI = 48.32, Price = ₹2334.35
# DCMSHRIRAM (DCM Shriram Limited): RSI = 48.30, Price = ₹1072.05
# BPCL (Bharat Petroleum Corporation Limited): RSI = 48.30, Price = ₹286.80
# ASKAUTOLTD (N/A): RSI = 48.29, Price = ₹477.60
# TARAPUR (Tarapur Transformers Limited): RSI = 48.28, Price = ₹45.98
# SURANAT&P (Surana Telecom and Power Limited): RSI = 48.23, Price = ₹23.70
# BLSE (N/A): RSI = 48.21, Price = ₹208.30
# ESCORTS (Escorts Kubota Limited): RSI = 48.20, Price = ₹3340.55
# SCPL (Sheetal Cool Products Limited): RSI = 48.19, Price = ₹331.00
# AKASH (Akash Infra-Projects Limited): RSI = 48.18, Price = ₹34.19
# TFCILTD (Tourism Finance Corporation of India Limited): RSI = 48.17, Price = ₹165.50
# PHOENIXLTD (The Phoenix Mills Limited): RSI = 48.16, Price = ₹1692.25
# LINCOLN (Lincoln Pharmaceuticals Limited): RSI = 48.16, Price = ₹803.95
# FINOPB (Fino Payments Bank Limited): RSI = 48.15, Price = ₹318.80
# ITDCEM (ITD Cementation India Limited): RSI = 48.15, Price = ₹518.00
# UMESLTD (Usha Martin Education & Solutions Limited): RSI = 48.15, Price = ₹6.87
# GUJGASLTD (Gujarat Gas Limited): RSI = 48.14, Price = ₹500.85
# LASA (Lasa Supergenerics Limited): RSI = 48.14, Price = ₹28.70
# LYKALABS (Lyka Labs Limited): RSI = 48.13, Price = ₹152.40
# PLASTIBLEN (Plastiblends India Limited): RSI = 48.13, Price = ₹250.05
# CHEMCON (Chemcon Speciality Chemicals Limited): RSI = 48.04, Price = ₹230.90
# VIRINCHI (Virinchi Limited): RSI = 48.03, Price = ₹28.67
# BANARBEADS (Banaras Beads Limited): RSI = 47.99, Price = ₹131.23
# SRM (N/A): RSI = 47.99, Price = ₹378.00
# DNAMEDIA (Diligent Media Corporation Limited): RSI = 47.96, Price = ₹5.79
# UBL (United Breweries Limited): RSI = 47.96, Price = ₹2000.80
# BIL (Bhartiya International Ltd.): RSI = 47.95, Price = ₹809.90
# SOTL (Savita Oil Technologies Limited): RSI = 47.93, Price = ₹556.85
# CORALFINAC (Coral India Finance and Housing Limited): RSI = 47.92, Price = ₹52.35
# SHILPAMED (Shilpa Medicare Limited): RSI = 47.91, Price = ₹819.50
# SUVEN (Suven Life Sciences Limited): RSI = 47.90, Price = ₹139.86
# KANORICHEM (Kanoria Chemicals & Industries Limited): RSI = 47.90, Price = ₹116.96
# CRISIL (CRISIL Limited): RSI = 47.87, Price = ₹5770.60
# EXXARO (Exxaro Tiles Limited): RSI = 47.87, Price = ₹9.13
# PKTEA (The Peria Karamalai Tea and Produce Company Limited): RSI = 47.85, Price = ₹755.70
# BANSALWIRE (N/A): RSI = 47.79, Price = ₹439.95
# GENSOL (Gensol Engineering Limited): RSI = 47.79, Price = ₹752.20
# NAVNETEDUL (Navneet Education Limited): RSI = 47.77, Price = ₹139.50
# MADRASFERT (Madras Fertilizers Limited): RSI = 47.75, Price = ₹99.16
# TIMESGTY (Times Guaranty Limited): RSI = 47.75, Price = ₹169.06
# RRKABEL (R R Kabel Limited): RSI = 47.69, Price = ₹1399.25
# ZENITHEXPO (Zenith Exports Limited): RSI = 47.69, Price = ₹271.10
# KEI (KEI Industries Limited): RSI = 47.68, Price = ₹4264.50
# LUMAXIND (Lumax Industries Limited): RSI = 47.65, Price = ₹2456.35
# RIIL (Reliance Industrial Infrastructure Limited): RSI = 47.64, Price = ₹1088.15
# AVL (Aditya Vision Limited): RSI = 47.64, Price = ₹504.20
# KOTAKBANK (Kotak Mahindra Bank Limited): RSI = 47.63, Price = ₹1768.65
# MOKSH (Moksh Ornaments Limited): RSI = 47.63, Price = ₹18.90
# ICICIGI (ICICI Lombard General Insurance Company Limited): RSI = 47.63, Price = ₹1859.20
# HMAAGRO (HMA Agro Industries Limited): RSI = 47.58, Price = ₹39.71
# MOTILALOFS (Motilal Oswal Financial Services Limited): RSI = 47.56, Price = ₹940.10
# GOCLCORP (GOCL Corporation Limited): RSI = 47.53, Price = ₹375.00
# SAMBHAAV (Sambhaav Media Limited): RSI = 47.53, Price = ₹7.79
# EMUDHRA (eMudhra Limited): RSI = 47.49, Price = ₹944.75
# PFS (PTC India Financial Services Limited): RSI = 47.47, Price = ₹40.32
# SUNDARMFIN (Sundaram Finance Limited): RSI = 47.47, Price = ₹4370.80
# DEN (DEN Networks Limited): RSI = 47.45, Price = ₹42.67
# VARROC (Varroc Engineering Limited): RSI = 47.43, Price = ₹602.55
# GPTHEALTH (GPT Healthcare Limited): RSI = 47.36, Price = ₹179.52
# STYRENIX (Styrenix Performance Materials Limited): RSI = 47.35, Price = ₹3010.30
# NIVABUPA (Niva Bupa Health Insurance Company Limited): RSI = 47.32, Price = ₹78.26
# GNA (G N A Axles Limited): RSI = 47.32, Price = ₹410.55
# MAXESTATES (N/A): RSI = 47.31, Price = ₹608.35
# GPTINFRA (GPT Infraprojects Limited): RSI = 47.30, Price = ₹142.11
# NEOGEN (Neogen Chemicals Limited): RSI = 47.28, Price = ₹2159.65
# SANGAMIND (Sangam (India) Limited): RSI = 47.27, Price = ₹419.00
# SYRMA (Syrma SGS Technology Limited): RSI = 47.25, Price = ₹604.65
# RAYMOND (Raymond Limited): RSI = 47.18, Price = ₹1696.65
# MOL (Meghmani Organics Limited): RSI = 47.17, Price = ₹83.31
# SAGCEM (Sagar Cements Limited): RSI = 47.17, Price = ₹219.98
# AFFORDABLE (Affordable Robotic & Automation Limited): RSI = 47.13, Price = ₹636.15
# SHOPERSTOP (Shoppers Stop Limited): RSI = 47.12, Price = ₹629.80
# WEL (Wonder Electricals Limited): RSI = 47.07, Price = ₹157.79
# PRIMESECU (Prime Securities Limited): RSI = 47.06, Price = ₹280.85
# RAJTV (Raj Television Network Limited): RSI = 47.03, Price = ₹78.50
# PNB (Punjab National Bank): RSI = 47.01, Price = ₹101.97
# UMAEXPORTS (Uma Exports Limited): RSI = 47.00, Price = ₹109.39
# SHRIRAMFIN (Shriram Finance Limited): RSI = 46.99, Price = ₹2898.75
# HARRMALAYA (Harrisons Malayalam Limited): RSI = 46.93, Price = ₹313.00
# SMLT (Sarthak Metals Limited): RSI = 46.92, Price = ₹158.51
# MHRIL (Mahindra Holidays & Resorts India Limited): RSI = 46.88, Price = ₹370.25
# SECURKLOUD (SecureKloud Technologies Limited): RSI = 46.86, Price = ₹33.41
# TIL (TIL Limited): RSI = 46.84, Price = ₹306.00
# MODIRUBBER (Modi Rubber Limited): RSI = 46.80, Price = ₹122.17
# NIPPOBATRY (Indo National Limited): RSI = 46.80, Price = ₹552.95
# SIKKO (Sikko Industries Limited): RSI = 46.79, Price = ₹97.40
# WILLAMAGOR (Williamson Magor & Co. Limited): RSI = 46.79, Price = ₹38.88
# VIMTALABS (Vimta Labs Limited): RSI = 46.78, Price = ₹979.45
# RUBFILA (Rubfila International Limited): RSI = 46.78, Price = ₹80.13
# MAHASTEEL (Mahamaya Steel Industries Limited): RSI = 46.75, Price = ₹199.09
# 21STCENMGM (Twentyfirst Century Management Services Limited): RSI = 46.74, Price = ₹88.30
# TEXMOPIPES (Texmo Pipes and Products Limited): RSI = 46.74, Price = ₹65.59
# MICEL (MIC Electronics Limited): RSI = 46.68, Price = ₹84.45
# KAYNES (Kaynes Technology India Limited): RSI = 46.67, Price = ₹6970.65
# FOSECOIND (Foseco India Limited): RSI = 46.66, Price = ₹4226.25
# COSMOFIRST (Cosmo First Limited): RSI = 46.65, Price = ₹952.10
# EIHAHOTELS (EIH Associated Hotels Limited): RSI = 46.65, Price = ₹408.60
# ANDHRSUGAR (The Andhra Sugars Limited): RSI = 46.65, Price = ₹94.40
# SINDHUTRAD (Sindhu Trade Links Limited): RSI = 46.65, Price = ₹23.25
# BLAL (BEML Land Assets Limited): RSI = 46.64, Price = ₹235.81
# GRMOVER (GRM Overseas Limited): RSI = 46.64, Price = ₹192.50
# THANGAMAYL (Thangamayil Jewellery Limited): RSI = 46.61, Price = ₹1968.70
# LTFOODS (LT Foods Limited): RSI = 46.54, Price = ₹416.60
# RELIABLE (Reliable Data Services Limited): RSI = 46.53, Price = ₹71.50
# DELTAMAGNT (Delta Manufacturing Limited): RSI = 46.53, Price = ₹108.26
# AGROPHOS (Agro Phos (India) Limited): RSI = 46.53, Price = ₹40.40
# INDOCO (Indoco Remedies Limited): RSI = 46.52, Price = ₹336.10
# SANSTAR (N/A): RSI = 46.50, Price = ₹118.77
# BBOX (Black Box Limited): RSI = 46.46, Price = ₹665.55
# LALPATHLAB (Dr. Lal PathLabs Limited): RSI = 46.45, Price = ₹2994.55
# KAPSTON (Kapston Services Limited): RSI = 46.39, Price = ₹259.80
# IDEAFORGE (ideaForge Technology Limited): RSI = 46.35, Price = ₹603.40
# NOVAAGRI (Nova Agritech Limited): RSI = 46.33, Price = ₹64.20
# TEMBO (Tembo Global Industries Limited): RSI = 46.33, Price = ₹788.00
# KAMDHENU (Kamdhenu Limited): RSI = 46.32, Price = ₹48.25
# HINDPETRO (Hindustan Petroleum Corporation Limited): RSI = 46.27, Price = ₹391.35
# GICHSGFIN (GIC Housing Finance Limited): RSI = 46.23, Price = ₹201.66
# HAPPSTMNDS (Happiest Minds Technologies Limited): RSI = 46.23, Price = ₹712.95
# CASTROLIND (Castrol India Limited): RSI = 46.18, Price = ₹199.94
# DICIND (DIC India Limited): RSI = 46.16, Price = ₹676.35
# GOCOLORS (Go Fashion (India) Limited): RSI = 46.16, Price = ₹984.00
# UNIDT (United Drilling Tools Limited): RSI = 46.13, Price = ₹261.55
# IRISDOREME (Iris Clothings Limited): RSI = 46.12, Price = ₹61.60
# CCHHL (Country Club Hospitality & Holidays Limited): RSI = 46.08, Price = ₹19.76
# EXICOM (Exicom Tele-Systems Limited): RSI = 46.07, Price = ₹262.59
# DIGIDRIVE (Digidrive Distributors Limited): RSI = 46.07, Price = ₹44.12
# ROSSELLIND (Rossell India Limited): RSI = 46.06, Price = ₹75.50
# AMBICAAGAR (Ambica Agarbathies Aroma & Industries Limited): RSI = 46.04, Price = ₹30.72
# OBEROIRLTY (Oberoi Realty Limited): RSI = 46.03, Price = ₹2282.40
# CLEAN (Clean Science and Technology Limited): RSI = 46.03, Price = ₹1446.40
# MACPOWER (Macpower CNC Machines Limited): RSI = 46.03, Price = ₹1410.95
# XCHANGING (Xchanging Solutions Limited): RSI = 46.02, Price = ₹110.76
# FACT (The Fertilisers and Chemicals Travancore Limited): RSI = 45.98, Price = ₹975.00
# RSSOFTWARE (R S Software (India) Limited): RSI = 45.96, Price = ₹199.45
# SUNTECK (Sunteck Realty Limited): RSI = 45.94, Price = ₹494.05
# STOVEKRAFT (Stove Kraft Limited): RSI = 45.92, Price = ₹900.00
# WOCKPHARMA (Wockhardt Limited): RSI = 45.89, Price = ₹1439.00
# ELECON (Elecon Engineering Company Limited): RSI = 45.88, Price = ₹607.35
# DIGISPICE (DiGiSPICE Technologies Limited): RSI = 45.84, Price = ₹30.16
# LATENTVIEW (Latent View Analytics Limited): RSI = 45.80, Price = ₹475.20
# GULPOLY (Gulshan Polyols Limited): RSI = 45.79, Price = ₹175.20
# MARSHALL (Marshall Machines Limited): RSI = 45.78, Price = ₹21.60
# ASAHISONG (Asahi Songwon Colors Limited): RSI = 45.77, Price = ₹362.25
# SRHHYPOLTD (Sree Rayalaseema Hi-Strength Hypo Limited): RSI = 45.74, Price = ₹777.65
# RHL (Robust Hotels Limited): RSI = 45.69, Price = ₹264.00
# SHARDACROP (Sharda Cropchem Limited): RSI = 45.67, Price = ₹808.30
# SREEL (Sreeleathers Limited): RSI = 45.66, Price = ₹260.25
# CROWN (Crown Lifters Limited): RSI = 45.66, Price = ₹205.61
# CTE (Cambridge Technology Enterprises Limited): RSI = 45.65, Price = ₹106.51
# PETRONET (Petronet LNG Limited): RSI = 45.65, Price = ₹331.00
# SIMPLEXINF (Simplex Infrastructures Limited): RSI = 45.64, Price = ₹329.70
# PANACHE (Panache Digilife Limited): RSI = 45.64, Price = ₹283.70
# METROBRAND (Metro Brands Limited): RSI = 45.64, Price = ₹1255.30
# GINNIFILA (Ginni Filaments Limited): RSI = 45.62, Price = ₹31.60
# JAMNAAUTO (Jamna Auto Industries Limited): RSI = 45.60, Price = ₹97.30
# SOMICONVEY (Somi Conveyor Beltings Limited): RSI = 45.57, Price = ₹201.75
# MAHSCOOTER (Maharashtra Scooters Ltd.): RSI = 45.56, Price = ₹9571.10
# USHAMART (Usha Martin Limited): RSI = 45.55, Price = ₹366.60
# TATAINVEST (Tata Investment Corporation Limited): RSI = 45.55, Price = ₹6607.60
# MOHITIND (Mohit Industries Limited): RSI = 45.53, Price = ₹36.27
# STYLEBAAZA (Baazar Style Retail Limited): RSI = 45.51, Price = ₹320.05
# SANGINITA (Sanginita Chemicals Limited): RSI = 45.51, Price = ₹15.17
# ZYDUSWELL (Zydus Wellness Limited): RSI = 45.50, Price = ₹1942.25
# SUPRIYA (Supriya Lifescience Limited): RSI = 45.50, Price = ₹732.60
# SEJALLTD (Sejal Glass Limited): RSI = 45.50, Price = ₹590.00
# REDINGTON (Redington Limited): RSI = 45.46, Price = ₹202.29
# KREBSBIO (Krebs Biochemicals & Industries Limited): RSI = 45.45, Price = ₹95.85
# STEELCAS (Steelcast Limited): RSI = 45.44, Price = ₹871.95
# SARDAEN (Sarda Energy & Minerals Limited): RSI = 45.44, Price = ₹471.05
# TOLINS (N/A): RSI = 45.44, Price = ₹207.43
# KANSAINER (Kansai Nerolac Paints Limited): RSI = 45.41, Price = ₹257.25
# JLHL (Jupiter Life Line Hospitals Limited): RSI = 45.38, Price = ₹1547.65
# ADORWELD (Ador Welding Limited): RSI = 45.38, Price = ₹1092.00
# RBLBANK (RBL Bank Limited): RSI = 45.37, Price = ₹161.66
# ORIENTCER (Orient Ceratech Limited): RSI = 45.36, Price = ₹47.61
# SOLARA (Solara Active Pharma Sciences Limited): RSI = 45.35, Price = ₹693.35
# DBEIL (N/A): RSI = 45.34, Price = ₹185.11
# SIGACHI (Sigachi Industries Limited): RSI = 45.32, Price = ₹50.20
# HITECHGEAR (The Hi-Tech Gears Limited): RSI = 45.30, Price = ₹830.35
# TECHNOE (Techno Electric & Engineering Company Limited): RSI = 45.27, Price = ₹1483.00
# ICICIPRULI (ICICI Prudential Life Insurance Company Limited): RSI = 45.27, Price = ₹652.95
# GALLANTT (Gallantt Ispat Limited): RSI = 45.25, Price = ₹340.30
# ENTERO (Entero Healthcare Solutions Limited): RSI = 45.24, Price = ₹1443.75
# GENUSPOWER (Genus Power Infrastructures Limited): RSI = 45.24, Price = ₹388.15
# TRACXN (Tracxn Technologies Limited): RSI = 45.23, Price = ₹74.26
# GAIL (GAIL (India) Limited): RSI = 45.22, Price = ₹190.58
# VENUSPIPES (Venus Pipes and Tubes Limited): RSI = 45.14, Price = ₹1567.10
# KANPRPLA (Kanpur Plastipack Limited): RSI = 45.13, Price = ₹126.92
# PRUDMOULI (Prudential Sugar Corporation Ltd.): RSI = 45.12, Price = ₹62.00
# ABINFRA (N/A): RSI = 45.12, Price = ₹92.45
# BCONCEPTS (Brand Concepts Limited): RSI = 45.11, Price = ₹475.10
# HINDNATGLS (Hindusthan National Glass & Industries Limited): RSI = 45.08, Price = ₹23.50
# RAYMONDLSL (Raymond Lifestyle Limited): RSI = 45.08, Price = ₹1994.40
# ...
# 523710 (Sayaji Hotels Limited): RSI = 44.82, Price = ₹325.10
# 531471 (N/A): RSI = 44.81, Price = ₹18.01
# 533152 (MBL Infrastructures Limited): RSI = 44.80, Price = ₹63.54
# 526568 (N/A): RSI = 44.79, Price = ₹50.33
# 508989 (Navneet Education Limited): RSI = 44.77, Price = ₹139.50
# 509760 (N/A): RSI = 44.75, Price = ₹58.41
# 519003 (Modi Naturals Limited): RSI = 44.75, Price = ₹514.55
# 540575 (Star Cement Limited): RSI = 44.74, Price = ₹218.50
# 534532 (Lypsa Gems & Jewellery Limited): RSI = 44.74, Price = ₹7.28
# 538979 (Greenlam Industries Limited): RSI = 44.73, Price = ₹562.40
# 532183 (N/A): RSI = 44.70, Price = ₹14.67
# 530341 (N/A): RSI = 44.69, Price = ₹148.35
# 504351 (Empower India Limited): RSI = 44.68, Price = ₹2.05
# 524480 (N/A): RSI = 44.67, Price = ₹635.35
# 537069 (Arnold Holdings Ltd.): RSI = 44.64, Price = ₹43.11
# 513488 (N/A): RSI = 44.64, Price = ₹39.08
# 538365 (Incredible Industries Limited): RSI = 44.61, Price = ₹46.00
# 524748 (N/A): RSI = 44.59, Price = ₹41.99
# 539658 (TeamLease Services Limited): RSI = 44.58, Price = ₹2837.50
# 539336 (Gujarat Gas Limited): RSI = 44.56, Price = ₹500.50
# 535754 (Orient Cement Limited): RSI = 44.53, Price = ₹338.00
# 534615 (North Eastern Carrying Corporation Limited): RSI = 44.52, Price = ₹34.45
# 540065 (RBL Bank Limited): RSI = 44.49, Price = ₹161.85
# 507981 (N/A): RSI = 44.47, Price = ₹98.05
# 530627 (N/A): RSI = 44.47, Price = ₹241.00
# 534741 (Virtual Global Education Limited): RSI = 44.44, Price = ₹0.76
# 539518 (Uday Jewellery Industries Limited): RSI = 44.41, Price = ₹150.10
# 532402 (USG Tech Solutions Limited): RSI = 44.40, Price = ₹17.29
# 530665 (N/A): RSI = 44.39, Price = ₹5.38
# 524717 (N/A): RSI = 44.38, Price = ₹745.90
# 539479 (GTV Engineering Limited): RSI = 44.38, Price = ₹525.80
# 533581 (PG Electroplast Limited): RSI = 44.38, Price = ₹950.65
# 539448 (InterGlobe Aviation Limited): RSI = 44.35, Price = ₹4259.10
# 524703 (N/A): RSI = 44.32, Price = ₹54.98
# 535205 (Mystic Electronics Limited): RSI = 44.30, Price = ₹7.18
# 540702 (Lasa Supergenerics Limited): RSI = 44.28, Price = ₹27.10
# 534338 (Max Heights Infrastructure Limited): RSI = 44.22, Price = ₹28.25
# 532806 (AI Champdany Industries Limited): RSI = 44.21, Price = ₹56.49
# 539040 (Tirupati Tyres Limited): RSI = 44.17, Price = ₹13.07
# 503100 (The Phoenix Mills Limited): RSI = 44.15, Price = ₹1696.55
# 526217 (Hitech Corporation Limited): RSI = 44.10, Price = ₹241.00
# 504058 (Indo National Limited): RSI = 44.10, Price = ₹554.40
# 500660 (GlaxoSmithKline Pharmaceuticals Limited): RSI = 44.03, Price = ₹2207.85
# 541353 (Innovators Façade Systems Limited): RSI = 44.02, Price = ₹225.20
# 532896 (Magnum Ventures Limited): RSI = 43.98, Price = ₹39.04
# 532070 (N/A): RSI = 43.97, Price = ₹200.45
# 539404 (Satin Creditcare Network Limited): RSI = 43.96, Price = ₹155.55
# 540710 (Capacit'e Infraprojects Limited): RSI = 43.94, Price = ₹420.90
# 531508 (Eveready Industries India Limited): RSI = 43.94, Price = ₹388.30
# 500159 (MetroGlobal Limited): RSI = 43.93, Price = ₹155.00
# 511493 (N/A): RSI = 43.93, Price = ₹12.15
# 530977 (N/A): RSI = 43.92, Price = ₹193.75
# 508969 (Sulabh Engineers & Services Limited): RSI = 43.90, Price = ₹4.94
# 500327 (Pil Italica Lifestyle Limited): RSI = 43.89, Price = ₹13.70
# 520051 (Jamna Auto Industries Limited): RSI = 43.88, Price = ₹97.41
# 523007 (N/A): RSI = 43.86, Price = ₹156.75
# 531041 (N/A): RSI = 43.85, Price = ₹503.00
# 539176 (Hawa Engineers Limited): RSI = 43.82, Price = ₹229.60
# 502090 (Sagar Cements Limited): RSI = 43.82, Price = ₹220.10
# 500870 (Castrol India Limited): RSI = 43.77, Price = ₹200.85
# 517356 (N/A): RSI = 43.75, Price = ₹2.54
# 540526 (IRB InvIT Fund): RSI = 43.75, Price = ₹60.09
# 526365 (Swarnsarita Jewels India Limited): RSI = 43.73, Price = ₹40.69
# 540006 (East West Freight Carriers Limited): RSI = 43.70, Price = ₹7.18
# 539607 (Blue Cloud Softech Solutions Limited): RSI = 43.66, Price = ₹102.60
# 540796 (N/A): RSI = 43.65, Price = ₹127.75
# 532268 (Accelya Solutions India Limited): RSI = 43.64, Price = ₹1541.95
# 511218 (Shriram Finance Limited): RSI = 43.64, Price = ₹2898.15
# 540210 (Heads UP Ventures Limited): RSI = 43.64, Price = ₹11.46
# 532879 (N/A): RSI = 43.62, Price = ₹286.20
# 526705 (N/A): RSI = 43.52, Price = ₹278.55
# 531335 (Zydus Wellness Limited): RSI = 43.49, Price = ₹1949.45
# 540647 (Ganges Securities Limited): RSI = 43.48, Price = ₹194.55
# 503624 (N/A): RSI = 43.45, Price = ₹10.12
# 500650 (Excel Industries Limited): RSI = 43.42, Price = ₹1291.40
# 532005 (Sam Industries Ltd.): RSI = 43.39, Price = ₹64.00
# 538795 (Shree Ajit Pulp and Paper Limited): RSI = 43.38, Price = ₹208.65
# 512175 (N/A): RSI = 43.35, Price = ₹8.39
# 505729 (N/A): RSI = 43.33, Price = ₹77.77
# 523648 (Plastiblends India Limited): RSI = 43.28, Price = ₹246.85
# 523842 (Super Tannery Limited): RSI = 43.28, Price = ₹12.20
# 533023 (ZF Commercial Vehicle Control Systems India Limited): RSI = 43.24, Price = ₹11469.60
# 531861 (N/A): RSI = 43.20, Price = ₹53.06
# 532531 (Strides Pharma Science Limited): RSI = 43.18, Price = ₹668.85
# 507598 (Kovilpatti Lakshmi Roller Flour Mills Limited): RSI = 43.18, Price = ₹132.00
# 517569 (KEI Industries Limited): RSI = 43.17, Price = ₹4264.00
# 533088 (Mahindra Holidays & Resorts India Limited): RSI = 43.17, Price = ₹369.65
# 511147 (N/A): RSI = 43.08, Price = ₹100.75
# 531300 (N/A): RSI = 43.04, Price = ₹4.39
# 531210 (N/A): RSI = 43.03, Price = ₹64.21
# 500250 (L.G. Balakrishnan & Bros Limited): RSI = 43.01, Price = ₹1295.30
# 530133 (N/A): RSI = 43.00, Price = ₹79.00
# 526409 (Kkalpana Industries (India) Limited): RSI = 42.98, Price = ₹15.53
# 507759 (N/A): RSI = 42.98, Price = ₹23.99
# 526492 (N/A): RSI = 42.96, Price = ₹216.00
# 530401 (N/A): RSI = 42.96, Price = ₹77.90
# 539770 (Darjeeling Ropeway Company Limited): RSI = 42.94, Price = ₹35.77
# 533193 (Kirloskar Electric Company Limited): RSI = 42.92, Price = ₹185.80
# 533168 (Rossell India Limited): RSI = 42.90, Price = ₹76.87
# 533289 (Kesar Terminals & Infrastructure Limited): RSI = 42.88, Price = ₹75.10
# 533096 (Adani Power Limited): RSI = 42.88, Price = ₹504.40
# 511012 (N/A): RSI = 42.86, Price = ₹1.48
# 532466 (Oracle Financial Services Software Limited): RSI = 42.84, Price = ₹11983.90
# 540757 (Sheetal Cool Products Limited): RSI = 42.76, Price = ₹329.85
# 539126 (MEP Infrastructure Developers Limited): RSI = 42.73, Price = ₹3.05
# 532892 (Motilal Oswal Financial Services Limited): RSI = 42.70, Price = ₹939.60
# 523782 (N/A): RSI = 42.70, Price = ₹16.86
# 531289 (National Fittings Limited): RSI = 42.69, Price = ₹131.95
# 531082 (Alankit Limited): RSI = 42.68, Price = ₹21.56
# 533260 (Career Point Limited): RSI = 42.67, Price = ₹389.85
# 539784 (LIC MF Nifty 100 ETF): RSI = 42.66, Price = ₹261.16
# 539984 (Hindusthan Urban Infrastructure Limited): RSI = 42.64, Price = ₹2480.00
# 517385 (Symphony Limited): RSI = 42.63, Price = ₹1298.90
# 500170 (N/A): RSI = 42.63, Price = ₹36.19
# 532407 (N/A): RSI = 42.60, Price = ₹213.50
# 530643 (Eco Recycling Limited): RSI = 42.58, Price = ₹913.85
# 532764 (GeeCee Ventures Limited): RSI = 42.58, Price = ₹432.00
# 524408 (N/A): RSI = 42.56, Price = ₹174.00
# 501848 (Global Offshore Services Limited): RSI = 42.54, Price = ₹114.75
# 538713 (Atishay Limited): RSI = 42.53, Price = ₹222.35
# 540743 (Godrej Agrovet Limited): RSI = 42.53, Price = ₹739.65
# 535267 (Comfort Fincap Limited): RSI = 42.47, Price = ₹9.99
# 538081 (Haria Apparels Limited): RSI = 42.44, Price = ₹5.34
# 534639 (Vinayak Polycon International Limited): RSI = 42.44, Price = ₹36.25
# 590024 (The Fertilisers And Chemicals Travancore Limited): RSI = 42.44, Price = ₹963.40
# 506906 (N/A): RSI = 42.38, Price = ₹3.81
# 531859 (N/A): RSI = 42.37, Price = ₹314.45
# 524711 (N/A): RSI = 42.37, Price = ₹11.35
# 531390 (N/A): RSI = 42.37, Price = ₹175.65
# 500285 (N/A): RSI = 42.36, Price = ₹53.33
# 532674 (Bannari Amman Spinning Mills Ltd): RSI = 42.22, Price = ₹53.54
# 526479 (N/A): RSI = 42.19, Price = ₹150.90
# 500319 (N/A): RSI = 42.17, Price = ₹114.65
# 539228 (Gala Global Products Limited): RSI = 42.17, Price = ₹3.21
# 523550 (N/A): RSI = 42.16, Price = ₹78.21
# 538635 (Snowman Logistics Limited): RSI = 42.14, Price = ₹69.01
# 540692 (Apex Frozen Foods Limited): RSI = 42.12, Price = ₹251.95
# 532398 (Usha Martin Education & Solutions Limited): RSI = 42.08, Price = ₹6.86
# 523465 (N/A): RSI = 42.08, Price = ₹49.90
# 520021 (Omax Autos Limited): RSI = 42.07, Price = ₹113.90
# 540777 (HDFC Life Insurance Company Limited): RSI = 42.06, Price = ₹617.55
# 540133 (ICICI Prudential Life Insurance Company Limited): RSI = 42.05, Price = ₹652.50
# 506003 (N/A): RSI = 42.05, Price = ₹57.40
# 526839 (Shelter Infra Projects Limited): RSI = 42.00, Price = ₹17.62
# 532776 (Shivam Autotech Limited): RSI = 41.99, Price = ₹44.28
# 506605 (N/A): RSI = 41.99, Price = ₹2585.00
# 515085 (N/A): RSI = 41.98, Price = ₹7.16
# 540393 (Sarthak Metals Limited): RSI = 41.97, Price = ₹159.60
# 533202 (Satchmo Holdings Limited): RSI = 41.96, Price = ₹3.93
# 540749 (MAS Financial Services Limited): RSI = 41.96, Price = ₹261.60
# 513252 (N/A): RSI = 41.95, Price = ₹707.35
# 500317 (Oswal Agro Mills Limited): RSI = 41.93, Price = ₹70.07
# 522207 (N/A): RSI = 41.91, Price = ₹117.70
# 522183 (N/A): RSI = 41.87, Price = ₹446.60
# 505232 (Veljan Denison Limited): RSI = 41.87, Price = ₹1214.40
# 537707 (ETT Limited): RSI = 41.86, Price = ₹16.64
# 532807 (Cineline India Limited): RSI = 41.84, Price = ₹129.60
# 518075 (N/A): RSI = 41.84, Price = ₹469.15
# 590134 (Madras Fertilizers Limited): RSI = 41.83, Price = ₹98.95
# 523606 (N/A): RSI = 41.82, Price = ₹2516.45
# 500104 (Hindustan Petroleum Corporation Limited): RSI = 41.78, Price = ₹391.10
# 540716 (ICICI Lombard General Insurance Company Limited): RSI = 41.78, Price = ₹1859.55
# 540729 (Vanta Bioscience Limited): RSI = 41.74, Price = ₹40.99
# 531822 (Rodium Realty Limited): RSI = 41.71, Price = ₹150.15
# 511131 (N/A): RSI = 41.69, Price = ₹16.79
# 506852 (N/A): RSI = 41.67, Price = ₹37.37
# 530557 (N/A): RSI = 41.67, Price = ₹0.80
# 504028 (N/A): RSI = 41.64, Price = ₹139.95
# 524667 (Savita Oil Technologies Limited): RSI = 41.63, Price = ₹554.00
# 500179 (HCL Infosystems Limited): RSI = 41.60, Price = ₹15.81
# 504093 (Panasonic Energy India Co. Ltd.): RSI = 41.58, Price = ₹451.95
# 512018 (Tomorrow Technologies Global Innovations Limited): RSI = 41.58, Price = ₹15.33
# 531688 (Prithvi Exchange (India) Limited): RSI = 41.57, Price = ₹235.80
# 540565 (India Grid Trust): RSI = 41.56, Price = ₹143.70
# 530131 (Udaipur Cement Works Limited): RSI = 41.56, Price = ₹29.34
# 540361 (Danube Industries Limited): RSI = 41.54, Price = ₹4.68
# 540124 (G N A Axles Limited): RSI = 41.54, Price = ₹409.35
# 505681 (N/A): RSI = 41.53, Price = ₹637.30
# 514300 (Pioneer Embroideries Limited): RSI = 41.52, Price = ₹54.79
# 519307 (N/A): RSI = 41.51, Price = ₹1.57
# 533164 (Texmo Pipes and Products Limited): RSI = 41.48, Price = ₹66.09
# 538567 (Gulf Oil Lubricants India Limited): RSI = 41.47, Price = ₹1137.00
# 500014 (N/A): RSI = 41.46, Price = ₹7.18
# 523840 (N/A): RSI = 41.46, Price = ₹35.33
# 538987 (Talbros Engineering Limited): RSI = 41.43, Price = ₹615.90
# 519224 (Williamson Magor & Co. Limited): RSI = 41.43, Price = ₹39.05
# 524731 (N/A): RSI = 41.40, Price = ₹1253.75
# 533270 (Bedmutha Industries Limited): RSI = 41.38, Price = ₹200.00
# 506685 (N/A): RSI = 41.37, Price = ₹532.35
# 524440 (N/A): RSI = 41.34, Price = ₹58.38
# 540268 (TruCap Finance Limited): RSI = 41.33, Price = ₹15.26
# 533014 (N/A): RSI = 41.33, Price = ₹82.64
# 533482 (Kridhan Infra Limited): RSI = 41.32, Price = ₹6.13
# 509423 (Sanathnagar Enterprises Limited): RSI = 41.31, Price = ₹39.79
# 541503 (Unick Fix-A-Form and Printers Limited): RSI = 41.30, Price = ₹81.90
# 532977 (Bajaj Auto Limited): RSI = 41.29, Price = ₹8642.25
# 500335 (Birla Corporation Limited): RSI = 41.28, Price = ₹1221.95
# 533286 (MOIL Limited): RSI = 41.27, Price = ₹338.25
# 526642 (Mirza International Limited): RSI = 41.25, Price = ₹36.72
# 532842 (Sree Rayalaseema Hi-Strength Hypo Limited): RSI = 41.25, Price = ₹777.65
# 530343 (Genus Power Infrastructures Limited): RSI = 41.23, Price = ₹387.90
# 500414 (N/A): RSI = 41.14, Price = ₹202.20
# 531595 (Capri Global Capital Limited): RSI = 41.14, Price = ₹189.30
# 530821 (SSPDL Limited): RSI = 41.13, Price = ₹21.38
# 506618 (Punjab Chemicals and Crop Protection Limited): RSI = 41.13, Price = ₹994.00
# 502450 (Seshasayee Paper and Boards Limited): RSI = 41.08, Price = ₹304.05
# 539227 (Loyal Equipments Limited): RSI = 41.05, Price = ₹272.00
# 532209 (The Jammu and Kashmir Bank Limited): RSI = 40.99, Price = ₹96.75
# 513729 (Aro Granite Industries Limited): RSI = 40.97, Price = ₹46.25
# 526849 (Banaras Beads Limited): RSI = 40.96, Price = ₹129.45
# 523736 (Dhunseri Ventures Limited): RSI = 40.94, Price = ₹351.20
# 533758 (APL Apollo Tubes Limited): RSI = 40.93, Price = ₹1538.80
# 533452 (Delphi World Money Limited): RSI = 40.89, Price = ₹203.05
# 531266 (V.S.T. Tillers Tractors Limited): RSI = 40.85, Price = ₹4925.65
# 531814 (N/A): RSI = 40.83, Price = ₹17.93
# 500304 (NIIT Limited): RSI = 40.82, Price = ₹187.20
# 502445 (Citadel Realty and Developers Limited): RSI = 40.81, Price = ₹69.35
# 539871 (Thyrocare Technologies Limited): RSI = 40.78, Price = ₹935.00
# 513693 (N/A): RSI = 40.75, Price = ₹42.18
# 513713 (N/A): RSI = 40.74, Price = ₹6.89
# 531307 (RRIL Limited): RSI = 40.72, Price = ₹20.96
# 541703 (Raconteur Global Resources Limited): RSI = 40.68, Price = ₹13.28
# 532173 (CyberTech Systems and Software Limited): RSI = 40.66, Price = ₹216.45
# 526355 (N/A): RSI = 40.66, Price = ₹101.50
# 506532 (N/A): RSI = 40.64, Price = ₹767.95
# 517494 (N/A): RSI = 40.60, Price = ₹21.87
# 539963 (Zeal Aqua Limited): RSI = 40.58, Price = ₹12.41
# 521240 (Sambandam Spinning Mills Limited): RSI = 40.55, Price = ₹157.40
# 532613 (VIP Clothing Limited): RSI = 40.54, Price = ₹44.34
# 513043 (Remi Edelstahl Tubulars Limited): RSI = 40.53, Price = ₹111.00
# 524576 (Vivid Global Industries Limited): RSI = 40.52, Price = ₹19.62
# 512048 (Luharuka Media & Infra Limited): RSI = 40.52, Price = ₹4.73
# 513566 (N/A): RSI = 40.51, Price = ₹17.58
# 526668 (Kamat Hotels (India) Limited): RSI = 40.50, Price = ₹225.35
# 523537 (N/A): RSI = 40.50, Price = ₹51.36
# 512131 (Signet Industries Limited): RSI = 40.47, Price = ₹68.85
# 522134 (N/A): RSI = 40.45, Price = ₹179.05
# 524654 (Natural Capsules Limited): RSI = 40.45, Price = ₹265.45
# 500209 (Infosys Limited): RSI = 40.44, Price = ₹1933.15
# 541006 (N/A): RSI = 40.42, Price = ₹20.00
# 537292 (Agri-tech (India) Limited): RSI = 40.42, Price = ₹196.95
# 535458 (NRB Industrial Bearings Limited): RSI = 40.41, Price = ₹23.96
# 502180 (Shree Digvijay Cement Company Ltd.): RSI = 40.39, Price = ₹84.84
# 538634 (Vasundhara Rasayans Limited): RSI = 40.32, Price = ₹280.35
# 523660 (The Waterbase Limited): RSI = 40.32, Price = ₹71.95
# 540769 (The New India Assurance Company Limited): RSI = 40.24, Price = ₹194.60
# 526721 (N/A): RSI = 40.23, Price = ₹129.90
# 530897 (N/A): RSI = 40.22, Price = ₹178.00
# 511413 (Crest Ventures Limited): RSI = 40.22, Price = ₹434.85
# 533477 (Enkei Wheels (India) Limited): RSI = 40.19, Price = ₹647.95
# 524752 (N/A): RSI = 40.17, Price = ₹15.15
# 535566 (KIFS Financial Services Limited): RSI = 40.16, Price = ₹152.80
# 517146 (Usha Martin Limited): RSI = 40.16, Price = ₹369.35
# 539254 (Adani Transmission Limited): RSI = 40.15, Price = ₹770.25
# 522275 (GE T&D India Limited): RSI = 40.15, Price = ₹1991.50
# 530427 (N/A): RSI = 40.15, Price = ₹90.01
# 519612 (N/A): RSI = 40.14, Price = ₹68.07
# 531215 (N/A): RSI = 40.12, Price = ₹285.05
# 505750 (N/A): RSI = 40.12, Price = ₹581.65
# 533019 (N/A): RSI = 40.10, Price = ₹2420.00
# 504879 (Orient Abrasives Limited): RSI = 40.10, Price = ₹48.73
# 526608 (Electrotherm (India) Limited): RSI = 40.10, Price = ₹1223.15
# 511543 (N/A): RSI = 40.10, Price = ₹43.19
# 590062 (The Andhra Sugars Limited): RSI = 40.06, Price = ₹93.87
# 524200 (Vinati Organics Limited): RSI = 40.03, Price = ₹1702.45
# 517421 (Butterfly Gandhimathi Appliances Limited): RSI = 40.02, Price = ₹779.00
# 500444 (West Coast Paper Mills Limited): RSI = 40.00, Price = ₹552.20
# 531518 (N/A): RSI = 40.00, Price = ₹0.49
# 531025 (Visagar Financial Services Limited): RSI = 40.00, Price = ₹0.75
#
# Daily analysis complete. Results saved in stock_analysis\daily_results
