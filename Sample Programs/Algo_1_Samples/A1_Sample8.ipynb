# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    # [Previous methods remain unchanged...]

    def calculate_ema(self, data, length=9, source='Close', offset=0):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=9).mean()  # Smoothing length of 9 as specified
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=60):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate EMA
            hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0)

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)
            self.save_delisted_stocks()
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    # [Rest of the class methods remain unchanged...]

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()

# %% [markdown]
# ema 9(above code)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:

    def __init__(self):
            self.base_dir = 'stock_analysis'
            self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
            self.results_dir = os.path.join(self.base_dir, 'daily_results')
            self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
            self.setup_directories()
            self.load_delisted_stocks()
            self.session = requests.Session()  # Reuse session for better performance

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def get_stock_data(self, symbol, exchange='NSE', days=60):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)  # Changed from add to append
                self.save_delisted_stocks()  # Save immediately after adding
                return None, None, None, None

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)  # Changed from add to append
            self.save_delisted_stocks()  # Save immediately after adding
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()

# %% [markdown]
# previous project(above code)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])


    def calculate_ema(self, data, length, source='Close', offset=0, smoothing_length=9):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            smoothing_length (int): Length of initial SMA smoothing
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=smoothing_length).mean()
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=60):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate both EMAs
            hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0, smoothing_length=9)
            hist_data['EMA_21'] = self.calculate_ema(hist_data, length=21, source='Close', offset=0, smoothing_length=9)
            hist_data['EMA_50'] = self.calculate_ema(hist_data, length=50, source='Close', offset=0, smoothing_length=9)

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)
            self.save_delisted_stocks()
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'EMA_21': hist_data['EMA_21'].iloc[-1] if 'EMA_21' in hist_data else 'N/A',
                            'EMA_50': hist_data['EMA_50'].iloc[-1] if 'EMA_50' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")


if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()

# %% [markdown]
# need to add code snippets in above part(need to do it tommorroe i.e.,today(10-01-2025))

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def calculate_ema(self, data, length, source='Close', offset=0, smoothing_length=9):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            smoothing_length (int): Length of initial SMA smoothing
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=smoothing_length).mean()
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=100):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate all three EMAs
            hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0, smoothing_length=9)
            hist_data['EMA_21'] = self.calculate_ema(hist_data, length=21, source='Close', offset=0, smoothing_length=9)
            hist_data['EMA_50'] = self.calculate_ema(hist_data, length=50, source='Close', offset=0, smoothing_length=9)

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)
            self.save_delisted_stocks()
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'EMA_21': hist_data['EMA_21'].iloc[-1] if 'EMA_21' in hist_data else 'N/A',
                            'EMA_50': hist_data['EMA_50'].iloc[-1] if 'EMA_50' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2062 NSE and 3026 BSE stocks
#
# Daily analysis complete. Results saved in stock_analysis\daily_results

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def calculate_ema(self, data, length, source='Close', offset=0, smoothing_length=9):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            smoothing_length (int): Length of initial SMA smoothing
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=smoothing_length).mean()
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=200):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            time.sleep(1)  # Add a delay of 1 second between requests
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate all three EMAs
            hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0, smoothing_length=9)
            hist_data['EMA_21'] = self.calculate_ema(hist_data, length=21, source='Close', offset=0, smoothing_length=9)
            hist_data['EMA_50'] = self.calculate_ema(hist_data, length=50, source='Close', offset=0, smoothing_length=9)

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)
            self.save_delisted_stocks()
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=8) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'EMA_21': hist_data['EMA_21'].iloc[-1] if 'EMA_21' in hist_data else 'N/A',
                            'EMA_50': hist_data['EMA_50'].iloc[-1] if 'EMA_50' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2062 NSE and 3026 BSE stocks
# $ICICIBANK.NS: possibly delisted; no price data found  (1d 2024-06-24 13:22:09.188021 -> 2025-01-10 13:22:09.188021)
# Error fetching data for MASTERTR: single positional indexer is out-of-bounds
# $MRF.NS: possibly delisted; no price data found  (1d 2024-06-24 13:23:53.392810 -> 2025-01-10 13:23:53.392810)
# Error fetching data for RACLGEAR: single positional indexer is out-of-bounds
# Error fetching data for ROSSTECH: single positional indexer is out-of-bounds
# Error fetching data for SAGILITY: single positional indexer is out-of-bounds
# Error fetching data for SURAKSHA: single positional indexer is out-of-bounds
# Error fetching data for SWIGGY: single positional indexer is out-of-bounds
#
# NSE analysis complete. Results saved to stock_analysis\daily_results\nse_analysis_20250110.xlsx
#
# NSE Stocks with RSI >= 40:
# SVLL (Shree Vasu Logistics Limited): RSI = 100.00, Price = ₹394.65
# VISASTEEL (VISA Steel Limited): RSI = 100.00, Price = ₹45.48
# GVT&D (GE Vernova T&D India Ltd): RSI = 100.00, Price = ₹1956.30
# BLUECOAST (Blue Coast Hotels Limited): RSI = 100.00, Price = ₹22.27
# BGRENERGY (BGR Energy Systems Limited): RSI = 100.00, Price = ₹119.00
# AARVEEDEN (Aarvee Denims and Exports Ltd.): RSI = 100.00, Price = ₹131.58
# ATLASCYCLE (Atlas Cycles (Haryana) Limited): RSI = 100.00, Price = ₹112.81
# FSC (Future Supply Chain Solutions Limited): RSI = 96.77, Price = ₹2.49
# INDOTHAI (Indo Thai Securities Limited): RSI = 96.13, Price = ₹1731.35
# TATACONSUM (Tata Consumer Products Limited): RSI = 90.06, Price = ₹976.55
# AXISCADES (AXISCADES Technologies Limited): RSI = 86.22, Price = ₹790.05
# PTCIL (PTC Industries Limited): RSI = 85.92, Price = ₹16743.95
# ZOTA (Zota Health Care Limited): RSI = 85.26, Price = ₹1039.00
# CAPITALSFB (Capital Small Finance Bank Limited): RSI = 85.18, Price = ₹307.20
# LLOYDSME (Lloyds Metals and Energy Limited): RSI = 84.06, Price = ₹1471.40
# SUNCLAY (Sundaram-Clayton Limited): RSI = 83.79, Price = ₹2829.55
# INDIACEM (The India Cements Limited): RSI = 83.30, Price = ₹376.85
# GODREJCP (Godrej Consumer Products Limited): RSI = 82.78, Price = ₹1173.55
# SHAKTIPUMP (Shakti Pumps (India) Limited): RSI = 81.86, Price = ₹1330.00
# BAJAJFINSV (Bajaj Finserv Ltd.): RSI = 79.80, Price = ₹1710.50
# VIJAYA (Vijaya Diagnostic Centre Limited): RSI = 79.27, Price = ₹1233.55
# ESCORTS (Escorts Kubota Limited): RSI = 79.24, Price = ₹3423.00
# BRITANNIA (Britannia Industries Limited): RSI = 79.23, Price = ₹4941.65
# CALSOFT (California Software Company Limited): RSI = 77.94, Price = ₹20.76
# AVONMORE (Avonmore Capital & Management Services Limited): RSI = 77.50, Price = ₹25.87
# PROZONER (Prozone Realty Limited): RSI = 77.32, Price = ₹36.99
# AVROIND (Avro India Limited): RSI = 76.10, Price = ₹217.92
# LLOYDSENT (Lloyds Enterprises Limited): RSI = 75.83, Price = ₹58.43
# UPL (UPL Limited): RSI = 75.81, Price = ₹553.60
# SRF (SRF Limited): RSI = 75.70, Price = ₹2604.40
# COFFEEDAY (Coffee Day Enterprises Limited): RSI = 75.69, Price = ₹30.28
# SEYAIND (Seya Industries Limited): RSI = 75.66, Price = ₹29.55
# KIMS (Krishna Institute of Medical Sciences Limited): RSI = 75.52, Price = ₹650.75
# HINDUNILVR (Hindustan Unilever Limited): RSI = 75.17, Price = ₹2450.70
# UNIVASTU (Univastu India Limited): RSI = 75.12, Price = ₹283.05
# V2RETAIL (V2 Retail Limited): RSI = 75.04, Price = ₹1729.90
# LFIC (Lakshmi Finance & Industrial Corporation Limited): RSI = 74.93, Price = ₹246.12
# JUBLFOOD (Jubilant FoodWorks Limited): RSI = 74.50, Price = ₹735.05
# ARIHANTSUP (Arihant Superstructures Limited): RSI = 74.28, Price = ₹510.70
# ATALREAL (Atal Realtech Limited): RSI = 74.01, Price = ₹14.15
# DNAMEDIA (Diligent Media Corporation Limited): RSI = 73.86, Price = ₹6.99
# JSWHL (JSW Holdings Limited): RSI = 73.63, Price = ₹17746.95
# MEDICO (Medico Remedies Limited): RSI = 73.41, Price = ₹61.00
# BROOKS (Brooks Laboratories Limited): RSI = 73.04, Price = ₹182.06
# MAZDA (Mazda Limited): RSI = 72.96, Price = ₹1921.00
# INDOTECH (Indo Tech Transformers Limited): RSI = 72.47, Price = ₹3554.20
# AMBER (Amber Enterprises India Limited): RSI = 72.32, Price = ₹7890.95
# HMT (HMT Limited): RSI = 72.29, Price = ₹73.85
# MARICO (Marico Limited): RSI = 72.18, Price = ₹674.50
# AARTIPHARM (Aarti Pharmalabs Limited): RSI = 72.08, Price = ₹670.95
# INDORAMA (Indo Rama Synthetics (India) Limited): RSI = 72.05, Price = ₹44.60
# INDGN (N/A): RSI = 72.01, Price = ₹623.80
# BAJFINANCE (Bajaj Finance Limited): RSI = 71.93, Price = ₹7284.25
# MANCREDIT (Mangal Credit and Fincorp Limited): RSI = 71.92, Price = ₹164.54
# RKFORGE (Ramkrishna Forgings Limited): RSI = 71.13, Price = ₹989.85
# COROMANDEL (Coromandel International Limited): RSI = 70.79, Price = ₹1933.95
# MVGJL (Manoj Vaibhav Gems 'N' Jewellers Limited): RSI = 70.44, Price = ₹286.30
# SMSLIFE (SMS Lifesciences India Limited): RSI = 70.27, Price = ₹1298.40
# KALYANIFRG (Kalyani Forge Limited): RSI = 70.25, Price = ₹771.00
# SBILIFE (SBI Life Insurance Company Limited): RSI = 69.82, Price = ₹1485.45
# WORTH (Worth Peripherals Limited): RSI = 69.82, Price = ₹166.03
# FMNL (Future Market Networks Limited): RSI = 69.56, Price = ₹25.96
# EPACK (EPACK Durable Limited): RSI = 69.32, Price = ₹598.35
# MEGASTAR (Megastar Foods Limited): RSI = 69.25, Price = ₹275.00
# BTML (Bodhi Tree Multimedia Limited): RSI = 69.23, Price = ₹12.30
# ASTERDM (Aster DM Healthcare Limited): RSI = 69.21, Price = ₹511.80
# EICHERMOT (Eicher Motors Limited): RSI = 69.19, Price = ₹5084.60
# ALLDIGI (Alldigi Tech Limited): RSI = 69.10, Price = ₹1043.00
# GLFL (Gujarat Lease Financing Limited): RSI = 69.03, Price = ₹8.03
# TATAMOTORS (Tata Motors Limited): RSI = 68.95, Price = ₹782.25
# BATAINDIA (Bata India Limited): RSI = 68.64, Price = ₹1439.20
# AURUM (Aurum PropTech Limited): RSI = 68.48, Price = ₹253.01
# ASMS (Bartronics India Limited): RSI = 68.10, Price = ₹21.62
# MEGASOFT (Megasoft Limited): RSI = 68.09, Price = ₹101.49
# APOLLO (Apollo Micro Systems Limited): RSI = 67.94, Price = ₹121.98
# M&M (Mahindra & Mahindra Limited): RSI = 67.71, Price = ₹3112.90
# SBICARD (SBI Cards and Payment Services Limited): RSI = 67.71, Price = ₹730.05
# MGL (Mahanagar Gas Limited): RSI = 67.69, Price = ₹1303.25
# JTLIND (JTL Industries Limited): RSI = 67.66, Price = ₹105.56
# USK (Udayshivakumar Infra Limited): RSI = 67.56, Price = ₹54.15
# CREDITACC (CreditAccess Grameen Limited): RSI = 67.37, Price = ₹959.05
# MARUTI (Maruti Suzuki India Limited): RSI = 67.24, Price = ₹11639.60
# AUBANK (AU Small Finance Bank Limited): RSI = 67.00, Price = ₹579.55
# GOLDIAM (Goldiam International Limited): RSI = 66.86, Price = ₹485.90
# DCXINDIA (DCX Systems Limited): RSI = 66.83, Price = ₹363.65
# DMART (Avenue Supermarts Limited): RSI = 66.78, Price = ₹3739.00
# MBAPL (Madhya Bharat Agro Products Limited): RSI = 66.71, Price = ₹241.02
# DELTACORP (Delta Corp Limited): RSI = 66.65, Price = ₹120.10
# ABDL (N/A): RSI = 66.50, Price = ₹416.55
# MGEL (Mangalam Global Enterprise Limited): RSI = 66.46, Price = ₹29.11
# EQUITASBNK (Equitas Small Finance Bank Limited): RSI = 66.31, Price = ₹68.28
# BLUECHIP (Blue Chip India Limited): RSI = 66.23, Price = ₹8.75
# CANTABIL (Cantabil Retail India Limited): RSI = 66.10, Price = ₹299.10
# ASHAPURMIN (Ashapura Minechem Limited): RSI = 65.87, Price = ₹463.55
# ASIANHOTNR (Asian Hotels (North) Limited): RSI = 65.83, Price = ₹282.00
# BERGEPAINT (Berger Paints India Limited): RSI = 65.77, Price = ₹463.50
# LTIM (LTIMindtree Limited): RSI = 65.72, Price = ₹6125.00
# VASWANI (Vaswani Industries Limited): RSI = 65.68, Price = ₹54.02
# JUSTDIAL (Just Dial Limited): RSI = 65.60, Price = ₹1056.95
# ALPA (Alpa Laboratories Limited): RSI = 65.47, Price = ₹126.20
# TECILCHEM (Tecil Chemicals and Hydro Power Ltd.): RSI = 65.29, Price = ₹26.80
# AIIL (Authum Investment & Infrastructure Limited): RSI = 65.11, Price = ₹1864.50
# DECCANCE (Deccan Cements Limited): RSI = 64.96, Price = ₹702.95
# GENESYS (Genesys International Corporation Limited): RSI = 64.68, Price = ₹1007.90
# DIAMONDYD (Prataap Snacks Limited): RSI = 64.67, Price = ₹1147.80
# EMBDL (N/A): RSI = 64.46, Price = ₹138.98
# KILITCH (Kilitch Drugs (India) Limited): RSI = 64.41, Price = ₹340.70
# ITI (ITI Limited): RSI = 64.41, Price = ₹443.85
# MANGCHEFER (Mangalore Chemicals & Fertilizers Limited): RSI = 64.39, Price = ₹167.12
# SPANDANA (Spandana Sphoorty Financial Limited): RSI = 64.26, Price = ₹409.65
# TITAN (Titan Company Limited): RSI = 64.12, Price = ₹3487.05
# M&MFIN (Mahindra & Mahindra Financial Services Limited): RSI = 63.88, Price = ₹276.50
# GMRP&UI (GMR Power And Urban Infra Limited): RSI = 63.78, Price = ₹116.21
# E2E (E2E Networks Limited): RSI = 63.74, Price = ₹4250.00
# ASALCBR (Associated Alcohols & Breweries Limited): RSI = 63.62, Price = ₹1165.05
# AARTIIND (Aarti Industries Limited): RSI = 63.59, Price = ₹426.20
# NACLIND (NACL Industries Limited): RSI = 63.38, Price = ₹65.23
# ATFL (Agro Tech Foods Limited): RSI = 63.33, Price = ₹936.25
# JYOTHYLAB (Jyothy Labs Limited): RSI = 63.27, Price = ₹402.70
# RELIANCE (Reliance Industries Limited): RSI = 63.22, Price = ₹1251.25
# AKUMS (N/A): RSI = 63.08, Price = ₹628.15
# INNOVACAP (Innova Captab Limited): RSI = 62.78, Price = ₹1092.00
# LORDSCHLO (Lords Chloro Alkali Limited): RSI = 62.71, Price = ₹194.40
# RAMAPHO (Rama Phosphates Limited): RSI = 62.70, Price = ₹219.41
# DEVIT (Dev Information Technology Limited): RSI = 62.54, Price = ₹171.38
# CONCORDBIO (Concord Biotech Limited): RSI = 62.49, Price = ₹2265.90
# VLEGOV (VL E-Governance & IT Solutions Limited): RSI = 62.39, Price = ₹171.71
# ZEEMEDIA (Zee Media Corporation Limited): RSI = 62.36, Price = ₹20.58
# LAURUSLABS (Laurus Labs Limited): RSI = 61.76, Price = ₹586.35
# ANANTRAJ (Anant Raj Limited): RSI = 61.72, Price = ₹900.30
# ROML (Raj Oil Mills Limited): RSI = 61.52, Price = ₹55.18
# GANESHHOUC (Ganesh Housing Corporation Limited): RSI = 61.44, Price = ₹1278.20
# SYNGENE (Syngene International Limited): RSI = 61.43, Price = ₹868.10
# DABUR (Dabur India Limited): RSI = 61.42, Price = ₹519.25
# FSL (Firstsource Solutions Limited): RSI = 61.41, Price = ₹380.90
# LLOYDSENGG (Lloyds Engineering Works Limited): RSI = 61.41, Price = ₹85.29
# SHAILY (Shaily Engineering Plastics Limited): RSI = 61.39, Price = ₹1581.00
# MONARCH (Monarch Networth Capital Limited): RSI = 61.21, Price = ₹443.15
# IDEA (Vodafone Idea Limited): RSI = 61.17, Price = ₹7.82
# MANGLMCEM (Mangalam Cement Limited): RSI = 61.05, Price = ₹974.05
# GUFICBIO (Gufic Biosciences Limited): RSI = 61.05, Price = ₹455.10
# SAPPHIRE (Sapphire Foods India Limited): RSI = 61.00, Price = ₹332.60
# MATRIMONY (Matrimony.com Limited): RSI = 60.86, Price = ₹659.15
# BIOCON (Biocon Limited): RSI = 60.84, Price = ₹361.00
# CHOLAFIN (Cholamandalam Investment and Finance Company Limited): RSI = 60.84, Price = ₹1257.30
# JISLJALEQS (Jain Irrigation Systems Limited): RSI = 60.64, Price = ₹74.15
# TCPLPACK (TCPL Packaging Limited): RSI = 60.63, Price = ₹3253.60
# REPL (Rudrabhishek Enterprises Limited): RSI = 60.42, Price = ₹316.65
# SASKEN (Sasken Technologies Limited): RSI = 60.15, Price = ₹2157.15
# IGL (Indraprastha Gas Limited): RSI = 60.13, Price = ₹416.70
# INFY (Infosys Limited): RSI = 60.07, Price = ₹1970.85
# HSCL (Himadri Speciality Chemical Limited): RSI = 60.04, Price = ₹568.00
# CHOLAHLDNG (Cholamandalam Financial Holdings Limited): RSI = 59.96, Price = ₹1516.25
# WELENT (Welspun Enterprises Limited): RSI = 59.84, Price = ₹617.85
# APARINDS (APAR Industries Limited): RSI = 59.76, Price = ₹10655.15
# LTTS (L&T Technology Services Limited): RSI = 59.73, Price = ₹4962.05
# TBOTEK (N/A): RSI = 59.68, Price = ₹1745.00
# ITDCEM (ITD Cementation India Limited): RSI = 59.67, Price = ₹522.50
# TCLCONS (Tantia Constructions Limited): RSI = 59.61, Price = ₹45.16
# MTEDUCARE (MT Educare Limited): RSI = 59.60, Price = ₹2.72
# GARUDA (N/A): RSI = 59.57, Price = ₹132.02
# GUJAPOLLO (Gujarat Apollo Industries Limited): RSI = 59.55, Price = ₹352.05
# SAREGAMA (Saregama India Limited): RSI = 59.46, Price = ₹535.80
# SHRADHA (Shradha Infraprojects Limited): RSI = 59.42, Price = ₹88.96
# PRUDMOULI (Prudential Sugar Corporation Ltd.): RSI = 59.40, Price = ₹69.00
# MANAKCOAT (Manaksia Coated Metals & Industries Limited): RSI = 59.31, Price = ₹110.50
# AMNPLST (Amines & Plasticizers Limited): RSI = 59.20, Price = ₹296.20
# DHANI (Dhani Services Limited): RSI = 59.16, Price = ₹96.22
# KHAITANLTD (Khaitan (India) Limited): RSI = 58.99, Price = ₹86.29
# CEATLTD (CEAT Limited): RSI = 58.93, Price = ₹3106.80
# KIOCL (KIOCL Limited): RSI = 58.90, Price = ₹396.00
# VARDMNPOLY (Vardhman Polytex Limited): RSI = 58.82, Price = ₹14.40
# GHCL (GHCL Limited): RSI = 58.70, Price = ₹692.55
# ZYDUSLIFE (Zydus Lifesciences Limited): RSI = 58.69, Price = ₹1008.15
# ASTRAZEN (AstraZeneca Pharma India Limited): RSI = 58.67, Price = ₹6883.90
# DCI (DC Infotech and Communication Limited): RSI = 58.66, Price = ₹360.30
# SUNDARMFIN (Sundaram Finance Limited): RSI = 58.52, Price = ₹4597.40
# JINDWORLD (Jindal Worldwide Limited): RSI = 58.47, Price = ₹424.50
# KAUSHALYA (Kaushalya Infrastructure Development Corporation Limited): RSI = 58.46, Price = ₹1029.40
# SIGNPOST (Signpost India Limited): RSI = 58.40, Price = ₹382.65
# VINCOFE (Vintage Coffee and Beverages Limited): RSI = 58.32, Price = ₹121.19
# UNIVCABLES (Universal Cables Limited): RSI = 58.22, Price = ₹781.40
# SUVIDHAA (Suvidhaa Infoserve Limited): RSI = 58.20, Price = ₹6.60
# AKZOINDIA (Akzo Nobel India Limited): RSI = 58.19, Price = ₹3732.30
# HOMEFIRST (Home First Finance Company India Limited): RSI = 58.11, Price = ₹1031.50
# ASHIANA (Ashiana Housing Limited): RSI = 57.96, Price = ₹363.20
# FUSION (Fusion Finance Limited): RSI = 57.91, Price = ₹181.68
# DEVYANI (Devyani International Limited): RSI = 57.87, Price = ₹182.07
# AADHARHFC (N/A): RSI = 57.87, Price = ₹434.45
# BANARBEADS (Banaras Beads Limited): RSI = 57.85, Price = ₹129.99
# AJOONI (Ajooni Biotech Limited): RSI = 57.84, Price = ₹7.71
# CREATIVE (Creative Newtech Limited): RSI = 57.83, Price = ₹943.95
# IIFL (IIFL Finance Limited): RSI = 57.76, Price = ₹423.15
# VAKRANGEE (Vakrangee Limited): RSI = 57.75, Price = ₹35.58
# FLEXITUFF (Flexituff Ventures International Limited): RSI = 57.71, Price = ₹64.69
# SUNDRMBRAK (Sundaram Brake Linings Limited): RSI = 57.64, Price = ₹1166.95
# MUKTAARTS (Mukta Arts Limited): RSI = 57.60, Price = ₹91.92
# IFBIND (IFB Industries Limited): RSI = 57.51, Price = ₹1886.05
# INDIAMART (IndiaMART InterMESH Limited): RSI = 57.49, Price = ₹2313.60
# IPCALAB (Ipca Laboratories Limited): RSI = 57.43, Price = ₹1630.35
# ASIANPAINT (Asian Paints Limited): RSI = 57.42, Price = ₹2327.75
# SUBROS (Subros Limited): RSI = 57.35, Price = ₹643.80
# SILVERTUC (Silver Touch Technologies Limited): RSI = 57.34, Price = ₹691.10
# COLPAL (Colgate-Palmolive (India) Limited): RSI = 57.31, Price = ₹2835.55
# GREAVESCOT (Greaves Cotton Limited): RSI = 57.31, Price = ₹256.80
# JCHAC (Johnson Controls-Hitachi Air Conditioning India Limited): RSI = 57.26, Price = ₹1835.70
# TCS (Tata Consultancy Services Limited): RSI = 57.17, Price = ₹4275.30
# ALPHAGEO (Alphageo (India) Limited): RSI = 56.98, Price = ₹456.00
# SBFC (SBFC Finance Limited): RSI = 56.91, Price = ₹87.47
# SHALPAINTS (Shalimar Paints Limited): RSI = 56.87, Price = ₹129.59
# JSFB (Jana Small Finance Bank Limited): RSI = 56.73, Price = ₹394.35
# LUPIN (Lupin Limited): RSI = 56.73, Price = ₹2209.10
# UNOMINDA (Uno Minda Limited): RSI = 56.72, Price = ₹1073.85
# MOIL (MOIL Limited): RSI = 56.71, Price = ₹358.50
# ANANDRATHI (Anand Rathi Wealth Limited): RSI = 56.64, Price = ₹4173.50
# TAJGVK (TAJGVK Hotels & Resorts Limited): RSI = 56.60, Price = ₹394.75
# JINDALSTEL (Jindal Steel & Power Limited): RSI = 56.58, Price = ₹926.05
# MUTHOOTFIN (Muthoot Finance Limited): RSI = 56.57, Price = ₹2132.65
# GUJRAFFIA (Gujarat Raffia Industries Limited): RSI = 56.47, Price = ₹88.23
# MINDACORP (Minda Corporation Limited): RSI = 56.46, Price = ₹521.90
# WEWIN (We Win Limited): RSI = 56.38, Price = ₹87.59
# PVP (PVP Ventures Limited): RSI = 56.33, Price = ₹30.53
# INTELLECT (Intellect Design Arena Limited): RSI = 56.26, Price = ₹905.20
# BALKRISHNA (Balkrishna Paper Mills Limited): RSI = 56.25, Price = ₹24.47
# SUNFLAG (Sunflag Iron and Steel Company Limited): RSI = 56.22, Price = ₹296.40
# HYUNDAI (N/A): RSI = 56.09, Price = ₹1792.60
# SFL (Sheela Foam Limited): RSI = 56.08, Price = ₹981.60
# GALAPREC (N/A): RSI = 56.04, Price = ₹1188.70
# MANINDS (Man Industries (India) Limited): RSI = 56.02, Price = ₹336.20
# BAFNAPH (Bafna Pharmaceuticals Limited): RSI = 55.99, Price = ₹84.06
# INFOBEAN (InfoBeans Technologies Limited): RSI = 55.97, Price = ₹430.70
# KELLTONTEC (Kellton Tech Solutions Limited): RSI = 55.92, Price = ₹162.04
# SUPERSPIN (Super Spinning Mills Limited): RSI = 55.77, Price = ₹14.33
# KOTAKBANK (Kotak Mahindra Bank Limited): RSI = 55.77, Price = ₹1790.20
# KINGFA (Kingfa Science & Technology (India) Limited): RSI = 55.75, Price = ₹3582.10
# ZEEL (Zee Entertainment Enterprises Limited): RSI = 55.71, Price = ₹128.50
# VISAKAIND (Visaka Industries Limited): RSI = 55.68, Price = ₹96.15
# MARATHON (Marathon Nextgen Realty Limited): RSI = 55.54, Price = ₹641.10
# SINDHUTRAD (Sindhu Trade Links Limited): RSI = 55.48, Price = ₹23.05
# JAIPURKURT (Nandani Creation Limited): RSI = 55.43, Price = ₹36.18
# SHANTI (Shanti Overseas (India) Limited): RSI = 55.43, Price = ₹16.90
# YUKEN (Yuken India Limited): RSI = 55.39, Price = ₹1094.70
# SWSOLAR (Sterling and Wilson Renewable Energy Limited): RSI = 55.36, Price = ₹456.00
# CAMLINFINE (Camlin Fine Sciences Limited): RSI = 55.25, Price = ₹131.39
# SANOFICONR (N/A): RSI = 55.23, Price = ₹4855.25
# CAPLIPOINT (Caplin Point Laboratories Limited): RSI = 55.22, Price = ₹2395.25
# GRPLTD (GRP Limited): RSI = 55.22, Price = ₹3282.95
# CCCL (Consolidated Construction Consortium Limited): RSI = 55.21, Price = ₹17.62
# ASTRON (Astron Paper & Board Mill Limited): RSI = 55.19, Price = ₹20.30
# KSCL (Kaveri Seed Company Limited): RSI = 55.09, Price = ₹910.40
# SOUTHBANK (The South Indian Bank Limited): RSI = 55.02, Price = ₹25.51
# ADANIENT (Adani Enterprises Limited): RSI = 54.99, Price = ₹2411.80
# DATAMATICS (Datamatics Global Services Limited): RSI = 54.93, Price = ₹660.50
# BEDMUTHA (Bedmutha Industries Limited): RSI = 54.87, Price = ₹206.00
# ITDC (India Tourism Development Corporation Limited): RSI = 54.83, Price = ₹641.15
# BHAGERIA (Bhageria Industries Limited): RSI = 54.83, Price = ₹202.95
# GLOBE (Globe Textiles (India) Limited): RSI = 54.80, Price = ₹4.99
# MAHESHWARI (Maheshwari Logistics Limited): RSI = 54.78, Price = ₹62.10
# RAMKY (Ramky Infrastructure Limited): RSI = 54.77, Price = ₹616.50
# LGHL (N/A): RSI = 54.68, Price = ₹511.10
# RKEC (RKEC Projects Limited): RSI = 54.68, Price = ₹96.45
# VAIBHAVGBL (Vaibhav Global Limited): RSI = 54.67, Price = ₹298.05
# SCHAEFFLER (Schaeffler India Limited): RSI = 54.66, Price = ₹3352.80
# DRREDDY (Dr. Reddy's Laboratories Limited): RSI = 54.53, Price = ₹1358.10
# CENTURYPLY (Century Plyboards (India) Limited): RSI = 54.49, Price = ₹801.20
# RELINFRA (Reliance Infrastructure Limited): RSI = 54.42, Price = ₹299.70
# ABBOTINDIA (Abbott India Limited): RSI = 54.42, Price = ₹29010.00
# BLUEJET (Blue Jet Healthcare Limited): RSI = 54.41, Price = ₹577.15
# HAPPSTMNDS (Happiest Minds Technologies Limited): RSI = 54.37, Price = ₹713.50
# TATACOMM (Tata Communications Limited): RSI = 54.35, Price = ₹1728.70
# BAJAJHCARE (Bajaj HealthCare Limited): RSI = 54.33, Price = ₹565.05
# SARDAEN (Sarda Energy & Minerals Limited): RSI = 54.25, Price = ₹477.40
# RBLBANK (RBL Bank Limited): RSI = 54.20, Price = ₹156.00
# HILTON (Hilton Metal Forging Limited): RSI = 54.03, Price = ₹101.35
# RBZJEWEL (RBZ Jewellers Limited): RSI = 54.02, Price = ₹213.76
# INDUSINDBK (IndusInd Bank Limited): RSI = 53.98, Price = ₹944.05
# AJMERA (Ajmera Realty & Infra India Limited): RSI = 53.97, Price = ₹1092.30
# CHENNPETRO (Chennai Petroleum Corporation Limited): RSI = 53.96, Price = ₹606.00
# SAGCEM (Sagar Cements Limited): RSI = 53.94, Price = ₹219.67
# RICOAUTO (Rico Auto Industries Limited): RSI = 53.93, Price = ₹88.26
# ARKADE (N/A): RSI = 53.91, Price = ₹167.49
# SHEKHAWATI (Shekhawati Industries Limited): RSI = 53.91, Price = ₹31.35
# TARSONS (Tarsons Products Limited): RSI = 53.90, Price = ₹407.20
# SPENCERS (Spencer's Retail Limited): RSI = 53.86, Price = ₹85.10
# GILLETTE (Gillette India Limited): RSI = 53.85, Price = ₹9620.05
# RITCO (Ritco Logistics Limited): RSI = 53.80, Price = ₹391.90
# JKCEMENT (J.K. Cement Limited): RSI = 53.78, Price = ₹4575.00
# AARTECH (Aartech Solonics Limited): RSI = 53.76, Price = ₹86.06
# SEQUENT (Sequent Scientific Limited): RSI = 53.75, Price = ₹182.00
# HINDMOTORS (Hindustan Motors Limited): RSI = 53.74, Price = ₹26.24
# HEUBACHIND (Heubach Colorants India Limited): RSI = 53.72, Price = ₹544.50
# SHRIPISTON (Shriram Pistons & Rings Limited): RSI = 53.71, Price = ₹2089.10
# FORTIS (Fortis Healthcare Limited): RSI = 53.59, Price = ₹691.00
# LTF (L&T Finance Limited): RSI = 53.48, Price = ₹138.58
# AARON (Aaron Industries Limited): RSI = 53.44, Price = ₹358.60
# ASIANENE (Asian Energy Services Limited): RSI = 53.32, Price = ₹388.05
# STARTECK (Starteck Finance Limited): RSI = 53.32, Price = ₹304.25
# BAJAJHLDNG (Bajaj Holdings & Investment Limited): RSI = 53.32, Price = ₹11029.55
# SIGMA (Sigma Solve Limited): RSI = 53.31, Price = ₹344.20
# ZENSARTECH (Zensar Technologies Limited): RSI = 53.27, Price = ₹780.05
# SHYAMMETL (Shyam Metalics and Energy Limited): RSI = 53.26, Price = ₹781.20
# SOMICONVEY (Somi Conveyor Beltings Limited): RSI = 53.24, Price = ₹204.00
# DSSL (Dynacons Systems & Solutions Limited): RSI = 53.22, Price = ₹1432.50
# RAJRATAN (Rajratan Global Wire Limited): RSI = 53.20, Price = ₹492.95
# AWL (Adani Wilmar Limited): RSI = 53.20, Price = ₹298.70
# IL&FSENGG (IL&FS Engineering and Construction Company Limited): RSI = 53.14, Price = ₹42.52
# GOCOLORS (Go Fashion (India) Limited): RSI = 53.14, Price = ₹990.45
# RELIABLE (Reliable Data Services Limited): RSI = 53.10, Price = ₹70.57
# CONTROLPR (Control Print Limited): RSI = 53.06, Price = ₹722.45
# TATVA (Tatva Chintan Pharma Chem Limited): RSI = 53.01, Price = ₹862.00
# ABMINTLLTD (ABM International Limited): RSI = 52.83, Price = ₹66.80
# GANGAFORGE (Ganga Forging Limited): RSI = 52.79, Price = ₹6.93
# DBSTOCKBRO (DB (International) Stock Brokers Limited): RSI = 52.71, Price = ₹44.81
# RESPONIND (Responsive Industries Limited): RSI = 52.71, Price = ₹255.05
# MHRIL (Mahindra Holidays & Resorts India Limited): RSI = 52.70, Price = ₹365.00
# BHARTIARTL (Bharti Airtel Limited): RSI = 52.69, Price = ₹1607.05
# AZAD (N/A): RSI = 52.67, Price = ₹1694.65
# KAMDHENU (Kamdhenu Limited): RSI = 52.66, Price = ₹48.65
# ROHLTD (Royal Orchid Hotels Limited): RSI = 52.63, Price = ₹349.10
# ARMANFIN (Arman Financial Services Limited): RSI = 52.63, Price = ₹1282.00
# LUMAXIND (Lumax Industries Limited): RSI = 52.60, Price = ₹2445.05
# SAURASHCEM (Saurashtra Cement Limited): RSI = 52.59, Price = ₹108.51
# LINDEINDIA (Linde India Limited): RSI = 52.55, Price = ₹6442.10
# TARIL (N/A): RSI = 52.51, Price = ₹1119.85
# WEBELSOLAR (Websol Energy System Limited): RSI = 52.48, Price = ₹1759.50
# KEI (KEI Industries Limited): RSI = 52.46, Price = ₹4202.65
# AIAENG (AIA Engineering Limited): RSI = 52.44, Price = ₹3385.45
# DOLPHIN (Dolphin Offshore Enterprises (India) Limited): RSI = 52.44, Price = ₹557.00
# GLENMARK (Glenmark Pharmaceuticals Limited): RSI = 52.44, Price = ₹1553.80
# HEIDELBERG (HeidelbergCement India Limited): RSI = 52.37, Price = ₹210.50
# JISLDVREQS (Jain Irrigation Systems Limited): RSI = 52.34, Price = ₹36.25
# ARTEMISMED (Artemis Medicare Services Limited): RSI = 52.28, Price = ₹327.00
# BALAJEE (N/A): RSI = 52.25, Price = ₹71.57
# KRN (N/A): RSI = 52.22, Price = ₹717.45
# MANAPPURAM (Manappuram Finance Limited): RSI = 52.19, Price = ₹182.72
# HONAUT (Honeywell Automation India Limited): RSI = 52.15, Price = ₹41450.00
# AARTIDRUGS (Aarti Drugs Limited): RSI = 52.13, Price = ₹434.15
# XCHANGING (Xchanging Solutions Limited): RSI = 52.13, Price = ₹110.82
# KARMAENG (Karma Energy Limited): RSI = 52.10, Price = ₹69.95
# KOHINOOR (Kohinoor Foods Limited): RSI = 52.06, Price = ₹40.77
# DANGEE (Dangee Dums Limited): RSI = 52.04, Price = ₹7.03
# SANGINITA (Sanginita Chemicals Limited): RSI = 52.03, Price = ₹15.38
# CIPLA (Cipla Limited): RSI = 51.98, Price = ₹1477.55
# SAMMAANCAP (Sammaan Capital Limited): RSI = 51.95, Price = ₹153.41
# AIROLAM (Airo Lam Limited): RSI = 51.89, Price = ₹128.23
# ZYDUSWELL (Zydus Wellness Limited): RSI = 51.89, Price = ₹1922.00
# STEELCAS (Steelcast Limited): RSI = 51.85, Price = ₹873.95
# GLAND (Gland Pharma Limited): RSI = 51.81, Price = ₹1785.00
# VINEETLAB (Vineet Laboratories Limited): RSI = 51.81, Price = ₹57.35
# GMMPFAUDLR (GMM Pfaudler Limited): RSI = 51.80, Price = ₹1227.15
# TANLA (Tanla Platforms Limited): RSI = 51.80, Price = ₹675.30
# UNITEDTEA (The United Nilgiri Tea Estates Company Limited): RSI = 51.75, Price = ₹528.15
# MANAKALUCO (Manaksia Aluminium Company Limited): RSI = 51.74, Price = ₹29.75
# MANINFRA (Man Infraconstruction Limited): RSI = 51.73, Price = ₹235.40
# RPSGVENT (RPSG Ventures Limited): RSI = 51.71, Price = ₹1061.35
# BLUESTARCO (Blue Star Limited): RSI = 51.68, Price = ₹2002.40
# GRANULES (Granules India Limited): RSI = 51.63, Price = ₹595.30
# SDBL (Som Distilleries & Breweries Limited): RSI = 51.56, Price = ₹111.01
# AEGISLOG (N/A): RSI = 51.55, Price = ₹837.15
# GPTHEALTH (GPT Healthcare Limited): RSI = 51.54, Price = ₹179.00
# DCMSHRIRAM (DCM Shriram Limited): RSI = 51.52, Price = ₹1074.95
# GOKULAGRO (Gokul Agro Resources Limited): RSI = 51.51, Price = ₹354.40
# ASTEC (Astec LifeSciences Limited): RSI = 51.51, Price = ₹1097.75
# STARCEMENT (Star Cement Limited): RSI = 51.44, Price = ₹215.03
# ASPINWALL (Aspinwall and Company Limited): RSI = 51.41, Price = ₹304.70
# ATGL (Adani Total Gas Limited): RSI = 51.41, Price = ₹679.45
# GOCLCORP (GOCL Corporation Limited): RSI = 51.41, Price = ₹369.80
# GLS (Alivus Life Sciences Limited): RSI = 51.35, Price = ₹1020.20
# UJJIVANSFB (Ujjivan Small Finance Bank Limited): RSI = 51.25, Price = ₹34.32
# BLISSGVS (Bliss GVS Pharma Limited): RSI = 51.23, Price = ₹162.76
# WEL (Wonder Electricals Limited): RSI = 51.23, Price = ₹159.92
# SATIN (Satin Creditcare Network Limited): RSI = 51.14, Price = ₹150.19
# BLKASHYAP (B.L. Kashyap and Sons Limited): RSI = 51.10, Price = ₹76.67
# GUJALKALI (Gujarat Alkalies and Chemicals Limited): RSI = 51.09, Price = ₹746.50
# SAH (Sah Polymers Limited): RSI = 51.09, Price = ₹90.00
# INDRAMEDCO (Indraprastha Medical Corporation Limited): RSI = 51.06, Price = ₹495.30
# LUMAXTECH (Lumax Auto Technologies Limited): RSI = 51.04, Price = ₹619.90
# JSWINFRA (JSW Infrastructure Limited): RSI = 50.96, Price = ₹310.15
# CRAFTSMAN (Craftsman Automation Limited): RSI = 50.95, Price = ₹5204.45
# KABRAEXTRU (Kabra Extrusiontechnik Limited): RSI = 50.93, Price = ₹513.65
# SILLYMONKS (Silly Monks Entertainment Limited): RSI = 50.85, Price = ₹24.50
# SETCO (Setco Automotive Limited): RSI = 50.84, Price = ₹20.29
# DEEPAKFERT (Deepak Fertilisers And Petrochemicals Corporation Limited): RSI = 50.84, Price = ₹1151.30
# MRPL (Mangalore Refinery and Petrochemicals Limited): RSI = 50.80, Price = ₹142.81
# CRISIL (CRISIL Limited): RSI = 50.77, Price = ₹5790.00
# EMCURE (N/A): RSI = 50.75, Price = ₹1377.25
# IRCTC (Indian Railway Catering & Tourism Corporation Limited): RSI = 50.64, Price = ₹785.75
# DICIND (DIC India Limited): RSI = 50.64, Price = ₹681.10
# TRIGYN (Trigyn Technologies Limited): RSI = 50.63, Price = ₹110.21
# BAJAJ-AUTO (Bajaj Auto Limited): RSI = 50.61, Price = ₹8804.35
# LYKALABS (Lyka Labs Limited): RSI = 50.59, Price = ₹150.22
# RHL (Robust Hotels Limited): RSI = 50.56, Price = ₹263.00
# MITTAL (Mittal Life Style Limited): RSI = 50.46, Price = ₹2.21
# SUPREMEENG (Supreme Engineering Limited): RSI = 50.44, Price = ₹2.92
# AMIORG (Ami Organics Limited): RSI = 50.39, Price = ₹2128.30
# ARROWGREEN (Arrow Greentech Limited): RSI = 50.37, Price = ₹824.35
# AUTOAXLES (Automotive Axles Limited): RSI = 50.33, Price = ₹1783.15
# ELGIRUBCO (Elgi Rubber Company Limited): RSI = 50.31, Price = ₹121.41
# GREENLAM (Greenlam Industries Limited): RSI = 50.30, Price = ₹551.30
# RVTH (Revathi Equipment India Limited): RSI = 50.29, Price = ₹2051.30
# XTGLOBAL (XTGlobal Infotech Limited): RSI = 50.28, Price = ₹42.24
# EMAMILTD (Emami Limited): RSI = 50.22, Price = ₹591.50
# KNRCON (KNR Constructions Limited): RSI = 50.21, Price = ₹325.55
# AWFIS (N/A): RSI = 50.17, Price = ₹715.35
# MEDIASSIST (N/A): RSI = 50.15, Price = ₹595.10
# JAYNECOIND (Jayaswal Neco Industries Limited): RSI = 50.15, Price = ₹39.79
# TEMBO (Tembo Global Industries Limited): RSI = 50.05, Price = ₹782.00
# SHALBY (Shalby Limited): RSI = 50.04, Price = ₹225.71
# TVTODAY (T.V. Today Network Limited): RSI = 50.02, Price = ₹206.36
# IDEAFORGE (ideaForge Technology Limited): RSI = 50.02, Price = ₹587.30
# REDINGTON (Redington Limited): RSI = 49.96, Price = ₹205.63
# MBECL (McNally Bharat Engineering Company Limited): RSI = 49.95, Price = ₹4.19
# IREDA (Indian Renewable Energy Development Agency Limited): RSI = 49.91, Price = ₹206.15
# MMP (MMP Industries Limited): RSI = 49.83, Price = ₹336.80
# ENTERO (Entero Healthcare Solutions Limited): RSI = 49.77, Price = ₹1422.25
# INDOWIND (Indowind Energy Limited): RSI = 49.75, Price = ₹24.03
# STCINDIA (The State Trading Corporation of India Limited): RSI = 49.75, Price = ₹153.01
# RPEL (Raghav Productivity Enhancers Limited): RSI = 49.74, Price = ₹710.40
# RATEGAIN (RateGain Travel Technologies Limited): RSI = 49.69, Price = ₹696.70
# DEEPINDS (Deep Industries Limited): RSI = 49.69, Price = ₹579.25
# ASKAUTOLTD (N/A): RSI = 49.67, Price = ₹469.90
# LINCOLN (Lincoln Pharmaceuticals Limited): RSI = 49.65, Price = ₹810.30
# MADRASFERT (Madras Fertilizers Limited): RSI = 49.61, Price = ₹96.51
# BCONCEPTS (Brand Concepts Limited): RSI = 49.61, Price = ₹475.85
# SIGNATURE (Signatureglobal (India) Limited): RSI = 49.60, Price = ₹1254.00
# VOLTAS (Voltas Limited): RSI = 49.43, Price = ₹1682.35
# APEX (Apex Frozen Foods Limited): RSI = 49.42, Price = ₹245.70
# RACE (Race Eco Chain Limited): RSI = 49.42, Price = ₹338.25
# UGROCAP (UGRO Capital Limited): RSI = 49.39, Price = ₹233.84
# SMSPHARMA (SMS Pharmaceuticals Limited): RSI = 49.39, Price = ₹230.40
# TI (Tilaknagar Industries Ltd.): RSI = 49.37, Price = ₹410.30
# MAXHEALTH (Max Healthcare Institute Limited): RSI = 49.35, Price = ₹1161.05
# KAVVERITEL (Kavveri Defence & Wireless Technologies Limited): RSI = 49.33, Price = ₹57.21
# RSSOFTWARE (R S Software (India) Limited): RSI = 49.32, Price = ₹195.46
# ZEELEARN (Zee Learn Limited): RSI = 49.32, Price = ₹8.28
# CROWN (Crown Lifters Limited): RSI = 49.31, Price = ₹206.00
# ACCELYA (Accelya Solutions India Limited): RSI = 49.30, Price = ₹1502.20
# THOMASCOTT (Thomas Scott (India) Limited): RSI = 49.29, Price = ₹451.50
# TIPSFILMS (Tips Films Limited): RSI = 49.26, Price = ₹618.70
# KHANDSE (Khandwala Securities Limited): RSI = 49.25, Price = ₹28.00
# VINATIORGA (Vinati Organics Limited): RSI = 49.21, Price = ₹1704.15
# GOKUL (Gokul Refoils & Solvent Limited): RSI = 49.17, Price = ₹61.44
# EXXARO (Exxaro Tiles Limited): RSI = 49.16, Price = ₹8.75
# THEMISMED (Themis Medicare Limited): RSI = 49.14, Price = ₹267.35
# SRM (N/A): RSI = 49.14, Price = ₹369.00
# ROSSARI (Rossari Biotech Limited): RSI = 49.08, Price = ₹790.00
# JTEKTINDIA (JTEKT India Limited): RSI = 49.07, Price = ₹161.34
# RCF (Rashtriya Chemicals and Fertilizers Limited): RSI = 48.99, Price = ₹168.80
# IMPEXFERRO (Impex Ferro Tech Limited): RSI = 48.98, Price = ₹2.87
# UNITDSPR (N/A): RSI = 48.94, Price = ₹1538.60
# FACT (The Fertilisers and Chemicals Travancore Limited): RSI = 48.92, Price = ₹941.40
# EUREKAFORB (Eureka Forbes Limited): RSI = 48.92, Price = ₹569.65
# HOVS (HOV Services Limited): RSI = 48.91, Price = ₹72.12
# GENSOL (Gensol Engineering Limited): RSI = 48.88, Price = ₹750.15
# JASH (Jash Engineering Limited): RSI = 48.85, Price = ₹592.05
# SANGAMIND (Sangam (India) Limited): RSI = 48.82, Price = ₹404.25
# UBL (United Breweries Limited): RSI = 48.80, Price = ₹2015.65
# CIEINDIA (CIE Automotive India Limited): RSI = 48.79, Price = ₹458.35
# ICICIGI (ICICI Lombard General Insurance Company Limited): RSI = 48.60, Price = ₹1892.85
# AJANTPHARM (Ajanta Pharma Limited): RSI = 48.51, Price = ₹2839.50
# GNA (G N A Axles Limited): RSI = 48.50, Price = ₹405.65
# AAVAS (Aavas Financiers Limited): RSI = 48.46, Price = ₹1661.50
# AVANTIFEED (Avanti Feeds Limited): RSI = 48.45, Price = ₹613.25
# EXICOM (Exicom Tele-Systems Limited): RSI = 48.39, Price = ₹259.70
# ABINFRA (N/A): RSI = 48.39, Price = ₹91.98
# TARAPUR (Tarapur Transformers Limited): RSI = 48.32, Price = ₹45.06
# DGCONTENT (Digicontent Limited): RSI = 48.31, Price = ₹59.48
# RAINBOW (Rainbow Children's Medicare Limited): RSI = 48.28, Price = ₹1537.50
# LOTUSEYE (Lotus Eye Hospital and Institute Limited): RSI = 48.26, Price = ₹67.35
# ALICON (Alicon Castalloy Limited): RSI = 48.26, Price = ₹1049.30
# LALPATHLAB (Dr. Lal PathLabs Limited): RSI = 48.25, Price = ₹2924.45
# VSTTILLERS (V.S.T. Tillers Tractors Limited): RSI = 48.23, Price = ₹4900.05
# ZAGGLE (Zaggle Prepaid Ocean Services Limited): RSI = 48.19, Price = ₹523.95
# SHIVAMILLS (Shiva Mills Limited): RSI = 48.12, Price = ₹98.00
# CSBBANK (CSB Bank Limited): RSI = 48.07, Price = ₹309.90
# STOVEKRAFT (Stove Kraft Limited): RSI = 48.03, Price = ₹854.45
# MANAKSIA (Manaksia Limited): RSI = 48.02, Price = ₹84.44
# INDIAGLYCO (India Glycols Limited): RSI = 48.00, Price = ₹1313.40
# VIMTALABS (Vimta Labs Limited): RSI = 47.99, Price = ₹949.25
# SICALLOG (Sical Logistics Limited): RSI = 47.98, Price = ₹139.87
# EIHOTEL (EIH Limited): RSI = 47.94, Price = ₹408.00
# JAMNAAUTO (Jamna Auto Industries Limited): RSI = 47.93, Price = ₹95.79
# ZENTEC (Zen Technologies Limited): RSI = 47.93, Price = ₹2464.85
# SWARAJENG (Swaraj Engines Limited): RSI = 47.92, Price = ₹2959.85
# HUBTOWN (Hubtown Limited): RSI = 47.92, Price = ₹271.50
# INNOVANA (N/A): RSI = 47.91, Price = ₹437.85
# ICICIPRULI (ICICI Prudential Life Insurance Company Limited): RSI = 47.88, Price = ₹649.60
# VARROC (Varroc Engineering Limited): RSI = 47.88, Price = ₹590.00
# VEEDOL (Veedol Corporation Limited): RSI = 47.85, Price = ₹1679.70
# TFCILTD (Tourism Finance Corporation of India Limited): RSI = 47.78, Price = ₹160.00
# ISEC (ICICI Securities Limited): RSI = 47.78, Price = ₹827.10
# MPHASIS (Mphasis Limited): RSI = 47.74, Price = ₹2927.65
# DCAL (Dishman Carbogen Amcis Limited): RSI = 47.74, Price = ₹271.75
# BORORENEW (Borosil Renewables Limited): RSI = 47.73, Price = ₹594.00
# VIPIND (V.I.P. Industries Limited): RSI = 47.68, Price = ₹460.25
# CARTRADE (CarTrade Tech Limited): RSI = 47.65, Price = ₹1585.00
# IDFCFIRSTB (IDFC First Bank Limited): RSI = 47.63, Price = ₹61.20
# IMFA (Indian Metals and Ferro Alloys Limited): RSI = 47.61, Price = ₹880.40
# FDC (FDC Limited): RSI = 47.53, Price = ₹487.05
# HGINFRA (H.G. Infra Engineering Limited): RSI = 47.50, Price = ₹1414.75
# SURAJLTD (Suraj Limited): RSI = 47.46, Price = ₹504.70
# DELTAMAGNT (Delta Manufacturing Limited): RSI = 47.45, Price = ₹105.52
# MANKIND (Mankind Pharma Limited): RSI = 47.45, Price = ₹2771.35
# SREEL (Sreeleathers Limited): RSI = 47.43, Price = ₹263.00
# SANSTAR (N/A): RSI = 47.43, Price = ₹115.67
# TGBHOTELS (TGB Banquets and Hotels Limited): RSI = 47.42, Price = ₹13.73
# CHEMCON (Chemcon Speciality Chemicals Limited): RSI = 47.39, Price = ₹226.95
# AETHER (Aether Industries Limited): RSI = 47.38, Price = ₹868.70
# ELECON (Elecon Engineering Company Limited): RSI = 47.28, Price = ₹595.20
# BALAXI (Balaxi Pharmaceuticals Limited): RSI = 47.28, Price = ₹73.04
# GALLANTT (Gallantt Ispat Limited): RSI = 47.24, Price = ₹333.95
# SHAH (Shah Metacorp Limited): RSI = 47.20, Price = ₹4.20
# TRACXN (Tracxn Technologies Limited): RSI = 47.15, Price = ₹73.74
# WCIL (N/A): RSI = 47.14, Price = ₹110.17
# WSTCSTPAPR (West Coast Paper Mills Limited): RSI = 47.02, Price = ₹548.50
# TOLINS (N/A): RSI = 46.97, Price = ₹198.52
# DEN (DEN Networks Limited): RSI = 46.97, Price = ₹41.65
# GRMOVER (GRM Overseas Limited): RSI = 46.90, Price = ₹189.00
# REFEX (Refex Industries Limited): RSI = 46.89, Price = ₹481.20
# AMDIND (AMD Industries Limited): RSI = 46.87, Price = ₹59.66
# ESAFSFB (ESAF Small Finance Bank): RSI = 46.86, Price = ₹37.95
# JKIL (J. Kumar Infraprojects Limited): RSI = 46.85, Price = ₹743.75
# BLSE (N/A): RSI = 46.83, Price = ₹203.16
# RIIL (Reliance Industrial Infrastructure Limited): RSI = 46.72, Price = ₹1047.60
# GOLDENTOBC (Golden Tobacco Limited): RSI = 46.71, Price = ₹38.00
# WHEELS (Wheels India Limited): RSI = 46.69, Price = ₹696.20
# SPAL (S.P. Apparels Limited): RSI = 46.68, Price = ₹896.00
# CHOICEIN (Choice International Limited): RSI = 46.67, Price = ₹526.25
# AMBICAAGAR (Ambica Agarbathies Aroma & Industries Limited): RSI = 46.64, Price = ₹30.32
# SURANAT&P (Surana Telecom and Power Limited): RSI = 46.63, Price = ₹22.61
# SYRMA (Syrma SGS Technology Limited): RSI = 46.62, Price = ₹582.50
# BEARDSELL (Beardsell Limited): RSI = 46.62, Price = ₹39.00
# VASCONEQ (Vascon Engineers Limited): RSI = 46.62, Price = ₹52.86
# DONEAR (Donear Industries Limited): RSI = 46.61, Price = ₹154.80
# WIPRO (Wipro Limited): RSI = 46.59, Price = ₹301.80
# KFINTECH (KFin Technologies Limited): RSI = 46.56, Price = ₹1399.95
# BAJAJELEC (Bajaj Electricals Limited): RSI = 46.51, Price = ₹764.60
# UTIAMC (UTI Asset Management Company Limited): RSI = 46.49, Price = ₹1206.00
# EXCELINDUS (Excel Industries Limited): RSI = 46.47, Price = ₹1274.75
# COSMOFIRST (Cosmo First Limited): RSI = 46.45, Price = ₹916.95
# GKWLIMITED (GKW Limited): RSI = 46.43, Price = ₹2410.00
# CAMPUS (Campus Activewear Limited): RSI = 46.38, Price = ₹280.85
# BALKRISIND (Balkrishna Industries Limited): RSI = 46.38, Price = ₹2756.60
# GATEWAY (Gateway Distriparks Limited): RSI = 46.37, Price = ₹79.63
# MEDPLUS (MedPlus Health Services Limited): RSI = 46.27, Price = ₹835.90
# SUNDARMHLD (Sundaram Finance Holdings Limited): RSI = 46.24, Price = ₹286.00
# MUKKA (Mukka Proteins Limited): RSI = 46.24, Price = ₹38.22
# RGL (Renaissance Global Limited): RSI = 46.24, Price = ₹173.50
# GULPOLY (Gulshan Polyols Limited): RSI = 46.23, Price = ₹170.95
# PSPPROJECT (PSP Projects Limited): RSI = 46.19, Price = ₹669.90
# MOTISONS (N/A): RSI = 46.18, Price = ₹26.91
# SHRENIK (Shrenik Limited): RSI = 46.15, Price = ₹0.77
# ADANIPOWER (Adani Power Limited): RSI = 46.14, Price = ₹487.60
# KRSNAA (Krsnaa Diagnostics Limited): RSI = 46.13, Price = ₹876.45
# AROGRANITE (Aro Granite Industries Limited): RSI = 46.11, Price = ₹46.19
# SUVEN (Suven Life Sciences Limited): RSI = 46.07, Price = ₹130.95
# LTFOODS (LT Foods Limited): RSI = 46.03, Price = ₹402.40
# HPIL (Hindprakash Industries Limited): RSI = 46.02, Price = ₹147.58
# BANCOINDIA (Banco Products (India) Limited): RSI = 46.02, Price = ₹475.55
# ARVINDFASN (Arvind Fashions Limited): RSI = 46.01, Price = ₹514.50
# KIRLOSBROS (Kirloskar Brothers Limited): RSI = 45.95, Price = ₹2082.15
# INDSWFTLTD (Ind-Swift Limited): RSI = 45.94, Price = ₹27.52
# CORALFINAC (Coral India Finance and Housing Limited): RSI = 45.93, Price = ₹50.39
# SINTERCOM (Sintercom India Limited): RSI = 45.90, Price = ₹161.71
# REGENCERAM (Regency Ceramics Limited): RSI = 45.88, Price = ₹53.03
# SIKKO (Sikko Industries Limited): RSI = 45.86, Price = ₹96.41
# IRB (IRB Infrastructure Developers Limited): RSI = 45.82, Price = ₹53.72
# TATAINVEST (Tata Investment Corporation Limited): RSI = 45.81, Price = ₹6436.10
# LATENTVIEW (Latent View Analytics Limited): RSI = 45.80, Price = ₹463.25
# AFFORDABLE (Affordable Robotic & Automation Limited): RSI = 45.77, Price = ₹623.95
# CONFIPET (Confidence Petroleum India Limited): RSI = 45.76, Price = ₹70.25
# FORCEMOT (Force Motors Limited): RSI = 45.76, Price = ₹6536.70
# WALCHANNAG (Walchandnagar Industries Limited): RSI = 45.76, Price = ₹253.45
# SHARDACROP (Sharda Cropchem Limited): RSI = 45.69, Price = ₹766.90
# SECURKLOUD (SecureKloud Technologies Limited): RSI = 45.69, Price = ₹31.57
# ALANKIT (Alankit Limited): RSI = 45.68, Price = ₹20.70
# ABSLAMC (Aditya Birla Sun Life AMC Limited): RSI = 45.67, Price = ₹784.50
# ASAHISONG (Asahi Songwon Colors Limited): RSI = 45.66, Price = ₹353.80
# ARIHANTCAP (Arihant Capital Markets Limited): RSI = 45.65, Price = ₹96.33
# UNICHEMLAB (Unichem Laboratories Limited): RSI = 45.65, Price = ₹703.55
# IRISDOREME (Iris Clothings Limited): RSI = 45.61, Price = ₹61.38
# IGARASHI (Igarashi Motors India Limited): RSI = 45.61, Price = ₹688.75
# APLAPOLLO (APL Apollo Tubes Limited): RSI = 45.58, Price = ₹1533.15
# VIRINCHI (Virinchi Limited): RSI = 45.52, Price = ₹27.57
# CLEAN (Clean Science and Technology Limited): RSI = 45.52, Price = ₹1411.10
# RALLIS (Rallis India Limited): RSI = 45.52, Price = ₹290.35
# RBA (Restaurant Brands Asia Limited): RSI = 45.51, Price = ₹78.15
# SHAREINDIA (Share India Securities Limited): RSI = 45.50, Price = ₹288.70
# ALMONDZ (Almondz Global Securities Limited): RSI = 45.50, Price = ₹32.50
# GENUSPOWER (Genus Power Infrastructures Limited): RSI = 45.49, Price = ₹378.05
# DIVISLAB (Divi's Laboratories Limited): RSI = 45.49, Price = ₹5764.80
# JLHL (Jupiter Life Line Hospitals Limited): RSI = 45.49, Price = ₹1550.75
# APCL (Anjani Portland Cement Limited): RSI = 45.48, Price = ₹157.92
# TEXMOPIPES (Texmo Pipes and Products Limited): RSI = 45.42, Price = ₹63.86
# BANARISUG (Bannari Amman Sugars Limited): RSI = 45.41, Price = ₹3660.80
# SRGHFL (SRG Housing Finance Limited): RSI = 45.40, Price = ₹368.20
# ALKEM (Alkem Laboratories Limited): RSI = 45.40, Price = ₹5356.40
# JINDRILL (Jindal Drilling & Industries Limited): RSI = 45.38, Price = ₹741.30
# UMAEXPORTS (Uma Exports Limited): RSI = 45.38, Price = ₹104.00
# CAREERP (Career Point Limited): RSI = 45.36, Price = ₹385.10
# KALAMANDIR (Sai Silks (Kalamandir) Limited): RSI = 45.36, Price = ₹164.28
# DAMODARIND (Damodar Industries Limited): RSI = 45.36, Price = ₹41.79
# GOODLUCK (Goodluck India Limited): RSI = 45.34, Price = ₹904.95
# HINDPETRO (Hindustan Petroleum Corporation Limited): RSI = 45.24, Price = ₹391.35
# SHREDIGCEM (Shree Digvijay Cement Company Limited): RSI = 45.23, Price = ₹83.67
# RPGLIFE (RPG Life Sciences Limited): RSI = 45.18, Price = ₹2134.00
# MIRCELECTR (MIRC Electronics Limited): RSI = 45.17, Price = ₹22.10
# INCREDIBLE (Incredible Industries Limited): RSI = 45.16, Price = ₹44.71
# IOLCP (IOL Chemicals and Pharmaceuticals Limited): RSI = 45.14, Price = ₹413.05
# RUBFILA (Rubfila International Limited): RSI = 45.11, Price = ₹77.50
# WEALTH (Wealth First Portfolio Managers Limited): RSI = 45.09, Price = ₹1518.55
# EQUIPPP (Equippp Social Impact Technologies Limited): RSI = 45.09, Price = ₹24.50
# MANGALAM (Mangalam Drugs & Organics Limited): RSI = 45.08, Price = ₹111.42
# WINDLAS (Windlas Biotech Limited): RSI = 45.07, Price = ₹1010.50
# MURUDCERA (Murudeshwar Ceramics Ltd.): RSI = 45.04, Price = ₹49.66
# TEGA (Tega Industries Limited): RSI = 45.03, Price = ₹1588.25
# METROBRAND (Metro Brands Limited): RSI = 45.03, Price = ₹1254.75
# SYMPHONY (Symphony Limited): RSI = 45.02, Price = ₹1282.25
# SOLARINDS (Solar Industries India Limited): RSI = 45.00, Price = ₹9535.00
# SANCO (Sanco Industries Limited): RSI = 45.00, Price = ₹4.06
# LASA (Lasa Supergenerics Limited): RSI = 44.98, Price = ₹27.28
# AIRAN (Airan Limited): RSI = 44.94, Price = ₹33.52
# SHILPAMED (Shilpa Medicare Limited): RSI = 44.91, Price = ₹790.00
# BBOX (Black Box Limited): RSI = 44.91, Price = ₹624.55
# INTERARCH (N/A): RSI = 44.90, Price = ₹1571.50
# KANORICHEM (Kanoria Chemicals & Industries Limited): RSI = 44.90, Price = ₹113.47
# TRF (TRF Limited): RSI = 44.90, Price = ₹413.05
# SOTL (Savita Oil Technologies Limited): RSI = 44.88, Price = ₹538.00
# SENCO (Senco Gold Limited): RSI = 44.88, Price = ₹1067.60
# SIYSIL (Siyaram Silk Mills Limited): RSI = 44.82, Price = ₹886.70
# BASML (Bannari Amman Spinning Mills Ltd): RSI = 44.82, Price = ₹50.72
# AWHCL (Antony Waste Handling Cell Limited): RSI = 44.82, Price = ₹622.45
# BHAGCHEM (Bhagiradha Chemicals & Industries Limited): RSI = 44.81, Price = ₹309.80
# MTARTECH (MTAR Technologies Limited): RSI = 44.77, Price = ₹1670.00
# PRUDENT (Prudent Corporate Advisory Services Limited): RSI = 44.75, Price = ₹2735.20
# REPCOHOME (Repco Home Finance Limited): RSI = 44.73, Price = ₹410.90
# COCHINSHIP (Cochin Shipyard Limited): RSI = 44.68, Price = ₹1453.50
# WELCORP (Welspun Corp Limited): RSI = 44.68, Price = ₹757.05
# FINOPB (Fino Payments Bank Limited): RSI = 44.68, Price = ₹311.05
# KECL (Kirloskar Electric Company Limited): RSI = 44.67, Price = ₹175.95
# KANPRPLA (Kanpur Plastipack Limited): RSI = 44.65, Price = ₹123.41
# CTE (Cambridge Technology Enterprises Limited): RSI = 44.64, Price = ₹105.50
# MANORG (Mangalam Organics Limited): RSI = 44.63, Price = ₹418.05
# HITECHGEAR (The Hi-Tech Gears Limited): RSI = 44.61, Price = ₹805.00
# GREENPANEL (Greenpanel Industries Limited): RSI = 44.61, Price = ₹352.35
# MOL (Meghmani Organics Limited): RSI = 44.58, Price = ₹79.77
# ADANIENSOL (Adani Energy Solutions Limited): RSI = 44.57, Price = ₹745.75
# APCOTEXIND (Apcotex Industries Limited): RSI = 44.54, Price = ₹371.40
# HARRMALAYA (Harrisons Malayalam Limited): RSI = 44.51, Price = ₹292.05
# WOCKPHARMA (Wockhardt Limited): RSI = 44.48, Price = ₹1405.15
# HITECHCORP (Hitech Corporation Limited): RSI = 44.47, Price = ₹232.87
# MOTILALOFS (Motilal Oswal Financial Services Limited): RSI = 44.41, Price = ₹893.05
# DYCL (Dynamic Cables Limited): RSI = 44.36, Price = ₹948.85
# DHRUV (Dhruv Consultancy Services Limited): RSI = 44.35, Price = ₹117.93
# GTPL (GTPL Hathway Limited): RSI = 44.34, Price = ₹133.89
# SSWL (Steel Strips Wheels Limited): RSI = 44.32, Price = ₹195.78
# STYLEBAAZA (Baazar Style Retail Limited): RSI = 44.31, Price = ₹311.90
# ANDHRSUGAR (The Andhra Sugars Limited): RSI = 44.31, Price = ₹92.09
# ESTER (Ester Industries Limited): RSI = 44.27, Price = ₹154.13
# VENKEYS (Venky's (India) Limited): RSI = 44.25, Price = ₹1723.65
# SHARDAMOTR (Sharda Motor Industries Limited): RSI = 44.21, Price = ₹1829.00
# AHLADA (Ahlada Engineers Limited): RSI = 44.18, Price = ₹91.60
# BIOFILCHEM (Biofil Chemicals and Pharmaceuticals Limited): RSI = 44.17, Price = ₹56.85
# EIHAHOTELS (EIH Associated Hotels Limited): RSI = 44.14, Price = ₹398.50
# BALUFORGE (Balu Forge Industries Limited): RSI = 44.14, Price = ₹748.15
# VBL (Varun Beverages Limited): RSI = 44.09, Price = ₹599.15
# MANOMAY (Manomay Tex India Limited): RSI = 44.07, Price = ₹214.91
# DVL (Dhunseri Ventures Limited): RSI = 43.99, Price = ₹350.85
# ASHOKA (Ashoka Buildcon Limited): RSI = 43.97, Price = ₹275.80
# TOUCHWOOD (Touchwood Entertainment Limited): RSI = 43.92, Price = ₹145.01
# JSWSTEEL (JSW Steel Limited): RSI = 43.90, Price = ₹901.45
# HIKAL (Hikal Limited): RSI = 43.86, Price = ₹363.35
# MMTC (MMTC Limited): RSI = 43.84, Price = ₹71.48
# SUPERHOUSE (Superhouse Limited): RSI = 43.83, Price = ₹198.22
# MAHASTEEL (Mahamaya Steel Industries Limited): RSI = 43.79, Price = ₹192.98
# CEREBRAINT (Cerebra Integrated Technologies Limited): RSI = 43.75, Price = ₹9.66
# XPROINDIA (Xpro India Limited): RSI = 43.73, Price = ₹1500.00
# LGBBROSLTD (L.G. Balakrishnan & Bros Limited): RSI = 43.72, Price = ₹1258.35
# FEDERALBNK (The Federal Bank Limited): RSI = 43.72, Price = ₹190.45
# JUBLINGREA (Jubilant Ingrevia Limited): RSI = 43.68, Price = ₹735.50
# GANGESSECU (Ganges Securities Limited): RSI = 43.67, Price = ₹189.89
# KAPSTON (Kapston Services Limited): RSI = 43.65, Price = ₹259.00
# GSFC (Gujarat State Fertilizers & Chemicals Limited): RSI = 43.60, Price = ₹197.11
# SPIC (Southern Petrochemical Industries Corporation Limited): RSI = 43.55, Price = ₹71.96
# ALBERTDAVD (Albert David Limited): RSI = 43.53, Price = ₹1269.40
# MAPMYINDIA (C. E. Info Systems Limited): RSI = 43.52, Price = ₹1640.65
# SUMIT (Sumit Woods Limited): RSI = 43.51, Price = ₹141.94
# MICEL (MIC Electronics Limited): RSI = 43.50, Price = ₹80.47
# COUNCODOS (Country Condo's Limited): RSI = 43.50, Price = ₹6.38
# BHARATGEAR (Bharat Gears Limited): RSI = 43.49, Price = ₹95.88
# RAILTEL (RailTel Corporation of India Limited): RSI = 43.48, Price = ₹385.95
# HECPROJECT (HEC Infra Projects Limited): RSI = 43.47, Price = ₹115.75
# SANDUMA (The Sandur Manganese & Iron Ores Limited): RSI = 43.45, Price = ₹393.75
# GLOBAL (Global Education Limited): RSI = 43.45, Price = ₹69.60
# GICHSGFIN (GIC Housing Finance Limited): RSI = 43.45, Price = ₹195.96
# INTLCONV (International Conveyors Limited): RSI = 43.44, Price = ₹82.30
# GPTINFRA (GPT Infraprojects Limited): RSI = 43.39, Price = ₹131.87
# HAPPYFORGE (N/A): RSI = 43.39, Price = ₹994.75
# TRANSWORLD (Transworld Shipping Lines Limited): RSI = 43.38, Price = ₹400.75
# TCI (Transport Corporation of India Limited): RSI = 43.37, Price = ₹1055.75
# SHEMAROO (Shemaroo Entertainment Limited): RSI = 43.35, Price = ₹153.77
# ...
# 524576 (Vivid Global Industries Limited): RSI = 45.56, Price = ₹19.94
# 522105 (N/A): RSI = 45.55, Price = ₹58.41
# 540405 (Oceanic Foods Limited): RSI = 45.54, Price = ₹50.00
# 524748 (N/A): RSI = 45.53, Price = ₹42.00
# 513309 (N/A): RSI = 45.49, Price = ₹13.56
# 539399 (Bella Casa Fashion & Retail Limited): RSI = 45.41, Price = ₹567.05
# 532070 (N/A): RSI = 45.35, Price = ₹202.10
# 500168 (Goodyear India Limited): RSI = 45.28, Price = ₹1019.30
# 520123 (N/A): RSI = 45.26, Price = ₹115.55
# 590109 (Nippon India ETF Nifty 50 Shariah BeES): RSI = 45.25, Price = ₹536.92
# 515145 (Hindusthan National Glass & Industries Limited): RSI = 45.24, Price = ₹23.99
# 506528 (N/A): RSI = 45.20, Price = ₹3490.00
# 516096 (N/A): RSI = 45.16, Price = ₹291.00
# 531952 (N/A): RSI = 45.11, Price = ₹98.40
# 500165 (Kansai Nerolac Paints Limited): RSI = 45.08, Price = ₹257.50
# 526881 (63 moons technologies limited): RSI = 45.08, Price = ₹904.00
# 539518 (Uday Jewellery Industries Limited): RSI = 45.06, Price = ₹148.20
# 539527 (Creative Castings Limited): RSI = 44.98, Price = ₹737.25
# 506605 (N/A): RSI = 44.95, Price = ₹2626.55
# 509438 (N/A): RSI = 44.94, Price = ₹8226.90
# 523694 (Apcotex Industries Limited): RSI = 44.86, Price = ₹367.90
# 500420 (Torrent Pharmaceuticals Limited): RSI = 44.85, Price = ₹3325.25
# 526161 (N/A): RSI = 44.81, Price = ₹155.00
# 518011 (N/A): RSI = 44.81, Price = ₹83.24
# 523550 (N/A): RSI = 44.80, Price = ₹78.72
# 533152 (MBL Infrastructures Limited): RSI = 44.80, Price = ₹63.54
# 538081 (Haria Apparels Limited): RSI = 44.79, Price = ₹5.18
# 508989 (Navneet Education Limited): RSI = 44.77, Price = ₹139.50
# 540575 (Star Cement Limited): RSI = 44.74, Price = ₹218.50
# 534532 (Lypsa Gems & Jewellery Limited): RSI = 44.74, Price = ₹7.28
# 538979 (Greenlam Industries Limited): RSI = 44.73, Price = ₹562.40
# 534691 (Comfort Commotrade Limited): RSI = 44.73, Price = ₹43.89
# 538365 (Incredible Industries Limited): RSI = 44.61, Price = ₹46.00
# 504392 (Krishna Ventures Limited): RSI = 44.61, Price = ₹67.18
# 539658 (TeamLease Services Limited): RSI = 44.58, Price = ₹2837.50
# 539336 (Gujarat Gas Limited): RSI = 44.56, Price = ₹500.50
# 539963 (Zeal Aqua Limited): RSI = 44.55, Price = ₹12.57
# 535754 (Orient Cement Limited): RSI = 44.53, Price = ₹338.00
# 534615 (North Eastern Carrying Corporation Limited): RSI = 44.52, Price = ₹34.45
# 534623 (Jupiter Infomedia Limited): RSI = 44.52, Price = ₹50.80
# 540065 (RBL Bank Limited): RSI = 44.49, Price = ₹161.85
# 524634 (N/A): RSI = 44.46, Price = ₹499.20
# 534741 (Virtual Global Education Limited): RSI = 44.44, Price = ₹0.76
# 530665 (N/A): RSI = 44.39, Price = ₹5.49
# 526751 (N/A): RSI = 44.39, Price = ₹26.16
# 533581 (PG Electroplast Limited): RSI = 44.38, Price = ₹950.65
# 539448 (InterGlobe Aviation Limited): RSI = 44.35, Price = ₹4259.10
# 532271 (N/A): RSI = 44.34, Price = ₹3.20
# 530979 (India Home Loan Limited): RSI = 44.31, Price = ₹35.01
# 540702 (Lasa Supergenerics Limited): RSI = 44.28, Price = ₹27.10
# 500319 (N/A): RSI = 44.25, Price = ₹113.45
# 505250 (N/A): RSI = 44.19, Price = ₹117.00
# 505650 (N/A): RSI = 44.18, Price = ₹18.32
# 503100 (The Phoenix Mills Limited): RSI = 44.15, Price = ₹1696.55
# 524520 (KMC Speciality Hospitals (India) Limited): RSI = 44.13, Price = ₹77.04
# 524717 (N/A): RSI = 44.13, Price = ₹754.00
# 526217 (Hitech Corporation Limited): RSI = 44.10, Price = ₹241.00
# 504058 (Indo National Limited): RSI = 44.10, Price = ₹554.40
# 514264 (N/A): RSI = 44.07, Price = ₹20.84
# 509423 (Sanathnagar Enterprises Limited): RSI = 44.05, Price = ₹40.00
# 500660 (GlaxoSmithKline Pharmaceuticals Limited): RSI = 44.03, Price = ₹2207.85
# 521149 (Prime Urban Development India Limited): RSI = 44.02, Price = ₹12.64
# 532896 (Magnum Ventures Limited): RSI = 43.98, Price = ₹39.04
# 533170 (Tamboli Industries Limited): RSI = 43.97, Price = ₹192.80
# 539404 (Satin Creditcare Network Limited): RSI = 43.96, Price = ₹155.55
# 540710 (Capacit'e Infraprojects Limited): RSI = 43.94, Price = ₹420.90
# 531508 (Eveready Industries India Limited): RSI = 43.94, Price = ₹388.30
# 500327 (Pil Italica Lifestyle Limited): RSI = 43.89, Price = ₹13.70
# 513548 (N/A): RSI = 43.89, Price = ₹299.10
# 520051 (Jamna Auto Industries Limited): RSI = 43.88, Price = ₹97.41
# 526721 (N/A): RSI = 43.85, Price = ₹131.65
# 502090 (Sagar Cements Limited): RSI = 43.82, Price = ₹220.10
# 500870 (Castrol India Limited): RSI = 43.77, Price = ₹200.85
# 512149 (N/A): RSI = 43.75, Price = ₹0.82
# 540526 (IRB InvIT Fund): RSI = 43.75, Price = ₹60.09
# 531233 (N/A): RSI = 43.68, Price = ₹30.61
# 539984 (Hindusthan Urban Infrastructure Limited): RSI = 43.68, Price = ₹2484.20
# 532485 (N/A): RSI = 43.66, Price = ₹76.17
# 532268 (Accelya Solutions India Limited): RSI = 43.64, Price = ₹1541.95
# 511218 (Shriram Finance Limited): RSI = 43.64, Price = ₹579.63
# 540210 (Heads UP Ventures Limited): RSI = 43.64, Price = ₹11.46
# 506003 (N/A): RSI = 43.56, Price = ₹57.11
# 533202 (Satchmo Holdings Limited): RSI = 43.54, Price = ₹4.05
# 532410 (N/A): RSI = 43.53, Price = ₹31.62
# 524136 (N/A): RSI = 43.50, Price = ₹602.00
# 531335 (Zydus Wellness Limited): RSI = 43.49, Price = ₹1949.45
# 540647 (Ganges Securities Limited): RSI = 43.48, Price = ₹194.55
# 530557 (N/A): RSI = 43.48, Price = ₹0.78
# 515059 (N/A): RSI = 43.46, Price = ₹56.45
# 511493 (N/A): RSI = 43.44, Price = ₹11.91
# 500650 (Excel Industries Limited): RSI = 43.42, Price = ₹1291.40
# 516108 (N/A): RSI = 43.33, Price = ₹104.60
# 539196 (Amba Enterprises Limited): RSI = 43.32, Price = ₹219.35
# 503624 (N/A): RSI = 43.30, Price = ₹10.11
# 523648 (Plastiblends India Limited): RSI = 43.28, Price = ₹246.85
# 523850 (N/A): RSI = 43.27, Price = ₹460.05
# 530341 (N/A): RSI = 43.27, Price = ₹147.05
# 533023 (ZF Commercial Vehicle Control Systems India Limited): RSI = 43.24, Price = ₹11469.60
# 500367 (N/A): RSI = 43.19, Price = ₹78.49
# 532531 (Strides Pharma Science Limited): RSI = 43.18, Price = ₹668.85
# 517569 (KEI Industries Limited): RSI = 43.17, Price = ₹4264.00
# 533088 (Mahindra Holidays & Resorts India Limited): RSI = 43.17, Price = ₹369.65
# 524480 (N/A): RSI = 43.15, Price = ₹632.00
# 511764 (N/A): RSI = 43.15, Price = ₹47.10
# 533608 (RDB Rasayans Limited): RSI = 43.14, Price = ₹160.20
# 500422 (Transchem Limited): RSI = 43.12, Price = ₹48.95
# 500250 (L.G. Balakrishnan & Bros Limited): RSI = 43.01, Price = ₹1295.30
# 532806 (AI Champdany Industries Limited): RSI = 42.98, Price = ₹53.78
# 507759 (N/A): RSI = 42.98, Price = ₹23.03
# 526113 (N/A): RSI = 42.97, Price = ₹20.58
# 524703 (N/A): RSI = 42.95, Price = ₹54.86
# 531861 (N/A): RSI = 42.95, Price = ₹51.37
# 533193 (Kirloskar Electric Company Limited): RSI = 42.92, Price = ₹185.80
# 524218 (Resonance Specialties Limited): RSI = 42.90, Price = ₹99.32
# 533168 (Rossell India Limited): RSI = 42.90, Price = ₹76.87
# 533096 (Adani Power Limited): RSI = 42.88, Price = ₹504.40
# 532466 (Oracle Financial Services Software Limited): RSI = 42.84, Price = ₹11983.90
# 532701 (N/A): RSI = 42.82, Price = ₹15.29
# 526409 (Kkalpana Industries (India) Limited): RSI = 42.82, Price = ₹15.84
# 501848 (Global Offshore Services Limited): RSI = 42.78, Price = ₹111.75
# 511359 (N/A): RSI = 42.76, Price = ₹88.80
# 540757 (Sheetal Cool Products Limited): RSI = 42.76, Price = ₹329.85
# 523606 (N/A): RSI = 42.75, Price = ₹2496.50
# 526117 (N/A): RSI = 42.75, Price = ₹481.00
# 513369 (N/A): RSI = 42.74, Price = ₹105.10
# 539126 (MEP Infrastructure Developers Limited): RSI = 42.73, Price = ₹3.05
# 532892 (Motilal Oswal Financial Services Limited): RSI = 42.70, Price = ₹939.60
# 519359 (N/A): RSI = 42.70, Price = ₹71.39
# 531082 (Alankit Limited): RSI = 42.68, Price = ₹21.56
# 533260 (Career Point Limited): RSI = 42.67, Price = ₹389.85
# 539784 (LIC MF Nifty 100 ETF): RSI = 42.66, Price = ₹261.16
# 513488 (N/A): RSI = 42.63, Price = ₹38.73
# 517385 (Symphony Limited): RSI = 42.63, Price = ₹1298.90
# 532764 (GeeCee Ventures Limited): RSI = 42.58, Price = ₹432.00
# 531862 (Bharat Agri Fert and Realty Limited): RSI = 42.57, Price = ₹72.25
# 512634 (Savera Industries Limited): RSI = 42.56, Price = ₹165.85
# 540743 (Godrej Agrovet Limited): RSI = 42.53, Price = ₹739.65
# 530697 (N/A): RSI = 42.51, Price = ₹38.79
# 518075 (N/A): RSI = 42.50, Price = ₹459.95
# 512175 (N/A): RSI = 42.49, Price = ₹8.06
# 539255 (Star Delta Transformers Limited): RSI = 42.48, Price = ₹910.35
# 530809 (N/A): RSI = 42.45, Price = ₹62.89
# 590024 (The Fertilisers And Chemicals Travancore Limited): RSI = 42.44, Price = ₹963.40
# 513687 (N/A): RSI = 42.41, Price = ₹4.51
# 526717 (N/A): RSI = 42.39, Price = ₹149.60
# 530643 (Eco Recycling Limited): RSI = 42.31, Price = ₹902.35
# 537707 (ETT Limited): RSI = 42.30, Price = ₹16.36
# 531041 (N/A): RSI = 42.27, Price = ₹488.25
# 532674 (Bannari Amman Spinning Mills Ltd): RSI = 42.22, Price = ₹53.54
# 513709 (N/A): RSI = 42.18, Price = ₹352.30
# 533285 (RDB Infrastructure and Power Limited): RSI = 42.16, Price = ₹517.30
# 513513 (N/A): RSI = 42.16, Price = ₹10.55
# 538635 (Snowman Logistics Limited): RSI = 42.14, Price = ₹69.01
# 540692 (Apex Frozen Foods Limited): RSI = 42.12, Price = ₹251.95
# 538795 (Shree Ajit Pulp and Paper Limited): RSI = 42.11, Price = ₹207.30
# 532398 (Usha Martin Education & Solutions Limited): RSI = 42.08, Price = ₹6.86
# 520021 (Omax Autos Limited): RSI = 42.07, Price = ₹113.90
# 540777 (HDFC Life Insurance Company Limited): RSI = 42.06, Price = ₹617.55
# 540133 (ICICI Prudential Life Insurance Company Limited): RSI = 42.05, Price = ₹652.50
# 532776 (Shivam Autotech Limited): RSI = 41.99, Price = ₹44.28
# 540393 (Sarthak Metals Limited): RSI = 41.97, Price = ₹159.60
# 540749 (MAS Financial Services Limited): RSI = 41.96, Price = ₹261.60
# 507981 (N/A): RSI = 41.95, Price = ₹94.71
# 500317 (Oswal Agro Mills Limited): RSI = 41.93, Price = ₹70.07
# 540956 (N/A): RSI = 41.89, Price = ₹28.96
# 526500 (N/A): RSI = 41.89, Price = ₹52.40
# 524828 (N/A): RSI = 41.88, Price = ₹335.55
# 530973 (N/A): RSI = 41.85, Price = ₹90.98
# 532807 (Cineline India Limited): RSI = 41.84, Price = ₹129.60
# 501945 (Dhenu Buildcon Infra Limited): RSI = 41.83, Price = ₹5.98
# 590134 (Madras Fertilizers Limited): RSI = 41.83, Price = ₹98.95
# 532975 (N/A): RSI = 41.79, Price = ₹20.23
# 500104 (Hindustan Petroleum Corporation Limited): RSI = 41.78, Price = ₹391.10
# 540716 (ICICI Lombard General Insurance Company Limited): RSI = 41.78, Price = ₹1859.55
# 513063 (N/A): RSI = 41.76, Price = ₹33.97
# 515085 (N/A): RSI = 41.71, Price = ₹7.17
# 517546 (N/A): RSI = 41.70, Price = ₹115.60
# 523840 (N/A): RSI = 41.69, Price = ₹35.34
# 526073 (N/A): RSI = 41.67, Price = ₹1028.15
# 530997 (N/A): RSI = 41.65, Price = ₹180.95
# 516106 (N/A): RSI = 41.64, Price = ₹11.31
# 541353 (Innovators Façade Systems Limited): RSI = 41.63, Price = ₹220.05
# 524667 (Savita Oil Technologies Limited): RSI = 41.63, Price = ₹554.00
# 500179 (HCL Infosystems Limited): RSI = 41.60, Price = ₹15.81
# 533212 (GKB Ophthalmics Limited): RSI = 41.59, Price = ₹97.10
# 540565 (India Grid Trust): RSI = 41.56, Price = ₹143.70
# 530131 (Udaipur Cement Works Limited): RSI = 41.56, Price = ₹29.34
# 533014 (N/A): RSI = 41.54, Price = ₹80.74
# 540124 (G N A Axles Limited): RSI = 41.54, Price = ₹409.35
# 514300 (Pioneer Embroideries Limited): RSI = 41.52, Price = ₹54.79
# 538891 (Magellanic Cloud Limited): RSI = 41.50, Price = ₹65.37
# 533164 (Texmo Pipes and Products Limited): RSI = 41.48, Price = ₹66.09
# 538567 (Gulf Oil Lubricants India Limited): RSI = 41.47, Price = ₹1137.00
# 519224 (Williamson Magor & Co. Limited): RSI = 41.43, Price = ₹39.05
# 533477 (Enkei Wheels (India) Limited): RSI = 41.41, Price = ₹654.95
# 533270 (Bedmutha Industries Limited): RSI = 41.38, Price = ₹200.00
# 540268 (TruCap Finance Limited): RSI = 41.33, Price = ₹15.26
# 533482 (Kridhan Infra Limited): RSI = 41.32, Price = ₹6.13
# 532977 (Bajaj Auto Limited): RSI = 41.29, Price = ₹8642.25
# 500335 (Birla Corporation Limited): RSI = 41.28, Price = ₹1221.95
# 533286 (MOIL Limited): RSI = 41.27, Price = ₹338.25
# 531539 (N/A): RSI = 41.26, Price = ₹39.57
# 526642 (Mirza International Limited): RSI = 41.25, Price = ₹36.72
# 517477 (N/A): RSI = 41.25, Price = ₹397.60
# 532842 (Sree Rayalaseema Hi-Strength Hypo Limited): RSI = 41.25, Price = ₹777.65
# 524731 (N/A): RSI = 41.23, Price = ₹1228.10
# 530343 (Genus Power Infrastructures Limited): RSI = 41.23, Price = ₹387.90
# 539018 (Beekay Steel Industries Limited): RSI = 41.21, Price = ₹670.65
# 531595 (Capri Global Capital Limited): RSI = 41.14, Price = ₹189.30
# 506618 (Punjab Chemicals and Crop Protection Limited): RSI = 41.13, Price = ₹994.00
# 531859 (N/A): RSI = 41.09, Price = ₹303.95
# 539227 (Loyal Equipments Limited): RSI = 41.09, Price = ₹273.90
# 502450 (Seshasayee Paper and Boards Limited): RSI = 41.08, Price = ₹304.05
# 532209 (The Jammu and Kashmir Bank Limited): RSI = 40.99, Price = ₹96.75
# 504093 (Panasonic Energy India Co. Ltd.): RSI = 40.98, Price = ₹445.30
# 513729 (Aro Granite Industries Limited): RSI = 40.97, Price = ₹46.25
# 526849 (Banaras Beads Limited): RSI = 40.96, Price = ₹129.45
# 523736 (Dhunseri Ventures Limited): RSI = 40.94, Price = ₹351.20
# 533758 (APL Apollo Tubes Limited): RSI = 40.93, Price = ₹1538.80
# 526839 (Shelter Infra Projects Limited): RSI = 40.93, Price = ₹18.44
# 533452 (Delphi World Money Limited): RSI = 40.89, Price = ₹203.05
# 531266 (V.S.T. Tillers Tractors Limited): RSI = 40.85, Price = ₹4925.65
# 500304 (NIIT Limited): RSI = 40.82, Price = ₹187.20
# 532407 (N/A): RSI = 40.81, Price = ₹209.60
# 538521 (Yaan Enterprises Limited): RSI = 40.79, Price = ₹79.53
# 524408 (N/A): RSI = 40.78, Price = ₹171.25
# 539871 (Thyrocare Technologies Limited): RSI = 40.78, Price = ₹935.00
# 531289 (National Fittings Limited): RSI = 40.76, Price = ₹132.35
# 531900 (CCL International Limited): RSI = 40.69, Price = ₹30.76
# 530309 (N/A): RSI = 40.66, Price = ₹23.88
# 532173 (CyberTech Systems and Software Limited): RSI = 40.66, Price = ₹216.45
# 504988 (N/A): RSI = 40.65, Price = ₹1302.30
# 526616 (N/A): RSI = 40.65, Price = ₹64.20
# 530427 (N/A): RSI = 40.57, Price = ₹90.00
# 505840 (N/A): RSI = 40.55, Price = ₹34.70
# 532613 (VIP Clothing Limited): RSI = 40.54, Price = ₹44.34
# 526668 (Kamat Hotels (India) Limited): RSI = 40.50, Price = ₹225.35
# 511754 (N/A): RSI = 40.48, Price = ₹695.50
# 517372 (N/A): RSI = 40.48, Price = ₹441.40
# 512131 (Signet Industries Limited): RSI = 40.47, Price = ₹68.85
# 530723 (N/A): RSI = 40.45, Price = ₹145.00
# 500209 (Infosys Limited): RSI = 40.44, Price = ₹1933.15
# 531499 (N/A): RSI = 40.43, Price = ₹6.67
# 532354 (Virgo Global Limited): RSI = 40.43, Price = ₹7.23
# 531273 (N/A): RSI = 40.43, Price = ₹2.94
# 537069 (Arnold Holdings Ltd.): RSI = 40.42, Price = ₹42.91
# 541006 (N/A): RSI = 40.42, Price = ₹20.00
# 537292 (Agri-tech (India) Limited): RSI = 40.42, Price = ₹196.95
# 535458 (NRB Industrial Bearings Limited): RSI = 40.41, Price = ₹23.96
# 504341 (N/A): RSI = 40.40, Price = ₹125.45
# 502180 (Shree Digvijay Cement Company Ltd.): RSI = 40.39, Price = ₹84.84
# 523660 (The Waterbase Limited): RSI = 40.32, Price = ₹71.95
# 526755 (N/A): RSI = 40.30, Price = ₹7.69
# 511147 (N/A): RSI = 40.24, Price = ₹101.90
# 540769 (The New India Assurance Company Limited): RSI = 40.24, Price = ₹194.60
# 511413 (Crest Ventures Limited): RSI = 40.22, Price = ₹434.85
# 514326 (Patspin India Limited): RSI = 40.19, Price = ₹12.63
# 531234 (N/A): RSI = 40.18, Price = ₹118.00
# 517146 (Usha Martin Limited): RSI = 40.16, Price = ₹369.35
# 539254 (Adani Transmission Limited): RSI = 40.15, Price = ₹770.25
# 522275 (GE T&D India Limited): RSI = 40.15, Price = ₹1991.50
# 531398 (Source Natural Foods and Herbal Supplements Limited): RSI = 40.14, Price = ₹182.35
# 533019 (N/A): RSI = 40.10, Price = ₹2420.00
# 504879 (Orient Abrasives Limited): RSI = 40.10, Price = ₹48.73
# 526608 (Electrotherm (India) Limited): RSI = 40.10, Price = ₹1223.15
# 590062 (The Andhra Sugars Limited): RSI = 40.06, Price = ₹93.87
# 524200 (Vinati Organics Limited): RSI = 40.03, Price = ₹1702.45
# 530991 (N/A): RSI = 40.02, Price = ₹71.50
# 517421 (Butterfly Gandhimathi Appliances Limited): RSI = 40.02, Price = ₹779.00
# 500444 (West Coast Paper Mills Limited): RSI = 40.00, Price = ₹552.20
# 539621 (BCL Enterprises Limited): RSI = 40.00, Price = ₹0.94
# 531025 (Visagar Financial Services Limited): RSI = 40.00, Price = ₹0.75
#
# Daily analysis complete. Results saved in stock_analysis\daily_results

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    # [Previous setup methods remain unchanged...]

    def calculate_ema(self, data, length, source='Close', offset=0, smoothing_length=9):
        """
        Calculate Exponential Moving Average with specified parameters and error handling
        """
        try:
            if len(data) < max(length, smoothing_length):
                return pd.Series(index=data.index, dtype=float)
            
            # First calculate SMA as the smoothing line
            sma = data[source].rolling(window=smoothing_length, min_periods=1).mean()
            
            # Calculate the multiplier
            multiplier = 2 / (length + 1)
            
            # Initialize EMA with SMA
            ema = pd.Series(index=data.index, dtype=float)
            ema.iloc[:length-1] = np.nan
            
            # Make sure we have enough data for the initial value
            if len(sma.dropna()) > length-1:
                ema.iloc[length-1] = sma.iloc[length-1]
                
                # Calculate EMA
                for i in range(length, len(data)):
                    ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
                
                # Apply offset if specified
                if offset != 0:
                    ema = ema.shift(offset)
            
            return ema
            
        except Exception as e:
            print(f"Error calculating EMA: {e}")
            return pd.Series(index=data.index, dtype=float)

    def get_stock_data(self, symbol, exchange='NSE', days=100):  # Increased days to ensure enough data
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate EMAs with error handling
            try:
                hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0, smoothing_length=9)
                hist_data['EMA_21'] = self.calculate_ema(hist_data, length=21, source='Close', offset=0, smoothing_length=9)
                hist_data['EMA_50'] = self.calculate_ema(hist_data, length=50, source='Close', offset=0, smoothing_length=9)
            except Exception as e:
                print(f"Error calculating EMAs for {symbol}: {e}")
                hist_data['EMA_9'] = np.nan
                hist_data['EMA_21'] = np.nan
                hist_data['EMA_50'] = np.nan

            latest_price = hist_data['Close'].iloc[-1] if not hist_data.empty else None
            prices_tuple = tuple(hist_data['Close'].values) if not hist_data.empty else ()
            latest_rsi = self.calculate_rsi(prices_tuple) if prices_tuple else None

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Get the latest available EMA values safely
                        ema_9 = hist_data['EMA_9'].iloc[-1] if not hist_data['EMA_9'].empty and not pd.isna(hist_data['EMA_9'].iloc[-1]) else 'N/A'
                        ema_21 = hist_data['EMA_21'].iloc[-1] if not hist_data['EMA_21'].empty and not pd.isna(hist_data['EMA_21'].iloc[-1]) else 'N/A'
                        ema_50 = hist_data['EMA_50'].iloc[-1] if not hist_data['EMA_50'].empty and not pd.isna(hist_data['EMA_50'].iloc[-1]) else 'N/A'
                        
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': ema_9,
                            'EMA_21': ema_21,
                            'EMA_50': ema_50,
                            'RSI': latest_rsi,
                            # [Rest of the fields remain the same...]
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None and not hist_data.empty:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    # [Rest of the class methods remain unchanged...]

if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
