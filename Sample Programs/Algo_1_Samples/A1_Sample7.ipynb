# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def calculate_ema(self, data, length=9, source='Close', offset=0):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=9).mean()  # Smoothing length of 9 as specified
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=60):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate EMA
            hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0)

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)
            self.save_delisted_stocks()
            return None, None, None, None
    
    def calculate_ema_21(self, data):
        """
        Calculate EMA with a period of 21 days.

        Args:
            data (pd.DataFrame): Historical price data
        
        Returns:
            pd.Series: EMA 21 values
        """
        return self.calculate_ema(data, length=21, source='Close', offset=0)
    
    def calculate_ema_50(self, data):
        """
        Calculate EMA with a period of 50 days.

        Args:
            data (pd.DataFrame): Historical price data
        
        Returns:
            pd.Series: EMA 50 values
        """
        return self.calculate_ema(data, length=50, source='Close', offset=0)

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean(),
                                # Adding EMA 21 and EMA 50 to stock_info
                                'EMA_21': self.calculate_ema_21(hist_data).iloc[-1],
                                'EMA_50': self.calculate_ema_50(hist_data).iloc[-1]
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")


if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2062 NSE and 3026 BSE stocks
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/HAPPSTMNDS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=HAPPSTMNDS.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GVT&D.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GVT%26D.NS&crumb=CdOdjA2vtBF
# NSE analysis complete. Results saved to stock_analysis\daily_results\nse_analysis_20250109.xlsx
#
# NSE Stocks with RSI >= 40:
# ATLASCYCLE (Atlas Cycles (Haryana) Limited): RSI = 100.00, Price = ₹102.56
# BGRENERGY (BGR Energy Systems Limited): RSI = 100.00, Price = ₹116.67
# BLUECOAST (Blue Coast Hotels Limited): RSI = 100.00, Price = ₹21.84
# VISASTEEL (VISA Steel Limited): RSI = 100.00, Price = ₹45.48
# GVT&D (N/A): RSI = 100.00, Price = ₹1990.20
# AARVEEDEN (Aarvee Denims and Exports Ltd.): RSI = 100.00, Price = ₹129.00
# FSC (Future Supply Chain Solutions Limited): RSI = 96.77, Price = ₹2.49
# INDOTHAI (Indo Thai Securities Limited): RSI = 94.57, Price = ₹1648.95
# PTCIL (PTC Industries Limited): RSI = 92.88, Price = ₹17392.15
# SVLL (Shree Vasu Logistics Limited): RSI = 91.62, Price = ₹386.95
# AXISCADES (AXISCADES Technologies Limited): RSI = 90.15, Price = ₹809.15
# SRF (SRF Limited): RSI = 84.05, Price = ₹2673.90
# AVONMORE (Avonmore Capital & Management Services Limited): RSI = 83.05, Price = ₹27.24
# GODREJCP (Godrej Consumer Products Limited): RSI = 82.11, Price = ₹1181.10
# LLOYDSME (Lloyds Metals and Energy Limited): RSI = 81.67, Price = ₹1435.75
# INDIACEM (The India Cements Limited): RSI = 81.39, Price = ₹376.70
# BROOKS (Brooks Laboratories Limited): RSI = 80.57, Price = ₹185.78
# ZOTA (Zota Health Care Limited): RSI = 79.12, Price = ₹1014.25
# DIAMONDYD (Prataap Snacks Limited): RSI = 78.87, Price = ₹1160.65
# CAPITALSFB (Capital Small Finance Bank Limited): RSI = 78.31, Price = ₹307.40
# SHAKTIPUMP (Shakti Pumps (India) Limited): RSI = 78.29, Price = ₹1283.50
# IRIS (IRIS Business Services Limited): RSI = 78.14, Price = ₹500.35
# MEGASTAR (Megastar Foods Limited): RSI = 77.89, Price = ₹288.09
# AVROIND (Avro India Limited): RSI = 76.88, Price = ₹217.92
# JUBLFOOD (Jubilant FoodWorks Limited): RSI = 76.85, Price = ₹745.60
# BTML (Bodhi Tree Multimedia Limited): RSI = 76.68, Price = ₹12.84
# TATACONSUM (Tata Consumer Products Limited): RSI = 76.27, Price = ₹970.10
# DCXINDIA (DCX Systems Limited): RSI = 76.05, Price = ₹375.10
# KIMS (Krishna Institute of Medical Sciences Limited): RSI = 75.95, Price = ₹653.75
# COFFEEDAY (Coffee Day Enterprises Limited): RSI = 75.69, Price = ₹30.28
# SEYAIND (Seya Industries Limited): RSI = 75.66, Price = ₹29.55
# PROZONER (Prozone Realty Limited): RSI = 75.63, Price = ₹36.05
# SUNCLAY (Sundaram-Clayton Limited): RSI = 74.98, Price = ₹2813.40
# LFIC (Lakshmi Finance & Industrial Corporation Limited): RSI = 74.95, Price = ₹248.92
# COROMANDEL (Coromandel International Limited): RSI = 74.66, Price = ₹1951.95
# MEGASOFT (Megasoft Limited): RSI = 74.51, Price = ₹104.32
# VIJAYA (Vijaya Diagnostic Centre Limited): RSI = 74.27, Price = ₹1221.30
# MEDICO (Medico Remedies Limited): RSI = 74.23, Price = ₹60.97
# UNIVASTU (Univastu India Limited): RSI = 74.07, Price = ₹281.80
# ABDL (N/A): RSI = 73.78, Price = ₹429.15
# ASIANHOTNR (Asian Hotels (North) Limited): RSI = 73.59, Price = ₹296.50
# KALYANIFRG (Kalyani Forge Limited): RSI = 72.89, Price = ₹811.55
# WORTH (Worth Peripherals Limited): RSI = 72.66, Price = ₹172.33
# SPANDANA (Spandana Sphoorty Financial Limited): RSI = 72.62, Price = ₹450.85
# APOLLO (Apollo Micro Systems Limited): RSI = 72.49, Price = ₹129.44
# KILITCH (Kilitch Drugs (India) Limited): RSI = 72.43, Price = ₹345.10
# JSWHL (JSW Holdings Limited): RSI = 72.08, Price = ₹18079.70
# ASMS (Bartronics India Limited): RSI = 71.92, Price = ₹22.76
# BERGEPAINT (Berger Paints India Limited): RSI = 71.82, Price = ₹468.75
# LLOYDSENT (Lloyds Enterprises Limited): RSI = 71.70, Price = ₹57.57
# BAJAJFINSV (Bajaj Finserv Ltd.): RSI = 71.34, Price = ₹1690.30
# MBAPL (Madhya Bharat Agro Products Limited): RSI = 71.31, Price = ₹245.62
# AMBER (Amber Enterprises India Limited): RSI = 71.17, Price = ₹7703.95
# HMT (HMT Limited): RSI = 71.02, Price = ₹76.00
# USK (Udayshivakumar Infra Limited): RSI = 70.86, Price = ₹56.64
# AARTIPHARM (Aarti Pharmalabs Limited): RSI = 70.60, Price = ₹660.15
# EICHERMOT (Eicher Motors Limited): RSI = 70.57, Price = ₹5139.90
# SAPPHIRE (Sapphire Foods India Limited): RSI = 70.53, Price = ₹343.90
# ARIHANTSUP (Arihant Superstructures Limited): RSI = 70.44, Price = ₹524.50
# MGEL (Mangalam Global Enterprise Limited): RSI = 70.08, Price = ₹30.56
# FMNL (Future Market Networks Limited): RSI = 70.04, Price = ₹26.49
# CALSOFT (California Software Company Limited): RSI = 69.93, Price = ₹19.78
# LAURUSLABS (Laurus Labs Limited): RSI = 69.83, Price = ₹613.05
# CONCORDBIO (Concord Biotech Limited): RSI = 69.63, Price = ₹2320.15
# CREDITACC (CreditAccess Grameen Limited): RSI = 69.57, Price = ₹999.55
# JTLIND (JTL Industries Limited): RSI = 69.46, Price = ₹107.87
# EPACK (EPACK Durable Limited): RSI = 69.32, Price = ₹598.35
# VASWANI (Vaswani Industries Limited): RSI = 69.22, Price = ₹54.84
# HSCL (Himadri Speciality Chemical Limited): RSI = 68.89, Price = ₹579.05
# MARUTI (Maruti Suzuki India Limited): RSI = 68.73, Price = ₹11740.55
# MVGJL (Manoj Vaibhav Gems 'N' Jewellers Limited): RSI = 68.50, Price = ₹295.25
# ATALREAL (Atal Realtech Limited): RSI = 68.45, Price = ₹14.20
# DECCANCE (Deccan Cements Limited): RSI = 68.28, Price = ₹712.75
# AURUM (Aurum PropTech Limited): RSI = 68.08, Price = ₹256.09
# IFBIND (IFB Industries Limited): RSI = 67.38, Price = ₹1981.15
# AEGISLOG (N/A): RSI = 67.16, Price = ₹887.80
# ASTERDM (Aster DM Healthcare Limited): RSI = 67.13, Price = ₹515.25
# INDOTECH (Indo Tech Transformers Limited): RSI = 67.10, Price = ₹3566.00
# BAJFINANCE (Bajaj Finance Limited): RSI = 66.97, Price = ₹7277.45
# GARUDA (N/A): RSI = 66.69, Price = ₹137.61
# BLUECHIP (Blue Chip India Limited): RSI = 66.52, Price = ₹8.93
# MANCREDIT (Mangal Credit and Fincorp Limited): RSI = 66.00, Price = ₹165.04
# DMART (Avenue Supermarts Limited): RSI = 65.78, Price = ₹3813.80
# HINDUNILVR (Hindustan Unilever Limited): RSI = 65.57, Price = ₹2435.40
# DEVIT (Dev Information Technology Limited): RSI = 65.55, Price = ₹173.88
# SBILIFE (SBI Life Insurance Company Limited): RSI = 65.46, Price = ₹1468.45
# ASHAPURMIN (Ashapura Minechem Limited): RSI = 65.31, Price = ₹473.95
# RAMAPHO (Rama Phosphates Limited): RSI = 65.26, Price = ₹229.14
# SMSLIFE (SMS Lifesciences India Limited): RSI = 65.17, Price = ₹1240.60
# V2RETAIL (V2 Retail Limited): RSI = 65.12, Price = ₹1752.35
# FSL (Firstsource Solutions Limited): RSI = 65.06, Price = ₹395.00
# NACLIND (NACL Industries Limited): RSI = 65.06, Price = ₹66.49
# LORDSCHLO (Lords Chloro Alkali Limited): RSI = 65.00, Price = ₹202.80
# CHOLAHLDNG (Cholamandalam Financial Holdings Limited): RSI = 64.95, Price = ₹1580.05
# ANANTRAJ (Anant Raj Limited): RSI = 64.61, Price = ₹905.15
# ALPA (Alpa Laboratories Limited): RSI = 64.54, Price = ₹128.52
# GMRP&UI (GMR Power And Urban Infra Limited): RSI = 64.48, Price = ₹121.84
# EQUITASBNK (Equitas Small Finance Bank Limited): RSI = 64.45, Price = ₹69.05
# BRITANNIA (Britannia Industries Limited): RSI = 64.38, Price = ₹4926.30
# MAZDA (Mazda Limited): RSI = 64.34, Price = ₹1730.30
# SUPERSPIN (Super Spinning Mills Limited): RSI = 64.26, Price = ₹14.62
# UNIVCABLES (Universal Cables Limited): RSI = 64.17, Price = ₹833.25
# SAREGAMA (Saregama India Limited): RSI = 64.12, Price = ₹552.30
# TITAN (Titan Company Limited): RSI = 64.12, Price = ₹3487.05
# ASTRAZEN (AstraZeneca Pharma India Limited): RSI = 64.07, Price = ₹7089.00
# DRREDDY (Dr. Reddy's Laboratories Limited): RSI = 64.02, Price = ₹1371.60
# DEVYANI (Devyani International Limited): RSI = 64.01, Price = ₹187.14
# CANTABIL (Cantabil Retail India Limited): RSI = 63.60, Price = ₹307.75
# UPL (UPL Limited): RSI = 63.44, Price = ₹545.45
# GENESYS (Genesys International Corporation Limited): RSI = 63.44, Price = ₹1028.50
# AKUMS (N/A): RSI = 63.33, Price = ₹617.40
# SYNGENE (Syngene International Limited): RSI = 63.26, Price = ₹877.10
# JUSTDIAL (Just Dial Limited): RSI = 63.12, Price = ₹1075.20
# SAGILITY (N/A): RSI = 63.02, Price = ₹51.10
# VLEGOV (VL E-Governance & IT Solutions Limited): RSI = 62.91, Price = ₹177.32
# GUJRAFFIA (Gujarat Raffia Industries Limited): RSI = 62.90, Price = ₹90.04
# AWL (Adani Wilmar Limited): RSI = 62.85, Price = ₹323.45
# ATFL (Agro Tech Foods Limited): RSI = 62.84, Price = ₹945.30
# TECILCHEM (Tecil Chemicals and Hydro Power Ltd.): RSI = 62.73, Price = ₹25.59
# AARTECH (Aartech Solonics Limited): RSI = 62.65, Price = ₹90.59
# WELENT (Welspun Enterprises Limited): RSI = 62.50, Price = ₹638.75
# JYOTHYLAB (Jyothy Labs Limited): RSI = 62.49, Price = ₹408.10
# GLENMARK (Glenmark Pharmaceuticals Limited): RSI = 62.45, Price = ₹1593.30
# ALLDIGI (Alldigi Tech Limited): RSI = 62.39, Price = ₹1045.45
# JKCEMENT (J.K. Cement Limited): RSI = 62.38, Price = ₹4738.80
# CHOLAFIN (Cholamandalam Investment and Finance Company Limited): RSI = 62.17, Price = ₹1288.20
# VAKRANGEE (Vakrangee Limited): RSI = 62.17, Price = ₹36.46
# SUVIDHAA (Suvidhaa Infoserve Limited): RSI = 62.09, Price = ₹6.84
# ZEEMEDIA (Zee Media Corporation Limited): RSI = 62.06, Price = ₹21.01
# VARDMNPOLY (Vardhman Polytex Limited): RSI = 62.03, Price = ₹14.89
# E2E (E2E Networks Limited): RSI = 62.03, Price = ₹4301.80
# DABUR (Dabur India Limited): RSI = 61.85, Price = ₹521.15
# INDGN (N/A): RSI = 61.77, Price = ₹629.05
# MARICO (Marico Limited): RSI = 61.76, Price = ₹666.90
# VINCOFE (Vintage Coffee and Beverages Limited): RSI = 61.47, Price = ₹124.00
# INNOVACAP (Innova Captab Limited): RSI = 61.36, Price = ₹1120.35
# KINGFA (Kingfa Science & Technology (India) Limited): RSI = 61.31, Price = ₹3633.10
# ITI (ITI Limited): RSI = 61.30, Price = ₹440.40
# SHAILY (Shaily Engineering Plastics Limited): RSI = 61.28, Price = ₹1630.70
# SURAJLTD (Suraj Limited): RSI = 61.21, Price = ₹515.00
# LUPIN (Lupin Limited): RSI = 61.19, Price = ₹2252.85
# ASTRON (Astron Paper & Board Mill Limited): RSI = 61.18, Price = ₹20.37
# IPCALAB (Ipca Laboratories Limited): RSI = 61.06, Price = ₹1661.95
# ALPHAGEO (Alphageo (India) Limited): RSI = 61.06, Price = ₹461.15
# FUSION (Fusion Finance Limited): RSI = 61.04, Price = ₹188.30
# SCHAEFFLER (Schaeffler India Limited): RSI = 61.03, Price = ₹3441.10
# FORTIS (Fortis Healthcare Limited): RSI = 60.99, Price = ₹713.25
# MANGCHEFER (Mangalore Chemicals & Fertilizers Limited): RSI = 60.83, Price = ₹171.40
# MANGLMCEM (Mangalam Cement Limited): RSI = 60.76, Price = ₹984.85
# IGL (Indraprastha Gas Limited): RSI = 60.67, Price = ₹419.50
# FLEXITUFF (Flexituff Ventures International Limited): RSI = 60.61, Price = ₹65.69
# SHRADHA (Shradha Infraprojects Limited): RSI = 60.59, Price = ₹90.78
# VISAKAIND (Visaka Industries Limited): RSI = 60.53, Price = ₹102.23
# TATAMOTORS (Tata Motors Limited): RSI = 60.51, Price = ₹780.10
# INDORAMA (Indo Rama Synthetics (India) Limited): RSI = 60.26, Price = ₹44.06
# AJOONI (Ajooni Biotech Limited): RSI = 60.00, Price = ₹7.92
# ASIANPAINT (Asian Paints Limited): RSI = 59.96, Price = ₹2350.20
# SBICARD (SBI Cards and Payment Services Limited): RSI = 59.94, Price = ₹730.70
# COLPAL (Colgate-Palmolive (India) Limited): RSI = 59.91, Price = ₹2890.60
# ESCORTS (Escorts Kubota Limited): RSI = 59.89, Price = ₹3389.60
# EMCURE (N/A): RSI = 59.63, Price = ₹1436.90
# MTEDUCARE (MT Educare Limited): RSI = 59.60, Price = ₹2.72
# ABBOTINDIA (Abbott India Limited): RSI = 59.54, Price = ₹29753.85
# M&MFIN (Mahindra & Mahindra Financial Services Limited): RSI = 59.53, Price = ₹279.75
# KAUSHALYA (Kaushalya Infrastructure Development Corporation Limited): RSI = 59.45, Price = ₹1076.70
# MARATHON (Marathon Nextgen Realty Limited): RSI = 59.18, Price = ₹649.10
# LLOYDSENGG (Lloyds Engineering Works Limited): RSI = 59.14, Price = ₹86.02
# ASALCBR (Associated Alcohols & Breweries Limited): RSI = 59.11, Price = ₹1178.95
# SIGNPOST (Signpost India Limited): RSI = 58.97, Price = ₹381.90
# MTARTECH (MTAR Technologies Limited): RSI = 58.94, Price = ₹1723.90
# ASHIANA (Ashiana Housing Limited): RSI = 58.88, Price = ₹378.20
# GLFL (Gujarat Lease Financing Limited): RSI = 58.88, Price = ₹7.88
# DCI (DC Infotech and Communication Limited): RSI = 58.86, Price = ₹367.35
# JSFB (Jana Small Finance Bank Limited): RSI = 58.74, Price = ₹402.70
# GUFICBIO (Gufic Biosciences Limited): RSI = 58.71, Price = ₹460.65
# LAGNAM (Lagnam Spintex Limited): RSI = 58.69, Price = ₹123.31
# DNAMEDIA (Diligent Media Corporation Limited): RSI = 58.63, Price = ₹6.36
# BATAINDIA (Bata India Limited): RSI = 58.58, Price = ₹1412.90
# AUBANK (AU Small Finance Bank Limited): RSI = 58.54, Price = ₹570.05
# ZENTEC (Zen Technologies Limited): RSI = 58.53, Price = ₹2539.05
# BHAGERIA (Bhageria Industries Limited): RSI = 58.50, Price = ₹205.49
# BIOCON (Biocon Limited): RSI = 58.46, Price = ₹370.70
# THOMASCOTT (Thomas Scott (India) Limited): RSI = 58.46, Price = ₹460.70
# GLAND (Gland Pharma Limited): RSI = 58.44, Price = ₹1829.95
# PRUDMOULI (Prudential Sugar Corporation Ltd.): RSI = 58.34, Price = ₹67.57
# APARINDS (APAR Industries Limited): RSI = 58.29, Price = ₹10514.40
# M&M (Mahindra & Mahindra Limited): RSI = 58.25, Price = ₹3126.50
# LGHL (N/A): RSI = 58.16, Price = ₹531.00
# GANESHHOUC (Ganesh Housing Corporation Limited): RSI = 58.00, Price = ₹1319.35
# ARKADE (N/A): RSI = 57.97, Price = ₹174.13
# GUJAPOLLO (Gujarat Apollo Industries Limited): RSI = 57.95, Price = ₹355.35
# REPL (Rudrabhishek Enterprises Limited): RSI = 57.91, Price = ₹308.25
# AIIL (Authum Investment & Infrastructure Limited): RSI = 57.86, Price = ₹1850.85
# AMNPLST (Amines & Plasticizers Limited): RSI = 57.84, Price = ₹303.25
# DHANI (Dhani Services Limited): RSI = 57.79, Price = ₹95.57
# HONAUT (Honeywell Automation India Limited): RSI = 57.77, Price = ₹42151.70
# GOLDIAM (Goldiam International Limited): RSI = 57.73, Price = ₹471.15
# SOUTHBANK (The South Indian Bank Limited): RSI = 57.68, Price = ₹25.95
# HISARMETAL (Hisar Metal Industries Limited): RSI = 57.59, Price = ₹208.05
# SILVERTUC (Silver Touch Technologies Limited): RSI = 57.54, Price = ₹693.00
# GALAPREC (N/A): RSI = 57.48, Price = ₹1226.40
# ARVINDFASN (Arvind Fashions Limited): RSI = 57.41, Price = ₹526.75
# GTPL (GTPL Hathway Limited): RSI = 57.40, Price = ₹146.52
# KIOCL (KIOCL Limited): RSI = 57.39, Price = ₹400.10
# GREAVESCOT (Greaves Cotton Limited): RSI = 57.38, Price = ₹264.35
# AKZOINDIA (Akzo Nobel India Limited): RSI = 57.36, Price = ₹3734.50
# UJJIVANSFB (Ujjivan Small Finance Bank Limited): RSI = 57.25, Price = ₹35.49
# MONARCH (Monarch Networth Capital Limited): RSI = 57.08, Price = ₹446.80
# CREATIVE (Creative Newtech Limited): RSI = 57.06, Price = ₹979.45
# TVTODAY (T.V. Today Network Limited): RSI = 57.02, Price = ₹213.38
# SHANTI (Shanti Overseas (India) Limited): RSI = 56.95, Price = ₹17.31
# ITDC (India Tourism Development Corporation Limited): RSI = 56.89, Price = ₹666.45
# CAMLINFINE (Camlin Fine Sciences Limited): RSI = 56.78, Price = ₹132.57
# GOKUL (Gokul Refoils & Solvent Limited): RSI = 56.67, Price = ₹62.77
# TBOTEK (N/A): RSI = 56.66, Price = ₹1742.90
# GANGAFORGE (Ganga Forging Limited): RSI = 56.64, Price = ₹7.02
# JINDWORLD (Jindal Worldwide Limited): RSI = 56.55, Price = ₹436.25
# KOTHARIPRO (Kothari Products Limited): RSI = 56.55, Price = ₹182.27
# GHCL (GHCL Limited): RSI = 56.50, Price = ₹707.65
# MUKTAARTS (Mukta Arts Limited): RSI = 56.37, Price = ₹92.74
# TAJGVK (TAJGVK Hotels & Resorts Limited): RSI = 56.24, Price = ₹404.25
# RELIANCE (Reliance Industries Limited): RSI = 56.21, Price = ₹1254.75
# UNOMINDA (Uno Minda Limited): RSI = 56.18, Price = ₹1066.30
# SPENCERS (Spencer's Retail Limited): RSI = 56.10, Price = ₹87.72
# PVP (PVP Ventures Limited): RSI = 56.05, Price = ₹31.08
# ZEELEARN (Zee Learn Limited): RSI = 56.03, Price = ₹8.81
# KAVVERITEL (Kavveri Defence & Wireless Technologies Limited): RSI = 56.00, Price = ₹58.38
# ZYDUSLIFE (Zydus Lifesciences Limited): RSI = 55.95, Price = ₹1010.50
# CARTRADE (CarTrade Tech Limited): RSI = 55.84, Price = ₹1619.95
# KOTAKBANK (Kotak Mahindra Bank Limited): RSI = 55.77, Price = ₹1790.20
# BAFNAPH (Bafna Pharmaceuticals Limited): RSI = 55.75, Price = ₹82.50
# SETCO (Setco Automotive Limited): RSI = 55.74, Price = ₹20.37
# EMBDL (N/A): RSI = 55.63, Price = ₹135.19
# IDEA (Vodafone Idea Limited): RSI = 55.56, Price = ₹7.92
# TCLCONS (Tantia Constructions Limited): RSI = 55.50, Price = ₹46.68
# HILTON (Hilton Metal Forging Limited): RSI = 55.36, Price = ₹105.48
# SAURASHCEM (Saurashtra Cement Limited): RSI = 55.34, Price = ₹112.40
# INDRAMEDCO (Indraprastha Medical Corporation Limited): RSI = 55.31, Price = ₹525.25
# TARIL (N/A): RSI = 55.25, Price = ₹1178.75
# SANCO (Sanco Industries Limited): RSI = 55.23, Price = ₹4.28
# CAPLIPOINT (Caplin Point Laboratories Limited): RSI = 55.23, Price = ₹2477.50
# ROSSARI (Rossari Biotech Limited): RSI = 55.06, Price = ₹815.75
# GICRE (General Insurance Corporation of India): RSI = 55.06, Price = ₹464.90
# JISLJALEQS (Jain Irrigation Systems Limited): RSI = 55.00, Price = ₹74.53
# SFL (Sheela Foam Limited): RSI = 54.98, Price = ₹1000.65
# INTELLECT (Intellect Design Arena Limited): RSI = 54.95, Price = ₹906.00
# MAXHEALTH (Max Healthcare Institute Limited): RSI = 54.84, Price = ₹1208.60
# MATRIMONY (Matrimony.com Limited): RSI = 54.81, Price = ₹670.85
# RBZJEWEL (RBZ Jewellers Limited): RSI = 54.79, Price = ₹218.31
# KARMAENG (Karma Energy Limited): RSI = 54.75, Price = ₹72.85
# JAIPURKURT (Nandani Creation Limited): RSI = 54.72, Price = ₹36.07
# ROML (Raj Oil Mills Limited): RSI = 54.69, Price = ₹57.14
# MINDACORP (Minda Corporation Limited): RSI = 54.68, Price = ₹528.95
# WEBELSOLAR (Websol Energy System Limited): RSI = 54.67, Price = ₹1755.80
# AWFIS (N/A): RSI = 54.61, Price = ₹740.45
# SUNFLAG (Sunflag Iron and Steel Company Limited): RSI = 54.60, Price = ₹294.85
# INDUSINDBK (IndusInd Bank Limited): RSI = 54.54, Price = ₹980.90
# CENTURYPLY (Century Plyboards (India) Limited): RSI = 54.53, Price = ₹827.85
# WEL (Wonder Electricals Limited): RSI = 54.46, Price = ₹161.76
# IIFL (IIFL Finance Limited): RSI = 54.44, Price = ₹429.30
# EUREKAFORB (Eureka Forbes Limited): RSI = 54.42, Price = ₹590.90
# AMIORG (Ami Organics Limited): RSI = 54.41, Price = ₹2184.35
# ADANIENT (Adani Enterprises Limited): RSI = 54.31, Price = ₹2477.90
# KHANDSE (Khandwala Securities Limited): RSI = 54.26, Price = ₹28.36
# SUBROS (Subros Limited): RSI = 54.23, Price = ₹656.00
# IREDA (Indian Renewable Energy Development Agency Limited): RSI = 54.20, Price = ₹216.09
# DOLPHIN (Dolphin Offshore Enterprises (India) Limited): RSI = 54.09, Price = ₹562.05
# SINDHUTRAD (Sindhu Trade Links Limited): RSI = 54.07, Price = ₹23.78
# SHEKHAWATI (Shekhawati Industries Limited): RSI = 53.97, Price = ₹31.99
# XTGLOBAL (XTGlobal Infotech Limited): RSI = 53.96, Price = ₹43.69
# AARTIDRUGS (Aarti Drugs Limited): RSI = 53.86, Price = ₹442.25
# GLOBE (Globe Textiles (India) Limited): RSI = 53.85, Price = ₹5.13
# DSSL (Dynacons Systems & Solutions Limited): RSI = 53.83, Price = ₹1503.80
# ZEEL (Zee Entertainment Enterprises Limited): RSI = 53.76, Price = ₹132.74
# GRPLTD (GRP Limited): RSI = 53.70, Price = ₹3305.60
# AJANTPHARM (Ajanta Pharma Limited): RSI = 53.63, Price = ₹2935.20
# GRANULES (Granules India Limited): RSI = 53.46, Price = ₹606.00
# JINDRILL (Jindal Drilling & Industries Limited): RSI = 53.43, Price = ₹761.45
# WEWIN (We Win Limited): RSI = 53.36, Price = ₹88.76
# HOVS (HOV Services Limited): RSI = 53.33, Price = ₹74.97
# HEUBACHIND (Heubach Colorants India Limited): RSI = 53.30, Price = ₹546.75
# ROHLTD (Royal Orchid Hotels Limited): RSI = 53.28, Price = ₹361.00
# ARMANFIN (Arman Financial Services Limited): RSI = 53.27, Price = ₹1300.05
# SANOFICONR (N/A): RSI = 53.14, Price = ₹4888.50
# JINDALSTEL (Jindal Steel & Power Limited): RSI = 53.14, Price = ₹931.55
# RAINBOW (Rainbow Children's Medicare Limited): RSI = 53.10, Price = ₹1592.30
# KABRAEXTRU (Kabra Extrusiontechnik Limited): RSI = 53.10, Price = ₹525.20
# ITDCEM (ITD Cementation India Limited): RSI = 53.09, Price = ₹525.00
# SIGNATURE (Signatureglobal (India) Limited): RSI = 53.07, Price = ₹1308.70
# SEQUENT (Sequent Scientific Limited): RSI = 53.01, Price = ₹186.42
# YUKEN (Yuken India Limited): RSI = 52.86, Price = ₹1123.70
# BHARTIARTL (Bharti Airtel Limited): RSI = 52.69, Price = ₹1607.05
# AETHER (Aether Industries Limited): RSI = 52.69, Price = ₹902.90
# KMEW (Knowledge Marine & Engineering Works Limited): RSI = 52.68, Price = ₹2166.50
# BALKRISHNA (Balkrishna Paper Mills Limited): RSI = 52.67, Price = ₹24.59
# MANAKCOAT (Manaksia Coated Metals & Industries Limited): RSI = 52.66, Price = ₹111.55
# STARTECK (Starteck Finance Limited): RSI = 52.65, Price = ₹307.10
# INFOBEAN (InfoBeans Technologies Limited): RSI = 52.63, Price = ₹434.50
# RICOAUTO (Rico Auto Industries Limited): RSI = 52.59, Price = ₹89.79
# ASPINWALL (Aspinwall and Company Limited): RSI = 52.56, Price = ₹317.00
# MANINFRA (Man Infraconstruction Limited): RSI = 52.56, Price = ₹240.28
# ASTEC (Astec LifeSciences Limited): RSI = 52.44, Price = ₹1109.90
# DATAMATICS (Datamatics Global Services Limited): RSI = 52.38, Price = ₹662.05
# SAMMAANCAP (Sammaan Capital Limited): RSI = 52.38, Price = ₹156.01
# GLS (Alivus Life Sciences Limited): RSI = 52.34, Price = ₹1028.85
# HINDMOTORS (Hindustan Motors Limited): RSI = 52.30, Price = ₹26.61
# JCHAC (Johnson Controls-Hitachi Air Conditioning India Limited): RSI = 52.29, Price = ₹1840.85
# BEARDSELL (Beardsell Limited): RSI = 52.28, Price = ₹40.58
# IL&FSENGG (IL&FS Engineering and Construction Company Limited): RSI = 52.20, Price = ₹42.52
# APLLTD (Alembic Pharmaceuticals Limited): RSI = 52.19, Price = ₹1054.75
# KOHINOOR (Kohinoor Foods Limited): RSI = 52.18, Price = ₹41.15
# KAMDHENU (Kamdhenu Limited): RSI = 52.17, Price = ₹51.00
# CONTROLPR (Control Print Limited): RSI = 52.16, Price = ₹725.90
# HOMEFIRST (Home First Finance Company India Limited): RSI = 52.14, Price = ₹1041.00
# MGL (Mahanagar Gas Limited): RSI = 52.11, Price = ₹1270.65
# LTF (L&T Finance Limited): RSI = 52.03, Price = ₹142.70
# CHEMBOND (Chembond Chemicals Limited): RSI = 52.03, Price = ₹592.85
# KSCL (Kaveri Seed Company Limited): RSI = 52.00, Price = ₹926.90
# JISLDVREQS (Jain Irrigation Systems Limited): RSI = 51.98, Price = ₹37.11
# CHENNPETRO (Chennai Petroleum Corporation Limited): RSI = 51.94, Price = ₹612.15
# KFINTECH (KFin Technologies Limited): RSI = 51.88, Price = ₹1452.05
# INDSWFTLTD (Ind-Swift Limited): RSI = 51.77, Price = ₹28.65
# RAMKY (Ramky Infrastructure Limited): RSI = 51.76, Price = ₹631.60
# JTEKTINDIA (JTEKT India Limited): RSI = 51.72, Price = ₹163.39
# BLKASHYAP (B.L. Kashyap and Sons Limited): RSI = 51.70, Price = ₹78.68
# TANLA (Tanla Platforms Limited): RSI = 51.70, Price = ₹687.30
# ELGIRUBCO (Elgi Rubber Company Limited): RSI = 51.64, Price = ₹127.81
# AUTOAXLES (Automotive Axles Limited): RSI = 51.37, Price = ₹1795.00
# SASKEN (Sasken Technologies Limited): RSI = 51.34, Price = ₹2151.35
# UGROCAP (UGRO Capital Limited): RSI = 51.32, Price = ₹239.17
# MANINDS (Man Industries (India) Limited): RSI = 51.29, Price = ₹341.70
# CCCL (Consolidated Construction Consortium Limited): RSI = 51.29, Price = ₹17.46
# INDOWIND (Indowind Energy Limited): RSI = 51.26, Price = ₹24.92
# TATVA (Tatva Chintan Pharma Chem Limited): RSI = 51.26, Price = ₹865.35
# MAHASTEEL (Mahamaya Steel Industries Limited): RSI = 51.20, Price = ₹203.14
# MANAKALUCO (Manaksia Aluminium Company Limited): RSI = 51.18, Price = ₹30.14
# AZAD (N/A): RSI = 51.16, Price = ₹1750.05
# ABMINTLLTD (ABM International Limited): RSI = 51.12, Price = ₹66.85
# WELINV (Welspun Investments and Commercials Limited): RSI = 51.06, Price = ₹922.85
# TVSELECT (TVS Electronics Limited): RSI = 50.96, Price = ₹389.15
# SPAL (S.P. Apparels Limited): RSI = 50.92, Price = ₹934.45
# SUNPHARMA (Sun Pharmaceutical Industries Limited): RSI = 50.89, Price = ₹1826.35
# EMMBI (Emmbi Industries Limited): RSI = 50.89, Price = ₹147.90
# BLUEJET (Blue Jet Healthcare Limited): RSI = 50.68, Price = ₹582.60
# SBFC (SBFC Finance Limited): RSI = 50.61, Price = ₹87.03
# DBSTOCKBRO (DB (International) Stock Brokers Limited): RSI = 50.60, Price = ₹44.48
# GILLETTE (Gillette India Limited): RSI = 50.53, Price = ₹9717.30
# CAMPUS (Campus Activewear Limited): RSI = 50.47, Price = ₹288.35
# UBL (United Breweries Limited): RSI = 50.42, Price = ₹2023.45
# CINEVISTA (Cinevista Limited): RSI = 50.41, Price = ₹18.76
# CONFIPET (Confidence Petroleum India Limited): RSI = 50.40, Price = ₹73.02
# VINATIORGA (Vinati Organics Limited): RSI = 50.40, Price = ₹1739.65
# UNITDSPR (N/A): RSI = 50.37, Price = ₹1574.45
# SENCO (Senco Gold Limited): RSI = 50.32, Price = ₹1127.55
# JSWINFRA (JSW Infrastructure Limited): RSI = 50.29, Price = ₹314.05
# DGCONTENT (Digicontent Limited): RSI = 50.28, Price = ₹61.50
# AFCONS (N/A): RSI = 50.27, Price = ₹515.85
# DIVISLAB (Divi's Laboratories Limited): RSI = 50.22, Price = ₹5824.55
# AAVAS (Aavas Financiers Limited): RSI = 50.19, Price = ₹1679.75
# SDBL (Som Distilleries & Breweries Limited): RSI = 50.16, Price = ₹112.36
# AIAENG (AIA Engineering Limited): RSI = 50.14, Price = ₹3433.20
# HCLTECH (HCL Technologies Limited): RSI = 50.11, Price = ₹1934.80
# MRPL (Mangalore Refinery and Petrochemicals Limited): RSI = 50.08, Price = ₹145.99
# KANSAINER (Kansai Nerolac Paints Limited): RSI = 50.07, Price = ₹257.10
# DANGEE (Dangee Dums Limited): RSI = 50.00, Price = ₹7.06
# MBECL (McNally Bharat Engineering Company Limited): RSI = 50.00, Price = ₹4.28
# INDSWFTLAB (Ind-Swift Laboratories Limited): RSI = 49.98, Price = ₹105.00
# RPEL (Raghav Productivity Enhancers Limited): RSI = 49.95, Price = ₹730.30
# SUNDRMBRAK (Sundaram Brake Linings Limited): RSI = 49.91, Price = ₹1143.50
# ESTER (Ester Industries Limited): RSI = 49.84, Price = ₹156.44
# KAPSTON (Kapston Services Limited): RSI = 49.83, Price = ₹262.65
# MUTHOOTFIN (Muthoot Finance Limited): RSI = 49.82, Price = ₹2135.10
# SSWL (Steel Strips Wheels Limited): RSI = 49.80, Price = ₹199.24
# KNRCON (KNR Constructions Limited): RSI = 49.79, Price = ₹335.60
# MAHESHWARI (Maheshwari Logistics Limited): RSI = 49.77, Price = ₹62.05
# DCAL (Dishman Carbogen Amcis Limited): RSI = 49.73, Price = ₹276.00
# IXIGO (N/A): RSI = 49.71, Price = ₹158.03
# LINDEINDIA (Linde India Limited): RSI = 49.62, Price = ₹6456.15
# HUBTOWN (Hubtown Limited): RSI = 49.60, Price = ₹283.95
# HYUNDAI (N/A): RSI = 49.59, Price = ₹1785.55
# SANGAMIND (Sangam (India) Limited): RSI = 49.58, Price = ₹414.35
# RVTH (Revathi Equipment India Limited): RSI = 49.51, Price = ₹2056.60
# CEATLTD (CEAT Limited): RSI = 49.51, Price = ₹3115.15
# THEMISMED (Themis Medicare Limited): RSI = 49.50, Price = ₹271.25
# ACMESOLAR (N/A): RSI = 49.45, Price = ₹238.10
# RACE (Race Eco Chain Limited): RSI = 49.44, Price = ₹345.35
# RAJTV (Raj Television Network Limited): RSI = 49.43, Price = ₹79.30
# ZENSARTECH (Zensar Technologies Limited): RSI = 49.43, Price = ₹775.90
# SIGMA (Sigma Solve Limited): RSI = 49.38, Price = ₹345.35
# AARON (Aaron Industries Limited): RSI = 49.30, Price = ₹357.15
# RKFORGE (Ramkrishna Forgings Limited): RSI = 49.26, Price = ₹903.70
# TI (Tilaknagar Industries Ltd.): RSI = 49.17, Price = ₹415.30
# JAYNECOIND (Jayaswal Neco Industries Limited): RSI = 49.15, Price = ₹40.33
# IDEAFORGE (ideaForge Technology Limited): RSI = 49.12, Price = ₹601.70
# SALZERELEC (Salzer Electronics Limited): RSI = 49.11, Price = ₹1448.90
# REFEX (Refex Industries Limited): RSI = 49.11, Price = ₹500.75
# ARTEMISMED (Artemis Medicare Services Limited): RSI = 49.10, Price = ₹334.55
# EMAMILTD (Emami Limited): RSI = 49.04, Price = ₹595.75
# ESAFSFB (ESAF Small Finance Bank): RSI = 49.03, Price = ₹38.93
# INDOCO (Indoco Remedies Limited): RSI = 49.03, Price = ₹334.15
# MEDIASSIST (N/A): RSI = 49.01, Price = ₹605.40
# STEELCAS (Steelcast Limited): RSI = 48.99, Price = ₹893.50
# WELCORP (Welspun Corp Limited): RSI = 48.99, Price = ₹774.35
# IMPEXFERRO (Impex Ferro Tech Limited): RSI = 48.98, Price = ₹2.91
# STCINDIA (The State Trading Corporation of India Limited): RSI = 48.92, Price = ₹158.57
# LUMAXTECH (Lumax Auto Technologies Limited): RSI = 48.90, Price = ₹628.80
# LINCOLN (Lincoln Pharmaceuticals Limited): RSI = 48.86, Price = ₹807.70
# VINEETLAB (Vineet Laboratories Limited): RSI = 48.85, Price = ₹58.02
# UNITEDTEA (The United Nilgiri Tea Estates Company Limited): RSI = 48.83, Price = ₹543.90
# KRN (N/A): RSI = 48.82, Price = ₹731.20
# AARTIIND (Aarti Industries Limited): RSI = 48.71, Price = ₹413.40
# AUROPHARMA (Aurobindo Pharma Limited): RSI = 48.70, Price = ₹1248.40
# GOCOLORS (Go Fashion (India) Limited): RSI = 48.69, Price = ₹993.70
# DEEPAKFERT (Deepak Fertilisers And Petrochemicals Corporation Limited): RSI = 48.63, Price = ₹1179.20
# ACCELYA (Accelya Solutions India Limited): RSI = 48.61, Price = ₹1525.70
# VOLTAS (Voltas Limited): RSI = 48.60, Price = ₹1727.90
# AJMERA (Ajmera Realty & Infra India Limited): RSI = 48.58, Price = ₹1110.05
# INTERARCH (N/A): RSI = 48.57, Price = ₹1685.50
# TARSONS (Tarsons Products Limited): RSI = 48.56, Price = ₹407.35
# RESPONIND (Responsive Industries Limited): RSI = 48.55, Price = ₹261.31
# ICICIGI (ICICI Lombard General Insurance Company Limited): RSI = 48.53, Price = ₹1888.25
# LALPATHLAB (Dr. Lal PathLabs Limited): RSI = 48.53, Price = ₹3004.25
# GODREJAGRO (Godrej Agrovet Limited): RSI = 48.50, Price = ₹743.20
# SUNDARMFIN (Sundaram Finance Limited): RSI = 48.48, Price = ₹4475.95
# SAMHI (SAMHI Hotels Limited): RSI = 48.38, Price = ₹200.99
# FORCEMOT (Force Motors Limited): RSI = 48.36, Price = ₹6544.20
# MANGALAM (Mangalam Drugs & Organics Limited): RSI = 48.36, Price = ₹115.32
# DCMSHRIRAM (DCM Shriram Limited): RSI = 48.30, Price = ₹1072.05
# ISEC (ICICI Securities Limited): RSI = 48.29, Price = ₹839.40
# KELLTONTEC (Kellton Tech Solutions Limited): RSI = 48.29, Price = ₹160.32
# TARAPUR (Tarapur Transformers Limited): RSI = 48.28, Price = ₹45.98
# BAJAJHLDNG (Bajaj Holdings & Investment Limited): RSI = 48.27, Price = ₹11168.90
# LUMAXIND (Lumax Industries Limited): RSI = 48.20, Price = ₹2461.80
# TRIGYN (Trigyn Technologies Limited): RSI = 48.16, Price = ₹110.65
# GENSOL (Gensol Engineering Limited): RSI = 48.15, Price = ₹753.55
# INTLCONV (International Conveyors Limited): RSI = 48.13, Price = ₹84.64
# RAJRATAN (Rajratan Global Wire Limited): RSI = 48.11, Price = ₹487.35
# SAGCEM (Sagar Cements Limited): RSI = 48.09, Price = ₹220.83
# MITTAL (Mittal Life Style Limited): RSI = 48.08, Price = ₹2.09
# BLUESTARCO (Blue Star Limited): RSI = 48.07, Price = ₹2013.10
# BIRLACORPN (Birla Corporation Limited): RSI = 48.06, Price = ₹1230.55
# BLISSGVS (Bliss GVS Pharma Limited): RSI = 47.94, Price = ₹166.95
# WCIL (N/A): RSI = 47.93, Price = ₹112.63
# ASKAUTOLTD (N/A): RSI = 47.89, Price = ₹476.70
# WINDLAS (Windlas Biotech Limited): RSI = 47.85, Price = ₹1016.05
# SURANAT&P (Surana Telecom and Power Limited): RSI = 47.85, Price = ₹23.63
# ASIANENE (Asian Energy Services Limited): RSI = 47.80, Price = ₹393.75
# AADHARHFC (N/A): RSI = 47.75, Price = ₹422.45
# MANORG (Mangalam Organics Limited): RSI = 47.75, Price = ₹421.45
# RBA (Restaurant Brands Asia Limited): RSI = 47.73, Price = ₹79.63
# RIIL (Reliance Industrial Infrastructure Limited): RSI = 47.67, Price = ₹1088.45
# TIL (TIL Limited): RSI = 47.65, Price = ₹307.85
# PSPPROJECT (PSP Projects Limited): RSI = 47.62, Price = ₹680.35
# RPSGVENT (RPSG Ventures Limited): RSI = 47.58, Price = ₹1078.45
# CORALFINAC (Coral India Finance and Housing Limited): RSI = 47.52, Price = ₹52.20
# RAYMOND (Raymond Limited): RSI = 47.49, Price = ₹1675.10
# SHALBY (Shalby Limited): RSI = 47.48, Price = ₹228.61
# DEEPINDS (Deep Industries Limited): RSI = 47.45, Price = ₹589.50
# SREEL (Sreeleathers Limited): RSI = 47.43, Price = ₹263.00
# SAMBHAAV (Sambhaav Media Limited): RSI = 47.42, Price = ₹7.78
# TFCILTD (Tourism Finance Corporation of India Limited): RSI = 47.41, Price = ₹164.83
# BEDMUTHA (Bedmutha Industries Limited): RSI = 47.37, Price = ₹202.02
# VARROC (Varroc Engineering Limited): RSI = 47.33, Price = ₹612.15
# HPIL (Hindprakash Industries Limited): RSI = 47.32, Price = ₹152.62
# INNOVANA (N/A): RSI = 47.29, Price = ₹459.85
# ALKEM (Alkem Laboratories Limited): RSI = 47.28, Price = ₹5453.95
# AVANTIFEED (Avanti Feeds Limited): RSI = 47.28, Price = ₹620.65
# GREENLAM (Greenlam Industries Limited): RSI = 47.27, Price = ₹557.30
# IRB (IRB Infrastructure Developers Limited): RSI = 47.26, Price = ₹55.51
# CRISIL (CRISIL Limited): RSI = 47.22, Price = ₹5673.70
# LASA (Lasa Supergenerics Limited): RSI = 47.21, Price = ₹28.44
# RITCO (Ritco Logistics Limited): RSI = 47.16, Price = ₹397.05
# UMESLTD (Usha Martin Education & Solutions Limited): RSI = 47.15, Price = ₹6.82
# RELINFRA (Reliance Infrastructure Limited): RSI = 47.13, Price = ₹287.05
# AFFORDABLE (Affordable Robotic & Automation Limited): RSI = 47.11, Price = ₹636.10
# RALLIS (Rallis India Limited): RSI = 47.11, Price = ₹297.15
# HARRMALAYA (Harrisons Malayalam Limited): RSI = 47.06, Price = ₹313.30
# ADORWELD (Ador Welding Limited): RSI = 47.02, Price = ₹1100.00
# ZYDUSWELL (Zydus Wellness Limited): RSI = 47.01, Price = ₹1952.05
# HMAAGRO (HMA Agro Industries Limited): RSI = 46.97, Price = ₹39.63
# VIMTALABS (Vimta Labs Limited): RSI = 46.95, Price = ₹980.65
# RPGLIFE (RPG Life Sciences Limited): RSI = 46.93, Price = ₹2209.45
# RELIABLE (Reliable Data Services Limited): RSI = 46.92, Price = ₹71.75
# MMTC (MMTC Limited): RSI = 46.91, Price = ₹74.46
# SHYAMMETL (Shyam Metalics and Energy Limited): RSI = 46.91, Price = ₹785.30
# GOCLCORP (GOCL Corporation Limited): RSI = 46.88, Price = ₹373.40
# MOKSH (Moksh Ornaments Limited): RSI = 46.87, Price = ₹18.73
# MHRIL (Mahindra Holidays & Resorts India Limited): RSI = 46.80, Price = ₹367.35
# BANSALWIRE (N/A): RSI = 46.79, Price = ₹438.35
# TEXMOPIPES (Texmo Pipes and Products Limited): RSI = 46.70, Price = ₹65.58
# LYPSAGEMS (Lypsa Gems & Jewellery Limited): RSI = 46.64, Price = ₹7.45
# VAIBHAVGBL (Vaibhav Global Limited): RSI = 46.64, Price = ₹295.95
# BORORENEW (Borosil Renewables Limited): RSI = 46.63, Price = ₹596.80
# TATAINVEST (Tata Investment Corporation Limited): RSI = 46.62, Price = ₹6556.10
# FINOPB (Fino Payments Bank Limited): RSI = 46.57, Price = ₹315.85
# UNIDT (United Drilling Tools Limited): RSI = 46.56, Price = ₹262.20
# GPTHEALTH (GPT Healthcare Limited): RSI = 46.54, Price = ₹177.78
# STARCEMENT (Star Cement Limited): RSI = 46.52, Price = ₹216.90
# SRM (N/A): RSI = 46.48, Price = ₹373.95
# THANGAMAYL (Thangamayil Jewellery Limited): RSI = 46.45, Price = ₹1966.80
# BIL (Bhartiya International Ltd.): RSI = 46.41, Price = ₹802.55
# DEN (DEN Networks Limited): RSI = 46.39, Price = ₹42.33
# LTFOODS (LT Foods Limited): RSI = 46.33, Price = ₹409.70
# WOCKPHARMA (Wockhardt Limited): RSI = 46.33, Price = ₹1443.05
# REDINGTON (Redington Limited): RSI = 46.32, Price = ₹203.25
# MODIRUBBER (Modi Rubber Limited): RSI = 46.28, Price = ₹121.70
# MOIL (MOIL Limited): RSI = 46.28, Price = ₹337.40
# GOLDENTOBC (Golden Tobacco Limited): RSI = 46.25, Price = ₹39.40
# ATGL (Adani Total Gas Limited): RSI = 46.25, Price = ₹682.15
# CHEMCON (Chemcon Speciality Chemicals Limited): RSI = 46.23, Price = ₹229.62
# AVL (Aditya Vision Limited): RSI = 46.23, Price = ₹500.25
# ZAGGLE (Zaggle Prepaid Ocean Services Limited): RSI = 46.22, Price = ₹516.15
# MADRASFERT (Madras Fertilizers Limited): RSI = 46.14, Price = ₹98.15
# EIHAHOTELS (EIH Associated Hotels Limited): RSI = 46.14, Price = ₹406.60
# HEIDELBERG (HeidelbergCement India Limited): RSI = 46.14, Price = ₹213.34
# CUPID (Cupid Limited): RSI = 46.13, Price = ₹78.33
# INDIAMART (IndiaMART InterMESH Limited): RSI = 46.12, Price = ₹2322.30
# ADANIPOWER (Adani Power Limited): RSI = 46.11, Price = ₹497.90
# SAHYADRI (Sahyadri Industries Limited): RSI = 46.10, Price = ₹309.60
# RELIGARE (Religare Enterprises Limited): RSI = 46.09, Price = ₹295.15
# KEI (KEI Industries Limited): RSI = 46.08, Price = ₹4202.95
# EXICOM (Exicom Tele-Systems Limited): RSI = 46.07, Price = ₹262.59
# SATIN (Satin Creditcare Network Limited): RSI = 46.06, Price = ₹152.74
# EXXARO (Exxaro Tiles Limited): RSI = 46.06, Price = ₹9.02
# ENTERO (Entero Healthcare Solutions Limited): RSI = 46.01, Price = ₹1448.35
# JAMNAAUTO (Jamna Auto Industries Limited): RSI = 46.01, Price = ₹97.47
# SICALLOG (Sical Logistics Limited): RSI = 46.01, Price = ₹142.98
# RSSOFTWARE (R S Software (India) Limited): RSI = 45.96, Price = ₹199.45
# GROBTEA (The Grob Tea Company Limited): RSI = 45.96, Price = ₹1231.95
# MAXESTATES (N/A): RSI = 45.96, Price = ₹602.60
# SUNTECK (Sunteck Realty Limited): RSI = 45.94, Price = ₹494.05
# GAYAPROJ (Gayatri Projects Limited): RSI = 45.94, Price = ₹8.60
# RCF (Rashtriya Chemicals and Fertilizers Limited): RSI = 45.94, Price = ₹174.82
# COSMOFIRST (Cosmo First Limited): RSI = 45.89, Price = ₹943.50
# AROGRANITE (Aro Granite Industries Limited): RSI = 45.88, Price = ₹46.63
# DIGISPICE (DiGiSPICE Technologies Limited): RSI = 45.84, Price = ₹30.16
# SANSTAR (N/A): RSI = 45.83, Price = ₹118.20
# KRSNAA (Krsnaa Diagnostics Limited): RSI = 45.82, Price = ₹898.15
# SARDAEN (Sarda Energy & Minerals Limited): RSI = 45.75, Price = ₹471.70
# XCHANGING (Xchanging Solutions Limited): RSI = 45.74, Price = ₹110.55
# JLHL (Jupiter Life Line Hospitals Limited): RSI = 45.74, Price = ₹1549.60
# RATEGAIN (RateGain Travel Technologies Limited): RSI = 45.73, Price = ₹714.80
# SOTL (Savita Oil Technologies Limited): RSI = 45.73, Price = ₹550.65
# TIMESGTY (Times Guaranty Limited): RSI = 45.69, Price = ₹164.72
# BALKRISIND (Balkrishna Industries Limited): RSI = 45.69, Price = ₹2779.05
# GRMOVER (GRM Overseas Limited): RSI = 45.68, Price = ₹191.27
# EQUIPPP (Equippp Social Impact Technologies Limited): RSI = 45.67, Price = ₹24.98
# SOMICONVEY (Somi Conveyor Beltings Limited): RSI = 45.67, Price = ₹201.93
# BASML (Bannari Amman Spinning Mills Ltd): RSI = 45.66, Price = ₹51.90
# AGROPHOS (Agro Phos (India) Limited): RSI = 45.65, Price = ₹40.24
# SHARDACROP (Sharda Cropchem Limited): RSI = 45.64, Price = ₹808.10
# DELTAMAGNT (Delta Manufacturing Limited): RSI = 45.63, Price = ₹107.20
# SHILPAMED (Shilpa Medicare Limited): RSI = 45.61, Price = ₹808.75
# CLEAN (Clean Science and Technology Limited): RSI = 45.61, Price = ₹1443.00
# SHRIPISTON (Shriram Pistons & Rings Limited): RSI = 45.59, Price = ₹2092.30
# UMAEXPORTS (Uma Exports Limited): RSI = 45.58, Price = ₹107.22
# DICIND (DIC India Limited): RSI = 45.58, Price = ₹673.40
# MOHITIND (Mohit Industries Limited): RSI = 45.53, Price = ₹36.27
# WEALTH (Wealth First Portfolio Managers Limited): RSI = 45.48, Price = ₹1539.90
# TECHNOE (Techno Electric & Engineering Company Limited): RSI = 45.47, Price = ₹1485.70
# GALLANTT (Gallantt Ispat Limited): RSI = 45.46, Price = ₹340.65
# MANKIND (Mankind Pharma Limited): RSI = 45.45, Price = ₹2828.05
# AMBICAAGAR (Ambica Agarbathies Aroma & Industries Limited): RSI = 45.41, Price = ₹30.58
# GNA (G N A Axles Limited): RSI = 45.41, Price = ₹407.25
# SMLT (Sarthak Metals Limited): RSI = 45.37, Price = ₹156.96
# HAPPYFORGE (N/A): RSI = 45.37, Price = ₹1010.25
# SAMPANN (Sampann Utpadan India Limited): RSI = 45.36, Price = ₹38.67
# SMSPHARMA (SMS Pharmaceuticals Limited): RSI = 45.34, Price = ₹233.33
# BAJAJ-AUTO (Bajaj Auto Limited): RSI = 45.32, Price = ₹8835.85
# BDL (Bharat Dynamics Limited): RSI = 45.31, Price = ₹1203.25
# BLSE (N/A): RSI = 45.30, Price = ₹206.15
# HITECHGEAR (The Hi-Tech Gears Limited): RSI = 45.29, Price = ₹830.30
# LGBBROSLTD (L.G. Balakrishnan & Bros Limited): RSI = 45.26, Price = ₹1283.75
# WILLAMAGOR (Williamson Magor & Co. Limited): RSI = 45.24, Price = ₹38.05
# IRISDOREME (Iris Clothings Limited): RSI = 45.17, Price = ₹61.41
# KANORICHEM (Kanoria Chemicals & Industries Limited): RSI = 45.16, Price = ₹115.32
# VENUSPIPES (Venus Pipes and Tubes Limited): RSI = 45.11, Price = ₹1566.90
# GICHSGFIN (GIC Housing Finance Limited): RSI = 45.10, Price = ₹200.77
# TGBHOTELS (TGB Banquets and Hotels Limited): RSI = 45.09, Price = ₹13.86
# DIAMINESQ (Diamines and Chemicals Limited): RSI = 45.06, Price = ₹491.20
# SOFTTECH (SoftTech Engineers Limited): RSI = 45.06, Price = ₹471.30
# ELECON (Elecon Engineering Company Limited): RSI = 45.03, Price = ₹605.30
# ASHOKLEY (Ashok Leyland Limited): RSI = 45.00, Price = ₹214.40
# BAJAJHCARE (Bajaj HealthCare Limited): RSI = 44.99, Price = ₹545.60
# APEX (Apex Frozen Foods Limited): RSI = 44.98, Price = ₹249.30
# BCONCEPTS (Brand Concepts Limited): RSI = 44.96, Price = ₹474.75
# VIRINCHI (Virinchi Limited): RSI = 44.96, Price = ₹28.08
# METROBRAND (Metro Brands Limited): RSI = 44.95, Price = ₹1270.50
# HAPPSTMNDS (N/A): RSI = 44.92, Price = ₹708.10
# HCL-INSYS (HCL Infosystems Limited): RSI = 44.88, Price = ₹15.58
# SYRMA (Syrma SGS Technology Limited): RSI = 44.82, Price = ₹594.75
# ENIL (Entertainment Network (India) Limited): RSI = 44.80, Price = ₹175.99
# SUMIT (Sumit Woods Limited): RSI = 44.80, Price = ₹144.84
# SUDARSCHEM (Sudarshan Chemical Industries Limited): RSI = 44.79, Price = ₹1116.25
# FOSECOIND (Foseco India Limited): RSI = 44.78, Price = ₹4191.35
# TOUCHWOOD (Touchwood Entertainment Limited): RSI = 44.77, Price = ₹147.92
# RKEC (RKEC Projects Limited): RSI = 44.76, Price = ₹96.01
# RKSWAMY (N/A): RSI = 44.76, Price = ₹259.70
# GULPOLY (Gulshan Polyols Limited): RSI = 44.73, Price = ₹173.94
# MAHSCOOTER (Maharashtra Scooters Ltd.): RSI = 44.71, Price = ₹9551.80
# CTE (Cambridge Technology Enterprises Limited): RSI = 44.64, Price = ₹105.50
# APLAPOLLO (APL Apollo Tubes Limited): RSI = 44.58, Price = ₹1550.80
# AIRAN (Airan Limited): RSI = 44.58, Price = ₹34.61
# GPTINFRA (GPT Infraprojects Limited): RSI = 44.56, Price = ₹137.68
# AMDIND (AMD Industries Limited): RSI = 44.51, Price = ₹60.70
# KREBSBIO (Krebs Biochemicals & Industries Limited): RSI = 44.50, Price = ₹95.25
# ALKYLAMINE (Alkyl Amines Chemicals Limited): RSI = 44.48, Price = ₹1870.20
# CASTROLIND (Castrol India Limited): RSI = 44.48, Price = ₹198.34
# AAREYDRUGS (Aarey Drugs & Pharmaceuticals Limited): RSI = 44.46, Price = ₹56.70
# AHLADA (Ahlada Engineers Limited): RSI = 44.39, Price = ₹92.91
# MICEL (MIC Electronics Limited): RSI = 44.39, Price = ₹83.20
# CIPLA (Cipla Limited): RSI = 44.36, Price = ₹1488.20
# MITCON (MITCON Consultancy & Engineering Services Limited): RSI = 44.36, Price = ₹112.53
# CROWN (Crown Lifters Limited): RSI = 44.35, Price = ₹203.32
# LATENTVIEW (Latent View Analytics Limited): RSI = 44.31, Price = ₹470.55
# BANARBEADS (Banaras Beads Limited): RSI = 44.28, Price = ₹129.18
# SAH (Sah Polymers Limited): RSI = 44.23, Price = ₹87.86
# COUNCODOS (Country Condo's Limited): RSI = 44.22, Price = ₹6.40
# ALANKIT (Alankit Limited): RSI = 44.21, Price = ₹21.16
# TOLINS (N/A): RSI = 44.17, Price = ₹201.17
# STYLEBAAZA (Baazar Style Retail Limited): RSI = 44.17, Price = ₹317.40
# BHARTIHEXA (N/A): RSI = 44.16, Price = ₹1475.65
# DBEIL (N/A): RSI = 44.13, Price = ₹183.14
# GUJGASLTD (Gujarat Gas Limited): RSI = 44.10, Price = ₹498.80
# GMMPFAUDLR (GMM Pfaudler Limited): RSI = 44.09, Price = ₹1218.15
# ANDHRSUGAR (The Andhra Sugars Limited): RSI = 44.08, Price = ₹93.51
# RRKABEL (R R Kabel Limited): RSI = 44.08, Price = ₹1385.55
# MOTISONS (N/A): RSI = 44.08, Price = ₹26.89
# SWARAJENG (Swaraj Engines Limited): RSI = 44.07, Price = ₹3018.95
# SIKKO (Sikko Industries Limited): RSI = 44.04, Price = ₹95.36
# MANAKSIA (Manaksia Limited): RSI = 44.03, Price = ₹85.03
# FACT (The Fertilisers and Chemicals Travancore Limited): RSI = 44.03, Price = ₹962.45
# GENUSPOWER (Genus Power Infrastructures Limited): RSI = 44.00, Price = ₹384.00
# HPAL (HP Adhesives Limited): RSI = 43.99, Price = ₹77.53
# ICICIPRULI (ICICI Prudential Life Insurance Company Limited): RSI = 43.94, Price = ₹646.85
# JBCHEPHARM (J. B. Chemicals & Pharmaceuticals Limited): RSI = 43.90, Price = ₹1870.30
# TEMBO (Tembo Global Industries Limited): RSI = 43.83, Price = ₹764.35
# TRACXN (Tracxn Technologies Limited): RSI = 43.82, Price = ₹73.34
# CCHHL (Country Club Hospitality & Holidays Limited): RSI = 43.78, Price = ₹19.40
# MANAPPURAM (Manappuram Finance Limited): RSI = 43.77, Price = ₹179.00
# BANCOINDIA (Banco Products (India) Limited): RSI = 43.76, Price = ₹487.45
# SHIVATEX (Shiva Texyarn Limited): RSI = 43.75, Price = ₹221.75
# SHALPAINTS (Shalimar Paints Limited): RSI = 43.72, Price = ₹125.70
# RBLBANK (RBL Bank Limited): RSI = 43.71, Price = ₹158.38
# KIRLOSBROS (Kirloskar Brothers Limited): RSI = 43.67, Price = ₹2132.45
# TRF (TRF Limited): RSI = 43.61, Price = ₹418.35
# MUKKA (Mukka Proteins Limited): RSI = 43.60, Price = ₹38.20
# JASH (Jash Engineering Limited): RSI = 43.58, Price = ₹581.35
# KHAITANLTD (Khaitan (India) Limited): RSI = 43.57, Price = ₹86.67
# UNIECOM (N/A): RSI = 43.56, Price = ₹163.92
# MAYURUNIQ (Mayur Uniquoters Limited): RSI = 43.54, Price = ₹593.45
# CAREERP (Career Point Limited): RSI = 43.53, Price = ₹389.05
# KANPRPLA (Kanpur Plastipack Limited): RSI = 43.51, Price = ₹125.28
# BALPHARMA (Bal Pharma Limited): RSI = 43.49, Price = ₹117.44
# ARCHIDPLY (Archidply Industries Limited): RSI = 43.47, Price = ₹106.43
# ALBERTDAVD (Albert David Limited): RSI = 43.35, Price = ₹1301.35
# USHAMART (Usha Martin Limited): RSI = 43.34, Price = ₹361.75
# SRGHFL (SRG Housing Finance Limited): RSI = 43.33, Price = ₹371.70
# AIROLAM (Airo Lam Limited): RSI = 43.33, Price = ₹127.56
# GOKULAGRO (Gokul Agro Resources Limited): RSI = 43.31, Price = ₹352.55
# MEDPLUS (MedPlus Health Services Limited): RSI = 43.31, Price = ₹842.05
# GINNIFILA (Ginni Filaments Limited): RSI = 43.31, Price = ₹31.22
# CHOICEIN (Choice International Limited): RSI = 43.25, Price = ₹532.95
# MACPOWER (Macpower CNC Machines Limited): RSI = 43.24, Price = ₹1384.90
# INFY (Infosys Limited): RSI = 43.19, Price = ₹1917.30
# HINDNATGLS (Hindusthan National Glass & Industries Limited): RSI = 43.17, Price = ₹23.23
# LOTUSEYE (Lotus Eye Hospital and Institute Limited): RSI = 43.16, Price = ₹68.78
# CIEINDIA (CIE Automotive India Limited): RSI = 43.13, Price = ₹460.70
# SUMICHEM (Sumitomo Chemical India Limited): RSI = 43.11, Price = ₹498.25
# RAYMONDLSL (Raymond Lifestyle Limited): RSI = 43.05, Price = ₹1979.95
# VENKEYS (Venky's (India) Limited): RSI = 43.03, Price = ₹1763.05
# STYRENIX (Styrenix Performance Materials Limited): RSI = 43.01, Price = ₹2984.10
# LYKALABS (Lyka Labs Limited): RSI = 42.98, Price = ₹147.88
# AGRITECH (Agri-tech (India) Limited): RSI = 42.97, Price = ₹192.53
# CARERATING (CARE Ratings Limited): RSI = 42.96, Price = ₹1328.70
# RADIANTCMS (Radiant Cash Management Services Limited): RSI = 42.94, Price = ₹75.49
# ASAHISONG (Asahi Songwon Colors Limited): RSI = 42.92, Price = ₹355.95
# SIMPLEXINF (Simplex Infrastructures Limited): RSI = 42.89, Price = ₹324.85
# BALAMINES (Balaji Amines Limited): RSI = 42.87, Price = ₹1909.05
# DALBHARAT (Dalmia Bharat Limited): RSI = 42.87, Price = ₹1802.30
# SHRENIK (Shrenik Limited): RSI = 42.86, Price = ₹0.78
# SUVEN (Suven Life Sciences Limited): RSI = 42.85, Price = ₹134.42
# DIGIDRIVE (Digidrive Distributors Limited): RSI = 42.84, Price = ₹43.13
# SIRCA (Sirca Paints India Limited): RSI = 42.82, Price = ₹316.55
# SURAJEST (N/A): RSI = 42.81, Price = ₹585.25
# IMFA (Indian Metals and Ferro Alloys Limited): RSI = 42.80, Price = ₹899.25
# HITECHCORP (Hitech Corporation Limited): RSI = 42.80, Price = ₹238.13
# MOL (Meghmani Organics Limited): RSI = 42.79, Price = ₹81.19
# SEJALLTD (Sejal Glass Limited): RSI = 42.76, Price = ₹579.95
# XPROINDIA (Xpro India Limited): RSI = 42.73, Price = ₹1528.10
# WHEELS (Wheels India Limited): RSI = 42.71, Price = ₹694.45
# FIVESTAR (Five-Star Business Finance Limited): RSI = 42.66, Price = ₹719.90
# VSTTILLERS (V.S.T. Tillers Tractors Limited): RSI = 42.64, Price = ₹4888.50
# GANGESSECU (Ganges Securities Limited): RSI = 42.58, Price = ₹191.26
# KALAMANDIR (Sai Silks (Kalamandir) Limited): RSI = 42.57, Price = ₹167.28
# DVL (Dhunseri Ventures Limited): RSI = 42.56, Price = ₹361.00
# SHIVAMAUTO (Shivam Autotech Limited): RSI = 42.55, Price = ₹43.77
# GSFC (Gujarat State Fertilizers & Chemicals Limited): RSI = 42.54, Price = ₹204.00
# BLS (BLS International Services Limited): RSI = 42.49, Price = ₹467.20
# HECPROJECT (HEC Infra Projects Limited): RSI = 42.48, Price = ₹117.60
# SINTERCOM (Sintercom India Limited): RSI = 42.46, Price = ₹162.40
# JHS (JHS Svendgaard Laboratories Limited): RSI = 42.44, Price = ₹20.50
# BALAXI (Balaxi Pharmaceuticals Limited): RSI = 42.43, Price = ₹74.96
# KPIGREEN (KPI Green Energy Limited): RSI = 42.41, Price = ₹483.10
# SNOWMAN (Snowman Logistics Limited): RSI = 42.40, Price = ₹67.09
# SHREDIGCEM (Shree Digvijay Cement Company Limited): RSI = 42.38, Price = ₹83.66
# DONEAR (Donear Industries Limited): RSI = 42.37, Price = ₹157.68
# ...
# 502587 (N/A): RSI = 46.40, Price = ₹70.11
# 539437 (IDFC First Bank Limited): RSI = 46.39, Price = ₹62.65
# 540175 (Regency Fincorp Limited): RSI = 46.35, Price = ₹39.80
# 532430 (BF Utilities Limited): RSI = 46.30, Price = ₹959.50
# 511411 (N/A): RSI = 46.28, Price = ₹44.00
# 538890 (M.K. Exim (India) Limited): RSI = 46.26, Price = ₹86.29
# 538812 (Aanchal Ispat Limited): RSI = 46.25, Price = ₹5.19
# 532933 (N/A): RSI = 46.24, Price = ₹57.72
# 539354 (Polyspin Exports Limited): RSI = 46.22, Price = ₹41.00
# 507410 (Walchandnagar Industries Limited): RSI = 46.22, Price = ₹270.15
# 533761 (GPT Infraprojects Limited): RSI = 46.22, Price = ₹142.20
# 500068 (N/A): RSI = 46.20, Price = ₹16330.00
# 535601 (Sreeleathers Limited): RSI = 46.14, Price = ₹254.05
# 536264 (Tiger Logistics (India) Limited): RSI = 46.13, Price = ₹70.20
# 506122 (Kairosoft AI Solutions Limited): RSI = 46.07, Price = ₹165.80
# 533203 (Tarapur Transformers Limited): RSI = 46.07, Price = ₹46.32
# 526550 (Country Club Hospitality & Holidays Limited): RSI = 46.01, Price = ₹19.89
# 539400 (Mallcom (India) Limited): RSI = 45.89, Price = ₹1488.65
# 526751 (N/A): RSI = 45.83, Price = ₹26.16
# 522004 (N/A): RSI = 45.81, Price = ₹130.15
# 532355 (Picturehouse Media Limited): RSI = 45.78, Price = ₹9.20
# 511359 (N/A): RSI = 45.78, Price = ₹91.83
# 500367 (N/A): RSI = 45.72, Price = ₹79.92
# 532616 (Xchanging Solutions Limited): RSI = 45.70, Price = ₹112.85
# 590025 (Ginni Filaments Limited): RSI = 45.70, Price = ₹31.29
# 537253 (Sunil Healthcare Limited): RSI = 45.67, Price = ₹80.00
# 506365 (N/A): RSI = 45.64, Price = ₹98.15
# 532373 (WeP Solutions Limited): RSI = 45.64, Price = ₹34.10
# 534708 (Shanti Guru Industries Limited): RSI = 45.64, Price = ₹12.38
# 540173 (PNB Housing Finance Limited): RSI = 45.63, Price = ₹873.75
# 531867 (N/A): RSI = 45.61, Price = ₹5.14
# 531672 (N/A): RSI = 45.60, Price = ₹29.00
# 505250 (N/A): RSI = 45.58, Price = ₹117.85
# 526143 (MPL Plastics Limited): RSI = 45.39, Price = ₹12.64
# 523248 (N/A): RSI = 45.37, Price = ₹241.00
# 539255 (Star Delta Transformers Limited): RSI = 45.37, Price = ₹953.20
# 539399 (Bella Casa Fashion & Retail Limited): RSI = 45.29, Price = ₹578.45
# 500168 (Goodyear India Limited): RSI = 45.28, Price = ₹1019.30
# 533407 (True Green Bio Energy Limited): RSI = 45.27, Price = ₹113.35
# 590109 (Nippon India ETF Nifty 50 Shariah BeES): RSI = 45.25, Price = ₹536.92
# 540405 (Oceanic Foods Limited): RSI = 45.25, Price = ₹50.00
# 532320 (Vaarad Ventures Limited): RSI = 45.24, Price = ₹12.60
# 501833 (Chowgule Steamships Limited): RSI = 45.09, Price = ₹27.88
# 500165 (Kansai Nerolac Paints Limited): RSI = 45.08, Price = ₹257.50
# 526881 (63 moons technologies limited): RSI = 45.08, Price = ₹904.00
# 541702 (N/A): RSI = 44.92, Price = ₹4.40
# 524136 (N/A): RSI = 44.90, Price = ₹598.55
# 526981 (N/A): RSI = 44.88, Price = ₹217.60
# 523694 (Apcotex Industries Limited): RSI = 44.86, Price = ₹367.90
# 500420 (Torrent Pharmaceuticals Limited): RSI = 44.85, Price = ₹3325.25
# 523710 (Sayaji Hotels Limited): RSI = 44.82, Price = ₹325.10
# 533152 (MBL Infrastructures Limited): RSI = 44.80, Price = ₹63.54
# 526568 (N/A): RSI = 44.79, Price = ₹50.33
# 508989 (Navneet Education Limited): RSI = 44.77, Price = ₹139.50
# 509760 (N/A): RSI = 44.75, Price = ₹58.41
# 540575 (Star Cement Limited): RSI = 44.74, Price = ₹218.50
# 534532 (Lypsa Gems & Jewellery Limited): RSI = 44.74, Price = ₹7.28
# 538979 (Greenlam Industries Limited): RSI = 44.73, Price = ₹562.40
# 532183 (N/A): RSI = 44.70, Price = ₹14.67
# 504351 (Empower India Limited): RSI = 44.68, Price = ₹2.05
# 524480 (N/A): RSI = 44.67, Price = ₹635.35
# 537069 (Arnold Holdings Ltd.): RSI = 44.64, Price = ₹43.11
# 538365 (Incredible Industries Limited): RSI = 44.61, Price = ₹46.00
# 524748 (N/A): RSI = 44.59, Price = ₹41.99
# 539658 (TeamLease Services Limited): RSI = 44.58, Price = ₹2837.50
# 539336 (Gujarat Gas Limited): RSI = 44.56, Price = ₹500.50
# 535754 (Orient Cement Limited): RSI = 44.53, Price = ₹338.00
# 534615 (North Eastern Carrying Corporation Limited): RSI = 44.52, Price = ₹34.45
# 540065 (RBL Bank Limited): RSI = 44.49, Price = ₹161.85
# 507981 (N/A): RSI = 44.47, Price = ₹98.05
# 534741 (Virtual Global Education Limited): RSI = 44.44, Price = ₹0.76
# 539518 (Uday Jewellery Industries Limited): RSI = 44.41, Price = ₹150.10
# 532402 (USG Tech Solutions Limited): RSI = 44.40, Price = ₹17.29
# 524717 (N/A): RSI = 44.38, Price = ₹745.90
# 539479 (GTV Engineering Limited): RSI = 44.38, Price = ₹525.80
# 533581 (PG Electroplast Limited): RSI = 44.38, Price = ₹950.65
# 539448 (InterGlobe Aviation Limited): RSI = 44.35, Price = ₹4259.10
# 524703 (N/A): RSI = 44.32, Price = ₹54.98
# 535205 (Mystic Electronics Limited): RSI = 44.30, Price = ₹7.18
# 540702 (Lasa Supergenerics Limited): RSI = 44.28, Price = ₹27.10
# 534338 (Max Heights Infrastructure Limited): RSI = 44.22, Price = ₹28.25
# 532806 (AI Champdany Industries Limited): RSI = 44.21, Price = ₹56.49
# 539040 (Tirupati Tyres Limited): RSI = 44.17, Price = ₹13.07
# 503100 (The Phoenix Mills Limited): RSI = 44.15, Price = ₹1696.55
# 526217 (Hitech Corporation Limited): RSI = 44.10, Price = ₹241.00
# 504058 (Indo National Limited): RSI = 44.10, Price = ₹554.40
# 500660 (GlaxoSmithKline Pharmaceuticals Limited): RSI = 44.03, Price = ₹2207.85
# 532896 (Magnum Ventures Limited): RSI = 43.98, Price = ₹39.04
# 532070 (N/A): RSI = 43.97, Price = ₹200.45
# 539404 (Satin Creditcare Network Limited): RSI = 43.96, Price = ₹155.55
# 540710 (Capacit'e Infraprojects Limited): RSI = 43.94, Price = ₹420.90
# 531508 (N/A): RSI = 43.94, Price = ₹388.30
# 500159 (MetroGlobal Limited): RSI = 43.93, Price = ₹155.00
# 511493 (N/A): RSI = 43.93, Price = ₹12.15
# 508969 (Sulabh Engineers & Services Limited): RSI = 43.90, Price = ₹4.94
# 500327 (Pil Italica Lifestyle Limited): RSI = 43.89, Price = ₹13.70
# 523007 (N/A): RSI = 43.86, Price = ₹156.75
# 539176 (Hawa Engineers Limited): RSI = 43.82, Price = ₹229.60
# 502090 (Sagar Cements Limited): RSI = 43.82, Price = ₹220.10
# 500870 (Castrol India Limited): RSI = 43.77, Price = ₹200.85
# 540526 (IRB InvIT Fund): RSI = 43.75, Price = ₹60.09
# 526365 (Swarnsarita Jewels India Limited): RSI = 43.73, Price = ₹40.69
# 540006 (East West Freight Carriers Limited): RSI = 43.70, Price = ₹7.18
# 539607 (Blue Cloud Softech Solutions Limited): RSI = 43.66, Price = ₹102.60
# 540796 (N/A): RSI = 43.65, Price = ₹127.75
# 532268 (Accelya Solutions India Limited): RSI = 43.64, Price = ₹1541.95
# 511218 (Shriram Finance Limited): RSI = 43.64, Price = ₹2898.15
# 540210 (Heads UP Ventures Limited): RSI = 43.64, Price = ₹11.46
# 532879 (N/A): RSI = 43.62, Price = ₹286.20
# 526705 (N/A): RSI = 43.52, Price = ₹278.55
# 540647 (Ganges Securities Limited): RSI = 43.48, Price = ₹194.55
# 503624 (N/A): RSI = 43.45, Price = ₹10.12
# 500650 (Excel Industries Limited): RSI = 43.42, Price = ₹1291.40
# 532005 (Sam Industries Ltd.): RSI = 43.39, Price = ₹64.00
# 538795 (Shree Ajit Pulp and Paper Limited): RSI = 43.38, Price = ₹208.65
# 512175 (N/A): RSI = 43.35, Price = ₹8.39
# 505729 (N/A): RSI = 43.33, Price = ₹77.77
# 523648 (Plastiblends India Limited): RSI = 43.28, Price = ₹246.85
# 523842 (Super Tannery Limited): RSI = 43.28, Price = ₹12.20
# 533023 (ZF Commercial Vehicle Control Systems India Limited): RSI = 43.24, Price = ₹11469.60
# 531861 (N/A): RSI = 43.20, Price = ₹53.06
# 532531 (Strides Pharma Science Limited): RSI = 43.18, Price = ₹668.85
# 507598 (Kovilpatti Lakshmi Roller Flour Mills Limited): RSI = 43.18, Price = ₹132.00
# 533088 (Mahindra Holidays & Resorts India Limited): RSI = 43.17, Price = ₹369.65
# 511147 (N/A): RSI = 43.08, Price = ₹100.75
# 500250 (L.G. Balakrishnan & Bros Limited): RSI = 43.01, Price = ₹1295.30
# 530133 (N/A): RSI = 43.00, Price = ₹79.00
# 526409 (Kkalpana Industries (India) Limited): RSI = 42.98, Price = ₹15.53
# 507759 (N/A): RSI = 42.98, Price = ₹23.99
# 526492 (N/A): RSI = 42.96, Price = ₹216.00
# 533193 (Kirloskar Electric Company Limited): RSI = 42.92, Price = ₹185.80
# 533168 (Rossell India Limited): RSI = 42.90, Price = ₹76.87
# 533289 (Kesar Terminals & Infrastructure Limited): RSI = 42.88, Price = ₹75.10
# 533096 (Adani Power Limited): RSI = 42.88, Price = ₹504.40
# 511012 (N/A): RSI = 42.86, Price = ₹1.48
# 532466 (Oracle Financial Services Software Limited): RSI = 42.84, Price = ₹11983.90
# 540757 (Sheetal Cool Products Limited): RSI = 42.76, Price = ₹329.85
# 539126 (MEP Infrastructure Developers Limited): RSI = 42.73, Price = ₹3.05
# 523782 (N/A): RSI = 42.70, Price = ₹16.86
# 533260 (Career Point Limited): RSI = 42.67, Price = ₹389.85
# 539984 (Hindusthan Urban Infrastructure Limited): RSI = 42.64, Price = ₹2480.00
# 500170 (N/A): RSI = 42.63, Price = ₹36.19
# 532407 (N/A): RSI = 42.60, Price = ₹213.50
# 532764 (GeeCee Ventures Limited): RSI = 42.58, Price = ₹432.00
# 524408 (N/A): RSI = 42.56, Price = ₹174.00
# 501848 (Global Offshore Services Limited): RSI = 42.54, Price = ₹114.75
# 538713 (Atishay Limited): RSI = 42.53, Price = ₹222.35
# 540743 (Godrej Agrovet Limited): RSI = 42.53, Price = ₹739.65
# 535267 (Comfort Fincap Limited): RSI = 42.47, Price = ₹9.99
# 538081 (Haria Apparels Limited): RSI = 42.44, Price = ₹5.34
# 534639 (Vinayak Polycon International Limited): RSI = 42.44, Price = ₹36.25
# 590024 (The Fertilisers And Chemicals Travancore Limited): RSI = 42.44, Price = ₹963.40
# 506906 (N/A): RSI = 42.38, Price = ₹3.81
# 531859 (N/A): RSI = 42.37, Price = ₹314.45
# 524711 (N/A): RSI = 42.37, Price = ₹11.35
# 500285 (N/A): RSI = 42.36, Price = ₹53.33
# 526479 (N/A): RSI = 42.19, Price = ₹150.90
# 500319 (N/A): RSI = 42.17, Price = ₹114.65
# 539228 (Gala Global Products Limited): RSI = 42.17, Price = ₹3.21
# 523550 (N/A): RSI = 42.16, Price = ₹78.21
# 538635 (Snowman Logistics Limited): RSI = 42.14, Price = ₹69.01
# 540692 (Apex Frozen Foods Limited): RSI = 42.12, Price = ₹251.95
# 532398 (Usha Martin Education & Solutions Limited): RSI = 42.08, Price = ₹6.86
# 523465 (N/A): RSI = 42.08, Price = ₹49.90
# 540777 (HDFC Life Insurance Company Limited): RSI = 42.06, Price = ₹617.55
# 540133 (ICICI Prudential Life Insurance Company Limited): RSI = 42.05, Price = ₹652.50
# 506003 (N/A): RSI = 42.05, Price = ₹57.40
# 526839 (Shelter Infra Projects Limited): RSI = 42.00, Price = ₹17.62
# 532776 (Shivam Autotech Limited): RSI = 41.99, Price = ₹44.28
# 506605 (N/A): RSI = 41.99, Price = ₹2585.00
# 540393 (Sarthak Metals Limited): RSI = 41.97, Price = ₹159.60
# 533202 (Satchmo Holdings Limited): RSI = 41.96, Price = ₹3.93
# 540749 (MAS Financial Services Limited): RSI = 41.96, Price = ₹261.60
# 500317 (Oswal Agro Mills Limited): RSI = 41.93, Price = ₹70.07
# 522207 (N/A): RSI = 41.91, Price = ₹117.70
# 522183 (N/A): RSI = 41.87, Price = ₹446.60
# 505232 (Veljan Denison Limited): RSI = 41.87, Price = ₹1214.40
# 537707 (ETT Limited): RSI = 41.86, Price = ₹16.64
# 532807 (Cineline India Limited): RSI = 41.84, Price = ₹129.60
# 590134 (Madras Fertilizers Limited): RSI = 41.83, Price = ₹98.95
# 523606 (N/A): RSI = 41.82, Price = ₹2516.45
# 500104 (Hindustan Petroleum Corporation Limited): RSI = 41.78, Price = ₹391.10
# 540716 (ICICI Lombard General Insurance Company Limited): RSI = 41.78, Price = ₹1859.55
# 540729 (Vanta Bioscience Limited): RSI = 41.74, Price = ₹40.99
# 531822 (Rodium Realty Limited): RSI = 41.71, Price = ₹150.15
# 511131 (N/A): RSI = 41.69, Price = ₹16.79
# 506852 (N/A): RSI = 41.67, Price = ₹37.37
# 504028 (N/A): RSI = 41.64, Price = ₹139.95
# 524667 (Savita Oil Technologies Limited): RSI = 41.63, Price = ₹554.00
# 500179 (HCL Infosystems Limited): RSI = 41.60, Price = ₹15.81
# 504093 (Panasonic Energy India Co. Ltd.): RSI = 41.58, Price = ₹451.95
# 512018 (Tomorrow Technologies Global Innovations Limited): RSI = 41.58, Price = ₹15.33
# 531688 (Prithvi Exchange (India) Limited): RSI = 41.57, Price = ₹235.80
# 540565 (India Grid Trust): RSI = 41.56, Price = ₹143.70
# 530131 (Udaipur Cement Works Limited): RSI = 41.56, Price = ₹29.34
# 540361 (Danube Industries Limited): RSI = 41.54, Price = ₹4.68
# 540124 (G N A Axles Limited): RSI = 41.54, Price = ₹409.35
# 505681 (N/A): RSI = 41.53, Price = ₹637.30
# 533164 (Texmo Pipes and Products Limited): RSI = 41.48, Price = ₹66.09
# 538567 (Gulf Oil Lubricants India Limited): RSI = 41.47, Price = ₹1137.00
# 500014 (N/A): RSI = 41.46, Price = ₹7.18
# 523840 (N/A): RSI = 41.46, Price = ₹35.33
# 538987 (Talbros Engineering Limited): RSI = 41.43, Price = ₹615.90
# 524731 (N/A): RSI = 41.40, Price = ₹1253.75
# 533270 (Bedmutha Industries Limited): RSI = 41.38, Price = ₹200.00
# 506685 (N/A): RSI = 41.37, Price = ₹532.35
# 524440 (N/A): RSI = 41.34, Price = ₹58.38
# 540268 (TruCap Finance Limited): RSI = 41.33, Price = ₹15.26
# 533014 (N/A): RSI = 41.33, Price = ₹82.64
# 533482 (Kridhan Infra Limited): RSI = 41.32, Price = ₹6.13
# 509423 (Sanathnagar Enterprises Limited): RSI = 41.31, Price = ₹39.79
# 541503 (Unick Fix-A-Form and Printers Limited): RSI = 41.30, Price = ₹81.90
# 532977 (Bajaj Auto Limited): RSI = 41.29, Price = ₹8642.25
# 500335 (Birla Corporation Limited): RSI = 41.28, Price = ₹1221.95
# 533286 (MOIL Limited): RSI = 41.27, Price = ₹338.25
# 526642 (N/A): RSI = 41.25, Price = ₹36.72
# 532842 (Sree Rayalaseema Hi-Strength Hypo Limited): RSI = 41.25, Price = ₹777.65
# 500414 (N/A): RSI = 41.14, Price = ₹202.20
# 531595 (Capri Global Capital Limited): RSI = 41.14, Price = ₹189.30
# 506618 (Punjab Chemicals and Crop Protection Limited): RSI = 41.13, Price = ₹994.00
# 502450 (Seshasayee Paper and Boards Limited): RSI = 41.08, Price = ₹304.05
# 539227 (Loyal Equipments Limited): RSI = 41.05, Price = ₹272.00
# 532209 (The Jammu and Kashmir Bank Limited): RSI = 40.99, Price = ₹96.75
# 526849 (Banaras Beads Limited): RSI = 40.96, Price = ₹129.45
# 523736 (Dhunseri Ventures Limited): RSI = 40.94, Price = ₹351.20
# 533758 (APL Apollo Tubes Limited): RSI = 40.93, Price = ₹1538.80
# 533452 (Delphi World Money Limited): RSI = 40.89, Price = ₹203.05
# 531814 (N/A): RSI = 40.83, Price = ₹17.93
# 500304 (NIIT Limited): RSI = 40.82, Price = ₹187.20
# 502445 (Citadel Realty and Developers Limited): RSI = 40.81, Price = ₹69.35
# 541703 (Raconteur Global Resources Limited): RSI = 40.68, Price = ₹13.28
# 532173 (CyberTech Systems and Software Limited): RSI = 40.66, Price = ₹216.45
# 506532 (N/A): RSI = 40.64, Price = ₹767.95
# 539963 (N/A): RSI = 40.58, Price = ₹12.41
# 521240 (Sambandam Spinning Mills Limited): RSI = 40.55, Price = ₹157.40
# 532613 (VIP Clothing Limited): RSI = 40.54, Price = ₹44.34
# 524576 (Vivid Global Industries Limited): RSI = 40.52, Price = ₹19.62
# 512048 (Luharuka Media & Infra Limited): RSI = 40.52, Price = ₹4.73
# 526668 (N/A): RSI = 40.50, Price = ₹225.35
# 523537 (N/A): RSI = 40.50, Price = ₹51.36
# 512131 (Signet Industries Limited): RSI = 40.47, Price = ₹68.85
# 522134 (N/A): RSI = 40.45, Price = ₹179.05
# 524654 (Natural Capsules Limited): RSI = 40.45, Price = ₹265.45
# 500209 (Infosys Limited): RSI = 40.44, Price = ₹1933.15
# 541006 (N/A): RSI = 40.42, Price = ₹20.00
# 537292 (Agri-tech (India) Limited): RSI = 40.42, Price = ₹196.95
# 535458 (NRB Industrial Bearings Limited): RSI = 40.41, Price = ₹23.96
# 502180 (Shree Digvijay Cement Company Ltd.): RSI = 40.39, Price = ₹84.84
# 538634 (Vasundhara Rasayans Limited): RSI = 40.32, Price = ₹280.35
# 523660 (The Waterbase Limited): RSI = 40.32, Price = ₹71.95
# 540769 (The New India Assurance Company Limited): RSI = 40.24, Price = ₹194.60
# 526721 (N/A): RSI = 40.23, Price = ₹129.90
# 511413 (Crest Ventures Limited): RSI = 40.22, Price = ₹434.85
# 533477 (Enkei Wheels (India) Limited): RSI = 40.19, Price = ₹647.95
# 524752 (N/A): RSI = 40.17, Price = ₹15.15
# 535566 (KIFS Financial Services Limited): RSI = 40.16, Price = ₹152.80
# 539254 (Adani Transmission Limited): RSI = 40.15, Price = ₹770.25
# 522275 (GE T&D India Limited): RSI = 40.15, Price = ₹1991.50
# 505750 (N/A): RSI = 40.12, Price = ₹581.65
# 504879 (Orient Abrasives Limited): RSI = 40.10, Price = ₹48.73
# 526608 (Electrotherm (India) Limited): RSI = 40.10, Price = ₹1223.15
# 511543 (N/A): RSI = 40.10, Price = ₹43.19
# 590062 (The Andhra Sugars Limited): RSI = 40.06, Price = ₹93.87
# 524200 (Vinati Organics Limited): RSI = 40.03, Price = ₹1702.45
# 500444 (West Coast Paper Mills Limited): RSI = 40.00, Price = ₹552.20
# 531518 (N/A): RSI = 40.00, Price = ₹0.49
#
# Daily analysis complete. Results saved in stock_analysis\daily_results

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from termcolor import colored
import requests
import io
import time
import os
import json
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache

class StockAnalyzer:
    def __init__(self):
        self.base_dir = 'stock_analysis'
        self.stock_lists_dir = os.path.join(self.base_dir, 'stock_lists')
        self.results_dir = os.path.join(self.base_dir, 'daily_results')
        self.delisted_cache_file = os.path.join(self.stock_lists_dir, 'delisted_stocks.json')
        self.setup_directories()
        self.load_delisted_stocks()
        self.session = requests.Session()

    def setup_directories(self):
        """Create necessary directories if they don't exist"""
        os.makedirs(self.stock_lists_dir, exist_ok=True)
        os.makedirs(self.results_dir, exist_ok=True)
        
    def should_update_stock_list(self, exchange):
        """Check if stock list needs updating (weekly update)"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        if not os.path.exists(list_file):
            return True
        # Check if file is older than 7 days
        file_time = datetime.fromtimestamp(os.path.getmtime(list_file))
        return (datetime.now() - file_time).days >= 7
    
    def load_delisted_stocks(self):
        """Load previously identified delisted stocks"""
        try:
            with open(self.delisted_cache_file, 'r') as f:
                self.delisted_stocks = json.load(f)
        except FileNotFoundError:
            self.delisted_stocks = {'NSE': [], 'BSE': []}  # Changed from set to list
            self.save_delisted_stocks()

    def save_delisted_stocks(self):
        """Save delisted stocks to cache"""
        with open(self.delisted_cache_file, 'w') as f:
            json.dump({
                'NSE': self.delisted_stocks['NSE'],
                'BSE': self.delisted_stocks['BSE']
            }, f)
    
    def save_stock_list(self, symbols, exchange):
        """Save stock list to JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        data = {
            'symbols': symbols,
            'last_updated': datetime.now().strftime('%Y-%m-%d')
        }
        with open(list_file, 'w') as f:
            json.dump(data, f)

    def load_stock_list(self, exchange):
        """Load stock list from JSON file"""
        list_file = os.path.join(self.stock_lists_dir, f'{exchange}_stocks.json')
        with open(list_file, 'r') as f:
            data = json.load(f)
        return data['symbols']
    
    def download_nse_stocks(self):
        """Download NSE stock list if needed"""
        if self.should_update_stock_list('NSE'):
            try:
                url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
                response = requests.get(url)
                df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
                symbols = df['SYMBOL'].tolist()
                self.save_stock_list(symbols, 'NSE')
                print("NSE stock list updated")
                return symbols
            except Exception as e:
                print(f"Error downloading NSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'NSE_stocks.json')):
                    return self.load_stock_list('NSE')
                return []
        return self.load_stock_list('NSE')

    def download_bse_stocks(self):
        """Download BSE stock list if needed"""
        if self.should_update_stock_list('BSE'):
            try:
                # Using the BSE list from static file or an appropriate source
                url = "https://www.bseindia.com/corporates/List_Scrips.aspx"
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                table = soup.find('table', {'id': 'ContentPlaceHolder1_tblData'})
                symbols = []

                if table:
                    rows = table.find_all('tr')[1:]  # Skip header row
                    for row in rows:
                        cols = row.find_all('td')
                        if cols:
                            bse_code = cols[0].text.strip()
                            symbols.append(bse_code)

                if symbols:
                    self.save_stock_list(symbols, 'BSE')
                    print("BSE stock list updated")
                    return symbols
            except Exception as e:
                print(f"Error downloading BSE stocks: {e}")
                if os.path.exists(os.path.join(self.stock_lists_dir, 'BSE_stocks.json')):
                    return self.load_stock_list('BSE')
                return []
        return self.load_stock_list('BSE')

    @lru_cache(maxsize=1000)
    def calculate_rsi(self, prices_tuple, periods=14):
        """Calculate RSI with caching for performance"""
        prices = pd.Series(prices_tuple)
        delta = prices.diff()
        gain = delta.where(delta > 0, 0).rolling(window=periods).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
        rs = gain / loss
        return float(100 - (100 / (1 + rs)).iloc[-1])

    def calculate_ema(self, data, length=9, source='Close', offset=0):
        """
        Calculate Exponential Moving Average with specified parameters
        
        Args:
            data (pd.DataFrame): Historical price data
            length (int): Length of EMA period
            source (str): Source column for calculation
            offset (int): Offset for calculation
            
        Returns:
            pd.Series: EMA values
        """
        # First calculate SMA as the smoothing line
        sma = data[source].rolling(window=9).mean()  # Smoothing length of 9 as specified
        
        # Calculate the multiplier
        multiplier = 2 / (length + 1)
        
        # Initialize EMA with SMA
        ema = pd.Series(index=data.index, dtype=float)
        ema.iloc[:length-1] = np.nan
        ema.iloc[length-1] = sma.iloc[length-1]
        
        # Calculate EMA
        for i in range(length, len(data)):
            ema.iloc[i] = (data[source].iloc[i] - ema.iloc[i-1]) * multiplier + ema.iloc[i-1]
        
        # Apply offset if specified
        if offset != 0:
            ema = ema.shift(offset)
            
        return ema

    def get_stock_data(self, symbol, exchange='NSE', days=60):
        """Fetch detailed stock data with additional information"""
        if symbol in self.delisted_stocks[exchange]:
            return None, None, None, None

        try:
            ticker_symbol = f"{symbol}.NS" if exchange == 'NSE' else f"{symbol}.BO"
            ticker = yf.Ticker(ticker_symbol)
            
            # Get stock info
            info = ticker.info
            
            end_date = datetime.now()
            start_date = end_date - timedelta(days=days)

            hist_data = ticker.history(
                start=start_date,
                end=end_date,
                interval="1d"
            )

            if hist_data.empty or len(hist_data) < 20:
                self.delisted_stocks[exchange].append(symbol)
                self.save_delisted_stocks()
                return None, None, None, None

            # Calculate EMA
            hist_data['EMA_9'] = self.calculate_ema(hist_data, length=9, source='Close', offset=0)

            latest_price = hist_data['Close'].iloc[-1]
            prices_tuple = tuple(hist_data['Close'].values)
            latest_rsi = self.calculate_rsi(prices_tuple)

            return latest_price, hist_data, latest_rsi, info

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
            self.delisted_stocks[exchange].append(symbol)
            self.save_delisted_stocks()
            return None, None, None, None

    def process_stock_batch(self, batch_data):
        """Process a batch of stocks with enhanced information"""
        symbols, exchange = batch_data
        results = []
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = {executor.submit(self.get_stock_data, symbol, exchange): symbol 
                      for symbol in symbols}
            
            for future in futures:
                symbol = futures[future]
                try:
                    latest_price, hist_data, latest_rsi, info = future.result()
                    if all(v is not None for v in [latest_price, hist_data, latest_rsi, info]):
                        # Extract additional information safely using get() method
                        stock_info = {
                            'Symbol': symbol,
                            'Exchange': exchange,
                            'Company_Name': info.get('longName', 'N/A'),
                            'Latest_Price': latest_price,
                            'EMA_9': hist_data['EMA_9'].iloc[-1] if 'EMA_9' in hist_data else 'N/A',
                            'RSI': latest_rsi,
                            'Volume': hist_data['Volume'].iloc[-1] if 'Volume' in hist_data else 0,
                            'Market_Cap': info.get('marketCap', 'N/A'),
                            'PE_Ratio': info.get('trailingPE', 'N/A'),
                            'EPS': info.get('trailingEps', 'N/A'),
                            'Dividend_Yield': info.get('dividendYield', 'N/A'),
                            'Book_Value': info.get('bookValue', 'N/A'),
                            'Sector': info.get('sector', 'N/A'),
                            'Industry': info.get('industry', 'N/A'),
                            '52W_High': info.get('fiftyTwoWeekHigh', 'N/A'),
                            '52W_Low': info.get('fiftyTwoWeekLow', 'N/A'),
                            '50d_MA': info.get('fiftyDayAverage', 'N/A'),
                            '200d_MA': info.get('twoHundredDayAverage', 'N/A'),
                            'Beta': info.get('beta', 'N/A'),
                            'Previous_Close': info.get('previousClose', 'N/A'),
                            'Open': info.get('open', 'N/A'),
                            'Day_High': info.get('dayHigh', 'N/A'),
                            'Day_Low': info.get('dayLow', 'N/A'),
                            'Date': datetime.now().strftime('%Y-%m-%d')
                        }
                        
                        # Calculate additional metrics
                        if hist_data is not None:
                            stock_info.update({
                                'Volatility_30d': hist_data['Close'].pct_change().std() * np.sqrt(252),
                                'Returns_30d': (hist_data['Close'].iloc[-1] / hist_data['Close'].iloc[0] - 1) * 100,
                                'Average_Volume_30d': hist_data['Volume'].mean()
                            })
                        
                        results.append(stock_info)
                        
                except Exception as e:
                    print(f"Error processing {symbol}: {e}")

        return results

    def run_daily_analysis(self):
        """Run daily analysis with Excel output"""
        current_date = datetime.now().strftime('%Y%m%d')
        
        print("Loading stock lists...")
        nse_symbols = self.download_nse_stocks()
        bse_symbols = self.download_bse_stocks()

        print(f"\nAnalyzing {len(nse_symbols)} NSE and {len(bse_symbols)} BSE stocks")

        for exchange, symbols in [('NSE', nse_symbols), ('BSE', bse_symbols)]:
            batch_data=(symbols, exchange)
            results = self.process_stock_batch(batch_data)
            
            if results:
                # Create Excel writer with xlsxwriter engine
                excel_file = os.path.join(
                    self.results_dir,
                    f'{exchange.lower()}_analysis_{current_date}.xlsx'
                )
                
                # Convert results list to DataFrame
                results_df = pd.DataFrame(results)
                
                with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                    # Write all stocks to first sheet
                    results_df.to_excel(writer, sheet_name='All Stocks', index=False)
                    
                    # Write high RSI stocks to second sheet
                    high_rsi = results_df[results_df['RSI'] >= 40].sort_values('RSI', ascending=False)
                    high_rsi.to_excel(writer, sheet_name='High RSI Stocks', index=False)
                    
                    # Get workbook and worksheet objects for formatting
                    workbook = writer.book
                    
                    # Add formats
                    header_format = workbook.add_format({
                        'bold': True,
                        'text_wrap': True,
                        'valign': 'top',
                        'bg_color': '#D9E1F2',
                        'border': 1
                    })
                    
                    # Format each worksheet
                    for worksheet in writer.sheets.values():
                        # Set column widths
                        worksheet.set_column('A:Z', 15)
                        # Apply header format to first row
                        for col_num, value in enumerate(results_df.columns.values):
                            worksheet.write(0, col_num, value, header_format)

                print(f"\n{exchange} analysis complete. Results saved to {excel_file}")
                
                # Print high RSI stocks
                print(f"\n{exchange} Stocks with RSI >= 40:")
                for _, row in high_rsi.iterrows():
                    print(colored(
                        f"{row['Symbol']} ({row['Company_Name']}): RSI = {row['RSI']:.2f}, "
                        f"Price = ₹{row['Latest_Price']:.2f}",
                        'green', attrs=['bold']
                    ))

        print(f"\nDaily analysis complete. Results saved in {self.results_dir}")


if __name__ == "__main__":
    analyzer = StockAnalyzer()
    analyzer.run_daily_analysis()
# Out:
# Loading stock lists...
#
# Analyzing 2062 NSE and 3026 BSE stocks
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/EMAMIPAP.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=EMAMIPAP.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KRONOX.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KRONOX.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KRN.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KRN.NS&crumb=CdOdjA2vtBF
# $KREBSBIO.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.059262 -> 2025-01-09 19:35:25.059262)
# $KRITINUT.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.090547 -> 2025-01-09 19:35:25.090547)
# $KRISHANA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.106131 -> 2025-01-09 19:35:25.106131)
# $KRBL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.043639 -> 2025-01-09 19:35:25.043639)
# $KRITIKA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.090547 -> 2025-01-09 19:35:25.090547)
# $KRIDHANINF.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.121754 -> 2025-01-09 19:35:25.121754)
# $KRITI.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.121754 -> 2025-01-09 19:35:25.121754)
# $KPRMILL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:25.059262 -> 2025-01-09 19:35:25.059262)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KROSS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KROSS.NS&crumb=CdOdjA2vtBF
# $KRONOX.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:28.182914 -> 2025-01-09 19:35:28.182914)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KRSNAA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KRSNAA.NS&crumb=CdOdjA2vtBF
# $KRN.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:28.206443 -> 2025-01-09 19:35:28.206443)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KSL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KSL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KSCL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KSCL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KRYSTAL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KRYSTAL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KSB.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KSB.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KSHITIJPOL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KSHITIJPOL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KSOLVES.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KSOLVES.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KTKBANK.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KTKBANK.NS&crumb=CdOdjA2vtBF
# $KSL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:30.885171 -> 2025-01-09 19:35:30.885171)
# $KRSNAA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:30.837465 -> 2025-01-09 19:35:30.837465)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/KUANTUM.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=KUANTUM.NS&crumb=CdOdjA2vtBF
# $KROSS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:30.805215 -> 2025-01-09 19:35:30.805215)
# $KSCL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:30.936589 -> 2025-01-09 19:35:30.936589)
# $KRYSTAL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:31.026974 -> 2025-01-09 19:35:31.026974)
# $KSB.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:30.919066 -> 2025-01-09 19:35:30.919066)
# $KSHITIJPOL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:30.939586 -> 2025-01-09 19:35:30.939586)
# $KSOLVES.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:31.031971 -> 2025-01-09 19:35:31.031971)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LALPATHLAB.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LALPATHLAB.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LAGNAM.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LAGNAM.NS&crumb=CdOdjA2vtBF
# $KTKBANK.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:35.434809 -> 2025-01-09 19:35:35.434809)
# $KUANTUM.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:35.434809 -> 2025-01-09 19:35:35.434809)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LAL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LAL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LAMBODHARA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LAMBODHARA.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LANDMARK.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LANDMARK.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LANCORHOL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LANCORHOL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LAOPALA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LAOPALA.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LASA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LASA.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LATENTVIEW.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LATENTVIEW.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LATTEYS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LATTEYS.NS&crumb=CdOdjA2vtBF
# $LALPATHLAB.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:37.250447 -> 2025-01-09 19:35:37.250447)
# $LAL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:39.071432 -> 2025-01-09 19:35:39.071432)
# $LAGNAM.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:39.040230 -> 2025-01-09 19:35:39.040230)
# $LAMBODHARA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:39.387200 -> 2025-01-09 19:35:39.387200)
# $LANCORHOL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:40.660871 -> 2025-01-09 19:35:40.660871)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LAURUSLABS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LAURUSLABS.NS&crumb=CdOdjA2vtBF
# $LAOPALA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:40.711361 -> 2025-01-09 19:35:40.711361)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LCCINFOTEC.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LCCINFOTEC.NS&crumb=CdOdjA2vtBF
# $LASA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:40.808204 -> 2025-01-09 19:35:40.808204)
# $LANDMARK.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:40.760362 -> 2025-01-09 19:35:40.760362)
# $LATTEYS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:40.892682 -> 2025-01-09 19:35:40.892682)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LEMONTREE.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LEMONTREE.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LAXMICOT.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LAXMICOT.NS&crumb=CdOdjA2vtBF
# $LATENTVIEW.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:40.948320 -> 2025-01-09 19:35:40.948320)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LEXUS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LEXUS.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LFIC.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LFIC.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LGHL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LGHL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LGBBROSLTD.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LGBBROSLTD.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIBAS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIBAS.NS&crumb=CdOdjA2vtBF
# $LCCINFOTEC.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:45.361999 -> 2025-01-09 19:35:45.361999)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIBERTSHOE.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIBERTSHOE.NS&crumb=CdOdjA2vtBF
# $LAURUSLABS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:45.135332 -> 2025-01-09 19:35:45.135332)
# $LAXMICOT.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:47.814295 -> 2025-01-09 19:35:47.814295)
# $LEMONTREE.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:47.954487 -> 2025-01-09 19:35:47.954487)
# $LFIC.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:50.281856 -> 2025-01-09 19:35:50.281856)
# $LEXUS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:50.238585 -> 2025-01-09 19:35:50.238585)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LICI.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LICI.NS&crumb=CdOdjA2vtBF
# $LGBBROSLTD.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:50.696546 -> 2025-01-09 19:35:50.696546)
# $LGHL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:50.503902 -> 2025-01-09 19:35:50.503902)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LICHSGFIN.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LICHSGFIN.NS&crumb=CdOdjA2vtBF
# $LIBAS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:52.286022 -> 2025-01-09 19:35:52.286022)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LIKHITHA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LIKHITHA.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LINC.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LINC.NS&crumb=CdOdjA2vtBF
# $LIBERTSHOE.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:52.433679 -> 2025-01-09 19:35:52.433679)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LINDEINDIA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LINDEINDIA.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LINCOLN.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LINCOLN.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LLOYDSENGG.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LLOYDSENGG.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LLOYDSME.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LLOYDSME.NS&crumb=CdOdjA2vtBF
# $LICHSGFIN.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:57.030377 -> 2025-01-09 19:35:57.030377)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LLOYDSENT.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LLOYDSENT.NS&crumb=CdOdjA2vtBF
# $LIKHITHA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:57.068976 -> 2025-01-09 19:35:57.068976)
# $LICI.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:54.502862 -> 2025-01-09 19:35:54.502862)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LMW.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LMW.NS&crumb=CdOdjA2vtBF
# $LINCOLN.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:58.838196 -> 2025-01-09 19:35:58.838196)
# $LINC.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:58.822537 -> 2025-01-09 19:35:58.822537)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LOKESHMACH.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LOKESHMACH.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LODHA.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LODHA.NS&crumb=CdOdjA2vtBF
# $LINDEINDIA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:58.985331 -> 2025-01-09 19:35:58.985331)
# $LLOYDSME.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:59.101907 -> 2025-01-09 19:35:59.101907)
# $LLOYDSENT.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:00.674194 -> 2025-01-09 19:36:00.674194)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LORDSCHLO.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LORDSCHLO.NS&crumb=CdOdjA2vtBF
# $LLOYDSENGG.NS: possibly delisted; no price data found  (1d 2024-11-10 19:35:59.058655 -> 2025-01-09 19:35:59.058655)
# $LMW.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:00.904743 -> 2025-01-09 19:36:00.904743)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LOVABLE.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LOVABLE.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LOTUSEYE.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LOTUSEYE.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LT.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LT.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LPDC.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LPDC.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LTFOODS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LTFOODS.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LTF.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LTF.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LOYALTEX.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LOYALTEX.NS&crumb=CdOdjA2vtBF
# $LODHA.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:02.829735 -> 2025-01-09 19:36:02.829735)
# $LOKESHMACH.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:02.599882 -> 2025-01-09 19:36:02.599882)
# $LORDSCHLO.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:04.212561 -> 2025-01-09 19:36:04.212561)
# $LOTUSEYE.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:04.383937 -> 2025-01-09 19:36:04.383937)
# $LOVABLE.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:04.399603 -> 2025-01-09 19:36:04.399603)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LTIM.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LTIM.NS&crumb=CdOdjA2vtBF
# $LT.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:06.360880 -> 2025-01-09 19:36:06.360880)
# $LPDC.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:08.354107 -> 2025-01-09 19:36:08.354107)
# $LOYALTEX.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:08.369726 -> 2025-01-09 19:36:08.369726)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LUMAXIND.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LUMAXIND.NS&crumb=CdOdjA2vtBF
# $LTF.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:08.378654 -> 2025-01-09 19:36:08.378654)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LTTS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LTTS.NS&crumb=CdOdjA2vtBF
# $LTFOODS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:08.439550 -> 2025-01-09 19:36:08.439550)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LUMAXTECH.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LUMAXTECH.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LUPIN.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LUPIN.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LXCHEM.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LXCHEM.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LUXIND.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LUXIND.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LYPSAGEMS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LYPSAGEMS.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LYKALABS.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LYKALABS.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/M&M.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=M%26M.NS&crumb=CdOdjA2vtBF
# $LUMAXIND.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:12.540794 -> 2025-01-09 19:36:12.540794)
# $LTTS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:12.529746 -> 2025-01-09 19:36:12.529746)
# $LTIM.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:10.951674 -> 2025-01-09 19:36:10.951674)
# $LUPIN.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.140633 -> 2025-01-09 19:36:15.140633)
# $LUMAXTECH.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.118941 -> 2025-01-09 19:36:15.118941)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAANALU.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAANALU.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MACPOWER.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MACPOWER.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/M&MFIN.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=M%26MFIN.NS&crumb=CdOdjA2vtBF
# $LXCHEM.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.310873 -> 2025-01-09 19:36:15.310873)
# $LUXIND.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.339289 -> 2025-01-09 19:36:15.339289)
# $LYPSAGEMS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.342187 -> 2025-01-09 19:36:15.342187)
# $M&M.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.385105 -> 2025-01-09 19:36:15.385105)
# $LYKALABS.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:15.357195 -> 2025-01-09 19:36:15.357195)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MADHUCON.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MADHUCON.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MADHAV.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MADHAV.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MADRASFERT.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MADRASFERT.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAGADSUGAR.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAGADSUGAR.NS&crumb=CdOdjA2vtBF
# $M&MFIN.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:19.842535 -> 2025-01-09 19:36:19.842535)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHAPEXLTD.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHAPEXLTD.NS&crumb=CdOdjA2vtBF
# $MAANALU.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:19.903998 -> 2025-01-09 19:36:19.903998)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAGNUM.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAGNUM.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHABANK.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHABANK.NS&crumb=CdOdjA2vtBF
# $MACPOWER.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:19.960656 -> 2025-01-09 19:36:19.960656)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHASTEEL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHASTEEL.NS&crumb=CdOdjA2vtBF
# $MADHAV.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:21.671131 -> 2025-01-09 19:36:21.671131)
# $MADRASFERT.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:23.384802 -> 2025-01-09 19:36:23.384802)
# $MADHUCON.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:21.613311 -> 2025-01-09 19:36:21.613311)
# $MAGADSUGAR.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:23.393054 -> 2025-01-09 19:36:23.393054)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHEPC.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHEPC.NS&crumb=CdOdjA2vtBF
# $MAHAPEXLTD.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:23.626316 -> 2025-01-09 19:36:23.626316)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHESHWARI.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHESHWARI.NS&crumb=CdOdjA2vtBF
# $MAHABANK.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:25.624441 -> 2025-01-09 19:36:25.624441)
# $MAGNUM.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:25.642008 -> 2025-01-09 19:36:25.642008)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHSCOOTER.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHSCOOTER.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHSEAMLES.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHSEAMLES.NS&crumb=CdOdjA2vtBF
# $MAHASTEEL.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:25.863065 -> 2025-01-09 19:36:25.863065)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHLIFE.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHLIFE.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAHLOG.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAHLOG.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAITHANALL.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAITHANALL.NS&crumb=CdOdjA2vtBF
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MALUPAPER.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MALUPAPER.NS&crumb=CdOdjA2vtBF
# $MAHESHWARI.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:29.373769 -> 2025-01-09 19:36:29.373769)
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MALLCOM.NS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MALLCOM.NS&crumb=CdOdjA2vtBF
# $MAHEPC.NS: possibly delisted; no price data found  (1d 2024-11-10 19:36:27.330930 -> 2025-01-09 19:36:27.330930)
# NSE analysis complete. Results saved to stock_analysis\daily_results\nse_analysis_20250109.xlsx
#
# NSE Stocks with RSI >= 40:
# ATLASCYCLE (Atlas Cycles (Haryana) Limited): RSI = 100.00, Price = ₹102.56
# VISASTEEL (VISA Steel Limited): RSI = 100.00, Price = ₹45.48
# BLUECOAST (Blue Coast Hotels Limited): RSI = 100.00, Price = ₹21.84
# GVT&D (GE Vernova T&D India Ltd): RSI = 100.00, Price = ₹1990.20
# AARVEEDEN (Aarvee Denims and Exports Ltd.): RSI = 100.00, Price = ₹129.00
# BGRENERGY (BGR Energy Systems Limited): RSI = 100.00, Price = ₹116.67
# FSC (Future Supply Chain Solutions Limited): RSI = 96.77, Price = ₹2.49
# INDOTHAI (Indo Thai Securities Limited): RSI = 94.57, Price = ₹1648.95
# PTCIL (PTC Industries Limited): RSI = 92.88, Price = ₹17392.15
# SVLL (Shree Vasu Logistics Limited): RSI = 91.62, Price = ₹386.95
# AXISCADES (AXISCADES Technologies Limited): RSI = 90.15, Price = ₹809.15
# SRF (SRF Limited): RSI = 84.05, Price = ₹2673.90
# AVONMORE (Avonmore Capital & Management Services Limited): RSI = 83.05, Price = ₹27.24
# GODREJCP (Godrej Consumer Products Limited): RSI = 82.11, Price = ₹1181.10
# INDIACEM (The India Cements Limited): RSI = 81.39, Price = ₹376.70
# BROOKS (Brooks Laboratories Limited): RSI = 80.57, Price = ₹185.78
# ZOTA (Zota Health Care Limited): RSI = 79.12, Price = ₹1014.25
# DIAMONDYD (Prataap Snacks Limited): RSI = 78.87, Price = ₹1160.65
# CAPITALSFB (Capital Small Finance Bank Limited): RSI = 78.31, Price = ₹307.40
# SHAKTIPUMP (Shakti Pumps (India) Limited): RSI = 78.29, Price = ₹1283.50
# IRIS (IRIS Business Services Limited): RSI = 78.14, Price = ₹500.35
# MEGASTAR (Megastar Foods Limited): RSI = 77.89, Price = ₹288.09
# AVROIND (Avro India Limited): RSI = 76.88, Price = ₹217.92
# JUBLFOOD (Jubilant FoodWorks Limited): RSI = 76.85, Price = ₹745.60
# BTML (Bodhi Tree Multimedia Limited): RSI = 76.68, Price = ₹12.84
# TATACONSUM (Tata Consumer Products Limited): RSI = 76.27, Price = ₹970.10
# DCXINDIA (DCX Systems Limited): RSI = 76.05, Price = ₹375.10
# KIMS (Krishna Institute of Medical Sciences Limited): RSI = 75.95, Price = ₹653.75
# COFFEEDAY (Coffee Day Enterprises Limited): RSI = 75.69, Price = ₹30.28
# SEYAIND (Seya Industries Limited): RSI = 75.66, Price = ₹29.55
# PROZONER (Prozone Realty Limited): RSI = 75.63, Price = ₹36.05
# SUNCLAY (Sundaram-Clayton Limited): RSI = 74.98, Price = ₹2813.40
# COROMANDEL (Coromandel International Limited): RSI = 74.66, Price = ₹1951.95
# MEGASOFT (Megasoft Limited): RSI = 74.51, Price = ₹104.32
# VIJAYA (Vijaya Diagnostic Centre Limited): RSI = 74.27, Price = ₹1221.30
# MEDICO (Medico Remedies Limited): RSI = 74.23, Price = ₹60.97
# UNIVASTU (Univastu India Limited): RSI = 74.07, Price = ₹281.80
# ABDL (N/A): RSI = 73.78, Price = ₹429.15
# ASIANHOTNR (Asian Hotels (North) Limited): RSI = 73.59, Price = ₹296.50
# KALYANIFRG (Kalyani Forge Limited): RSI = 72.89, Price = ₹811.55
# WORTH (Worth Peripherals Limited): RSI = 72.66, Price = ₹172.33
# SPANDANA (Spandana Sphoorty Financial Limited): RSI = 72.62, Price = ₹450.85
# APOLLO (Apollo Micro Systems Limited): RSI = 72.49, Price = ₹129.44
# KILITCH (Kilitch Drugs (India) Limited): RSI = 72.43, Price = ₹345.10
# JSWHL (JSW Holdings Limited): RSI = 72.08, Price = ₹18079.70
# ASMS (Bartronics India Limited): RSI = 71.92, Price = ₹22.76
# BERGEPAINT (Berger Paints India Limited): RSI = 71.82, Price = ₹468.75
# BAJAJFINSV (Bajaj Finserv Ltd.): RSI = 71.34, Price = ₹1690.30
# MBAPL (Madhya Bharat Agro Products Limited): RSI = 71.31, Price = ₹245.62
# AMBER (Amber Enterprises India Limited): RSI = 71.17, Price = ₹7703.95
# HMT (HMT Limited): RSI = 71.02, Price = ₹76.00
# USK (Udayshivakumar Infra Limited): RSI = 70.86, Price = ₹56.64
# AARTIPHARM (Aarti Pharmalabs Limited): RSI = 70.60, Price = ₹660.15
# EICHERMOT (Eicher Motors Limited): RSI = 70.57, Price = ₹5139.90
# SAPPHIRE (Sapphire Foods India Limited): RSI = 70.53, Price = ₹343.90
# ARIHANTSUP (Arihant Superstructures Limited): RSI = 70.44, Price = ₹524.50
# MGEL (Mangalam Global Enterprise Limited): RSI = 70.08, Price = ₹30.56
# FMNL (Future Market Networks Limited): RSI = 70.04, Price = ₹26.49
# CALSOFT (California Software Company Limited): RSI = 69.93, Price = ₹19.78
# CONCORDBIO (Concord Biotech Limited): RSI = 69.63, Price = ₹2320.15
# CREDITACC (CreditAccess Grameen Limited): RSI = 69.57, Price = ₹999.55
# JTLIND (JTL Industries Limited): RSI = 69.46, Price = ₹107.87
# EPACK (EPACK Durable Limited): RSI = 69.32, Price = ₹598.35
# VASWANI (Vaswani Industries Limited): RSI = 69.22, Price = ₹54.84
# HSCL (Himadri Speciality Chemical Limited): RSI = 68.89, Price = ₹579.05
# MARUTI (Maruti Suzuki India Limited): RSI = 68.73, Price = ₹11740.55
# MVGJL (Manoj Vaibhav Gems 'N' Jewellers Limited): RSI = 68.50, Price = ₹295.25
# ATALREAL (Atal Realtech Limited): RSI = 68.45, Price = ₹14.20
# DECCANCE (Deccan Cements Limited): RSI = 68.28, Price = ₹712.75
# AURUM (Aurum PropTech Limited): RSI = 68.08, Price = ₹256.09
# IFBIND (IFB Industries Limited): RSI = 67.38, Price = ₹1981.15
# AEGISLOG (N/A): RSI = 67.16, Price = ₹887.80
# ASTERDM (Aster DM Healthcare Limited): RSI = 67.13, Price = ₹515.25
# INDOTECH (Indo Tech Transformers Limited): RSI = 67.10, Price = ₹3566.00
# BAJFINANCE (Bajaj Finance Limited): RSI = 66.97, Price = ₹7277.45
# GARUDA (N/A): RSI = 66.69, Price = ₹137.61
# BLUECHIP (Blue Chip India Limited): RSI = 66.52, Price = ₹8.93
# MANCREDIT (Mangal Credit and Fincorp Limited): RSI = 66.00, Price = ₹165.04
# DMART (Avenue Supermarts Limited): RSI = 65.78, Price = ₹3813.80
# HINDUNILVR (Hindustan Unilever Limited): RSI = 65.57, Price = ₹2435.40
# DEVIT (Dev Information Technology Limited): RSI = 65.55, Price = ₹173.88
# SBILIFE (SBI Life Insurance Company Limited): RSI = 65.46, Price = ₹1468.45
# ASHAPURMIN (Ashapura Minechem Limited): RSI = 65.31, Price = ₹473.95
# RAMAPHO (Rama Phosphates Limited): RSI = 65.26, Price = ₹229.14
# SMSLIFE (SMS Lifesciences India Limited): RSI = 65.17, Price = ₹1240.60
# V2RETAIL (V2 Retail Limited): RSI = 65.12, Price = ₹1752.35
# FSL (Firstsource Solutions Limited): RSI = 65.06, Price = ₹395.00
# NACLIND (NACL Industries Limited): RSI = 65.06, Price = ₹66.49
# CHOLAHLDNG (Cholamandalam Financial Holdings Limited): RSI = 64.95, Price = ₹1580.05
# ANANTRAJ (Anant Raj Limited): RSI = 64.61, Price = ₹905.15
# ALPA (Alpa Laboratories Limited): RSI = 64.54, Price = ₹128.52
# GMRP&UI (GMR Power And Urban Infra Limited): RSI = 64.48, Price = ₹121.84
# EQUITASBNK (Equitas Small Finance Bank Limited): RSI = 64.45, Price = ₹69.05
# BRITANNIA (Britannia Industries Limited): RSI = 64.38, Price = ₹4926.30
# MAZDA (Mazda Limited): RSI = 64.34, Price = ₹1730.30
# SUPERSPIN (Super Spinning Mills Limited): RSI = 64.26, Price = ₹14.62
# UNIVCABLES (Universal Cables Limited): RSI = 64.17, Price = ₹833.25
# SAREGAMA (Saregama India Limited): RSI = 64.12, Price = ₹552.30
# TITAN (Titan Company Limited): RSI = 64.12, Price = ₹3487.05
# ASTRAZEN (AstraZeneca Pharma India Limited): RSI = 64.07, Price = ₹7089.00
# DRREDDY (Dr. Reddy's Laboratories Limited): RSI = 64.02, Price = ₹1371.60
# DEVYANI (Devyani International Limited): RSI = 64.01, Price = ₹187.14
# CANTABIL (Cantabil Retail India Limited): RSI = 63.60, Price = ₹307.75
# UPL (UPL Limited): RSI = 63.44, Price = ₹545.45
# GENESYS (Genesys International Corporation Limited): RSI = 63.44, Price = ₹1028.50
# AKUMS (N/A): RSI = 63.33, Price = ₹617.40
# SYNGENE (Syngene International Limited): RSI = 63.26, Price = ₹877.10
# JUSTDIAL (Just Dial Limited): RSI = 63.12, Price = ₹1075.20
# SAGILITY (N/A): RSI = 63.02, Price = ₹51.10
# VLEGOV (VL E-Governance & IT Solutions Limited): RSI = 62.91, Price = ₹177.32
# GUJRAFFIA (Gujarat Raffia Industries Limited): RSI = 62.90, Price = ₹90.04
# AWL (Adani Wilmar Limited): RSI = 62.85, Price = ₹323.45
# ATFL (Agro Tech Foods Limited): RSI = 62.84, Price = ₹945.30
# TECILCHEM (Tecil Chemicals and Hydro Power Ltd.): RSI = 62.73, Price = ₹25.59
# AARTECH (Aartech Solonics Limited): RSI = 62.65, Price = ₹90.59
# WELENT (Welspun Enterprises Limited): RSI = 62.50, Price = ₹638.75
# JYOTHYLAB (Jyothy Labs Limited): RSI = 62.49, Price = ₹408.10
# GLENMARK (Glenmark Pharmaceuticals Limited): RSI = 62.45, Price = ₹1593.30
# ALLDIGI (Alldigi Tech Limited): RSI = 62.39, Price = ₹1045.45
# JKCEMENT (J.K. Cement Limited): RSI = 62.38, Price = ₹4738.80
# CHOLAFIN (Cholamandalam Investment and Finance Company Limited): RSI = 62.17, Price = ₹1288.20
# VAKRANGEE (Vakrangee Limited): RSI = 62.17, Price = ₹36.46
# SUVIDHAA (Suvidhaa Infoserve Limited): RSI = 62.09, Price = ₹6.84
# ZEEMEDIA (Zee Media Corporation Limited): RSI = 62.06, Price = ₹21.01
# VARDMNPOLY (Vardhman Polytex Limited): RSI = 62.03, Price = ₹14.89
# E2E (E2E Networks Limited): RSI = 62.03, Price = ₹4301.80
# DABUR (Dabur India Limited): RSI = 61.85, Price = ₹521.15
# INDGN (N/A): RSI = 61.77, Price = ₹629.05
# MARICO (Marico Limited): RSI = 61.76, Price = ₹666.90
# VINCOFE (Vintage Coffee and Beverages Limited): RSI = 61.47, Price = ₹124.00
# INNOVACAP (Innova Captab Limited): RSI = 61.36, Price = ₹1120.35
# KINGFA (Kingfa Science & Technology (India) Limited): RSI = 61.31, Price = ₹3633.10
# ITI (ITI Limited): RSI = 61.30, Price = ₹440.40
# SHAILY (Shaily Engineering Plastics Limited): RSI = 61.28, Price = ₹1630.70
# SURAJLTD (Suraj Limited): RSI = 61.21, Price = ₹515.00
# ASTRON (Astron Paper & Board Mill Limited): RSI = 61.18, Price = ₹20.37
# IPCALAB (Ipca Laboratories Limited): RSI = 61.06, Price = ₹1661.95
# ALPHAGEO (Alphageo (India) Limited): RSI = 61.06, Price = ₹461.15
# FUSION (Fusion Finance Limited): RSI = 61.04, Price = ₹188.30
# SCHAEFFLER (Schaeffler India Limited): RSI = 61.03, Price = ₹3441.10
# FORTIS (Fortis Healthcare Limited): RSI = 60.99, Price = ₹713.25
# MANGCHEFER (Mangalore Chemicals & Fertilizers Limited): RSI = 60.83, Price = ₹171.40
# MANGLMCEM (Mangalam Cement Limited): RSI = 60.76, Price = ₹984.85
# IGL (Indraprastha Gas Limited): RSI = 60.67, Price = ₹419.50
# FLEXITUFF (Flexituff Ventures International Limited): RSI = 60.61, Price = ₹65.69
# SHRADHA (Shradha Infraprojects Limited): RSI = 60.59, Price = ₹90.78
# VISAKAIND (Visaka Industries Limited): RSI = 60.53, Price = ₹102.23
# TATAMOTORS (Tata Motors Limited): RSI = 60.51, Price = ₹780.10
# INDORAMA (Indo Rama Synthetics (India) Limited): RSI = 60.26, Price = ₹44.06
# AJOONI (Ajooni Biotech Limited): RSI = 60.00, Price = ₹7.92
# ASIANPAINT (Asian Paints Limited): RSI = 59.96, Price = ₹2350.20
# SBICARD (SBI Cards and Payment Services Limited): RSI = 59.94, Price = ₹730.70
# COLPAL (Colgate-Palmolive (India) Limited): RSI = 59.91, Price = ₹2890.60
# ESCORTS (Escorts Kubota Limited): RSI = 59.89, Price = ₹3389.60
# EMCURE (N/A): RSI = 59.63, Price = ₹1436.90
# MTEDUCARE (MT Educare Limited): RSI = 59.60, Price = ₹2.72
# ABBOTINDIA (Abbott India Limited): RSI = 59.54, Price = ₹29753.85
# KAUSHALYA (Kaushalya Infrastructure Development Corporation Limited): RSI = 59.45, Price = ₹1076.70
# MARATHON (Marathon Nextgen Realty Limited): RSI = 59.18, Price = ₹649.10
# ASALCBR (Associated Alcohols & Breweries Limited): RSI = 59.11, Price = ₹1178.95
# SIGNPOST (Signpost India Limited): RSI = 58.97, Price = ₹381.90
# MTARTECH (MTAR Technologies Limited): RSI = 58.94, Price = ₹1723.90
# ASHIANA (Ashiana Housing Limited): RSI = 58.88, Price = ₹378.20
# GLFL (Gujarat Lease Financing Limited): RSI = 58.88, Price = ₹7.88
# DCI (DC Infotech and Communication Limited): RSI = 58.86, Price = ₹367.35
# JSFB (Jana Small Finance Bank Limited): RSI = 58.74, Price = ₹402.70
# GUFICBIO (Gufic Biosciences Limited): RSI = 58.71, Price = ₹460.65
# DNAMEDIA (Diligent Media Corporation Limited): RSI = 58.63, Price = ₹6.36
# BATAINDIA (Bata India Limited): RSI = 58.58, Price = ₹1412.90
# AUBANK (AU Small Finance Bank Limited): RSI = 58.54, Price = ₹570.05
# ZENTEC (Zen Technologies Limited): RSI = 58.53, Price = ₹2539.05
# BHAGERIA (Bhageria Industries Limited): RSI = 58.50, Price = ₹205.49
# BIOCON (Biocon Limited): RSI = 58.46, Price = ₹370.70
# THOMASCOTT (Thomas Scott (India) Limited): RSI = 58.46, Price = ₹460.70
# GLAND (Gland Pharma Limited): RSI = 58.44, Price = ₹1829.95
# PRUDMOULI (Prudential Sugar Corporation Ltd.): RSI = 58.34, Price = ₹67.57
# APARINDS (APAR Industries Limited): RSI = 58.29, Price = ₹10514.40
# GANESHHOUC (Ganesh Housing Corporation Limited): RSI = 58.00, Price = ₹1319.35
# ARKADE (N/A): RSI = 57.97, Price = ₹174.13
# GUJAPOLLO (Gujarat Apollo Industries Limited): RSI = 57.95, Price = ₹355.35
# REPL (Rudrabhishek Enterprises Limited): RSI = 57.91, Price = ₹308.25
# AIIL (Authum Investment & Infrastructure Limited): RSI = 57.86, Price = ₹1850.85
# AMNPLST (Amines & Plasticizers Limited): RSI = 57.84, Price = ₹303.25
# DHANI (Dhani Services Limited): RSI = 57.79, Price = ₹95.57
# HONAUT (Honeywell Automation India Limited): RSI = 57.77, Price = ₹42151.70
# GOLDIAM (Goldiam International Limited): RSI = 57.73, Price = ₹471.15
# SOUTHBANK (The South Indian Bank Limited): RSI = 57.68, Price = ₹25.95
# HISARMETAL (Hisar Metal Industries Limited): RSI = 57.59, Price = ₹208.05
# SILVERTUC (Silver Touch Technologies Limited): RSI = 57.54, Price = ₹693.00
# GALAPREC (N/A): RSI = 57.48, Price = ₹1226.40
# ARVINDFASN (Arvind Fashions Limited): RSI = 57.41, Price = ₹526.75
# GTPL (GTPL Hathway Limited): RSI = 57.40, Price = ₹146.52
# KIOCL (KIOCL Limited): RSI = 57.39, Price = ₹400.10
# GREAVESCOT (Greaves Cotton Limited): RSI = 57.38, Price = ₹264.35
# AKZOINDIA (Akzo Nobel India Limited): RSI = 57.36, Price = ₹3734.50
# UJJIVANSFB (Ujjivan Small Finance Bank Limited): RSI = 57.25, Price = ₹35.49
# MONARCH (Monarch Networth Capital Limited): RSI = 57.08, Price = ₹446.80
# CREATIVE (Creative Newtech Limited): RSI = 57.06, Price = ₹979.45
# TVTODAY (T.V. Today Network Limited): RSI = 57.02, Price = ₹213.38
# SHANTI (Shanti Overseas (India) Limited): RSI = 56.95, Price = ₹17.31
# ITDC (India Tourism Development Corporation Limited): RSI = 56.89, Price = ₹666.45
# CAMLINFINE (Camlin Fine Sciences Limited): RSI = 56.78, Price = ₹132.57
# GOKUL (Gokul Refoils & Solvent Limited): RSI = 56.67, Price = ₹62.77
# TBOTEK (N/A): RSI = 56.66, Price = ₹1742.90
# GANGAFORGE (Ganga Forging Limited): RSI = 56.64, Price = ₹7.02
# JINDWORLD (Jindal Worldwide Limited): RSI = 56.55, Price = ₹436.25
# KOTHARIPRO (Kothari Products Limited): RSI = 56.55, Price = ₹182.27
# GHCL (GHCL Limited): RSI = 56.50, Price = ₹707.65
# MUKTAARTS (Mukta Arts Limited): RSI = 56.37, Price = ₹92.74
# TAJGVK (TAJGVK Hotels & Resorts Limited): RSI = 56.24, Price = ₹404.25
# RELIANCE (Reliance Industries Limited): RSI = 56.21, Price = ₹1254.75
# UNOMINDA (Uno Minda Limited): RSI = 56.18, Price = ₹1066.30
# SPENCERS (Spencer's Retail Limited): RSI = 56.10, Price = ₹87.72
# PVP (PVP Ventures Limited): RSI = 56.05, Price = ₹31.08
# ZEELEARN (Zee Learn Limited): RSI = 56.03, Price = ₹8.81
# KAVVERITEL (Kavveri Defence & Wireless Technologies Limited): RSI = 56.00, Price = ₹58.38
# ZYDUSLIFE (Zydus Lifesciences Limited): RSI = 55.95, Price = ₹1010.50
# CARTRADE (CarTrade Tech Limited): RSI = 55.84, Price = ₹1619.95
# KOTAKBANK (Kotak Mahindra Bank Limited): RSI = 55.77, Price = ₹1790.20
# BAFNAPH (Bafna Pharmaceuticals Limited): RSI = 55.75, Price = ₹82.50
# ...
# 538942 (Mercantile Ventures Limited): RSI = 47.48, Price = ₹23.33
# 511609 (ISL Consulting Limited): RSI = 47.39, Price = ₹25.02
# 533275 (Gyscoal Alloys Limited): RSI = 47.37, Price = ₹4.15
# 532654 (McLeod Russel India Limited): RSI = 47.31, Price = ₹47.18
# 504132 (N/A): RSI = 47.30, Price = ₹963.65
# 532286 (Jindal Steel & Power Limited): RSI = 47.25, Price = ₹942.75
# 533608 (RDB Rasayans Limited): RSI = 47.24, Price = ₹162.35
# 505537 (Zee Entertainment Enterprises Limited): RSI = 47.22, Price = ₹133.75
# 532993 (Sejal Glass Limited): RSI = 47.17, Price = ₹590.05
# 539251 (Balkrishna Paper Mills Limited): RSI = 47.13, Price = ₹24.96
# 570004 (Jain Irrigation Systems Limited): RSI = 47.07, Price = ₹37.50
# 511110 (N/A): RSI = 47.00, Price = ₹31.43
# 541578 (Varroc Engineering Limited): RSI = 46.99, Price = ₹604.15
# 504067 (Zensar Technologies Limited): RSI = 46.97, Price = ₹789.10
# 531847 (Asian Star Company Limited): RSI = 46.94, Price = ₹796.15
# 533047 (Indian Metals and Ferro Alloys Limited): RSI = 46.92, Price = ₹906.80
# 533271 (Ashoka Buildcon Limited): RSI = 46.91, Price = ₹291.40
# 539524 (Dr. Lal PathLabs Limited): RSI = 46.89, Price = ₹2991.60
# 538476 (Capital Trade Links Limited): RSI = 46.88, Price = ₹47.49
# 512068 (N/A): RSI = 46.86, Price = ₹109.95
# 523457 (Linde India Limited): RSI = 46.86, Price = ₹6515.85
# 500266 (Maharashtra Scooters Ltd.): RSI = 46.83, Price = ₹9605.80
# 523367 (DCM Shriram Limited): RSI = 46.78, Price = ₹1059.30
# 500089 (DIC India Limited): RSI = 46.75, Price = ₹693.65
# 500279 (MIRC Electronics Limited): RSI = 46.70, Price = ₹23.56
# 522101 (N/A): RSI = 46.68, Price = ₹475.50
# 540725 (Share India Securities Limited): RSI = 46.67, Price = ₹302.10
# 512149 (N/A): RSI = 46.67, Price = ₹0.84
# 533137 (DEN Networks Limited): RSI = 46.66, Price = ₹43.56
# 538706 (Ultracab (India) Limited): RSI = 46.60, Price = ₹17.45
# 534598 (S. E. Power Limited): RSI = 46.58, Price = ₹37.92
# 532324 (Cinevista Limited): RSI = 46.58, Price = ₹19.23
# 502355 (Balkrishna Industries Limited): RSI = 46.48, Price = ₹2773.85
# 533273 (Oberoi Realty Limited): RSI = 46.47, Price = ₹2285.85
# 502587 (N/A): RSI = 46.40, Price = ₹70.11
# 539437 (IDFC First Bank Limited): RSI = 46.39, Price = ₹62.65
# 540175 (Regency Fincorp Limited): RSI = 46.35, Price = ₹39.80
# 532430 (BF Utilities Limited): RSI = 46.30, Price = ₹959.50
# 511411 (N/A): RSI = 46.28, Price = ₹44.00
# 538890 (M.K. Exim (India) Limited): RSI = 46.26, Price = ₹86.29
# 538812 (Aanchal Ispat Limited): RSI = 46.25, Price = ₹5.19
# 532933 (N/A): RSI = 46.24, Price = ₹57.72
# 539354 (Polyspin Exports Limited): RSI = 46.22, Price = ₹41.00
# 507410 (Walchandnagar Industries Limited): RSI = 46.22, Price = ₹270.15
# 533761 (GPT Infraprojects Limited): RSI = 46.22, Price = ₹142.20
# 500068 (N/A): RSI = 46.20, Price = ₹16330.00
# 535601 (Sreeleathers Limited): RSI = 46.14, Price = ₹254.05
# 536264 (Tiger Logistics (India) Limited): RSI = 46.13, Price = ₹70.20
# 506122 (Kairosoft AI Solutions Limited): RSI = 46.07, Price = ₹165.80
# 533203 (Tarapur Transformers Limited): RSI = 46.07, Price = ₹46.32
# 539400 (Mallcom (India) Limited): RSI = 45.89, Price = ₹1488.65
# 522004 (N/A): RSI = 45.81, Price = ₹130.15
# 532355 (Picturehouse Media Limited): RSI = 45.78, Price = ₹9.20
# 511359 (N/A): RSI = 45.78, Price = ₹91.83
# 500367 (N/A): RSI = 45.72, Price = ₹79.92
# 532616 (Xchanging Solutions Limited): RSI = 45.70, Price = ₹112.85
# 590025 (Ginni Filaments Limited): RSI = 45.70, Price = ₹31.29
# 537253 (Sunil Healthcare Limited): RSI = 45.67, Price = ₹80.00
# 506365 (N/A): RSI = 45.64, Price = ₹98.15
# 532373 (WeP Solutions Limited): RSI = 45.64, Price = ₹34.10
# 534708 (Shanti Guru Industries Limited): RSI = 45.64, Price = ₹12.38
# 540173 (PNB Housing Finance Limited): RSI = 45.63, Price = ₹873.75
# 531867 (N/A): RSI = 45.61, Price = ₹5.14
# 531672 (N/A): RSI = 45.60, Price = ₹29.00
# 505250 (N/A): RSI = 45.58, Price = ₹117.85
# 523248 (N/A): RSI = 45.37, Price = ₹241.00
# 539255 (Star Delta Transformers Limited): RSI = 45.37, Price = ₹953.20
# 539399 (Bella Casa Fashion & Retail Limited): RSI = 45.29, Price = ₹578.45
# 500168 (Goodyear India Limited): RSI = 45.28, Price = ₹1019.30
# 533407 (True Green Bio Energy Limited): RSI = 45.27, Price = ₹113.35
# 590109 (Nippon India ETF Nifty 50 Shariah BeES): RSI = 45.25, Price = ₹536.92
# 540405 (Oceanic Foods Limited): RSI = 45.25, Price = ₹50.00
# 532320 (Vaarad Ventures Limited): RSI = 45.24, Price = ₹12.60
# 501833 (Chowgule Steamships Limited): RSI = 45.09, Price = ₹27.88
# 500165 (Kansai Nerolac Paints Limited): RSI = 45.08, Price = ₹257.50
# 541702 (N/A): RSI = 44.92, Price = ₹4.40
# 500420 (Torrent Pharmaceuticals Limited): RSI = 44.85, Price = ₹3325.25
# 533152 (MBL Infrastructures Limited): RSI = 44.80, Price = ₹63.54
# 508989 (Navneet Education Limited): RSI = 44.77, Price = ₹139.50
# 509760 (N/A): RSI = 44.75, Price = ₹58.41
# 540575 (Star Cement Limited): RSI = 44.74, Price = ₹218.50
# 534532 (Lypsa Gems & Jewellery Limited): RSI = 44.74, Price = ₹7.28
# 538979 (Greenlam Industries Limited): RSI = 44.73, Price = ₹562.40
# 532183 (N/A): RSI = 44.70, Price = ₹14.67
# 504351 (Empower India Limited): RSI = 44.68, Price = ₹2.05
# 537069 (Arnold Holdings Ltd.): RSI = 44.64, Price = ₹43.11
# 538365 (Incredible Industries Limited): RSI = 44.61, Price = ₹46.00
# 539658 (TeamLease Services Limited): RSI = 44.58, Price = ₹2837.50
# 539336 (Gujarat Gas Limited): RSI = 44.56, Price = ₹500.50
# 535754 (Orient Cement Limited): RSI = 44.53, Price = ₹338.00
# 534615 (North Eastern Carrying Corporation Limited): RSI = 44.52, Price = ₹34.45
# 540065 (RBL Bank Limited): RSI = 44.49, Price = ₹161.85
# 507981 (N/A): RSI = 44.47, Price = ₹98.05
# 534741 (Virtual Global Education Limited): RSI = 44.44, Price = ₹0.76
# 539518 (Uday Jewellery Industries Limited): RSI = 44.41, Price = ₹150.10
# 532402 (USG Tech Solutions Limited): RSI = 44.40, Price = ₹17.29
# 539479 (GTV Engineering Limited): RSI = 44.38, Price = ₹525.80
# 533581 (PG Electroplast Limited): RSI = 44.38, Price = ₹950.65
# 539448 (InterGlobe Aviation Limited): RSI = 44.35, Price = ₹4259.10
# 535205 (Mystic Electronics Limited): RSI = 44.30, Price = ₹7.18
# 540702 (Lasa Supergenerics Limited): RSI = 44.28, Price = ₹27.10
# 534338 (Max Heights Infrastructure Limited): RSI = 44.22, Price = ₹28.25
# 532806 (AI Champdany Industries Limited): RSI = 44.21, Price = ₹56.49
# 539040 (Tirupati Tyres Limited): RSI = 44.17, Price = ₹13.07
# 503100 (The Phoenix Mills Limited): RSI = 44.15, Price = ₹1696.55
# 504058 (Indo National Limited): RSI = 44.10, Price = ₹554.40
# 500660 (GlaxoSmithKline Pharmaceuticals Limited): RSI = 44.03, Price = ₹2207.85
# 532896 (Magnum Ventures Limited): RSI = 43.98, Price = ₹39.04
# 532070 (N/A): RSI = 43.97, Price = ₹200.45
# 539404 (Satin Creditcare Network Limited): RSI = 43.96, Price = ₹155.55
# 540710 (Capacit'e Infraprojects Limited): RSI = 43.94, Price = ₹420.90
# 531508 (Eveready Industries India Limited): RSI = 43.94, Price = ₹388.30
# 500159 (MetroGlobal Limited): RSI = 43.93, Price = ₹155.00
# 511493 (N/A): RSI = 43.93, Price = ₹12.15
# 508969 (Sulabh Engineers & Services Limited): RSI = 43.90, Price = ₹4.94
# 500327 (Pil Italica Lifestyle Limited): RSI = 43.89, Price = ₹13.70
# 523007 (N/A): RSI = 43.86, Price = ₹156.75
# 539176 (Hawa Engineers Limited): RSI = 43.82, Price = ₹229.60
# 502090 (Sagar Cements Limited): RSI = 43.82, Price = ₹220.10
# 500870 (Castrol India Limited): RSI = 43.77, Price = ₹200.85
# 540526 (IRB InvIT Fund): RSI = 43.75, Price = ₹60.09
# 540006 (East West Freight Carriers Limited): RSI = 43.70, Price = ₹7.18
# 539607 (Blue Cloud Softech Solutions Limited): RSI = 43.66, Price = ₹102.60
# 540796 (N/A): RSI = 43.65, Price = ₹127.75
# 532268 (Accelya Solutions India Limited): RSI = 43.64, Price = ₹1541.95
# 511218 (Shriram Finance Limited): RSI = 43.64, Price = ₹2898.15
# 540210 (Heads UP Ventures Limited): RSI = 43.64, Price = ₹11.46
# 532879 (N/A): RSI = 43.62, Price = ₹286.20
# 540647 (Ganges Securities Limited): RSI = 43.48, Price = ₹194.55
# 503624 (N/A): RSI = 43.45, Price = ₹10.12
# 500650 (Excel Industries Limited): RSI = 43.42, Price = ₹1291.40
# 532005 (Sam Industries Ltd.): RSI = 43.39, Price = ₹64.00
# 538795 (Shree Ajit Pulp and Paper Limited): RSI = 43.38, Price = ₹208.65
# 512175 (N/A): RSI = 43.35, Price = ₹8.39
# 505729 (N/A): RSI = 43.33, Price = ₹77.77
# 523648 (Plastiblends India Limited): RSI = 43.28, Price = ₹246.85
# 533023 (ZF Commercial Vehicle Control Systems India Limited): RSI = 43.24, Price = ₹11469.60
# 531861 (N/A): RSI = 43.20, Price = ₹53.06
# 532531 (Strides Pharma Science Limited): RSI = 43.18, Price = ₹668.85
# 507598 (Kovilpatti Lakshmi Roller Flour Mills Limited): RSI = 43.18, Price = ₹132.00
# 533088 (Mahindra Holidays & Resorts India Limited): RSI = 43.17, Price = ₹369.65
# 511147 (N/A): RSI = 43.08, Price = ₹100.75
# 500250 (L.G. Balakrishnan & Bros Limited): RSI = 43.01, Price = ₹1295.30
# 507759 (N/A): RSI = 42.98, Price = ₹23.99
# 533193 (Kirloskar Electric Company Limited): RSI = 42.92, Price = ₹185.80
# 533168 (Rossell India Limited): RSI = 42.90, Price = ₹76.87
# 533289 (Kesar Terminals & Infrastructure Limited): RSI = 42.88, Price = ₹75.10
# 533096 (Adani Power Limited): RSI = 42.88, Price = ₹504.40
# 511012 (N/A): RSI = 42.86, Price = ₹1.48
# 532466 (Oracle Financial Services Software Limited): RSI = 42.84, Price = ₹11983.90
# 540757 (Sheetal Cool Products Limited): RSI = 42.76, Price = ₹329.85
# 539126 (MEP Infrastructure Developers Limited): RSI = 42.73, Price = ₹3.05
# 533260 (Career Point Limited): RSI = 42.67, Price = ₹389.85
# 539984 (Hindusthan Urban Infrastructure Limited): RSI = 42.64, Price = ₹2480.00
# 500170 (N/A): RSI = 42.63, Price = ₹36.19
# 532407 (N/A): RSI = 42.60, Price = ₹213.50
# 532764 (GeeCee Ventures Limited): RSI = 42.58, Price = ₹432.00
# 501848 (Global Offshore Services Limited): RSI = 42.54, Price = ₹114.75
# 538713 (Atishay Limited): RSI = 42.53, Price = ₹222.35
# 540743 (Godrej Agrovet Limited): RSI = 42.53, Price = ₹739.65
# 535267 (Comfort Fincap Limited): RSI = 42.47, Price = ₹9.99
# 538081 (Haria Apparels Limited): RSI = 42.44, Price = ₹5.34
# 534639 (Vinayak Polycon International Limited): RSI = 42.44, Price = ₹36.25
# 590024 (The Fertilisers And Chemicals Travancore Limited): RSI = 42.44, Price = ₹963.40
# 506906 (N/A): RSI = 42.38, Price = ₹3.81
# 531859 (N/A): RSI = 42.37, Price = ₹314.45
# 500285 (N/A): RSI = 42.36, Price = ₹53.33
# 500319 (N/A): RSI = 42.17, Price = ₹114.65
# 539228 (Gala Global Products Limited): RSI = 42.17, Price = ₹3.21
# 523550 (N/A): RSI = 42.16, Price = ₹78.21
# 538635 (Snowman Logistics Limited): RSI = 42.14, Price = ₹69.01
# 540692 (Apex Frozen Foods Limited): RSI = 42.12, Price = ₹251.95
# 532398 (Usha Martin Education & Solutions Limited): RSI = 42.08, Price = ₹6.86
# 523465 (N/A): RSI = 42.08, Price = ₹49.90
# 540777 (HDFC Life Insurance Company Limited): RSI = 42.06, Price = ₹617.55
# 540133 (ICICI Prudential Life Insurance Company Limited): RSI = 42.05, Price = ₹652.50
# 506003 (N/A): RSI = 42.05, Price = ₹57.40
# 532776 (Shivam Autotech Limited): RSI = 41.99, Price = ₹44.28
# 506605 (N/A): RSI = 41.99, Price = ₹2585.00
# 540393 (Sarthak Metals Limited): RSI = 41.97, Price = ₹159.60
# 533202 (Satchmo Holdings Limited): RSI = 41.96, Price = ₹3.93
# 540749 (MAS Financial Services Limited): RSI = 41.96, Price = ₹261.60
# 500317 (Oswal Agro Mills Limited): RSI = 41.93, Price = ₹70.07
# 522207 (N/A): RSI = 41.91, Price = ₹117.70
# 522183 (N/A): RSI = 41.87, Price = ₹446.60
# 505232 (Veljan Denison Limited): RSI = 41.87, Price = ₹1214.40
# 537707 (ETT Limited): RSI = 41.86, Price = ₹16.64
# 532807 (Cineline India Limited): RSI = 41.84, Price = ₹129.60
# 590134 (Madras Fertilizers Limited): RSI = 41.83, Price = ₹98.95
# 523606 (N/A): RSI = 41.82, Price = ₹2516.45
# 500104 (Hindustan Petroleum Corporation Limited): RSI = 41.78, Price = ₹391.10
# 540716 (ICICI Lombard General Insurance Company Limited): RSI = 41.78, Price = ₹1859.55
# 540729 (Vanta Bioscience Limited): RSI = 41.74, Price = ₹40.99
# 531822 (Rodium Realty Limited): RSI = 41.71, Price = ₹150.15
# 511131 (N/A): RSI = 41.69, Price = ₹16.79
# 506852 (N/A): RSI = 41.67, Price = ₹37.37
# 504028 (N/A): RSI = 41.64, Price = ₹139.95
# 500179 (HCL Infosystems Limited): RSI = 41.60, Price = ₹15.81
# 504093 (Panasonic Energy India Co. Ltd.): RSI = 41.58, Price = ₹451.95
# 512018 (Tomorrow Technologies Global Innovations Limited): RSI = 41.58, Price = ₹15.33
# 531688 (Prithvi Exchange (India) Limited): RSI = 41.57, Price = ₹235.80
# 540565 (India Grid Trust): RSI = 41.56, Price = ₹143.70
# 540361 (Danube Industries Limited): RSI = 41.54, Price = ₹4.68
# 540124 (G N A Axles Limited): RSI = 41.54, Price = ₹409.35
# 505681 (N/A): RSI = 41.53, Price = ₹637.30
# 533164 (Texmo Pipes and Products Limited): RSI = 41.48, Price = ₹66.09
# 538567 (Gulf Oil Lubricants India Limited): RSI = 41.47, Price = ₹1137.00
# 500014 (N/A): RSI = 41.46, Price = ₹7.18
# 538987 (Talbros Engineering Limited): RSI = 41.43, Price = ₹615.90
# 533270 (Bedmutha Industries Limited): RSI = 41.38, Price = ₹200.00
# 506685 (N/A): RSI = 41.37, Price = ₹532.35
# 540268 (TruCap Finance Limited): RSI = 41.33, Price = ₹15.26
# 533014 (N/A): RSI = 41.33, Price = ₹82.64
# 533482 (Kridhan Infra Limited): RSI = 41.32, Price = ₹6.13
# 509423 (Sanathnagar Enterprises Limited): RSI = 41.31, Price = ₹39.79
# 541503 (Unick Fix-A-Form and Printers Limited): RSI = 41.30, Price = ₹81.90
# 532977 (Bajaj Auto Limited): RSI = 41.29, Price = ₹8642.25
# 500335 (Birla Corporation Limited): RSI = 41.28, Price = ₹1221.95
# 533286 (MOIL Limited): RSI = 41.27, Price = ₹338.25
# 532842 (Sree Rayalaseema Hi-Strength Hypo Limited): RSI = 41.25, Price = ₹777.65
# 500414 (N/A): RSI = 41.14, Price = ₹202.20
# 531595 (Capri Global Capital Limited): RSI = 41.14, Price = ₹189.30
# 506618 (Punjab Chemicals and Crop Protection Limited): RSI = 41.13, Price = ₹994.00
# 502450 (Seshasayee Paper and Boards Limited): RSI = 41.08, Price = ₹304.05
# 539227 (Loyal Equipments Limited): RSI = 41.05, Price = ₹272.00
# 532209 (The Jammu and Kashmir Bank Limited): RSI = 40.99, Price = ₹96.75
# 533758 (APL Apollo Tubes Limited): RSI = 40.93, Price = ₹1538.80
# 533452 (Delphi World Money Limited): RSI = 40.89, Price = ₹203.05
# 531814 (N/A): RSI = 40.83, Price = ₹17.93
# 500304 (NIIT Limited): RSI = 40.82, Price = ₹187.20
# 502445 (Citadel Realty and Developers Limited): RSI = 40.81, Price = ₹69.35
# 541703 (Raconteur Global Resources Limited): RSI = 40.68, Price = ₹13.28
# 532173 (CyberTech Systems and Software Limited): RSI = 40.66, Price = ₹216.45
# 506532 (N/A): RSI = 40.64, Price = ₹767.95
# 539963 (Zeal Aqua Limited): RSI = 40.58, Price = ₹12.41
# 521240 (Sambandam Spinning Mills Limited): RSI = 40.55, Price = ₹157.40
# 532613 (VIP Clothing Limited): RSI = 40.54, Price = ₹44.34
# 512048 (Luharuka Media & Infra Limited): RSI = 40.52, Price = ₹4.73
# 523537 (N/A): RSI = 40.50, Price = ₹51.36
# 512131 (Signet Industries Limited): RSI = 40.47, Price = ₹68.85
# 522134 (N/A): RSI = 40.45, Price = ₹179.05
# 500209 (Infosys Limited): RSI = 40.44, Price = ₹1933.15
# 541006 (N/A): RSI = 40.42, Price = ₹20.00
# 537292 (Agri-tech (India) Limited): RSI = 40.42, Price = ₹196.95
# 535458 (NRB Industrial Bearings Limited): RSI = 40.41, Price = ₹23.96
# 502180 (Shree Digvijay Cement Company Ltd.): RSI = 40.39, Price = ₹84.84
# 538634 (Vasundhara Rasayans Limited): RSI = 40.32, Price = ₹280.35
# 523660 (The Waterbase Limited): RSI = 40.32, Price = ₹71.95
# 540769 (The New India Assurance Company Limited): RSI = 40.24, Price = ₹194.60
# 511413 (Crest Ventures Limited): RSI = 40.22, Price = ₹434.85
# 533477 (Enkei Wheels (India) Limited): RSI = 40.19, Price = ₹647.95
# 535566 (KIFS Financial Services Limited): RSI = 40.16, Price = ₹152.80
# 539254 (Adani Transmission Limited): RSI = 40.15, Price = ₹770.25
# 522275 (GE T&D India Limited): RSI = 40.15, Price = ₹1991.50
# 505750 (N/A): RSI = 40.12, Price = ₹581.65
# 504879 (Orient Abrasives Limited): RSI = 40.10, Price = ₹48.73
# 511543 (N/A): RSI = 40.10, Price = ₹43.19
# 590062 (The Andhra Sugars Limited): RSI = 40.06, Price = ₹93.87
# 500444 (West Coast Paper Mills Limited): RSI = 40.00, Price = ₹552.20
# 531518 (N/A): RSI = 40.00, Price = ₹0.49
#
# Daily analysis complete. Results saved in stock_analysis\daily_results

# %%
import yfinance as yf

symbol = 'AARTECH.NS'
period = '1mo'

# Fetch the historical data
ticker = yf.Ticker(symbol)
hist_data = ticker.history(period=period)

# Display the historical data
print(hist_data)
# Out:
#                                  Open        High        Low       Close  \
# Date
# 2024-12-10 00:00:00+05:30   82.400002   83.000000  78.019997   79.120003
# 2024-12-11 00:00:00+05:30   80.699997   80.699997  76.940002   77.129997
# 2024-12-12 00:00:00+05:30   78.389999   78.949997  77.000000   77.699997
# 2024-12-13 00:00:00+05:30   77.989998   80.099998  75.500000   79.559998
# 2024-12-16 00:00:00+05:30   80.900002   81.080002  77.070000   77.500000
# 2024-12-17 00:00:00+05:30   77.919998   78.169998  76.000000   77.699997
# 2024-12-18 00:00:00+05:30   77.669998   77.669998  74.199997   75.169998
# 2024-12-19 00:00:00+05:30   74.239998   78.919998  73.110001   78.900002
# 2024-12-20 00:00:00+05:30   79.010002   82.839996  79.010002   82.519997
# 2024-12-23 00:00:00+05:30   85.779999   86.379997  79.500000   80.339996
# 2024-12-24 00:00:00+05:30   80.000000   82.000000  80.000000   80.250000
# 2024-12-26 00:00:00+05:30   81.599998   81.599998  78.199997   78.620003
# 2024-12-27 00:00:00+05:30   79.000000   82.550003  76.599998   82.260002
# 2024-12-30 00:00:00+05:30   82.570000   83.389999  79.050003   80.150002
# 2024-12-31 00:00:00+05:30   79.510002   80.000000  77.910004   78.699997
# 2025-01-01 00:00:00+05:30   79.989998   82.629997  79.250000   82.629997
# 2025-01-02 00:00:00+05:30   84.500000   86.760002  83.500000   86.720001
# 2025-01-03 00:00:00+05:30   87.500000   91.050003  87.500000   91.050003
# 2025-01-06 00:00:00+05:30   93.949997   95.599998  88.349998   95.599998
# 2025-01-07 00:00:00+05:30  100.379997  100.379997  97.519997  100.379997
# 2025-01-08 00:00:00+05:30  100.379997  105.389999  95.360001   95.360001
# 2025-01-09 00:00:00+05:30   90.589996   90.589996  90.589996   90.589996
# 2025-01-10 00:00:00+05:30   86.059998   86.059998  86.059998   86.059998
#
#                             Volume  Dividends  Stock Splits
# Date
# 2024-12-10 00:00:00+05:30   163927        0.0           0.0
# 2024-12-11 00:00:00+05:30    76297        0.0           0.0
# 2024-12-12 00:00:00+05:30    52219        0.0           0.0
# 2024-12-13 00:00:00+05:30   142685        0.0           0.0
# 2024-12-16 00:00:00+05:30   173379        0.0           0.0
# 2024-12-17 00:00:00+05:30    55023        0.0           0.0
# 2024-12-18 00:00:00+05:30    51335        0.0           0.0
# 2024-12-19 00:00:00+05:30   241832        0.0           0.0
# 2024-12-20 00:00:00+05:30   964181        0.0           0.0
# 2024-12-23 00:00:00+05:30   191413        0.0           0.0
# 2024-12-24 00:00:00+05:30    70683        0.0           0.0
# 2024-12-26 00:00:00+05:30    35956        0.0           0.0
# 2024-12-27 00:00:00+05:30   211530        0.0           0.0
# 2024-12-30 00:00:00+05:30    88574        0.0           0.0
# 2024-12-31 00:00:00+05:30    32958        0.0           0.0
# 2025-01-01 00:00:00+05:30   168726        0.0           0.0
# 2025-01-02 00:00:00+05:30   693947        0.0           0.0
# 2025-01-03 00:00:00+05:30   386751        0.0           0.0
# 2025-01-06 00:00:00+05:30  1160985        0.0           0.0
# 2025-01-07 00:00:00+05:30   560173        0.0           0.0
# 2025-01-08 00:00:00+05:30  3042299        0.0           0.0
# 2025-01-09 00:00:00+05:30   182869        0.0           0.0
# 2025-01-10 00:00:00+05:30    29750        0.0           0.0

# %%
from datetime import datetime 

start_date = datetime(2023, 12, 10)
end_date = datetime(2024, 1, 10)

hist_data = ticker.history(
    start=start_date,
    end=end_date,
    interval="1d"
)

print(hist_data)
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2023-12-11 00:00:00+05:30  49.000000  49.000000  47.400002  48.166664   15462
# 2023-12-12 00:00:00+05:30  48.833332  48.833332  47.333332  47.549999   13290
# 2023-12-13 00:00:00+05:30  48.333332  49.400002  47.333332  48.549999   20982
# 2023-12-14 00:00:00+05:30  48.333332  48.666664  47.666664  48.200001   12666
# 2023-12-15 00:00:00+05:30  48.166664  48.333332  46.666664  47.433334   18066
# 2023-12-18 00:00:00+05:30  48.966667  49.599998  46.000000  47.200001  274809
# 2023-12-19 00:00:00+05:30  47.366665  47.950001  44.849998  45.666664   52569
# 2023-12-20 00:00:00+05:30  45.333332  46.983334  43.500000  43.900002  112848
# 2023-12-21 00:00:00+05:30  44.016666  44.299999  42.416664  43.400002   97257
# 2023-12-22 00:00:00+05:30  43.616665  44.650002  43.616665  44.466667  275493
# 2023-12-26 00:00:00+05:30  43.833332  46.683334  43.833332  46.500000   73197
# 2023-12-27 00:00:00+05:30  46.683334  48.616665  46.683334  47.633331   45504
# 2023-12-28 00:00:00+05:30  49.599998  49.599998  46.099998  46.483334   81210
# 2023-12-29 00:00:00+05:30  46.333332  47.216667  44.666664  44.900002   67515
# 2024-01-01 00:00:00+05:30  45.333332  47.133331  45.000000  47.133331   39900
# 2024-01-02 00:00:00+05:30  48.983334  49.333332  47.183334  48.033333  172716
# 2024-01-03 00:00:00+05:30  49.900002  49.900002  48.049999  49.299999   92997
# 2024-01-04 00:00:00+05:30  51.200001  51.200001  47.733334  49.299999  151704
# 2024-01-05 00:00:00+05:30  51.333332  51.333332  48.400002  49.033333  121836
# 2024-01-08 00:00:00+05:30  48.400002  50.483334  48.083332  49.599998  133896
# 2024-01-09 00:00:00+05:30  48.383331  49.866665  48.383331  48.983334   91935
#
#                            Dividends  Stock Splits
# Date
# 2023-12-11 00:00:00+05:30        0.0           0.0
# 2023-12-12 00:00:00+05:30        0.0           0.0
# 2023-12-13 00:00:00+05:30        0.0           0.0
# 2023-12-14 00:00:00+05:30        0.0           0.0
# 2023-12-15 00:00:00+05:30        0.0           0.0
# 2023-12-18 00:00:00+05:30        0.0           0.0
# 2023-12-19 00:00:00+05:30        0.0           0.0
# 2023-12-20 00:00:00+05:30        0.0           0.0
# 2023-12-21 00:00:00+05:30        0.0           0.0
# 2023-12-22 00:00:00+05:30        0.0           0.0
# 2023-12-26 00:00:00+05:30        0.0           0.0
# 2023-12-27 00:00:00+05:30        0.0           0.0
# 2023-12-28 00:00:00+05:30        0.0           0.0
# 2023-12-29 00:00:00+05:30        0.0           0.0
# 2024-01-01 00:00:00+05:30        0.0           0.0
# 2024-01-02 00:00:00+05:30        0.0           0.0
# 2024-01-03 00:00:00+05:30        0.0           0.0
# 2024-01-04 00:00:00+05:30        0.0           0.0
# 2024-01-05 00:00:00+05:30        0.0           0.0
# 2024-01-08 00:00:00+05:30        0.0           0.0
# 2024-01-09 00:00:00+05:30        0.0           0.0
